# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from math import sqrt
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style") 
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
from main.draw_tools.stacking_with_error_bars import MC_stack_plot, MC_stack_plot_density

from main.data_tools.error_bars import make_data_weight
from main.data_tools.query_dataframes import cut_dfs_7types

from matplotlib.ticker import ScalarFormatter
# Out:
# Welcome to JupyROOT 6.26/04

# %%
from math import sqrt

# Error-weighted combination function
def combine_error_weighted(x, y, x_err, y_err):
    central_value = (x / x_err**2 + y / y_err**2) / (1 / x_err**2 + 1 / y_err**2)
    error = 1 / sqrt(1 / x_err**2 + 1 / y_err**2)
    return central_value, error

# %%
def combine_x_plus_y_divided_by_2(x, y, x_err, y_err):
    central_value = (x+y)/2
    error = sqrt(x_err**2 +  y_err**2)/2
    return central_value, error

# %%
def correct_Acp_stats( Araw, Araw_err, Aref, Aref_err, Aref_pdg, Aref_K_mix):
    final_Acp = Araw - Aref + Aref_pdg + Aref_K_mix
    final_Acp_err = sqrt(Araw_err**2 + Aref_err**2)

    return final_Acp, final_Acp_err

# %%
def correct_Acp_stats_no_Kmix( Araw, Araw_err, Aref, Aref_err, Aref_pdg):
    final_Acp = Araw - Aref + Aref_pdg 
    final_Acp_err = sqrt(Araw_err**2 + Aref_err**2)

    return final_Acp, final_Acp_err

# %%
def delta_Acp_sys_unc(A_original, A_original_error, A, A_error):
    delta_Acp = A - A_original
    if A_original_error > A_error:
        delta_Acp_error = sqrt(A_original_error**2 - A_error**2)
    elif A_original_error < A_error:
        delta_Acp_error = sqrt(A_error**2 - A_original_error**2)
    else: 
        print("Error: unable to proceed.")
        sys.exit()

    # print(f"delta_Acp: {delta_Acp}, delta_Acp_error: {delta_Acp_error}")
    print(f"Original Acp: {A_original * 100:.5f}%, Original Acp error: {A_original_error * 100:.5f}%")
    print(f"Acp: {A * 100:.5f}%, Acp error: {A_error * 100:.5f}%")
    print(f"delta_Acp: {delta_Acp * 100:.5f}%, delta_Acp_error: {delta_Acp_error * 100:.5f}%")
    return delta_Acp, delta_Acp_error

# %% [markdown]
# # MC15 full

# %% [markdown]
# ## Acp(D+ -> eta pi+)

# %% [markdown]
# ### eta -> gg

# %%
#fit_v12
Araw_gg_cms_plus = 0.004562153323163898
Araw_gg_cms_plus_error =  0.004610831210831377
Araw_gg_cms_minus = 0.009549290256925858
Araw_gg_cms_minus_error =  0.00520242745395254
Araw_gg , Araw_gg_stats_error= combine_x_plus_y_divided_by_2(Araw_gg_cms_plus,Araw_gg_cms_minus, Araw_gg_cms_plus_error,Araw_gg_cms_minus_error )

print(f"Araw_gg: {Araw_gg}, Araw_gg_stats_error: {Araw_gg_stats_error}")
print(f"Araw_gg: {Araw_gg * 100:.5f}%, Araw_gg_stats_error: {Araw_gg_stats_error * 100:.5f}%")
# Out:
# Araw_gg: 0.007055721790044878, Araw_gg_stats_error: 0.0034758098289612975
# Araw_gg: 0.70557%, Araw_gg_stats_error: 0.34758%

# %%
#fit_v3
Aref_gg_cms_plus = -0.00495716868227114
Aref_gg_cms_plus_error = 0.0012428556744885479
Aref_gg_cms_minus = 0.009190873073308792 
Aref_gg_cms_minus_error = 0.001354329439157585
Aref_gg, Aref_gg_stats_error = combine_x_plus_y_divided_by_2(Aref_gg_cms_plus,Aref_gg_cms_minus, Aref_gg_cms_plus_error,Aref_gg_cms_minus_error )

print(f"Aref_gg: {Aref_gg}, Aref_gg_stats_error: {Aref_gg_stats_error}")
print(f"Aref_gg: {Aref_gg * 100:.5f}%, Aref_gg_stats_error: {Aref_gg_stats_error * 100:.5f}%")
# Out:
# Aref_gg: 0.0021168521955188258, Aref_gg_stats_error: 0.0009190890132867003
# Aref_gg: 0.21169%, Aref_gg_stats_error: 0.09191%

# %%
Aref_gg_pdg = 0
Acp_etapip_gg_value, Acp_etapip_gg_error = correct_Acp_stats_no_Kmix(Araw_gg, Araw_gg_stats_error, Aref_gg, Aref_gg_stats_error, Aref_gg_pdg)
print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value}, Acp_etapip_gg_error: {Acp_etapip_gg_error}")
print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value * 100:.5f}%, Acp_etapip_gg_error: {Acp_etapip_gg_error * 100:.5f}%")
# Out:
# Acp_etapip_gg_value: 0.004938869594526052, Acp_etapip_gg_error: 0.003595271697862108
# Acp_etapip_gg_value: 0.49389%, Acp_etapip_gg_error: 0.35953%

# %% [markdown]
# ### eta -> pipipi

# %%
#fitv12
Araw_3pi_cms_plus = -0.0047297403389876536
Araw_3pi_cms_plus_error = 0.005942262119240707
Araw_3pi_cms_minus = 0.006900182770741781
Araw_3pi_cms_minus_error =  0.006526541152690868

Araw_3pi , Araw_3pi_stats_error = combine_x_plus_y_divided_by_2(Araw_3pi_cms_plus,Araw_3pi_cms_minus, Araw_3pi_cms_plus_error,Araw_3pi_cms_minus_error )

print(f"Araw_3pi: {Araw_3pi}, Araw_3pi_stats_error: {Araw_3pi_stats_error}")
print(f"Araw_3pi: {Araw_3pi * 100:.5f}%, Araw_3pi_stats_error: {Araw_3pi_stats_error * 100:.5f}%")
# Out:
# Araw_3pi: 0.0010852212158770635, Araw_3pi_stats_error: 0.004413224969099426
# Araw_3pi: 0.10852%, Araw_3pi_stats_error: 0.44132%

# %%
#fitv3
Aref_3pi_cms_plus = -0.005620825562001497 
Aref_3pi_cms_plus_error =   0.0011461459010934164
Aref_3pi_cms_minus = 0.009010943177567787
Aref_3pi_cms_minus_error =   0.0012540251077938882
Aref_pipipi, Aref_pipipi_stats_error = combine_x_plus_y_divided_by_2(Aref_3pi_cms_plus,Aref_3pi_cms_minus, Aref_3pi_cms_plus_error,Aref_3pi_cms_minus_error )

print(f"Aref_pipipi: {Aref_pipipi * 100:.5f}%, Aref_pipipi_stats_error: {Aref_pipipi_stats_error * 100:.5f}%")
# Out:
# Aref_pipipi: 0.16951%, Aref_pipipi_stats_error: 0.08494%

# %%
Aref_pipipi_pdg = 0
Acp_etapip_pipipi_value, Acp_etapip_pipipi_error =correct_Acp_stats_no_Kmix(Araw_3pi, Araw_3pi_stats_error, Aref_pipipi, Aref_pipipi_stats_error, Aref_pipipi_pdg)

print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value}, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error}")
print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value * 100:.5f}%, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error * 100:.5f}%")
# Out:
# Acp_etapip_pipipi_value: -0.0006098375919060817, Acp_etapip_pipipi_error: 0.0044942309661693295
# Acp_etapip_pipipi_value: -0.06098%, Acp_etapip_pipipi_error: 0.44942%

# %%
combined_central_value, combined_error = combine_error_weighted(Acp_etapip_gg_value, Acp_etapip_pipipi_value, Acp_etapip_gg_error, Acp_etapip_pipipi_error)

print(f"Acp_combined: {combined_central_value * 100:.5f}%, Acp_combined_error: {combined_error * 100:.5f}%")
# Out:
# Acp_combined: 0.27736%, Acp_combined_error: 0.28075%

# %% [markdown]
# ## Acp(Ds+ -> eta pi+)

# %% [markdown]
# ### eta -> gg

# %%
#fit_v12
Araw_gg_cms_plus = -0.004177367032941248
Araw_gg_cms_plus_error = 0.002925567978213119
Araw_gg_cms_minus = 0.010064500278946564
Araw_gg_cms_minus_error = 0.003206283298628111
Araw_gg , Araw_gg_stats_error= combine_x_plus_y_divided_by_2(Araw_gg_cms_plus,Araw_gg_cms_minus, Araw_gg_cms_plus_error,Araw_gg_cms_minus_error )

print(f"Araw_gg: {Araw_gg}, Araw_gg_stats_error: {Araw_gg_stats_error}")
print(f"Araw_gg: {Araw_gg * 100:.5f}%, Araw_gg_stats_error: {Araw_gg_stats_error * 100:.5f}%")
# Out:
# Araw_gg: 0.002943566623002658, Araw_gg_stats_error: 0.002170207397128645
# Araw_gg: 0.29436%, Araw_gg_stats_error: 0.21702%

# %%
#fit_v3
Aref_gg_cms_plus = -0.00495716868227114
Aref_gg_cms_plus_error = 0.0012428556744885479
Aref_gg_cms_minus = 0.009190873073308792 
Aref_gg_cms_minus_error = 0.001354329439157585
Aref_gg, Aref_gg_stats_error = combine_x_plus_y_divided_by_2(Aref_gg_cms_plus,Aref_gg_cms_minus, Aref_gg_cms_plus_error,Aref_gg_cms_minus_error )

print(f"Aref_gg: {Aref_gg * 100:.5f}%, Aref_gg_stats_error: {Aref_gg_stats_error * 100:.5f}%")
# Out:
# Aref_gg: 0.21169%, Aref_gg_stats_error: 0.09191%

# %%
Aref_gg_pdg = 0
Acp_etapip_gg_value, Acp_etapip_gg_error = correct_Acp_stats_no_Kmix(Araw_gg, Araw_gg_stats_error, Aref_gg, Aref_gg_stats_error, Aref_gg_pdg)
print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value}, Acp_etapip_gg_error: {Acp_etapip_gg_error}")
print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value * 100:.5f}%, Acp_etapip_gg_error: {Acp_etapip_gg_error * 100:.5f}%")
# Out:
# Acp_etapip_gg_value: 0.0008267144274838323, Acp_etapip_gg_error: 0.0023568039292432047
# Acp_etapip_gg_value: 0.08267%, Acp_etapip_gg_error: 0.23568%

# %% [markdown]
# ### eta -> pipipi

# %%
#fitv12
Araw_3pi_cms_plus = -0.0034145538595863334
Araw_3pi_cms_plus_error = 0.003917908837046205
Araw_3pi_cms_minus = 0.0056838130952818755
Araw_3pi_cms_minus_error = 0.004289032878321728
Araw_3pi , Araw_3pi_stats_error = combine_x_plus_y_divided_by_2(Araw_3pi_cms_plus,Araw_3pi_cms_minus, Araw_3pi_cms_plus_error,Araw_3pi_cms_minus_error )

print(f"Araw_3pi: {Araw_3pi}, Araw_3pi_stats_error: {Araw_3pi_stats_error}")
print(f"Araw_3pi: {Araw_3pi * 100:.5f}%, Araw_3pi_stats_error: {Araw_3pi_stats_error * 100:.5f}%")
# Out:
# Araw_3pi: 0.001134629617847771, Araw_3pi_stats_error: 0.002904557310793226
# Araw_3pi: 0.11346%, Araw_3pi_stats_error: 0.29046%

# %%
#fitv3
Aref_3pi_cms_plus = -0.005620825562001497 
Aref_3pi_cms_plus_error =   0.0011461459010934164
Aref_3pi_cms_minus = 0.009010943177567787
Aref_3pi_cms_minus_error =   0.0012540251077938882
Aref_pipipi, Aref_pipipi_stats_error = combine_x_plus_y_divided_by_2(Aref_3pi_cms_plus,Aref_3pi_cms_minus, Aref_3pi_cms_plus_error,Aref_3pi_cms_minus_error )

print(f"Aref_pipipi: {Aref_pipipi * 100:.5f}%, Aref_pipipi_stats_error: {Aref_pipipi_stats_error * 100:.5f}%")
# Out:
# Aref_pipipi: 0.16951%, Aref_pipipi_stats_error: 0.08494%

# %%
Aref_pipipi_pdg = 0
Acp_etapip_pipipi_value, Acp_etapip_pipipi_error =correct_Acp_stats_no_Kmix(Araw_3pi, Araw_3pi_stats_error, Aref_pipipi, Aref_pipipi_stats_error, Aref_pipipi_pdg)

print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value}, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error}")
print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value * 100:.5f}%, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error * 100:.5f}%")
# Out:
# Acp_etapip_pipipi_value: -0.0005604291899353742, Acp_etapip_pipipi_error: 0.00302622050106648
# Acp_etapip_pipipi_value: -0.05604%, Acp_etapip_pipipi_error: 0.30262%

# %%
combined_central_value, combined_error = combine_error_weighted(Acp_etapip_gg_value, Acp_etapip_pipipi_value, Acp_etapip_gg_error, Acp_etapip_pipipi_error)

print(f"Acp_combined: {combined_central_value * 100:.5f}%, Acp_combined_error: {combined_error * 100:.5f}%")
# Out:
# Acp_combined: 0.03030%, Acp_combined_error: 0.18594%

# %% [markdown]
# ## Acp(D+ -> eta K+)

# %% [markdown]
# ### eta -> gg

# %%
#fitv12
Araw_gg_cms_plus = 0.1064171745897613
Araw_gg_cms_plus_error = 0.06465096493604734
Araw_gg_cms_minus = 0.10504291780740149
Araw_gg_cms_minus_error = 0.0621202582928456
Araw_gg , Araw_gg_stats_error= combine_x_plus_y_divided_by_2(Araw_gg_cms_plus,Araw_gg_cms_minus, Araw_gg_cms_plus_error,Araw_gg_cms_minus_error )

print(f"Araw_gg: {Araw_gg * 100:.5f}%, Araw_gg_stats_error: {Araw_gg_stats_error * 100:.5f}%")
# Out:
# Araw_gg: 10.57300%, Araw_gg_stats_error: 4.48293%

# %%
#fitv3
Aref_gg_cms_plus = -0.000891053282276677
Aref_gg_cms_plus_error = 0.002591316856349276
Aref_gg_cms_minus = 0.01696678351479708 
Aref_gg_cms_minus_error = 0.002695345787618729
Aref_gg, Aref_gg_stats_error = combine_x_plus_y_divided_by_2(Aref_gg_cms_plus,Aref_gg_cms_minus, Aref_gg_cms_plus_error,Aref_gg_cms_minus_error )

print(f"Aref_gg: {Aref_gg * 100:.5f}%, Aref_gg_stats_error: {Aref_gg_stats_error * 100:.5f}%")
# Out:
# Aref_gg: 0.80379%, Aref_gg_stats_error: 0.18695%

# %%
Aref_gg_pdg = 0
Acp_etapip_gg_value, Acp_etapip_gg_error = correct_Acp_stats_no_Kmix(Araw_gg, Araw_gg_stats_error, Aref_gg, Aref_gg_stats_error, Aref_gg_pdg)

print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value * 100:.5f}%, Acp_etapip_gg_error: {Acp_etapip_gg_error * 100:.5f}%")
# Out:
# Acp_etapip_gg_value: 9.76922%, Acp_etapip_gg_error: 4.48683%

# %% [markdown]
# ### eta -> pipipi

# %%
#fitv12
Araw_3pi_cms_plus = -0.022011393066735163
Araw_3pi_cms_plus_error = 0.06469668073810945
Araw_3pi_cms_minus = 0.06283601481701084
Araw_3pi_cms_minus_error = 0.06271278000854053
Araw_3pi , Araw_3pi_stats_error = combine_x_plus_y_divided_by_2(Araw_3pi_cms_plus,Araw_3pi_cms_minus, Araw_3pi_cms_plus_error,Araw_3pi_cms_minus_error )

print(f"Araw_3pi: {Araw_3pi * 100:.5f}%, Araw_3pi_stats_error: {Araw_3pi_stats_error * 100:.5f}%")
# Out:
# Araw_3pi: 2.04123%, Araw_3pi_stats_error: 4.50515%

# %%
#fitv3
Aref_3pi_cms_plus = 0.00013218589725561003
Aref_3pi_cms_plus_error =   0.002166365637515913
Aref_3pi_cms_minus = 0.01753684985818671
Aref_3pi_cms_minus_error =   0.0022719620271573465
Aref_pipipi, Aref_pipipi_stats_error = combine_x_plus_y_divided_by_2(Aref_3pi_cms_plus,Aref_3pi_cms_minus, Aref_3pi_cms_plus_error,Aref_3pi_cms_minus_error )

print(f"Aref_pipipi: {Aref_pipipi * 100:.5f}%, Aref_pipipi_stats_error: {Aref_pipipi_stats_error * 100:.5f}%")
# Out:
# Aref_pipipi: 0.88345%, Aref_pipipi_stats_error: 0.15696%

# %%
Aref_pipipi_pdg = 0
Acp_etapip_pipipi_value, Acp_etapip_pipipi_error =correct_Acp_stats_no_Kmix(Araw_3pi, Araw_3pi_stats_error, Aref_pipipi, Aref_pipipi_stats_error, Aref_pipipi_pdg)
print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value * 100:.5f}%, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error * 100:.5f}%")
# Out:
# Acp_etapip_pipipi_value: 1.15778%, Acp_etapip_pipipi_error: 4.50788%

# %%
combined_central_value, combined_error = combine_error_weighted(Acp_etapip_gg_value, Acp_etapip_pipipi_value, Acp_etapip_gg_error, Acp_etapip_pipipi_error)

print(f"Acp_combined: {combined_central_value * 100:.5f}%, Acp_combined_error: {combined_error * 100:.5f}%")
# Out:
# Acp_combined: 5.48366%, Acp_combined_error: 3.18009%

# %% [markdown]
# ## Acp(Ds+ -> eta K+)

# %% [markdown]
# ### eta -> gg

# %%
#fitv12
Araw_gg_cms_plus = 0.028255116978362027
Araw_gg_cms_plus_error = 0.01443567753057698
Araw_gg_cms_minus = 0.039435424547427766
Araw_gg_cms_minus_error = 0.014995730785763647
Araw_gg , Araw_gg_stats_error= combine_x_plus_y_divided_by_2(Araw_gg_cms_plus,Araw_gg_cms_minus, Araw_gg_cms_plus_error,Araw_gg_cms_minus_error )

print(f"Araw_gg: {Araw_gg * 100:.5f}%, Araw_gg_stats_error: {Araw_gg_stats_error * 100:.5f}%")
# Out:
# Araw_gg: 3.38453%, Araw_gg_stats_error: 1.04075%

# %%
#fitv3
Aref_gg_cms_plus = -0.000891053282276677
Aref_gg_cms_plus_error = 0.002591316856349276
Aref_gg_cms_minus = 0.01696678351479708 
Aref_gg_cms_minus_error = 0.002695345787618729
Aref_gg, Aref_gg_stats_error = combine_x_plus_y_divided_by_2(Aref_gg_cms_plus,Aref_gg_cms_minus, Aref_gg_cms_plus_error,Aref_gg_cms_minus_error )

print(f"Aref_gg: {Aref_gg}, Aref_gg_stats_error: {Aref_gg_stats_error}")
print(f"Aref_gg: {Aref_gg * 100:.5f}%, Aref_gg_stats_error: {Aref_gg_stats_error * 100:.5f}%")
# Out:
# Aref_gg: 0.008037865116260201, Aref_gg_stats_error: 0.0018694793369300662
# Aref_gg: 0.80379%, Aref_gg_stats_error: 0.18695%

# %%
Aref_gg_pdg = 0
Acp_etapip_gg_value, Acp_etapip_gg_error = correct_Acp_stats_no_Kmix(Araw_gg, Araw_gg_stats_error, Aref_gg, Aref_gg_stats_error, Aref_gg_pdg)

print(f"Acp_etapip_gg_value: {Acp_etapip_gg_value * 100:.5f}%, Acp_etapip_gg_error: {Acp_etapip_gg_error * 100:.5f}%")
# Out:
# Acp_etapip_gg_value: 2.58074%, Acp_etapip_gg_error: 1.05740%

# %% [markdown]
# ### eta -> pipipi

# %%
#fitv12
Araw_3pi_cms_plus = -0.010374809486891179
Araw_3pi_cms_plus_error = 0.017616495697287363
Araw_3pi_cms_minus = 0.029390746967061343
Araw_3pi_cms_minus_error = 0.018209998419019727
Araw_3pi , Araw_3pi_stats_error = combine_x_plus_y_divided_by_2(Araw_3pi_cms_plus,Araw_3pi_cms_minus, Araw_3pi_cms_plus_error,Araw_3pi_cms_minus_error )

print(f"Araw_3pi: {Araw_3pi * 100:.5f}%, Araw_3pi_stats_error: {Araw_3pi_stats_error * 100:.5f}%")
# Out:
# Araw_3pi: 0.95080%, Araw_3pi_stats_error: 1.26683%

# %%
#fitv3
Aref_3pi_cms_plus = 0.00013218589725561003
Aref_3pi_cms_plus_error =   0.002166365637515913
Aref_3pi_cms_minus = 0.01753684985818671
Aref_3pi_cms_minus_error =   0.0022719620271573465  
Aref_pipipi, Aref_pipipi_stats_error = combine_x_plus_y_divided_by_2(Aref_3pi_cms_plus,Aref_3pi_cms_minus, Aref_3pi_cms_plus_error,Aref_3pi_cms_minus_error )

print(f"Aref_pipipi: {Aref_pipipi * 100:.5f}%, Aref_pipipi_stats_error: {Aref_pipipi_stats_error * 100:.5f}%")
# Out:
# Aref_pipipi: 0.88345%, Aref_pipipi_stats_error: 0.15696%

# %%
Aref_pipipi_pdg = 0
Acp_etapip_pipipi_value, Acp_etapip_pipipi_error =correct_Acp_stats_no_Kmix(Araw_3pi, Araw_3pi_stats_error, Aref_pipipi, Aref_pipipi_stats_error, Aref_pipipi_pdg)
print(f"Acp_etapip_pipipi_value: {Acp_etapip_pipipi_value * 100:.5f}%, Acp_etapip_pipipi_error: {Acp_etapip_pipipi_error * 100:.5f}%")
# Out:
# Acp_etapip_pipipi_value: 0.06735%, Acp_etapip_pipipi_error: 1.27652%

# %%
combined_central_value, combined_error = combine_error_weighted(Acp_etapip_gg_value, Acp_etapip_pipipi_value, Acp_etapip_gg_error, Acp_etapip_pipipi_error)

print(f"Acp_combined: {combined_central_value * 100:.5f}%, Acp_combined_error: {combined_error * 100:.5f}%")
# Out:
# Acp_combined: 1.55795%, Acp_combined_error: 0.81431%
