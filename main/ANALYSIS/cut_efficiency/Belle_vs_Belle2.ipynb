# %%
import ROOT
import numpy as np
 
ROOT.gROOT.LoadMacro('/home/jykim/workspace/DRAW_and_FITTING/main/Belle2Style.C')
ROOT.SetBelle2Style()
# Out:
# Applying BELLE2 style settings...

# %%
Nfile = "/media/jykim/T7/storage/01_recon/phi/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
# Nfile = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_phi_*.root'

file_list = [Nfile]
#file_list = ['/media/jykim/T7/storage/01_recon/antiKstar/D0_massveto_v2_half_1_optimzed_sigext_signalMC_recon_mdst_antiKstar_*.root']
# file_list = ["/media/jykim/T7/storage/01_recon/massvetov2_optimzed_sigext_1ab_bkg/topo/resultfile/result_antiKstar/standard.root"]

# %%
mychain = ROOT.TChain("phi")
# mychain = ROOT.TChain("phi_cc")

for i in file_list:
    mychain.Add(i)

# %%
# file = ROOT.TFile.Open("/media/jykim/T7/storage/01_recon/phi/b2bii_phig_pre_half1M.root")  # Replace with your data file name
# tree = mychain.Get("phi")  # Replace with your tree name

# %%
def apply_cut1(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if  event.D0_M > 1.68 and event.D0_M < 2.05  and event.Dstarp_isSignal==1:

            histogram.Fill(event.D0_M)
    return histogram

# %%
def apply_cut2(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if abs(event.Phi_M - 1.0195) < 0.011  and event.D0_M > 1.68 and event.D0_M < 2.05 and event.gamma_E > 0.4 and event.Dstarp_isSignal==1:

            histogram.Fill(event.D0_M)
    return histogram

# %%
def apply_cut3(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if event.Dstarp_CMS_p>2.5 and abs(event.Phi_M - 1.0195) < 0.011  and event.D0_M > 1.68 and event.D0_M < 2.05 and event.gamma_E > 0.4 and event.Dstarp_isSignal==1:

            histogram.Fill(event.D0_M)
    return histogram

# %%
def apply_cut4(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if abs(event.Dstarp_delM-(2.0103-1.8648))<0.0008 and event.Dstarp_CMS_p>2.5 and abs(event.Phi_M - 1.0195) < 0.011  and event.D0_M > 1.68 and event.D0_M < 2.05 and event.gamma_E > 0.4 and event.Dstarp_isSignal==1:

            histogram.Fill(event.D0_M)
    return histogram

# %%
def apply_cut5(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if event.gamma_E>0.48 and abs(event.Dstarp_delM-(2.0103-1.8648))<0.0008 and event.Dstarp_CMS_p>2.5 and abs(event.Phi_M - 1.0195) < 0.011  and event.D0_M > 1.68 and event.D0_M < 2.05 and event.gamma_E > 0.4 and event.Dstarp_isSignal==1:

            histogram.Fill(event.D0_M)
    return histogram

# %%
D0_M_TH1F = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
D0_M_TH1F_cut1_after = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
D0_M_TH1F_cut2_after = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
D0_M_TH1F_cut3_after = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
D0_M_TH1F_cut4_after = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
D0_M_TH1F_cut5_after = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.68, 2.05)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: D0_M_TH1F (Potential memory leak).

# %%
D0_M_TH1F_cut1_after = apply_cut1(mychain, D0_M_TH1F)
selectedEvents1 = D0_M_TH1F_cut1_after.GetEntries()

# %%
D0_M_TH1F_cut2_after = apply_cut2(mychain, D0_M_TH1F_cut2_after)
selectedEvents2 = D0_M_TH1F_cut2_after.GetEntries()

# %%
D0_M_TH1F_cut3_after = apply_cut3(mychain, D0_M_TH1F_cut3_after)
selectedEvents3 = D0_M_TH1F_cut3_after.GetEntries()

# %%
D0_M_TH1F_cut4_after = apply_cut4(mychain, D0_M_TH1F_cut4_after)
selectedEvents4 = D0_M_TH1F_cut4_after.GetEntries()

# %%
D0_M_TH1F_cut5_after = apply_cut5(mychain, D0_M_TH1F_cut5_after)
selectedEvents5 = D0_M_TH1F_cut5_after.GetEntries()

# %%
import ROOT
totalEvents = 0.5 * 1e+6
# Define your efficiencies and cut labels
efficiency1 = selectedEvents1 / totalEvents
efficiency2 = selectedEvents2 / totalEvents
efficiency3 = selectedEvents3 / totalEvents
efficiency4 = selectedEvents4 / totalEvents
efficiency5 = selectedEvents5 / totalEvents

efficiency = list()
efficiency.append(efficiency1)
efficiency.append(efficiency2)
efficiency.append(efficiency3)
efficiency.append(efficiency4)
efficiency.append(efficiency5)

# Define the corresponding errors for each efficiency
# You can calculate these errors based on the statistics of your selected events
error1 = (efficiency1 * (1 - efficiency1) / totalEvents) ** 0.5
error2 = (efficiency2 * (1 - efficiency2) / totalEvents) ** 0.5
error3 = (efficiency3 * (1 - efficiency3) / totalEvents) ** 0.5
error4 = (efficiency4 * (1 - efficiency4) / totalEvents) ** 0.5
error5 = (efficiency5 * (1 - efficiency5) / totalEvents) ** 0.5

# error5 = 0.05
errors = [error1, error2, error3, error4, error5]

cut_labels = ["Cut 1", "Cut 2", "Cut 3", "Cut 4", "Cut 5"]

# Create and customize a TGraphErrors
canvas = ROOT.TCanvas("efficiency_plot", "Cut Efficiency")
graph = ROOT.TGraphErrors(len(cut_labels))

graph.GetXaxis().SetTitle("Cuts")
graph.GetYaxis().SetTitle("Efficiency")

# Fill the TGraphErrors with efficiencies and errors
for i in range(len(cut_labels)):
    graph.SetPoint(i, i, efficiency[i])
    graph.SetPointError(i, 0.0, errors[i])  # No x-error, only y-error

graph.Draw("APE")  # AP stands for Axis and Points

# Show the plot
canvas.Update()
canvas.Draw()

print("Total events in tree:", totalEvents)
print("Selected events for Cut 1:", selectedEvents1)
print("Selected events for Cut 2:", selectedEvents2)
print("Selected events for Cut 3:", selectedEvents3)
print("Selected events for Cut 4:", selectedEvents4)
print("Selected events for Cut 5:", selectedEvents5)


    # graph.GetXaxis().SetBinLabel(i + 1, cut_labels[i])
# file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_belleII_no_vertexfit.png'
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_belle_no_vertexfit.png'

canvas.SaveAs(file_name)
# Out:
# Total events in tree: 500000.0
# Selected events for Cut 1: 29312.0
# Selected events for Cut 2: 26087.0
# Selected events for Cut 3: 22701.0
# Selected events for Cut 4: 17689.0
# Selected events for Cut 5: 16917.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: efficiency_plot
# Info in <TCanvas::Print>: png file /media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_belle_no_vertexfit.png has been created

# %%
import ROOT
totalEvents = 0.5 * 1e+6
# Define your efficiencies and cut labels
efficiency1 = selectedEvents1 / totalEvents
efficiency2 = selectedEvents2 / totalEvents
efficiency3 = selectedEvents3 / totalEvents
efficiency4 = selectedEvents4 / totalEvents
efficiency5 = selectedEvents5 / totalEvents

efficiency = list()
efficiency.append(efficiency1)
efficiency.append(efficiency2)
efficiency.append(efficiency3)
efficiency.append(efficiency4)
efficiency.append(efficiency5)


# efficiency += efficiency2
# efficiency += efficiency3

cut_labels = ["Cut 1", "Cut 2", "Cut 3", "Cut 4", "Cut 5"]

# Create and customize a TGraph
canvas = ROOT.TCanvas("efficiency_plot", "Cut Efficiency")
graph = ROOT.TGraph(len(cut_labels))

graph.GetXaxis().SetTitle("Cuts")
graph.GetYaxis().SetTitle("Efficiency")

# Fill the TGraph with efficiencies
# graph.SetMarkerStyle(20)
# graph.SetMarkerSize(1.5)
for i in range(len(cut_labels)):
    graph.SetPoint(i, i, efficiency[i])
    graph.GetXaxis().SetBinLabel(i + 1, cut_labels[i])

# Set the y-axis range from 0.00 to 0.15
# graph.GetYaxis().SetRangeUser(0.00, 0.15)

graph.Draw("AP")  # AP stands for Axis and Points

# Show the plot
canvas.Update()
canvas.Draw()

print("Total events in tree:", totalEvents)
print("Selected events for Cut 1:", selectedEvents1)
print("Selected events for Cut 2:", selectedEvents2)
print("Selected events for Cut 3:", selectedEvents3)
print("Selected events for Cut 4:", selectedEvents4)
print("Selected events for Cut 5:", selectedEvents5)
# Out:
# Total events in tree: 500000.0
# Selected events for Cut 1: 29327.0
# Selected events for Cut 2: 26077.0
# Selected events for Cut 3: 22685.0
# Selected events for Cut 4: 17685.0
# Selected events for Cut 5: 16920.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: efficiency_plot

# %%
nbins = 50  # Number of bins for your histogram
xmin = 1.68  # Minimum value for your histogram
xmax = 2.05  # Maximum value for your histogram

hist_passed = ROOT.TH1F("hist_passed", "Passed Events vs. Cuts", nbins, xmin, xmax)
hist_total = ROOT.TH1F("hist_total", "Total Events vs. Cuts", nbins, xmin, xmax)

efficiency_graph = ROOT.TGraph()

# %%
nEntries = tree.GetEntries()
for i in range(nEntries):
    tree.GetEntry(i)

    # Apply your cuts and calculate efficiency
    if PassesCut(your_cut):
        hist_passed.Fill(cut_value)
    hist_total.Fill(cut_value)

    efficiency = hist_passed.GetEntries() / hist_total.GetEntries()
    efficiency_graph.SetPoint(i, cut_value, efficiency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 6
#       3 tree.GetEntry(i)
#       5 # Apply your cuts and calculate efficiency
# ----> 6 if PassesCut(your_cut):
#       7     hist_passed.Fill(cut_value)
#       8 hist_total.Fill(cut_value)
#
# NameError: name 'PassesCut' is not defined

# %%
canvas = ROOT.TCanvas("canvas", "Efficiency vs. Cuts", 800, 600)
efficiency_graph.SetTitle("Efficiency vs. Cuts")
efficiency_graph.GetXaxis().SetTitle("Cut Value")
efficiency_graph.GetYaxis().SetTitle("Efficiency")
efficiency_graph.Draw("APL")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Error in <TGraphPainter::PaintGraph>: illegal number of points (0)
# Error in <TGraphPainter::PaintGraph>: illegal number of points (0)

# %%
canvas.SaveAs("efficiency_vs_cuts.png")  # Save as an image file
# Out:
# Error in <TGraphPainter::PaintGraph>: illegal number of points (0)
# Info in <TCanvas::Print>: png file efficiency_vs_cuts.png has been created

# %%
import ROOT

# Create a ROOT file and a TTree with some example data
file = ROOT.TFile("/media/jykim/T7/storage/01_recon/phi/b2bii_phig_pre_half1M.root", "READ")
tree = ROOT.TTree("phi", "phi")

# Fill the tree with some data
# Replace this with your actual data

# Define the cuts
cut = "gamma_E > 0.5"

# Apply the cut and calculate efficiency
pass_cut = tree.Draw("D0_M", cut)
total_events = tree.GetEntries()
efficiency = pass_cut / total_events

# Create a TGraph to visualize the efficiency
gr = ROOT.TGraph()
gr.SetPoint(0, cut_value_1, efficiency_1)
gr.SetPoint(1, cut_value_2, efficiency_2)
# Add more points as needed

# Create a canvas and draw the graph
c = ROOT.TCanvas("c", "Efficiency vs Cuts")
gr.Draw("APL")
gr.SetTitle("Efficiency vs Cuts")
gr.GetXaxis().SetTitle("Cut Value")
gr.GetYaxis().SetTitle("Efficiency")

# Save or display the plot
c.SaveAs("efficiency_vs_cuts.png")

# Close the ROOT file
file.Close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [13], line 16
#      14 pass_cut = tree.Draw("D0_M", cut)
#      15 total_events = tree.GetEntries()
# ---> 16 efficiency = pass_cut / total_events
#      18 # Create a TGraph to visualize the efficiency
#      19 gr = ROOT.TGraph()
#
# ZeroDivisionError: division by zero

# %%
total_events
# Out:
# 0

# %%
# Out:
# Total events in tree: 55174
# Selected events for Cut 1: 0
# Selected events for Cut 2: 0
# Selected events for Cut 3: 0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: efficiency_plot

# %%
efficiency1
# Out:
# 0.0

# %%
efficiency2
# Out:
# 0.0

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import glob
try:
#     plt.style.use('belle2')
\
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.cm as cm
import matplotlib.ticker as ticker
# Out:
# Welcome to JupyROOT 6.26/04

# %%
file = '/media/jykim/T7/storage/01_recon/phi/v6_sig_ext_signalMC_recon_mdst_phi.root'
tree = 'phi'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/antiKstar/v6_sig_ext_signalMC_recon_mdst_antiKstar.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_Kg_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/rho/v6_sig_ext_signalMC_recon_mdst_rho.root'
tree = 'rho'
base_filter = 'rho_rank_Dstp==1 && D0_M>1.67 && D0_M<2.06 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_rhog_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/omega/v6_sig_ext_signalMC_recon_mdst_omega.root'
tree = 'omega'
base_filter = 'omega_rank_Dstp==1 && D0_M>1.67 && D0_M<2.06 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_omegag_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_Kg_sigMC['D0_M']
h3=pd_rhog_sigMC['D0_M']
h4=pd_omegag_sigMC['D0_M']


xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \phi \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$",density=True)
plt.hist(h3, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
plt.hist(h4, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)



px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)


#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

# plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
#plot_title=r"$D^0 \rightarrow V \gamma$"

#plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
# def cal_eff_purity(file, tree, base_filter, N_gen):
    
#     variables = ['Dstarp_isSignal','D0_M','__experiment__', '__run__', '__event__']
#     recon_df = get_pd(file, tree, base_filter, variables)
    
#     multiplicity = len(recon_df[["__experiment__", "__run__", "__event__"]].drop_duplicates()) / len(recon_df[["__experiment__", "__run__", "__event__"]])
    
#     N_rec = len(recon_df)
#     eff = N_rec/N_gen
    
#     N_true = len(recon_df[recon_df['Dstarp_isSignal']==1])
#     purity = N_true/N_rec
    
#     print(f"eff={eff:.4f}, purity={purity:.4f}, multiplicity={multiplicity:.4f}")
    
#     return (eff, purity, multiplicity)

# %%
def cal_eff_purity_ownMC(file_name,file_list, tree, base_filter, N_gen):
    
    variables = ['Dstarp_isSignal','D0_M','__experiment__', '__run__', '__event__']
    
    N_rec = 0

    # Initialize an empty dataframe to store concatenated results
    concatenated_df = pd.DataFrame()

    for file in file_list:
        recon_df = get_pd(file, tree, base_filter, variables)
        N_rec += len(recon_df)
        extracted_df = recon_df[["__experiment__", "__run__", "__event__"]].drop_duplicates()

        # Concatenate the extracted dataframe with the concatenated_df
        concatenated_df = pd.concat([concatenated_df, extracted_df], ignore_index=True)

    multiplicity = len(concatenated_df) / N_rec

    eff = N_rec/N_gen
    
    recon_df = get_pd(file_name, tree, base_filter, variables)
    N_true = len(recon_df.query('Dstarp_isSignal==1'))
    purity = N_true/N_rec
    signal_eff = eff * purity
    
    signal_eff_error = math.sqrt(signal_eff * (1 - signal_eff) / N_gen)
    
    print(f"signal_eff={signal_eff:.4f}, signal_eff_error={signal_eff_error: .4f} ,eff={eff:.4f}, purity={purity:.4f}, multiplicity={multiplicity:.4f}, ")
    
    return (signal_eff, eff, purity, multiplicity)

# %% [markdown]
# # phi gamma

# %%
file = "/media/jykim/T7/storage/01_recon/phi/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05'
base_filter=' D0_M>1.68 && D0_M<2.05 && abs(Phi_M - 1.0195) < 0.011 && abs(Dstarp_delM-(2.0103-1.8648))<0.0008 \
             && Dstarp_CMS_p>2.5 && gamma_E>0.48 && dM_pi0_75MeV>0.023'
tree = 'phi'

root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 42
# signal_eff=0.0307, signal_eff_error= 0.0002 ,eff=0.0345, purity=0.8905, multiplicity=0.9919,

# %%
file = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_phi_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
base_filter=' D0_M>1.68 && D0_M<2.05 && abs(Phi_M - 1.0195) < 0.011 && abs(Dstarp_delM-(2.0103-1.8648))<0.0008 \
             && Dstarp_CMS_p>2.5 && gamma_E>0.48 && dM_pi0_75MeV>0.023'
tree = 'phi'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.0812, signal_eff_error= 0.0004 ,eff=0.0832, purity=0.9756, multiplicity=0.9966,

# %%
file = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_pre_signalMC_recon_mdst_phi_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
base_filter=' D0_M>1.68 && D0_M<2.05 && abs(Phi_M - 1.0195) < 0.011 && abs(Dstarp_delM-(2.0103-1.8648))<0.0008 \
             && Dstarp_CMS_p>2.5 && gamma_E>0.48 && dM_pi0_75MeV>0.023'
tree = 'phi'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.0747, signal_eff_error= 0.0004 ,eff=0.0762, purity=0.9795, multiplicity=0.9981,

# %%
file = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_pre_signalMC_recon_mdst_phi_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
tree = 'phi'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.1243, eff=0.1410, purity=0.8814, multiplicity=0.9385,

# %% [markdown]
# # antiKstar gamma

# %%
file = "/media/jykim/T7/storage/01_recon/antiKstar/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05'
tree = 'antiKstar'

root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 42
# signal_eff=0.0848, signal_eff_error= 0.0004 ,eff=0.1383, purity=0.6130, multiplicity=0.7849,

# %%
file = '/media/jykim/T7/storage/01_recon/antiKstar/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_antiKstar_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
tree = 'antiKstar'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.2131, signal_eff_error= 0.0006 ,eff=0.3092, purity=0.6893, multiplicity=0.7875,

# %% [markdown]
# # rho gamma

# %%
file = "/media/jykim/T7/storage/01_recon/rho/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05'
tree = 'rho'

root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 42
# signal_eff=0.1356, signal_eff_error= 0.0005 ,eff=0.2544, purity=0.5332, multiplicity=0.7209,

# %%
file = '/media/jykim/T7/storage/01_recon/rho/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_rho_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
tree = 'rho'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.3123, signal_eff_error= 0.0007 ,eff=0.5145, purity=0.6070, multiplicity=0.7228,

# %% [markdown]
# # omega gamma

# %%
file = "/media/jykim/T7/storage/01_recon/omega/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05'
tree = 'omega'

root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 42
# signal_eff=0.0848, signal_eff_error= 0.0004 ,eff=0.1382, purity=0.6133, multiplicity=0.7851,

# %%
file = '/media/jykim/T7/storage/01_recon/omega/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_omega_*.root'
base_filter=' D0_M>1.68 && D0_M<2.05 '
tree = 'omega'
root_files = glob.glob(file)
print(len(root_files))
D0signal_eff,D0eff,D0purity,D0multiplicity = cal_eff_purity_ownMC(file,root_files, tree, base_filter, 1e+6*0.5)
# Out:
# 3
# signal_eff=0.1602, signal_eff_error= 0.0005 ,eff=0.7446, purity=0.2151, multiplicity=0.3759,

# %% [markdown]
# # Plot

# %% [markdown]
# # phi

# %%
def draw_phi(var,xrange,xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$",file_name=str()):
    file = "/media/jykim/T7/storage/01_recon/phi/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
    base_filter=' D0_M>1.68 && D0_M<2.05'
    tree = 'phi'
    variables = [var,'Dstarp_isSignal']
    pd_phig_sigMC_belle = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

    file = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_phi_*.root'
    pd_phig_sigMC_belle2 = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

    h1=pd_phig_sigMC_belle[variables[0]]
    h2=pd_phig_sigMC_belle2[variables[0]]

    h3=pd_phig_sigMC_belle.query('Dstarp_isSignal==1')[variables[0]]
    h4=pd_phig_sigMC_belle2.query('Dstarp_isSignal==1')[variables[0]]



    # h2=pd_Kg_sigMC['D0_M']


    xrange=xrange
    xbins = np.linspace(*xrange,51)

    plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ",density=True)
    plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II",density=True)
    # plt.hist(h3, bins=xbins, histtype='step',label=r"Belle(True) ",density=True)
    # plt.hist(h4, bins=xbins, histtype='step',label=r"Belle II(True) ",density=True)


    px = 1/plt.rcParams['figure.dpi']
    # plt.figure(figsize=(576*px, 396*px))

    plt.xlim(xrange)


    #plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

    #plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

    # plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
    plot_title=r"$D^0 \rightarrow \phi \gamma$"

    plt.title(plot_title)
    ax = plt.gca()
    # xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
    ax.set_xlabel(xlabel)
    plt.legend()

    
    plt.tight_layout()
    first_fname = file_name + '_all.png'
    plt.savefig(first_fname)
    plt.show()
    plt.clf()


    # plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ",density=True)
    # plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II",density=True)
    plt.hist(h3, bins=xbins, histtype='step',label=r"Belle(True) ",density=True)
    plt.hist(h4, bins=xbins, histtype='step',label=r"Belle II(True) ",density=True)


    px = 1/plt.rcParams['figure.dpi']
    # plt.figure(figsize=(576*px, 396*px))

    plt.xlim(xrange)


    #plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

    #plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

    # plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
    plot_title=r"$D^0 \rightarrow \phi \gamma$"

    plt.title(plot_title)
    ax = plt.gca()
    # xlabel = xlabel
    ax.set_xlabel(xlabel)
    plt.legend()

    
    plt.tight_layout()
    second_fname = file_name + '_true.png'
    plt.savefig(second_fname)
    plt.show()

# %%
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_vertexfit_no_yes_D0_M'

draw_phi('D0_M', (1.68,2.05), xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$",file_name=file_name)

# %%
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_vertexfit_no_yes_Phi_M'


draw_phi('Phi_M', (1.0195 - 0.02,1.0195 + 0.02), xlabel = r"$M(\phi) \; [\mathrm{GeV/c^2}]$",file_name=file_name)

# %%
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_vertexfit_no_yes_Dstarp_CMS_p'


draw_phi('Dstarp_CMS_p', (2,5), xlabel = r"$p_{CMS}(D^{*+}) \; [\mathrm{GeV/c}]$",file_name=file_name)

# %%
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_vertexfit_no_yes_Dstarp_delM'

xrange=(2.0103-1.8648 - 0.008 ,0.160)
draw_phi('Dstarp_delM', xrange, xlabel = r"$\Delta m \; [\mathrm{GeV/c^2}]$",file_name=file_name)

# %%
file_name = '/media/jykim/T7/saved_plots/belle_vs_belleII/phi_half1M_vertexfit_no_yes_gamma_E'


xrange=(0.3, 4.2)
draw_phi('gamma_p', xrange, xlabel = r"$p_{\gamma} \; [\mathrm{GeV/c}]$",file_name=file_name)

# %%
file = "/media/jykim/T7/storage/01_recon/phi/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05'
tree = 'phi'
variables = ['phi_Km_Lkpi']
pd_phig_sigMC_belle = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_phi_*.root'

variables2 = ['phi_Km_binaryK']
# pd_phig_sigMC_belle2 = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables2)


h1=pd_phig_sigMC_belle[variables[0]]
# h2=pd_phig_sigMC_belle2[variables2[0]]

# h2=pd_Kg_sigMC['D0_M']


xrange=(0.5,1)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ",density=True)
# plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II",density=True)
# plt.hist(h3, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
# plt.hist(h4, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)



px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)


#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

# plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
plot_title=r"$D^0 \rightarrow \phi \gamma$"

plt.title(plot_title)
ax = plt.gca()
xlabel = r"$\mathcal{L}_{K /\pi}$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = "/media/jykim/T7/storage/01_recon/antiKstar/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05 && Dstarp_isSignal==1'
tree = 'antiKstar'
variables = ['D0_M']
pd_phig_sigMC_belle = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/antiKstar/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_antiKstar_*.root'
pd_phig_sigMC_belle2 = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC_belle['D0_M']
h2=pd_phig_sigMC_belle2['D0_M']

# h2=pd_Kg_sigMC['D0_M']


xrange=(1.68,2.05)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II",density=True)
# plt.hist(h3, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
# plt.hist(h4, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)



px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)


#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

# plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
plot_title=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$"

plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = "/media/jykim/T7/storage/01_recon/rho/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05 && Dstarp_isSignal==1'
tree = 'rho'
variables = ['D0_M']
pd_phig_sigMC_belle = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/rho/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_rho_*.root'
pd_phig_sigMC_belle2 = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC_belle['D0_M']
h2=pd_phig_sigMC_belle2['D0_M']

# h2=pd_Kg_sigMC['D0_M']


xrange=(1.68,2.05)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ")#,density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II")#,density=True)
# plt.hist(h3, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
# plt.hist(h4, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)



px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)


#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

# plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
plot_title=r"$D^0 \rightarrow \rho^0 \gamma$"

plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = "/media/jykim/T7/storage/01_recon/omega/B2Bii/D0_b2bii_massveto_v2_half_1_very_pre_signalMC_recon_evtgen_exp*.root" 
base_filter=' D0_M>1.68 && D0_M<2.05 && Dstarp_isSignal==1'
tree = 'omega'
variables = ['D0_M']
pd_phig_sigMC_belle = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/omega/D0_massveto_v2_half_1_very_pre_signalMC_recon_mdst_omega_*.root'
pd_phig_sigMC_belle2 = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC_belle['D0_M']
h2=pd_phig_sigMC_belle2['D0_M']

# h2=pd_Kg_sigMC['D0_M']


xrange=(1.68,2.05)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"Belle ",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"Belle II",density=True)
# plt.hist(h3, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
# plt.hist(h4, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)



px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)


#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.BuPu)

#plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Greys)

# plot_title=r"$D^0 \rightarrow K_S^0 \pi^0$"
plot_title=r"$D^0 \rightarrow \omega \gamma$"

plt.title(plot_title)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()
