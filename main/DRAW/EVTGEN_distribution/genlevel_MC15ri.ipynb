# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
# Out:
# Welcome to JupyROOT 6.26/04

# %%
def DRAW_gen_gamma_p(df, label):

    label = label
    df = df
    
    fig = plt.figure()
    ax = fig.subplots()

    xrange = (0, 4.2)
    nbins = 84
    
    xbins = np.linspace(*xrange, nbins+1)
    bin_width = xbins[1] - xbins[0]
    
    plt.hist(df["gamma_p"],bins=xbins,histtype='step',label=label);

    plt.legend(loc="upper right")
    #ax.set_title(r'1M signal MC' )


    plt.xlabel("$E(\gamma) \; [\mathrm{GeV}]$")
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(bin_width).rstrip('0').rstrip('.') + '\mathrm{GeV})$');

    plt.xlim(xrange[0], xrange[1])
    plt.tight_layout()

# %%
file_name = '/media/jykim/T7/storage/genlevel_ntuples/genlevel_phi_1M.root'
base_filter = 'gamma_p>0'
signal_variables = ['gamma_cosTheta',"gamma_p","gamma_CMS_p","gamma_CMS_cosTheta","D0_cosHel_0"]
tree = 'phi'
pd_df = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=signal_variables)

# %%
file_name = '/media/jykim/T7/storage/genlevel_ntuples/genlevel_phi_1M.root'
base_filter = 'gamma_p>0'
signal_variables = ['gamma_cosTheta',"gamma_p","gamma_CMS_p","gamma_CMS_cosTheta","D0_cosHel_0"]
tree = 'phi'
pd_df = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=signal_variables)

file_name = '/media/jykim/T7/storage/genlevel_ntuples/genlevel_antiKstar_1M.root'
tree = 'antiKstar'
pd_df2 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=signal_variables)

file_name = '/media/jykim/T7/storage/genlevel_ntuples/genlevel_rho_1M.root'
tree = 'rho'
pd_df3 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=signal_variables)

file_name = '/media/jykim/T7/storage/genlevel_ntuples/genlevel_omega_1M.root'
tree = 'omega'
pd_df4 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=signal_variables)

# %%
DRAW_gen_gamma_p(pd_df, r'$D^0 \to \phi \gamma$')

# %%
fig = plt.figure()
ax = fig.subplots()

xrange = (0, 4.5)
nbins = 90

xbins = np.linspace(*xrange, nbins+1)
bin_width = xbins[1] - xbins[0]

plt.hist(pd_df["gamma_p"],bins=xbins,histtype='step',label=r'$D^0 \to \phi \gamma$',density=True);
plt.hist(pd_df2["gamma_p"],bins=xbins,histtype='step',label=r'$D^0 \to \bar{K}^{*0} \gamma$',density=True);
plt.hist(pd_df3["gamma_p"],bins=xbins,histtype='step',label=r'$D^0 \to \rho^0 \gamma$',density=True);
plt.hist(pd_df4["gamma_p"],bins=xbins,histtype='step',label=r'$D^0 \to \omega \gamma$',density=True);

plt.legend(loc="upper right")
#ax.set_title(r'1M signal MC' )


plt.xlabel("$E(\gamma) \; [\mathrm{GeV}]$")
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(bin_width).rstrip('0').rstrip('.') + '\mathrm{GeV})$');
plt.axvline(x=0.3,  color='magenta', linestyle='dotted',lw=2)

plt.xlim(xrange[0], xrange[1])
plt.tight_layout()

plt.savefig("genlevel_Eg_presel_cut.png")

# %%
fig = plt.figure()
ax = fig.subplots()

xrange = (-1,1)
nbins = 50

xbins = np.linspace(*xrange, nbins+1)
bin_width = xbins[1] - xbins[0]

var = "D0_cosHel_0"
plt.hist(pd_df[var],bins=xbins,histtype='step',label=r'$D^0 \to \phi \gamma$',density=True);
plt.hist(pd_df2[var],bins=xbins,histtype='step',label=r'$D^0 \to \bar{K}^{*0} \gamma$',density=True);
plt.hist(pd_df3[var],bins=xbins,histtype='step',label=r'$D^0 \to \rho^0 \gamma$',density=True);
# plt.hist(pd_df4[var],bins=xbins,histtype='step',label=r'$D^0 \to \omega \gamma$',density=True);

plt.legend(loc="upper right")
#ax.set_title(r'1M signal MC' )


plt.xlabel(r"$\cos \theta_H$")
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(bin_width).rstrip('0').rstrip('.') + ')$');

plt.xlim(xrange[0], xrange[1])
plt.tight_layout()
