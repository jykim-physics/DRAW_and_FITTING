# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
# Out:
# Welcome to JupyROOT 6.26/04

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_pi0calib_sigext/'
base_file_loc =  '/media/jykim/T7/storage/01_recon/v18_pi0calib_sigext_naive_skim/'
base_file_loc =  '/media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/'

base_filter =  'D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006'
base_filter += ' && Pi0_Prob<0.8'
tree = 'kshort'

variables=['D0_M','D0_cosHel_0','Dstarp_Q','Dstarp_CMS_p','Pi0_Prob','gamma_E','__ncandidates__','__candidate__']
var = 'D0_M'

# %%
ccbar_0 = base_file_loc + 'topo/resultfile/result_kshort/standard.root'

uubar_0 = base_file_loc + 'generic_uubar.root'
ddbar_0 = base_file_loc + 'generic_ddbar.root'
ssbar_0 = base_file_loc + 'generic_ssbar.root'
charged_0 = base_file_loc + 'generic_charged.root'
mixed_0 = base_file_loc + 'generic_mixed.root'
taupair_0 = base_file_loc + 'generic_taupair.root'


ccbar_0 = base_file_loc + 'ccbar/recon_output_*.root'
uubar_0 = base_file_loc + 'uubar/recon_output_*.root'
ddbar_0 = base_file_loc + 'ddbar/recon_output_*.root'
ssbar_0 = base_file_loc + 'ssbar/recon_output_*.root'
charged_0 = base_file_loc + 'charged/recon_output_*.root'
mixed_0 = base_file_loc + 'mixed/recon_output_*.root'
taupair_0 = base_file_loc + 'taupair/recon_output_*.root'

# %%
base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar_0 = get_pd(file=ccbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_uubar_0 = get_pd(file=uubar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_ddbar_0 = get_pd(file=ddbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar_0 = get_pd(file=ssbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_charged_0 = get_pd(file=charged_0, tree=tree,base_filter=base_filter,variables=variables)

pd_mixed_0 = get_pd(file=mixed_0, tree=tree,base_filter=base_filter,variables=variables)

pd_taupair_0 = get_pd(file=taupair_0, tree=tree,base_filter=base_filter,variables=variables)

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(1.67,2.06)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(1.67,2.06)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["__ncandidates__"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(0,6)
    xbins = np.linspace(*xrange,7)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black',align='left')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=xrange)

    ax.set_xlim(xrange[0],xrange[1])
#     ax.set_ylim(0,6000)

    plt.xlabel("__ncandidates__")
    width = xe[1]-xe[0]
    plt.ylabel('Entries');
    plt.show()
    plt.clf()
# Out:
# __ncandidates__

# %%
test_merged_pd  = pd.concat([pd_ccbar_0,pd_uubar_0,pd_ddbar_0,pd_ssbar_0,pd_charged_0,pd_mixed_0,pd_taupair_0] )
print(len(test_merged_pd))
# Out:
# 42592

# %%
print(len(test_merged_pd.query('__candidate__==0')))
# Out:
# 42199

# %%
(42592-42199)/42199
# Out:
# 0.009313016896134979

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/'

# base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_pi0calib_sigext/'
# base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_pi0calib_sigext_naive_skim/'
# base_file_loc =  '/media/jykim/T7/storage/01_recon/v18_pi0calib_sigext_naive_skim/'


# base_filter =  'kshort_rank_Dstp==1 &&D0_M>1.67 && D0_M<2.06  '
base_filter =  'D0_M>1.67 && D0_M<2.06'
base_filter += ' && Pi0_Prob<0.85'
# tree = 'kshort'
tree = 'kshortpi0'

variables=['D0_M','D0_D0_M_before','D0_cosHel_0','Dstarp_Q','Dstarp_CMS_p','Pi0_Prob','Pi0veto_Easym','__ncandidates__', \
           'Pi0_soft_clusterSecondMoment','Pi0_soft_clusterLAT','Pi0_soft_clusterAbsZernikeMoment51','Pi0_soft_clusterAbsZernikeMoment40','Pi0_soft_clusterE9E21','Pi0_soft_clusterE1E9','Pi0_soft_clusterZernikeMVA','Pi0_soft_clusterTheta','ROE_Pi0_InvM']
# variables+=['Pi0veto_cosHelicityAngleMomentum']

# variables=['D0_M','Pi0_Prob']
var = 'D0_M'

# %%
ccbar_0 = base_file_loc + 'topo/resultfile/result_kshortpi0/standard.root'

#ccbar_0 = base_file_loc + 'topo/generic_ccbar.root'
uubar_0 = base_file_loc + 'generic_uubar.root'
ddbar_0 = base_file_loc + 'generic_ddbar.root'
ssbar_0 = base_file_loc + 'generic_ssbar.root'
charged_0 = base_file_loc + 'generic_charged.root'
mixed_0 = base_file_loc + 'generic_mixed.root'
taupair_0 = base_file_loc + 'generic_taupair.root'


ccbar_0 = base_file_loc + 'ccbar/recon_output_*.root'
uubar_0 = base_file_loc + 'uubar/recon_output_*.root'
ddbar_0 = base_file_loc + 'ddbar/recon_output_*.root'
ssbar_0 = base_file_loc + 'ssbar/recon_output_*.root'
charged_0 = base_file_loc + 'charged/recon_output_*.root'
mixed_0 = base_file_loc + 'mixed/recon_output_*.root'
taupair_0 = base_file_loc + 'taupair/recon_output_*.root'

# %%
kshortpi0_filter = base_filter + ' && (iCascDcyBrP_Dst_0==1 || iCascDcyBrP_Dst_0==14)'

kshorteta_filter = base_filter + ' && (iCascDcyBrP_Dst_0==8 || iCascDcyBrP_Dst_0==114 )'

remaining_filter = base_filter + '&& iCascDcyBrP_Dst_0!=8 && iCascDcyBrP_Dst_0!=114 && iCascDcyBrP_Dst_0!=1 && iCascDcyBrP_Dst_0!=14'


kshortpi0_filter = base_filter 

kshorteta_filter = base_filter + ' && D0_M<0'

remaining_filter = base_filter + ' && D0_M<0'

# %%
base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar_kshortpi0 = get_pd(file=ccbar_0, tree=tree,base_filter=kshortpi0_filter,variables=variables)
pd_ccbar_kshorteta = get_pd(file=ccbar_0, tree=tree,base_filter=kshorteta_filter,variables=variables)
pd_ccbar_remain = get_pd(file=ccbar_0, tree=tree,base_filter=remaining_filter,variables=variables)



pd_uubar_0 = get_pd(file=uubar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ddbar_0 = get_pd(file=ddbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar_0 = get_pd(file=ssbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_charged_0 = get_pd(file=charged_0, tree=tree,base_filter=base_filter,variables=variables)
pd_mixed_0 = get_pd(file=mixed_0, tree=tree,base_filter=base_filter,variables=variables)
pd_taupair_0 = get_pd(file=taupair_0, tree=tree,base_filter=base_filter,variables=variables)
# Out:
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# Cell In [84], line 5
#       2 varaiables = variables
#       3 tree=tree
# ----> 5 pd_ccbar_kshortpi0 = get_pd(file=ccbar_0, tree=tree,base_filter=kshortpi0_filter,variables=variables)
#       6 pd_ccbar_kshorteta = get_pd(file=ccbar_0, tree=tree,base_filter=kshorteta_filter,variables=variables)
#       7 pd_ccbar_remain = get_pd(file=ccbar_0, tree=tree,base_filter=remaining_filter,variables=variables)
#
# File ~/workspace/DRAW_and_FITTING/main/data_tools/extract_ntuples.py:12, in get_pd(file, tree, base_filter, variables)
#       9 base_filter  = base_filter
#      11 ROOT_df_start = ROOT.RDataFrame(tree, f)
# ---> 12 col_dict  = ROOT_df_start.AsNumpy(variables)
#      14 if base_filter !=None:
#      15     ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)
#
# File ~/anaconda3/envs/draw/lib/python3.10/site-packages/ROOT/_pythonization/_rdataframe.py:79, in RDataFrameAsNumpy(df, columns, exclude, lazy)
#      77 result_ptrs = {}
#      78 for column in columns:
# ---> 79     column_type = df.GetColumnType(column)
#      80     result_ptrs[column] = df.Take[column_type](column)
#      82 result = AsNumpyResult(result_ptrs, columns)
#
# runtime_error: string ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::GetColumnType(basic_string_view<char,char_traits<char> > column) =>
#     runtime_error: Column "D0_M" is not in a dataset and is not a custom column been defined.
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00000.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00001.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00002.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00003.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00004.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00005.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00006.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00007.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00008.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00009.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00010.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00011.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00012.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00013.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00014.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00015.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00016.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00017.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00018.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00019.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00020.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00021.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00022.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00023.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00024.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00025.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00026.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00027.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00028.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00029.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00030.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00031.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00032.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00033.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00034.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00035.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00036.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00037.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00038.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00039.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00040.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00041.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00042.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00043.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00044.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00045.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00046.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00047.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00048.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00049.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00050.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00051.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00052.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00053.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00054.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00055.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00056.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00057.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00058.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00059.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00060.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00061.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00062.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00063.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00064.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00065.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00066.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00067.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00068.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00069.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00070.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00071.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00072.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00073.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00074.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00075.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00076.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00077.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00078.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00079.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00080.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00081.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00082.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00083.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00084.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00085.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00086.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00087.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00088.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00089.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00090.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00091.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00092.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00093.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00094.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00095.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00096.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00097.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00098.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00099.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00100.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00101.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00102.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00103.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00104.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00105.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00106.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00107.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00108.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00109.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00110.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00111.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00112.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00113.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00114.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00115.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00116.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00117.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00118.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00119.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00120.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00121.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00122.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00123.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00124.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00125.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00126.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00127.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00128.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00129.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00130.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00131.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00132.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00133.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00134.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00135.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00136.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00137.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00138.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00139.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00140.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00141.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00142.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00143.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00144.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00145.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00146.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00147.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00148.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00149.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00150.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00151.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00152.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00153.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00154.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00155.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00156.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00157.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00158.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00159.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00160.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00161.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00162.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00163.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00164.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00165.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00166.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00167.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00168.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00169.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00170.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00171.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00172.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00173.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00174.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00175.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00176.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00177.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00178.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00179.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00180.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00181.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00182.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00183.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00184.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00185.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00186.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00187.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00188.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00189.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00190.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00191.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00192.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00193.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00194.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00195.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00196.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00197.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00198.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00199.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00200.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00201.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00202.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00203.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00204.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00205.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00206.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00207.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00208.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00209.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00210.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00211.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00212.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00213.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00214.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00215.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00216.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00217.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00218.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00219.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00220.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00221.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00222.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00223.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00224.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00225.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00226.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00227.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00228.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00229.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00230.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00231.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00232.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00233.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00234.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00235.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00236.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00237.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00238.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00239.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00240.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00241.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00242.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00243.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00244.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00245.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00246.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00247.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00248.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00249.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00250.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00251.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00252.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00253.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00254.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00255.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00256.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00257.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00258.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00259.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00260.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00261.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00262.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00263.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00264.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00265.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00266.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00267.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00268.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00269.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00270.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00271.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00272.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00273.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00274.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00275.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00276.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00277.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00278.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00279.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00280.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00281.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00282.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00283.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00284.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00285.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00286.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00287.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00288.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00289.root
# ...
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02802.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02803.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02804.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02805.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02806.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02807.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02808.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02809.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02810.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02811.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02812.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02813.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02814.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02815.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02816.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02817.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02818.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02819.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02820.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02821.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02822.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02823.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02824.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02825.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02826.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02827.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02828.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02829.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02830.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02831.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02832.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02833.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02834.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02835.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02836.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02837.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02838.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02839.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02840.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02841.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02842.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02843.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02844.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02845.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02846.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02847.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02848.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02849.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02850.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02851.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02852.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02853.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02854.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02855.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02856.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02857.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02858.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02859.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02860.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02861.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02862.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02863.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02864.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02865.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02866.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02867.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02868.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02869.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02870.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02871.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02872.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02873.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02874.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02875.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02876.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02877.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02878.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02879.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02880.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02881.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02882.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02883.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02884.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02885.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02886.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02887.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02888.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02889.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02890.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02891.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02892.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02893.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02894.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02895.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02896.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02897.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_02898.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00000.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00000.root
# Error in <TChain::LoadTree>: Cannot find tree with name kshortpi0 in file /media/jykim/T7/storage/01_recon/v9mask_pi0calib_sigext/ccbar/recon_output_00000.root

# %%
# plt.hist(pd_taupair_0[var], bins=xbins, histtype='stepfilled', stacked=True,label='taupair',edgecolor='black')
# plt.hist(pd_mixed_0[var], bins=xbins, histtype='stepfilled', stacked=True,label='taupair',edgecolor='black')
# plt.hist(pd_charged_0[var], bins=xbins, histtype='stepfilled', stacked=True,label='taupair',edgecolor='black')
# plt.hist(pd_ssbar_0[var], bins=xbins, histtype='stepfilled', stacked=True,label='taupair',edgecolor='black')

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_remain[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    kshort_eta = {var : pd_ccbar_kshorteta[var] }
    kshort_pi0 = {var : pd_ccbar_kshortpi0[var] }
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var], kshort_eta[var], kshort_pi0[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(1.67,2.06)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_remain[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    kshort_eta = {var : pd_ccbar_kshorteta[var] }
    kshort_pi0 = {var : pd_ccbar_kshortpi0[var] }
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var], kshort_eta[var], kshort_pi0[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(1.67,2.06)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_remain[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    kshort_eta = {var : pd_ccbar_kshorteta[var] }
    kshort_pi0 = {var : pd_ccbar_kshortpi0[var] }
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var], kshort_eta[var], kshort_pi0[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(1.67,2.06)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

data_list=dict()
signal_variables = ["__ncandidates__"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_remain[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    kshort_eta = {var : pd_ccbar_kshorteta[var] }
    kshort_pi0 = {var : pd_ccbar_kshortpi0[var] }
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var], kshort_eta[var], kshort_pi0[var]]  

#     for labeling in labels:
    xrange=(0,6)
    xbins = np.linspace(*xrange,7)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black',align='left')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=xrange)

    ax.set_xlim(xrange[0],xrange[1])
#     ax.set_ylim(0,6000)

    plt.xlabel("__ncandidates__")
    width = xe[1]-xe[0]
    plt.ylabel('Entries');
    plt.show()
    plt.clf()
# Out:
# __ncandidates__

# %%
var ='D0_M'
weights = None
data_list = [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]
merged_pd = pd.concat( [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]
)
scale = 174.90/400
# scale = 1

# %%
if weights is None:
    weights = []
    for i,d in enumerate(data_list):
        wei = np.ones(len(d))
        if scale is not None:
            if isinstance(scale, int) or isinstance(scale, float):
                if not isinstance(scale, bool):
                    wei *= scale
            elif isinstance(scale, dict):
                assert cats[i] in scale.keys(), "Scale list must have same lenght as data"
                wei *= scale[cats[i]]
            else:
                print("Please provide int or float with scale")
        weights.append(wei)

# %%
weights
# Out:
# [array([0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, ..., 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725, 0.43725,
#         0.43725]),
#  array([0.43725, 0.43725, 0.43725, ..., 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, ..., 0.43725, 0.43725, 0.43725]),
#  array([0.43725, 0.43725, 0.43725, ..., 0.43725, 0.43725, 0.43725])]

# %%
file = '/media/jykim/T7/storage_b2/storage/pi0calib_23_pr_all_4S_v1/output_*.root'
file = '/media/jykim/T7/storage_b2/storage/v16_23_pr_all_4S_v1/output_*.root'
# file = '/media/jykim/T7/storage/grid/fbdtv18_23_pr_all_4S_v1/output_*.root'


tree = 'kshort'
# tree = 'kshortpi0'

#variables = ['D0_M',"D0_cosHel_0"]
# base_filter='kshort_rank_Dstp==1 && D0_M>1.67 && D0_M<2.06 '
base_filter=' D0_M>1.67 && D0_M<2.06 '

# base_filter += ' && Pi0_Prob<0.85'

#base_filter=' D0_M>1.67 && D0_M<2.06 '

variables=['D0_M','D0_D0_M_before','D0_cosHel_0','Dstarp_Q','Dstarp_CMS_p','Pi0_Prob','Pi0_Prob','Pi0veto_Easym',\
           'Pi0_soft_clusterSecondMoment','Pi0_soft_clusterLAT','Pi0_soft_clusterAbsZernikeMoment51','Pi0_soft_clusterAbsZernikeMoment40','Pi0_soft_clusterE9E21','Pi0_soft_clusterE1E9','Pi0_soft_clusterZernikeMVA','Pi0_soft_clusterTheta','ROE_Pi0_InvM']
variables+=['gamma_E','Pi0veto_cosHelicityAngleMomentum']
        
# tree='kshort'

prompt_pd = get_pd(file=file , tree=tree, variables=variables ,base_filter=base_filter)

# %%
error_weights = None

# %%
if error_weights is None:
    #error_weights = np.ones(len(merged_pd))
    error_weights = np.ones(len(prompt_pd))

# %%
if scale is not None:
    if isinstance(scale, int) or isinstance(scale, float):
        if not isinstance(scale, bool):
            error_weights *= scale
    else:
        print("Please provide int or float with scale")
else:
    scale = 1

# %%
error_weights
# Out:
# array([0.43725, 0.43725, 0.43725, ..., 0.43725, 0.43725, 0.43725])

# %%
y, xe = np.histogram(prompt_pd['D0_M'], bins=50, range=(1.67,2.06), density=False)
# y, xe = np.histogram(prompt_pd['D0_M'], bins=50, range=(1.67,2.06), density=False, weights=error_weights)

#y, x = np.histogram(merged_pd, bins=50, range=(1.67,2.06), density=False, weights=error_weights)

# %%
error_scale = 1
    # https://www-cdf.fnal.gov/physics/statistics    
err = (-0.5 + np.sqrt(np.array(y*scale + 0.25)), +0.5 + np.sqrt(np.array(y*scale + 0.25)))  # np.sqrt(np.array(y))
#err = (-0.5 + np.sqrt(np.array(y*scale)), +0.5 + np.sqrt(np.array(y*scale)))  # np.sqrt(np.array(y))
#err = (- np.sqrt(np.array(y)),  + np.sqrt(np.array(y)))


err = (-0.5 + np.sqrt(np.array(y*error_scale)), +0.5 + np.sqrt(np.array(y*error_scale)))

err = (-0.5 + np.sqrt(np.array(y*error_scale + 0.25)), +0.5 + np.sqrt(np.array(y*error_scale + 0.25)))  # np.sqrt(np.array(y))

# %%
err
# Out:
# (array([18.79378138, 19.2040605 , 19.53122562, 20.17002661, 20.67191536,
#         20.        , 19.60596926, 20.09732992, 21.32315284, 21.25430992,
#         20.95343795, 22.67865397, 21.95551157, 23.2118114 , 22.87199179,
#         23.67126393, 24.40481881, 25.52402736, 26.96361229, 27.84166544,
#         28.27933286, 28.60755916, 26.50462923, 23.97958333, 20.02437575,
#         16.41892432, 14.20544117, 11.59338662, 11.21537451, 10.09481005,
#          9.75914226,  9.5124922 ,  9.95227248,  8.94722181, 10.6467484 ,
#          9.75914226, 10.82475165, 10.09481005, 10.09481005, 10.4658561 ,
#          9.36154146,  9.95227248,  9.75914226, 10.42016483,  9.5124922 ,
#          9.95227248,  9.5124922 , 10.4658561 ,  9.75914226,  9.75914226]),
#  array([19.79378138, 20.2040605 , 20.53122562, 21.17002661, 21.67191536,
#         21.        , 20.60596926, 21.09732992, 22.32315284, 22.25430992,
#         21.95343795, 23.67865397, 22.95551157, 24.2118114 , 23.87199179,
#         24.67126393, 25.40481881, 26.52402736, 27.96361229, 28.84166544,
#         29.27933286, 29.60755916, 27.50462923, 24.97958333, 21.02437575,
#         17.41892432, 15.20544117, 12.59338662, 12.21537451, 11.09481005,
#         10.75914226, 10.5124922 , 10.95227248,  9.94722181, 11.6467484 ,
#         10.75914226, 11.82475165, 11.09481005, 11.09481005, 11.4658561 ,
#         10.36154146, 10.95227248, 10.75914226, 11.42016483, 10.5124922 ,
#         10.95227248, 10.5124922 , 11.4658561 , 10.75914226, 10.75914226]))

# %%
# y, xe = np.histogram(prompt_pd['D0_M'], bins=50, range=(1.67,2.06), density=False)
# y, xe = np.histogram(prompt_pd['D0_M'], bins=50, range=(1.67,2.06), density=True)

data_MC_weights = None
if data_MC_weights is None:
    data_MC_weights = np.ones(len(merged_pd))
    #error_weights = np.ones(len(prompt_pd))
if scale is not None:
    if isinstance(scale, int) or isinstance(scale, float):
        if not isinstance(scale, bool):
            data_MC_weights *= scale
    else:
        print("Please provide int or float with scale")
else:
    scale = 1
n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), weights=data_MC_weights)
# n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), density=True)

# %%
n
# Out:
# array([398.772  , 412.32675, 426.31875, 417.1365 , 442.497  , 477.91425,
#        490.15725, 488.40825, 511.14525, 505.461  , 550.49775, 565.36425,
#        592.47375, 579.35625, 625.70475, 667.68075, 747.26025, 757.75425,
#        809.34975, 947.0835 , 968.50875, 930.90525, 889.3665 , 759.9405 ,
#        545.25075, 350.23725, 236.115  , 159.59625, 145.60425, 114.5595 ,
#        125.928  , 118.49475, 111.936  , 105.37725, 109.3125 , 113.685  ,
#        100.5675 , 105.8145 , 110.187  , 101.87925, 109.74975, 114.99675,
#         93.5715 ,  94.88325,  96.63225,  94.446  , 100.5675 , 103.191  ,
#        105.37725,  94.00875])

# %%
n/y
# Out:
# array([1.07196774, 1.06269781, 1.06313903, 0.97690047, 0.98771652,
#        1.13789107, 1.21326052, 1.15190625, 1.07383456, 1.06862791,
#        1.19673424, 1.05281983, 1.17554315, 1.03088301, 1.1459794 ,
#        1.14328896, 1.20525847, 1.1192825 , 1.07340816, 1.17943151,
#        1.16969656, 1.09906169, 1.21998148, 1.26868197, 1.29513242,
#        1.22460577, 1.093125  , 1.093125  , 1.06280474, 1.02285268,
#        1.19931429, 1.1849475 , 1.02693578, 1.18401404, 0.88155242,
#        1.08271429, 0.78568359, 0.94477232, 0.9838125 , 0.84899375,
#        1.13144072, 1.05501606, 0.89115714, 0.79733824, 0.9663225 ,
#        0.86647706, 1.005675  , 0.859925  , 1.00359286, 0.89532143])

# %%
#pull_err = (-0.5 + np.sqrt(np.array(n/y + 0.25)), +0.5 + np.sqrt(np.array(n/y + 0.25)))  # np.sqrt(np.array(y))

# %%
import matplotlib.ticker as mticker
from matplotlib import gridspec
# fig = plt.figure()
#plt.figure(figsize=(800,550))
fig = plt.figure(figsize=(8, 7.5)) 
gs = gridspec.GridSpec(nrows=2, # row 몇 개 
                       ncols=1, # col 몇 개 
                       height_ratios=[ 4, 1], 
#                        width_ratios=[1, 1]
                      )
#plt.subplot(2,1,1)
ax0 = plt.subplot(gs[0])
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

#n, xe = np.histogram(prompt_pd, bins=50, range=(1.67,2.06), weights=error_weights)


#n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), weights=error_weights)






#y_error = np.sqrt(n)

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist( data_list , bins=xbins, histtype='stepfilled', stacked=True,label=labels,\
         color=colors,edgecolor='black',weights=weights, density=False,)

bin_centres = (xe[:-1] + xe[1:])/2.


plt.errorbar(x=bin_centres, y=y,
             yerr=err, fmt='o', capsize=2, color='black', drawstyle='steps',label=r'174.90$\mathrm{fb^{-1}}$' + '\n' + '(prompt)')

#plt.hist(prompt_pd['D0_M'],bins=xbins,density=True,histtype='step')

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width , box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
plt.legend(prop={'size':13})

# watermark(t="",logo="MC15ri")
ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

ax.set_xlim(*xrange)
# ax.set_ylim(0,100)


plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');



ax2 = plt.subplot(2,1,2)
#fig2, ax2 = plt.subplots()
#ig2.set_size_inches(, 2)
#ax.xaxis.set_major_locator(mticker.FixedLocator(np.arange(labels.size).tolist()))
#ax.set_xticklabels(labels, rotation=30, ha="right")

# plt.plot(xbins[:50],n/y)
plt.scatter(bin_centres,y/n,color='black')

#plt.errorbar(x=bin_centres, y=n/y,
#              yerr=pull_err, fmt='o', capsize=2, color='black', drawstyle='steps')

#ax2 = plt.gca()
ax2.set_xlim(*xrange)
ax2.set_ylim(0,2)
plt.axhline(y=1, color='gray', linestyle='--')


plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
plt.ylabel("data/MC")
#plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

width = xe[1]-xe[0]



plt.show()
plt.clf()

# %%
scale = 174.90/400
var ='Pi0_soft_clusterTheta'
var ='Pi0_Prob'
var = 'ROE_Pi0_InvM'
# var = 'Pi0_soft_cosHelicityAngleMomentum'
xrange = (0.08,0.25)

weights = None
data_list = None
merged_pd = None
data_list = [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]
merged_pd = pd.concat( [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]
)

# scale = 1

if weights is None:
    weights = []
    for i,d in enumerate(data_list):
        wei = np.ones(len(d))
        if scale is not None:
            if isinstance(scale, int) or isinstance(scale, float):
                if not isinstance(scale, bool):
                    wei *= scale
            elif isinstance(scale, dict):
                assert cats[i] in scale.keys(), "Scale list must have same lenght as data"
                wei *= scale[cats[i]]
            else:
                print("Please provide int or float with scale")
        weights.append(wei)

# %%
error_weights = None

# %%
if error_weights is None:
    #error_weights = np.ones(len(merged_pd))
    error_weights = np.ones(len(prompt_pd))
if scale is not None:
    if isinstance(scale, int) or isinstance(scale, float):
        if not isinstance(scale, bool):
            error_weights *= scale
    else:
        print("Please provide int or float with scale")
else:
    scale = 1

# %%
y, xe = np.histogram(prompt_pd[var], bins=50, range=xrange, density=False)
error_scale = 1
    # https://www-cdf.fnal.gov/physics/statistics    

err = (-0.5 + np.sqrt(np.array(y*error_scale + 0.25)), +0.5 + np.sqrt(np.array(y*error_scale + 0.25)))  # np.sqrt(np.array(y))

# %%
data_MC_weights = None
if data_MC_weights is None:
    data_MC_weights = np.ones(len(merged_pd))
    #error_weights = np.ones(len(prompt_pd))
if scale is not None:
    if isinstance(scale, int) or isinstance(scale, float):
        if not isinstance(scale, bool):
            data_MC_weights *= scale
    else:
        print("Please provide int or float with scale")
else:
    scale = 1
n, xe = np.histogram(merged_pd, bins=50, range=xrange, weights=data_MC_weights)

# %%
import matplotlib.ticker as mticker
from matplotlib import gridspec
# fig = plt.figure()
#plt.figure(figsize=(800,550))
fig = plt.figure(figsize=(8, 7.5)) 
gs = gridspec.GridSpec(nrows=2, # row 몇 개 
                       ncols=1, # col 몇 개 
                       height_ratios=[ 4, 1], 
#                        width_ratios=[1, 1]
                      )
#plt.subplot(2,1,1)
ax0 = plt.subplot(gs[0])
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

#n, xe = np.histogram(prompt_pd, bins=50, range=(1.67,2.06), weights=error_weights)


#n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), weights=error_weights)


var =var
data_list = [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]





#y_error = np.sqrt(n)

xrange=xrange
xbins = np.linspace(*xrange,51)

plt.hist( data_list , bins=xbins, histtype='stepfilled', stacked=True,label=labels,\
         color=colors,edgecolor='black',weights=weights, density=False)

bin_centres = (xe[:-1] + xe[1:])/2.


plt.errorbar(x=bin_centres, y=y,
             yerr=err, fmt='o', capsize=2, color='black', drawstyle='steps',label=r'174.90$fb^{-1}$' + '\n' + '(prompt)')

#plt.hist(prompt_pd[var],bins=xbins,density=True,histtype='step')

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width , box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
# ax.legend(loc='best', bbox_to_anchor=(0, 1))   

# plt.legend(prop={'size':13})
# plt.tight_layout()
# watermark(t="",logo="MC15ri")
ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

ax.set_xlim(*xrange)
# ax.set_xlim(0.1,0.2)
# ax.set_ylim(0,100)

width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + ')$');



ax2 = plt.subplot(2,1,2)
#fig2, ax2 = plt.subplots()
#ig2.set_size_inches(, 2)
#ax.xaxis.set_major_locator(mticker.FixedLocator(np.arange(labels.size).tolist()))
#ax.set_xticklabels(labels, rotation=30, ha="right")

# plt.plot(xbins[:50],n/y)
plt.scatter(bin_centres,y/n,color='black')

#plt.errorbar(x=bin_centres, y=n/y,
#              yerr=pull_err, fmt='o', capsize=2, color='black', drawstyle='steps')

#ax2 = plt.gca()
ax2.set_xlim(*xrange)


ax2.set_ylim(0,2)
plt.axhline(y=1, color='gray', linestyle='--')


# plt.xlabel("$\pi^0$ probability")
#plt.xlabel("clusterTheta($\gamma_2$)")
plt.xlabel("M($\gamma_1\gamma_2)\;[\mathrm{GeV/c^2}]$")

plt.ylabel("data/MC")
#plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');





plt.show()
plt.clf()

# %%
import matplotlib.ticker as mticker
from matplotlib import gridspec
# fig = plt.figure()
#plt.figure(figsize=(800,550))
fig = plt.figure(figsize=(8, 7.5)) 
gs = gridspec.GridSpec(nrows=2, # row 몇 개 
                       ncols=1, # col 몇 개 
                       height_ratios=[ 4, 1], 
#                        width_ratios=[1, 1]
                      )
#plt.subplot(2,1,1)
ax0 = plt.subplot(gs[0])
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

#n, xe = np.histogram(prompt_pd, bins=50, range=(1.67,2.06), weights=error_weights)


#n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), weights=error_weights)


var ='Pi0veto_Easym'
data_list = [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]





#y_error = np.sqrt(n)

xrange=(0,1)
xbins = np.linspace(*xrange,51)

plt.hist( data_list , bins=xbins, histtype='stepfilled', stacked=True,label=labels,\
         color=colors,edgecolor='black',weights=weights, density=True)

bin_centres = (xe[:-1] + xe[1:])/2.


# plt.errorbar(x=bin_centres, y=y,
#              yerr=err, fmt='o', capsize=2, color='black', drawstyle='steps',label=r'174.90$fb^{-1}$' + '\n' + '(prompt)')

plt.hist(prompt_pd[var],bins=xbins,density=True,histtype='step')

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width , box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
plt.legend(prop={'size':13})

# watermark(t="",logo="MC15ri")
ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

ax.set_xlim(*xrange)
# ax.set_ylim(0,100)


plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');



ax2 = plt.subplot(2,1,2)
#fig2, ax2 = plt.subplots()
#ig2.set_size_inches(, 2)
#ax.xaxis.set_major_locator(mticker.FixedLocator(np.arange(labels.size).tolist()))
#ax.set_xticklabels(labels, rotation=30, ha="right")

# plt.plot(xbins[:50],n/y)
plt.scatter(bin_centres,y/n,color='black')

#plt.errorbar(x=bin_centres, y=n/y,
#              yerr=pull_err, fmt='o', capsize=2, color='black', drawstyle='steps')

#ax2 = plt.gca()
ax2.set_xlim(*xrange)
ax2.set_ylim(0,2)
plt.axhline(y=1, color='gray', linestyle='--')


plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
plt.ylabel("data/MC")
#plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

width = xe[1]-xe[0]



plt.show()
plt.clf()

# %%
import matplotlib.ticker as mticker
from matplotlib import gridspec
# fig = plt.figure()
#plt.figure(figsize=(800,550))
fig = plt.figure(figsize=(8, 7.5)) 
gs = gridspec.GridSpec(nrows=2, # row 몇 개 
                       ncols=1, # col 몇 개 
                       height_ratios=[ 4, 1], 
#                        width_ratios=[1, 1]
                      )
#plt.subplot(2,1,1)
ax0 = plt.subplot(gs[0])
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','other ccbar',r'$D^0 \to K_S^0 \eta$',r'$D^0 \to K_S^0 \pi^0$']


colors=b2helix(len(labels))

#n, xe = np.histogram(prompt_pd, bins=50, range=(1.67,2.06), weights=error_weights)


#n, xe = np.histogram(merged_pd, bins=50, range=(1.67,2.06), weights=error_weights)


var ='Pi0_Prob'
data_list = [pd_mixed_0[var], pd_charged_0[var], pd_uubar_0[var], pd_ddbar_0[var], pd_ssbar_0[var], pd_taupair_0[var], pd_ccbar_remain[var], pd_ccbar_kshorteta[var], pd_ccbar_kshortpi0[var]]





#y_error = np.sqrt(n)

xrange=(0,1)
xbins = np.linspace(*xrange,51)

plt.hist( data_list , bins=xbins, histtype='stepfilled', stacked=True,label=labels,\
         color=colors,edgecolor='black',weights=weights, density=True)

bin_centres = (xe[:-1] + xe[1:])/2.


# plt.errorbar(x=bin_centres, y=y,
#              yerr=err, fmt='o', capsize=2, color='black', drawstyle='steps',label=r'174.90$fb^{-1}$' + '\n' + '(prompt)')

plt.hist(prompt_pd[var],bins=xbins,density=True,histtype='step')

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width , box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
plt.legend(prop={'size':13})

# watermark(t="",logo="MC15ri")
ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

ax.set_xlim(*xrange)
# ax.set_ylim(0,100)


plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');



ax2 = plt.subplot(2,1,2)
#fig2, ax2 = plt.subplots()
#ig2.set_size_inches(, 2)
#ax.xaxis.set_major_locator(mticker.FixedLocator(np.arange(labels.size).tolist()))
#ax.set_xticklabels(labels, rotation=30, ha="right")

# plt.plot(xbins[:50],n/y)
plt.scatter(bin_centres,y/n,color='black')

#plt.errorbar(x=bin_centres, y=n/y,
#              yerr=pull_err, fmt='o', capsize=2, color='black', drawstyle='steps')

#ax2 = plt.gca()
ax2.set_xlim(*xrange)
ax2.set_ylim(0,2)
plt.axhline(y=1, color='gray', linestyle='--')


plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
plt.ylabel("data/MC")
#plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

width = xe[1]-xe[0]



plt.show()
plt.clf()

# %%
fig.dpi
# Out:
# 100.0

# %%
err
# Out:
# (array([18.6637679 , 19.15324401, 19.45620204, 20.09732992, 20.60094785,
#         19.87768387, 19.45620204, 20.04872259, 21.23131381, 21.23131381,
#         20.90677463, 22.61384866, 21.82151429, 23.2118114 , 22.76478025,
#         23.56761309, 24.30423351, 25.33118271, 26.72590678, 27.68244134,
#         28.22716484, 28.41798748, 26.3374738 , 23.81563283, 19.90220576,
#         16.30029762, 14.        , 11.4687092 , 11.21537451,  9.75914226,
#          9.61187421,  9.5124922 ,  9.71028893,  8.73309266, 10.4658561 ,
#          9.71028893, 10.69151464,  9.90432602,  9.95227248, 10.23545528,
#          9.10468636,  9.80776406,  9.66120072, 10.28192933,  9.46242942,
#          9.90432602,  9.4121138 , 10.28192933,  9.75914226,  9.5124922 ]),
#  array([19.6637679 , 20.15324401, 20.45620204, 21.09732992, 21.60094785,
#         20.87768387, 20.45620204, 21.04872259, 22.23131381, 22.23131381,
#         21.90677463, 23.61384866, 22.82151429, 24.2118114 , 23.76478025,
#         24.56761309, 25.30423351, 26.33118271, 27.72590678, 28.68244134,
#         29.22716484, 29.41798748, 27.3374738 , 24.81563283, 20.90220576,
#         17.30029762, 15.        , 12.4687092 , 12.21537451, 10.75914226,
#         10.61187421, 10.5124922 , 10.71028893,  9.73309266, 11.4658561 ,
#         10.71028893, 11.69151464, 10.90432602, 10.95227248, 11.23545528,
#         10.10468636, 10.80776406, 10.66120072, 11.28192933, 10.46242942,
#         10.90432602, 10.4121138 , 11.28192933, 10.75914226, 10.5124922 ]))

# %%
len(ccbar_bkg[var])

# %%
n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

w = 100*(np.zeros_like(s) + 1. / len(ccbar_bkg[var]))

w = (np.zeros_like(s) + 0.7)

plt.hist(ccbar_bkg[var], xe, weights=w)
# plt.hist(ccbar_bkg[var], xe, density=True)

# %%
plt.hist(ccbar_bkg[var], xe)
# Out:
# (array([102., 107.,  96.,  92., 113.,  83.,  96.,  80.,  72.,  75.,  59.,
#          71.,  54.,  49.,  39.,  53.,  61.,  58.,  56.,  72.,  81.,  76.,
#          82.,  55.,  38.,  42.,  47.,  29.,  15.,  19.,  20.,  24.,  15.,
#          25.,  21.,  24.,  17.,  17.,  28.,  19.,  16.,  20.,  17.,  16.,
#          17.,   9.,  17.,  24.,  20.,  19.]),
#  array([1.67  , 1.6778, 1.6856, 1.6934, 1.7012, 1.709 , 1.7168, 1.7246,
#         1.7324, 1.7402, 1.748 , 1.7558, 1.7636, 1.7714, 1.7792, 1.787 ,
#         1.7948, 1.8026, 1.8104, 1.8182, 1.826 , 1.8338, 1.8416, 1.8494,
#         1.8572, 1.865 , 1.8728, 1.8806, 1.8884, 1.8962, 1.904 , 1.9118,
#         1.9196, 1.9274, 1.9352, 1.943 , 1.9508, 1.9586, 1.9664, 1.9742,
#         1.982 , 1.9898, 1.9976, 2.0054, 2.0132, 2.021 , 2.0288, 2.0366,
#         2.0444, 2.0522, 2.06  ]),
#  <BarContainer object of 50 artists>)

# %%
len(s)
# Out:
# 2357

# %%
s = ccbar_bkg[var].dropna()
w = 100*(np.zeros_like(s) + 1. / len(s))
s.hist(bins=100,  cumulative=False)
# s.hist(bins=100,  cumulative=False, weights=w)
# Out:
# <AxesSubplot:>

# %%
s.hist(bins=100,  cumulative=False, weights=w)
# Out:
# <AxesSubplot:>

# %%
s.hist(bins=100, density=True)
# Out:
# <AxesSubplot:>
