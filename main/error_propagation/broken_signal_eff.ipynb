# %%
def relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true):
    # d_epsilon_sig = abs(sig_eff - sig_eff_true)
    # d_epsilon_ref = abs(ref_eff - ref_eff_true)
    d_epsilon_sig = sig_eff - sig_eff_true
    d_epsilon_ref = ref_eff - ref_eff_true
    rel_unc = d_epsilon_sig/sig_eff - d_epsilon_ref/ref_eff
    abs_rel_unc = abs(rel_unc)
    print(f"d_epsilon_sig/sig_eff = {d_epsilon_sig/sig_eff*100:.6f}%")
    print(f"d_epsilon_ref/ref_eff = {d_epsilon_ref/ref_eff*100:.6f}%")

    print(f"rel_unc = {abs_rel_unc*100:.6f}%")
    # print(f"rel_unc = {abs_rel_unc:.6f}")

# %%
#D+ -> eta_gg K+, pi+
sig_eff_true = 0.045197
sig_eff = 0.045523

ref_eff_true = 0.062680
ref_eff = 0.063126
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 0.716122%
# d_epsilon_ref/ref_eff = 0.706523%
# rel_unc = 0.009598%

# %%
#D+ -> eta_3pi K+, pi+
sig_eff_true = 0.036820
sig_eff = 0.038100

ref_eff_true = 0.050859
ref_eff = 0.052408
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 3.359580%
# d_epsilon_ref/ref_eff = 2.955656%
# rel_unc = 0.403924%

# %%
#D_s+ -> eta_gg K+, pi+
sig_eff_true = 0.038174
sig_eff = 0.038620

ref_eff_true = 0.053826
ref_eff = 0.054430
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 1.154842%
# d_epsilon_ref/ref_eff = 1.109682%
# rel_unc = 0.045160%

# %%
#D_s+ -> eta_3pi K+, pi+
sig_eff_true = 0.027118
sig_eff = 0.027621

ref_eff_true = 0.038457
ref_eff = 0.039159
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 1.821078%
# d_epsilon_ref/ref_eff = 1.792691%
# rel_unc = 0.028387%

# %%
#D+ -> eta_gg K+, pi+
sig_eff_true = 0.055137
sig_eff = 0.055650

ref_eff_true = 0.075684
ref_eff = 0.076356
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 0.921833%
# d_epsilon_ref/ref_eff = 0.880088%
# rel_unc = 0.041745%

# %%
#D+ -> eta_3pi K+, pi+
sig_eff_true = 0.054688
sig_eff = 0.056526

ref_eff_true = 0.073031
ref_eff = 0.075213
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 3.251601%
# d_epsilon_ref/ref_eff = 2.901094%
# rel_unc = 0.350507%

# %%
#D_s+ -> eta_gg K+, pi+
sig_eff_true = 0.048212 
sig_eff = 0.048909

ref_eff_true = 0.067112
ref_eff = 0.068025
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 1.425096%
# d_epsilon_ref/ref_eff = 1.342154%
# rel_unc = 0.082942%

# %%
#D_s+ -> eta_3pi K+, pi+
sig_eff_true = 0.048466 
sig_eff = 0.049451

ref_eff_true = 0.065834
ref_eff = 0.067130
relative_unc(sig_eff, sig_eff_true, ref_eff, ref_eff_true)
# Out:
# d_epsilon_sig/sig_eff = 1.991871%
# d_epsilon_ref/ref_eff = 1.930582%
# rel_unc = 0.061288%
