# %%
Br_kpi = 0.039500000
Br_kpipipi = 0.008800000
Br_kk = 0.004080000

# %%
import math

# Given values
y = 1795
dy = math.sqrt(y)
x = 43542
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kpi
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.041225 ± 0.000993
# 1.736935 sigma difference

# %%
import math

# Given values
y = 17129
dy = math.sqrt(y)
x = 433552
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kpi
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.039509 ± 0.000308
# 0.027698 sigma difference

# %%
# Decay D0sig
# 1.000 K- pi+ PHSP;
# Enddecay

# %%
import math

# Given values
y = 2298
dy = math.sqrt(y)
x = 60584
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kpi
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.037931 ± 0.000806
# -1.946593 sigma difference

# %%
60584/100000
# Out:
# 0.60584

# %%
# Decay D0
# 1.000 K- pi+ PHSP;
# Enddecay

# %%
import math

# Given values
y = 239
dy = math.sqrt(y)
x = 6065
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kpi
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.039406 ± 0.002599
# -0.036006 sigma difference

# %%
#D0 -> k pipipi

# %%
# Given values
y = 37452
dy = math.sqrt(y)
x = 432676
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kpipipi
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.086559 ± 0.000466
# 166.782041 sigma difference

# %%
# Given values
y = 173
dy = math.sqrt(y)
x = 43548
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kk
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.003973 ± 0.000303
# -0.354793 sigma difference

# %%
# Given values
y = 3428/2
dy = math.sqrt(y)
x = 433706
dx = math.sqrt(x)

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error

difference = f - Br_kk
sigma = difference / df

print(f"f = {f:.6f} ± {df:.6f}")
print(f"{sigma:.6f} sigma difference")
# Out:
# f = 0.003952 ± 0.000096
# -1.338417 sigma difference

# %%
# Given values
x = 0.9718
dx =0.0037
y = 0.9728
dy = 0.0013

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.001029 ± 0.004039

# %%
# Given values
x = 0.9722
dx =0.0037
y = 0.9730
dy = 0.0013

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.000823 ± 0.004037

# %%
# Given values
x = 0.9716
dx =0.0037
y = 0.9729
dy = 0.0013

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.001338 ± 0.004041

# %%
# Given values
x = 0.9715
dx =0.0034
y = 0.9732
dy = 0.0014

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.001750 ± 0.003790

# %%
# Given values
x = 97.1721
dx = 0.3827
y = 97.3506
dy = 0.1304

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.001837 ± 0.004168

# %%
# Given values
x = 97.1273
dx = 0.3690
y = 97.3544
dy = 0.1360

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.002338 ± 0.004057

# %%
# Given values
x = 97.2245
dx = 0.3973
y =  97.4114 
dy = 0.1368

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.001922 ± 0.004329

# %%
# Given values
x = 97.1457 
dx = 0.3716
y = 97.4227
dy = 0.1428

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 1.002851 ± 0.004108

# %%
# Given values
x = 1.000613
dx = 0.005203
y =  0.993316
dy = 0.001770

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 0.992707 ± 0.005457

# %%
# Given values
x = 0.996498
dx =  0.004276
y = 0.993925
dy = 0.001395

f = y / x
# Relative error propagation
rel_error = math.sqrt((dy / y) ** 2 + (dx / x) ** 2)
# Absolute uncertainty
df = f * rel_error


print(f"f = {f:.6f} ± {df:.6f}")
# Out:
# f = 0.997418 ± 0.004503
