# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
# Out:
# Welcome to JupyROOT 6.26/04

# %%
#base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
#Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'
base_file_loc = '/media/jykim/T7/storage/01_recon/v15_sig_ext_sigbkg_1ab/'
Vg_ccbar = base_file_loc + 'topo/resultfile/result_rho/standard.root'

# phigamma_ccbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ccbar/topo/trainv2_sigbkg_sigextract_phi/topoana.root'
# phigamma_uubar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/uubar/train_v2_signalextraction_sigbkg_uubar_recon_output_0*.root'
# phigamma_ddbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ddbar/train_v2_signalextraction_sigbkg_ddbar_recon_output_0*.root'
# phigamma_ssbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ssbar/train_v2_signalextraction_sigbkg_ssbar_recon_output_0*.root'
# phigamma_charged = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/charged/train_v2_signalextraction_sigbkg_charged_recon_output_0*.root'
# phigamma_mixed = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/mixed/train_v2_signalextraction_sigbkg_mixed_recon_output_0*.root'
# phigamma_taupair = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/taupair/train_v2_signalextraction_sigbkg_taupair_recon_output_0*.root'

#base_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06'
ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==3)'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<1.90 && ( iCascDcyBrP_Dst_0 ==0 || iCascDcyBrP_Dst_0 ==3)'
#ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==54)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0']
tree='rho'

# %%
pd_Vgamma_ccbar = get_np(file=Vg_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)

# %%
fitting_region = (1.67, 1.90)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(100)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.83, 1.88)
# mean2 = ROOT.RooRealVar("mean2", "mean of gaussians", 1.865,1.85, 1.88)

#sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.03,0,0.1)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0,0.1)
alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0.1,3)
n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 4,0,10)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 5,0.5,10)    
Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 3,0.5,10)    


    
sig = ROOT.RooCBShape("sig", "Signal component 2", x, mean, sigma2, alpha, n_CB)
#sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean2, sigma1)


# sig2= ROOT.RooNovosibirsk("sig2", "Signal component 3", x, mean2, Novo_width, Novo_tail)


# sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.2, 0.0, 1.0)
# sig = ROOT.RooAddPdf("sig", "Signal1", [sig1, sig2], sig1frac)


data = ROOT.RooDataSet.from_numpy({"M(D^{0})": pd_Vgamma_ccbar['D0_M']}, [x])
r = sig.fitTo(data,NumCPU=12, Range=fitting_region)


# data = rooDataSet



# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))
# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

sig.plotOn(frame, Name="fitting",)


# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.67,1.9]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.67,1.9]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_sig_' created with bounds [1.67,1.9]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **  136 **SET PRINT           1
#  **********
#  **********
#  **  137 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        5.00000e-01  2.00000e-01    1.00000e-01  3.00000e+00
#      2 mean         1.86000e+00  5.00000e-03    1.83000e+00  1.88000e+00
#      3 n_CB         4.00000e+00  1.00000e+00    0.00000e+00  1.00000e+01
#      4 sigma2       3.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#  **********
#  **  138 **SET ERR         0.5
#  **********
#  **********
#  **  139 **SET PRINT           1
#  **********
#  **********
#  **  140 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  141 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-14656.1 FROM MIGRAD    STATUS=INITIATE       38 CALLS          39 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        5.00000e-01   2.00000e-01   0.00000e+00  -1.89353e+03
#    2  mean         1.83378e+00   5.00000e-03  -1.21541e+00  -4.37261e+01
#    3  n_CB         4.00000e+00   1.00000e+00   0.00000e+00  -1.84343e+02
#    4  sigma2       3.00000e-02   1.00000e-02   0.00000e+00   2.48884e+03
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-13608.8) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.846368	mean=1.83463	n_CB=6.19223	sigma2=0.000774824
# PID44389/RooRealMPFE::nll_sig__55950c4d0700_MPFE11[ arg=nll_sig__GOF11 vars=(alpha,mean,n_CB,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.8689, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.86922, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.88349, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.86534, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.88186, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.89042, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.86887, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.8714, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.86638, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.87492, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.88123, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#      getLogVal() top-level p.d.f evaluates to zero @ m=M(D^{0})=1.87522, m0=mean=1.83463, sigma=sigma2=0.000774824, alpha=alpha=0.846368, n=n_CB=6.19223
#     ... (remaining 1014 messages suppressed)
# RooNLLVar::nll_sig_[ paramSet=(alpha,mean,n_CB,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 0.846368,mean = 1.83463,n_CB = 6.19223,sigma2 = 0.000774824)
#
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-15144 FROM MIGRAD    STATUS=CONVERGED     177 CALLS         178 TOTAL
#                      EDM=1.23182e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        6.12891e-01   4.62280e-02   8.62575e-04   3.37807e-03
#    2  mean         1.83781e+00   7.45764e-04   1.54459e-03   3.46152e-02
#    3  n_CB         3.50435e+00   6.22175e-01   3.68242e-03   3.91599e-03
#    4  sigma2       2.02212e-02   5.01203e-04   5.13906e-04   6.07229e-02
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.138e-03 -2.744e-05 -2.599e-02  1.662e-05
#  -2.744e-05  5.565e-07  2.656e-04 -3.166e-07
#  -2.599e-02  2.656e-04  3.893e-01 -1.442e-04
#   1.662e-05 -3.166e-07 -1.442e-04  2.512e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.97007   1.000 -0.796 -0.901  0.717
#         2  0.89689  -0.796  1.000  0.571 -0.847
#         3  0.94337  -0.901  0.571  1.000 -0.461
#         4  0.87480   0.717 -0.847 -0.461  1.000
#  **********
#  **  142 **SET ERR         0.5
#  **********
#  **********
#  **  143 **SET PRINT           1
#  **********
#  **********
#  **  144 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-15144 FROM HESSE     STATUS=OK             23 CALLS         201 TOTAL
#                      EDM=1.23902e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        6.12891e-01   4.64154e-02   3.45030e-05  -7.02702e-01
#    2  mean         1.83781e+00   7.48328e-04   6.17834e-05  -7.58320e-01
#    3  n_CB         3.50435e+00   6.24683e-01   1.47297e-04  -3.03781e-01
#    4  sigma2       2.02212e-02   5.03085e-04   2.05562e-05  -6.37982e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   2.156e-03 -2.766e-05 -2.622e-02  1.676e-05
#  -2.766e-05  5.603e-07  2.677e-04 -3.194e-07
#  -2.622e-02  2.677e-04  3.925e-01 -1.454e-04
#   1.676e-05 -3.194e-07 -1.454e-04  2.531e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.97031   1.000 -0.796 -0.901  0.717
#         2  0.89763  -0.796  1.000  0.571 -0.848
#         3  0.94384  -0.901  0.571  1.000 -0.461
#         4  0.87580   0.717 -0.848 -0.461  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) only plotting range 'fit_nll_sig_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
fitting_region = (-1, 1)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(100)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.83, 1.88)
# mean2 = ROOT.RooRealVar("mean2", "mean of gaussians", 1.865,1.85, 1.88)

#sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.03,0,0.1)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0,0.1)
alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0.1,3)
n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 4,0,10)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 5,0.5,10)    
Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 3,0.5,10)    


    
sig = ROOT.RooCBShape("sig", "Signal component 2", x, mean, sigma2, alpha, n_CB)
#sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean2, sigma1)


# sig2= ROOT.RooNovosibirsk("sig2", "Signal component 3", x, mean2, Novo_width, Novo_tail)


# sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.2, 0.0, 1.0)
# sig = ROOT.RooAddPdf("sig", "Signal1", [sig1, sig2], sig1frac)


data = ROOT.RooDataSet.from_numpy({"M(D^{0})": pd_Vgamma_ccbar['D0_cosHel_0']}, [x])
r = sig.fitTo(data,NumCPU=12, Range=fitting_region)


# data = rooDataSet



# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))
# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

sig.plotOn(frame, Name="fitting",)


# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [-1,1]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [-1,1]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_sig_' created with bounds [-1,1]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **  145 **SET PRINT           1
#  **********
#  **********
#  **  146 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        5.00000e-01  2.00000e-01    1.00000e-01  3.00000e+00
#      2 mean         1.86000e+00  5.00000e-03    1.83000e+00  1.88000e+00
#      3 n_CB         4.00000e+00  1.00000e+00    0.00000e+00  1.00000e+01
#      4 sigma2       3.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#  **********
#  **  147 **SET ERR         0.5
#  **********
#  **********
#  **  148 **SET PRINT           1
#  **********
#  **********
#  **  149 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  150 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=5528.72 FROM MIGRAD    STATUS=INITIATE       62 CALLS          63 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.00211e-01   2.00000e-01   0.00000e+00  -2.07599e-05
#    2  mean         1.86000e+00   5.00000e-03   0.00000e+00  -6.55535e-04
#    3  n_CB         4.01160e-04   1.00000e+00  -1.35677e+00   2.73921e+01
#    4  sigma2       3.00000e-02   1.00000e-02   0.00000e+00   1.18484e-04
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 4 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=5528.54 FROM MIGRAD    STATUS=CONVERGED      94 CALLS          95 TOTAL
#                      EDM=8.09689e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.00000e-01   6.66561e-01   2.78432e-02** at limit **
#    2  mean         1.87253e+00   1.49954e-02   5.00000e-01  -1.15051e-09
#    3  n_CB         9.39099e-10   1.15870e-03   1.10334e-03** at limit **
#    4  sigma2       3.11611e-02   3.89729e-02   7.52806e-02  -2.41628e-10
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   9.012e-11 -3.552e-17 -5.265e-17 -9.764e-16
#  -3.552e-17  3.176e-04  2.023e-12  8.241e-13
#  -5.265e-17  2.023e-12  4.353e-12  1.859e-12
#  -9.764e-16  8.241e-13  1.859e-12  2.145e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.00000   1.000 -0.000 -0.000 -0.000
#         2  0.00005  -0.000  1.000  0.000  0.000
#         3  0.00006  -0.000  0.000  1.000  0.000
#         4  0.00002  -0.000  0.000  0.000  1.000
#  **********
#  **  151 **SET ERR         0.5
#  **********
#  **********
#  **  152 **SET PRINT           1
#  **********
#  **********
#  **  153 **HESSE        2000
#  **********
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -6.8899e-01  5.7931e-01  1.3351e+00  2.7746e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.691761 TO DIAGONAL.
#  FCN=5528.54 FROM HESSE     STATUS=NOT POSDEF     31 CALLS         126 TOTAL
#                      EDM=1.50202e-06    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        1.00000e-01   1.50104e+00   5.00000e-01  -1.57079e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    2  mean         1.87253e+00   2.62329e-02   5.00000e-01   7.06047e+00
#    3  n_CB         9.39099e-10   3.62801e-03   2.20669e-04  -1.57078e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    4  sigma2       3.11611e-02   6.38032e-02   5.00000e-01  -2.75528e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   5.569e+00  5.631e+02  7.742e-06  1.461e+05
#   5.631e+02  2.466e+05  9.558e-04  1.488e+07
#   7.742e-06  9.558e-04  1.363e-11  2.046e-01
#   1.461e+05  1.488e+07  2.046e-01  3.847e+09
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.99831   1.000  0.481  0.889  0.998
#         2  0.52286   0.481  1.000  0.521  0.483
#         3  0.90064   0.889  0.521  1.000  0.893
#         4  0.99838   0.998  0.483  0.893  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) only plotting range 'fit_nll_sig_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
#base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
#Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'
base_file_loc = '/media/jykim/T7/storage/01_recon/v15_sig_ext_sigbkg_1ab/'
Vg_ccbar = base_file_loc + 'topo/resultfile/result_rho/standard.root'

# phigamma_ccbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ccbar/topo/trainv2_sigbkg_sigextract_phi/topoana.root'
# phigamma_uubar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/uubar/train_v2_signalextraction_sigbkg_uubar_recon_output_0*.root'
# phigamma_ddbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ddbar/train_v2_signalextraction_sigbkg_ddbar_recon_output_0*.root'
# phigamma_ssbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ssbar/train_v2_signalextraction_sigbkg_ssbar_recon_output_0*.root'
# phigamma_charged = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/charged/train_v2_signalextraction_sigbkg_charged_recon_output_0*.root'
# phigamma_mixed = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/mixed/train_v2_signalextraction_sigbkg_mixed_recon_output_0*.root'
# phigamma_taupair = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/taupair/train_v2_signalextraction_sigbkg_taupair_recon_output_0*.root'

#base_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06'
ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==3)'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 !=0 && iCascDcyBrP_Dst_0 !=3 && iCascDcyBrP_Dst_0 !=58 && iCascDcyBrP_Dst_0 !=230)'
#ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==54)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0']
tree='rho'

# %%
pd_Vgamma_ccbar = get_np(file=Vg_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)

# %%
fitting_region = (1.67, 2.06)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(100)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.83, 1.88)
# mean2 = ROOT.RooRealVar("mean2", "mean of gaussians", 1.865,1.85, 1.88)

#sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.03,0,0.1)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0,0.1)
alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0.1,3)
n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 4,0,10)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 5,0.5,10)    
Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 3,0.5,10)    


    
sig = ROOT.RooCBShape("sig", "Signal component 2", x, mean, sigma2, alpha, n_CB)
#sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean2, sigma1)


# sig2= ROOT.RooNovosibirsk("sig2", "Signal component 3", x, mean2, Novo_width, Novo_tail)


# sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.2, 0.0, 1.0)
# sig = ROOT.RooAddPdf("sig", "Signal1", [sig1, sig2], sig1frac)


data = ROOT.RooDataSet.from_numpy({"M(D^{0})": pd_Vgamma_ccbar['D0_M']}, [x])
r = sig.fitTo(data,NumCPU=12, Range=fitting_region)


# data = rooDataSet



# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))
# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

sig.plotOn(frame, Name="fitting",)


# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.67,2.06]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.67,2.06]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_sig_' created with bounds [1.67,2.06]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **  181 **SET PRINT           1
#  **********
#  **********
#  **  182 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        5.00000e-01  2.00000e-01    1.00000e-01  3.00000e+00
#      2 mean         1.86000e+00  5.00000e-03    1.83000e+00  1.88000e+00
#      3 n_CB         4.00000e+00  1.00000e+00    0.00000e+00  1.00000e+01
#      4 sigma2       3.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#  **********
#  **  183 **SET ERR         0.5
#  **********
#  **********
#  **  184 **SET PRINT           1
#  **********
#  **********
#  **  185 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  186 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=1652.61 FROM MIGRAD    STATUS=INITIATE       37 CALLS          38 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        5.00000e-01   2.00000e-01   0.00000e+00   3.60029e+02
#    2  mean         1.86000e+00   5.00000e-03   0.00000e+00  -3.72038e+03
#    3  n_CB         1.73344e-01   1.00000e+00  -1.10535e+00   1.88345e+03
#    4  sigma2       3.00000e-02   1.00000e-02   0.00000e+00  -3.40643e+04
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-7255.44 FROM MIGRAD    STATUS=CONVERGED     337 CALLS         338 TOTAL
#                      EDM=9.78223e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.00000e-01   6.12405e-03   5.40698e-03** at limit **
#    2  mean         1.83044e+00   4.29716e-03   3.00691e-02  -3.04465e-03
#    3  n_CB         2.20740e-10   4.27900e-05   2.47514e-04** at limit **
#    4  sigma2       1.00000e-01   7.37924e-05   3.20503e-03** at limit **
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.190e-08 -9.997e-11 -3.762e-16  1.016e-16
#  -9.997e-11  7.949e-06  7.816e-14 -2.935e-12
#  -3.762e-16  7.816e-14  3.778e-14  9.709e-20
#   1.016e-16 -2.935e-12  9.709e-20  1.263e-13
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.00033   1.000 -0.000 -0.000  0.000
#         2  0.00295  -0.000  1.000  0.000 -0.003
#         3  0.00014  -0.000  0.000  1.000  0.000
#         4  0.00293   0.000 -0.003  0.000  1.000
#  **********
#  **  187 **SET ERR         0.5
#  **********
#  **********
#  **  188 **SET PRINT           1
#  **********
#  **********
#  **  189 **HESSE        2000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-7255.44 FROM HESSE     STATUS=OK             33 CALLS         371 TOTAL
#                      EDM=0.00010242    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        1.00000e-01   6.12486e-03   1.08140e-03  -1.57161e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    2  mean         1.83044e+00   4.08814e-03   1.22682e-01  -1.75969e+00
#    3  n_CB         2.20740e-10   8.49290e-05   8.68175e-03  -1.57081e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    4  sigma2       1.00000e-01   7.37926e-05   6.41007e-04   1.57067e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   1.191e-08 -1.074e-11  1.812e-15 -8.818e-19
#  -1.074e-11  7.550e-06  6.607e-12 -2.656e-13
#   1.812e-15  6.607e-12  7.499e-14  2.480e-19
#  -8.818e-19 -2.656e-13  2.480e-19  1.263e-13
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.00007   1.000 -0.000  0.000 -0.000
#         2  0.00878  -0.000  1.000  0.009 -0.000
#         3  0.00878   0.000  0.009  1.000  0.000
#         4  0.00027  -0.000 -0.000  0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) only plotting range 'fit_nll_sig_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
fitting_region = (-1, 1)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(100)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.83, 1.88)
# mean2 = ROOT.RooRealVar("mean2", "mean of gaussians", 1.865,1.85, 1.88)

#sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.03,0,0.1)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0,0.1)
alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0.1,3)
n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 4,0,10)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 5,0.5,10)    
Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 3,0.5,10)    


    
sig = ROOT.RooCBShape("sig", "Signal component 2", x, mean, sigma2, alpha, n_CB)
#sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean2, sigma1)


# sig2= ROOT.RooNovosibirsk("sig2", "Signal component 3", x, mean2, Novo_width, Novo_tail)


# sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.2, 0.0, 1.0)
# sig = ROOT.RooAddPdf("sig", "Signal1", [sig1, sig2], sig1frac)


data = ROOT.RooDataSet.from_numpy({"M(D^{0})": pd_Vgamma_ccbar['D0_cosHel_0']}, [x])
r = sig.fitTo(data,NumCPU=12, Range=fitting_region)


# data = rooDataSet



# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))
# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

sig.plotOn(frame, Name="fitting",)


# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [-1,1]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [-1,1]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_sig_' created with bounds [-1,1]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **  190 **SET PRINT           1
#  **********
#  **********
#  **  191 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        5.00000e-01  2.00000e-01    1.00000e-01  3.00000e+00
#      2 mean         1.86000e+00  5.00000e-03    1.83000e+00  1.88000e+00
#      3 n_CB         4.00000e+00  1.00000e+00    0.00000e+00  1.00000e+01
#      4 sigma2       3.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#  **********
#  **  192 **SET ERR         0.5
#  **********
#  **********
#  **  193 **SET PRINT           1
#  **********
#  **********
#  **  194 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  195 **MIGRAD        2000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=4903.33 FROM MIGRAD    STATUS=INITIATE       64 CALLS          65 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.00144e-01   2.00000e-01   0.00000e+00  -7.23670e-07
#    2  mean         1.86000e+00   5.00000e-03   0.00000e+00  -2.88464e-05
#    3  n_CB         3.84658e-06   1.00000e+00  -1.36820e+00   3.79381e+00
#    4  sigma2       3.00000e-02   1.00000e-02   0.00000e+00   5.42139e-06
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 4 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=4903.32 FROM MIGRAD    STATUS=CONVERGED      96 CALLS          97 TOTAL
#                      EDM=1.89195e-13    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.00000e-01   6.66561e-01   2.63170e-02** at limit **
#    2  mean         1.83032e+00   1.13439e-02   5.00000e-01   4.54747e-12
#    3  n_CB         0.00000e+00   8.05060e-04   8.74374e-04** at limit **
#    4  sigma2       2.68372e-02   3.72866e-02   7.10943e-02  -3.19820e-11
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   4.416e-10 -8.817e-18 -9.363e-20 -1.225e-15
#  -8.817e-18  1.605e-05  7.670e-17  2.483e-13
#  -9.363e-20  7.670e-17  4.907e-19  1.676e-15
#  -1.225e-15  2.483e-13  1.676e-15  1.963e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.00001   1.000 -0.000 -0.000 -0.000
#         2  0.00003  -0.000  1.000  0.000  0.000
#         3  0.00006  -0.000  0.000  1.000  0.000
#         4  0.00005  -0.000  0.000  0.000  1.000
#  **********
#  **  196 **SET ERR         0.5
#  **********
#  **********
#  **  197 **SET PRINT           1
#  **********
#  **********
#  **  198 **HESSE        2000
#  **********
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=4903.32 FROM HESSE     STATUS=OK             27 CALLS         124 TOTAL
#                      EDM=1.88749e-13    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        1.00000e-01   6.66561e-01   2.63170e-02  -1.57081e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    2  mean         1.83032e+00   1.13439e-02   5.00000e-01   4.55144e+00
#    3  n_CB         0.00000e+00   8.05060e-04   1.74875e-04  -1.57080e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    4  sigma2       2.68372e-02   3.72866e-02   5.00000e-01  -2.65993e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  4    ERR DEF=0.5
#   4.416e-10  5.230e-18 -1.884e-20 -1.396e-16
#   5.230e-18  1.605e-05  1.534e-17  8.228e-15
#  -1.884e-20  1.534e-17  4.907e-19  2.838e-16
#  -1.396e-16  8.228e-15  2.838e-16  1.963e-03
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4
#         1  0.00000   1.000  0.000 -0.000 -0.000
#         2  0.00001   0.000  1.000  0.000  0.000
#         3  0.00001  -0.000  0.000  1.000  0.000
#         4  0.00001  -0.000  0.000  0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) only plotting range 'fit_nll_sig_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==3)'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==2 || iCascDcyBrP_Dst_0 ==13)'
# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==2)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0']
tree='rho'

# %%
pd_Vgamma_ccbar = get_np(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)

# %%
pd_Vgamma_ccbar = get_np(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)
plt.hist(pd_Vgamma_ccbar['D0_M'], bins=50);
print(len(pd_Vgamma_ccbar['D0_M']))
# Out:
# 9783

# %%
base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==3)'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 !=2 && iCascDcyBrP_Dst_0 !=13  && iCascDcyBrP_Dst_0 !=54)'
# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==2)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0']
tree='rho'

# %%
pd_Vgamma_ccbar = get_pd(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)
plt.hist(pd_Vgamma_ccbar['D0_M'], bins=50);
print(len(pd_Vgamma_ccbar['D0_M']))
# Out:
# 9795

# %%
n = 10
pd_Vgamma_ccbar['iCascDcyBrP_Dst_0'].value_counts()[:n].index.tolist()
# Out:
# [0, -1, 16, 26, 52, 67, 6, 89, 41, 30]

# %%
base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==0)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==2)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0']
tree='rho'

# %%
pd_Vgamma_ccbar = get_pd(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)
plt.hist(pd_Vgamma_ccbar['D0_M'], bins=50);
print(len(pd_Vgamma_ccbar['D0_M']))
# Out:
# 2795

# %%
base_file_loc = '/media/jykim/T7/storage/pi0veto_skim_1ab_inv_bkg_sig/'
Vgamma_ccbar = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/topo/topo_rho_D0_M/topoana.root'

ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && ( iCascDcyBrP_Dst_0 ==54)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.72 && D0_M<1.93 && ( iCascDcyBrP_Dst_0 ==2)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0','Rho_CMS_p','Rho_CMS_p']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0','Rho_CMS_p','Rho_p']
tree='rho'

# %%
pd_Vgamma_ccbar = get_pd(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)
plt.hist(pd_Vgamma_ccbar['Rho_p'], bins=50);
print(len(pd_Vgamma_ccbar['D0_M']))
# Out:
# 325

# %% [markdown]
# # generic MC

# %%
base_file_loc = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/'
Vgamma_ccbar = base_file_loc + 'topo/topo_rho_D0_M/topoana.root'
Vgamma_uubar = base_file_loc + 'uubar/recon_udst_*.root'
Vgamma_ddbar = base_file_loc + 'ddbar/recon_udst_*.root'
Vgamma_ssbar = base_file_loc + 'ssbar/recon_udst_*.root'
Vgamma_charged = base_file_loc + 'charged/recon_udst_*.root'
Vgamma_mixed = base_file_loc + 'mixed/recon_udst_*.root'
Vgamma_taupair = base_file_loc + 'taupair/recon_udst_*.root'


# phigamma_ccbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ccbar/topo/trainv2_sigbkg_sigextract_phi/topoana.root'
# phigamma_uubar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/uubar/train_v2_signalextraction_sigbkg_uubar_recon_output_0*.root'
# phigamma_ddbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ddbar/train_v2_signalextraction_sigbkg_ddbar_recon_output_0*.root'
# phigamma_ssbar = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/ssbar/train_v2_signalextraction_sigbkg_ssbar_recon_output_0*.root'
# phigamma_charged = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/charged/train_v2_signalextraction_sigbkg_charged_recon_output_0*.root'
# phigamma_mixed = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/mixed/train_v2_signalextraction_sigbkg_mixed_recon_output_0*.root'
# phigamma_taupair = '/media/jykim/T7/storage/01_recon/merge_generic_bkg/taupair/train_v2_signalextraction_sigbkg_taupair_recon_output_0*.root'

base_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06'
ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06'
# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=5 )'
#
variables=['D0_M','D0_cosHel_0','Rho_CMS_p','Rho_p']
topo_variables=['D0_M','D0_cosHel_0','iCascDcyBrP_Dst_0','Rho_CMS_p','Rho_p']
tree='rho'

# %%
pd_Vgamma_ccbar = get_pd(file=Vgamma_ccbar, tree=tree,base_filter=ccbar_filter,variables=topo_variables)
pd_Vgamma_uubar = get_pd(file=Vgamma_uubar, tree=tree,base_filter=base_filter,variables=variables)
pd_Vgamma_ddbar = get_pd(file=Vgamma_ddbar, tree=tree,base_filter=base_filter,variables=variables)
pd_Vgamma_ssbar = get_pd(file=Vgamma_ssbar, tree=tree,base_filter=base_filter,variables=variables)
pd_Vgamma_charged = get_pd(file=Vgamma_charged, tree=tree,base_filter=base_filter,variables=variables)
pd_Vgamma_mixed = get_pd(file=Vgamma_mixed, tree=tree,base_filter=base_filter,variables=variables)
pd_Vgamma_taupair = get_pd(file=Vgamma_taupair, tree=tree,base_filter=base_filter,variables=variables)

# %%
Vgamma_generic=pd.concat([pd_Vgamma_ccbar,
                           pd_Vgamma_uubar,
                           pd_Vgamma_ddbar,
                           pd_Vgamma_ssbar,
                           pd_Vgamma_charged,
                           pd_Vgamma_mixed,
                           pd_Vgamma_taupair],ignore_index=True)

# %%
plt.hist(Vgamma_generic.D0_M, bins=50);

# %%
plt.hist(pd_Vgamma_ccbar.Rho_p, bins=50);

# %%
Vgamma_generic=pd.concat([pd_Vgamma_uubar,
                           pd_Vgamma_ddbar,
                           pd_Vgamma_ssbar,
                           pd_Vgamma_charged,
                           pd_Vgamma_mixed,
                           pd_Vgamma_taupair],ignore_index=True)

# %%
plt.hist(Vgamma_generic.D0_M, bins=50);

# %%
plt.hist(Vgamma_generic.D0_cosHel_0, bins=50);

# %%
plt.hist(Vgamma_generic.Rho_p, bins=50);
