# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style") 
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
# Out:
# Welcome to JupyROOT 6.26/04

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_ref_sig_ext_naive_skim/'

base_filter =  'D0_M>1.67 && D0_M<2.06 '
# base_filter += '&& Dstarp_isSignal!=1'
tree = 'ref_omega'

variables=['D0_M','Dstarp_Q','Dstarp_CMS_p','__ncandidates__','Dstarp_isSignal']
var = 'D0_M'

# %%
ccbar_0 = base_file_loc + 'topo/resultfile/result_ref_omega/standard.root'
ccbar_0 = base_file_loc + 'topo/generic_ccbar.root'

# ccbar_0 = base_file_loc + 'generic_ccbar.root'

uubar_0 = base_file_loc + 'generic_uubar.root'
ddbar_0 = base_file_loc + 'generic_ddbar.root'
ssbar_0 = base_file_loc + 'generic_ssbar.root'
charged_0 = base_file_loc + 'generic_charged.root'
mixed_0 = base_file_loc + 'generic_mixed.root'
taupair_0 = base_file_loc + 'generic_taupair.root'

# %%
base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar_0 = get_pd(file=ccbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_uubar_0 = get_pd(file=uubar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_ddbar_0 = get_pd(file=ddbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar_0 = get_pd(file=ssbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_charged_0 = get_pd(file=charged_0, tree=tree,base_filter=base_filter,variables=variables)

pd_mixed_0 = get_pd(file=mixed_0, tree=tree,base_filter=base_filter,variables=variables)

pd_taupair_0 = get_pd(file=taupair_0, tree=tree,base_filter=base_filter,variables=variables)

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.67,2.06)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["__ncandidates__"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(0,6)
    xbins = np.linspace(*xrange,7)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black',align="left")
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=5, range=(1,6))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("ncandidates")
    width = xe[1]-xe[0]
    plt.ylabel('Entries');
    plt.show()
    plt.clf()
# Out:
# __ncandidates__

# %%
# pd_ccbar = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_uubar = get_pd(file=file_uubar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ddbar = get_pd(file=file_ddbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ssbar = get_pd(file=file_ssbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_charged = get_pd(file=file_charged, tree=tree,base_filter=base_filter,variables=variables)
# pd_mixed = get_pd(file=file_mixed, tree=tree,base_filter=base_filter,variables=variables)
# pd_taupair = get_pd(file=file_taupair, tree=tree,base_filter=base_filter,variables=variables)


pd_all_generic = pd.concat([pd_ccbar_0, pd_uubar_0, pd_ddbar_0, pd_ssbar_0, pd_charged_0, pd_mixed_0, pd_taupair_0], ignore_index=True)

pd_all_generic.describe()
# Out:
#                D0_M      Dstarp_Q  Dstarp_CMS_p  __ncandidates__  \
# count  29287.000000  29287.000000  29287.000000     29287.000000
# mean       1.864299      0.005876      3.532175         1.007239
# std        0.010304      0.000323      0.532385         0.084774
# min        1.830004      0.004930      2.750013         1.000000
# 25%        1.860385      0.005724      3.076738         1.000000
# 50%        1.864729      0.005862      3.455348         1.000000
# 75%        1.868742      0.006008      3.924301         1.000000
# max        1.899996      0.006930      5.188950         2.000000
#
#        Dstarp_isSignal
# count     28783.000000
# mean          0.838412
# std           0.368079
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %%
N_isSignal_1 = len(pd_all_generic.query('Dstarp_isSignal==1'))
print(N_isSignal_1)
# Out:
# 24132

# %%
np_data = pd_all_generic['D0_M'].to_numpy()

# %%
fitting_region = (1.83, 1.90)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(70)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.85, 1.87)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.02,0.001,0.05)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.01,0.001,0.05)
# alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
# n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 20,0,100)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    


    
sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean, sigma2)

sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)





data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

# data = rooDataSet

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))


r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


# extended_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)

# extended_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)


extended_model.plotOn(frame, Name="sig", Components=ROOT.RooArgSet(sig1,sig2), LineStyle=ROOT.kDashed, LineColor=ROOT.kRed)



extended_model.plotOn(frame, Name="bkg", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)

extended_model.plotOn(frame, Name="fitting")





# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")

leg1 = ROOT.TLegend(0.65, 0.6, 0.9, 0.85)
# leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(0)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
# leg1.AddEntry("sig1", "sig1", "l")
# leg1.AddEntry("sig2", "sig1", "l")

leg1.AddEntry("sig", "sig", "l")
leg1.AddEntry("bkg", "bkg", "l")
leg1.SetTextSize(0.05)
leg1.SetBorderSize(0)

leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.83,1.9]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.83,1.9]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_extended_model_' created with bounds [1.83,1.9]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 c0           1.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 c1           5.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      3 mean         1.86000e+00  2.00000e-03    1.85000e+00  1.87000e+00
#      4 nbkg         5.85740e+03  2.92870e+03    0.00000e+00  2.92870e+04
#      5 nsig         2.34296e+04  2.92870e+03    0.00000e+00  2.92870e+04
#      6 sig1frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 sigma1       2.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#      8 sigma2       1.00000e-02  4.50000e-03    1.00000e-03  5.00000e-02
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   15 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-364018 FROM MIGRAD    STATUS=INITIATE       95 CALLS          96 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0          -9.96398e-01   2.00000e-01   0.00000e+00   7.12381e-01
#    2  c1           5.00000e-01   2.00000e-01   0.00000e+00  -3.53490e+00
#    3  mean         1.86000e+00   2.00000e-03   0.00000e+00  -1.30786e+04
#    4  nbkg         5.85740e+03   2.92870e+03   0.00000e+00   1.27590e+03
#    5  nsig         2.34296e+04   2.92870e+03   0.00000e+00  -3.19060e+02
#    6  sig1frac     5.00000e-01   1.00000e-01   0.00000e+00  -5.15350e+02
#    7  sigma1       7.07032e-03   4.90000e-03  -6.25024e-01   2.46387e+03
#    8  sigma2       1.00000e-02   4.50000e-03   0.00000e+00   3.22845e+03
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.979263	c1=-0.349339	mean=1.8647	nbkg=6719.35	nsig=21753.2	sig1frac=0.87915	sigma1=0.00475021	sigma2=0.00655077
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 69.7702,bkg_x_model = -2.03463/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 72.6445,bkg_x_model = -2.04596/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 80.4779,bkg_x_model = -2.03926/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 5.13445,bkg_x_model = -2.06739/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 54.0753,bkg_x_model = -2.03072/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 75.8955,bkg_x_model = -2.0448/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 76.1854,bkg_x_model = -2.03678/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.8876,bkg_x_model = -2.0479/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 42.5119,bkg_x_model = -2.02809/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 37.4651,bkg_x_model = -2.0269/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 81.0934,bkg_x_model = -2.04128/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 81.1205,bkg_x_model = -2.0412/-0.142908), !coefficients=(nsig = 21753.2,nbkg = 6719.35)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.979263,c1 = -0.349339,mean = 1.8647,nbkg = 6719.35,nsig = 21753.2,sig1frac = 0.87915,sigma1 = 0.00475021,sigma2 = 0.00655077)
#
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -2.7006e-02  1.1205e-02  1.0468e-01  2.5852e-01  8.3390e-01  9.9642e-01  1.3829e+00  4.4394e+00
#  MINUIT WARNING IN MIGRAD
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.031445 TO DIAGONAL.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 5.13997 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-369643 FROM HESSE     STATUS=OK             65 CALLS         602 TOTAL
#                      EDM=1.77836    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           9.99293e-01   8.12061e-02   4.34819e-01   3.45635e-02
#    2  c1           8.38655e-01   1.42246e+00   2.06333e-01   1.87956e+00
#    3  mean         1.86483e+00   3.74564e-05   1.78999e-03  -4.95235e-01
#    4  nbkg         5.89884e+03   1.62388e+02   3.53975e-03   1.28895e+00
#    5  nsig         2.33846e+04   2.09164e+02   5.76079e-03  -2.13690e+00
#    6  sig1frac     6.76942e-01   5.20817e-02   8.32347e-03   4.96153e-01
#    7  sigma1       4.04766e-03   1.29532e-04   1.33021e-03   6.54246e+00
#    8  sigma2       7.99955e-03   5.90648e-04   3.36688e-03  -1.92847e-01
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.995346	c1=-0.83876	mean=1.86484	nbkg=5960.77	nsig=23340.8	sig1frac=0.639092	sigma1=0.0039564	sigma2=0.00759844
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.7828,bkg_x_model = -0.0547439/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.726,bkg_x_model = -0.0653379/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 82.0538,bkg_x_model = -0.0590669/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.91572,bkg_x_model = -0.0854321/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.4257,bkg_x_model = -0.0511039/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.5709,bkg_x_model = -0.0642541/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 76.0438,bkg_x_model = -0.0567511/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.7762,bkg_x_model = -0.0671548/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.3564,bkg_x_model = -0.0486477/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.4711,bkg_x_model = -0.0475394/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 83.3649,bkg_x_model = -0.0609622/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 83.3793,bkg_x_model = -0.0608873/-0.00429928), !coefficients=(nsig = 23340.8,nbkg = 5960.77)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.995346,c1 = -0.83876,mean = 1.86484,nbkg = 5960.77,nsig = 23340.8,sig1frac = 0.639092,sigma1 = 0.0039564,sigma2 = 0.00759844)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.998574	c1=-0.999305	mean=1.86483	nbkg=5915.43	nsig=23372.8	sig1frac=0.666889	sigma1=0.00402305	sigma2=0.00789097
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6886,bkg_x_model = -0.605369/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4367,bkg_x_model = -0.618921/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6805,bkg_x_model = -0.610899/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.86987,bkg_x_model = -0.644616/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.5309,bkg_x_model = -0.600712/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.2241,bkg_x_model = -0.617535/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.8045,bkg_x_model = -0.607937/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.5963,bkg_x_model = -0.621245/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.4956,bkg_x_model = -0.597569/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.6001,bkg_x_model = -0.59615/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9438,bkg_x_model = -0.613324/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9587,bkg_x_model = -0.613228/-0.0429714), !coefficients=(nsig = 23372.8,nbkg = 5915.43)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.998574,c1 = -0.999305,mean = 1.86483,nbkg = 5915.43,nsig = 23372.8,sig1frac = 0.666889,sigma1 = 0.00402305,sigma2 = 0.00789097)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.998679	c1=-0.936255	mean=1.86483	nbkg=5913.32	nsig=23374.3	sig1frac=0.668172	sigma1=0.00402617	sigma2=0.00790475
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6854,bkg_x_model = -0.386568/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4245,bkg_x_model = -0.398952/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6643,bkg_x_model = -0.391622/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.86668,bkg_x_model = -0.422435/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.5369,bkg_x_model = -0.382313/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.2092,bkg_x_model = -0.397685/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7945,bkg_x_model = -0.388915/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.5891,bkg_x_model = -0.401076/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5031,bkg_x_model = -0.379441/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.607,bkg_x_model = -0.378145/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9254,bkg_x_model = -0.393837/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9403,bkg_x_model = -0.39375/-0.0276047), !coefficients=(nsig = 23374.3,nbkg = 5913.32)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.998679,c1 = -0.936255,mean = 1.86483,nbkg = 5913.32,nsig = 23374.3,sig1frac = 0.668172,sigma1 = 0.00402617,sigma2 = 0.00790475)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.99873	c1=-0.867901	mean=1.86483	nbkg=5912.27	nsig=23375.1	sig1frac=0.668814	sigma1=0.00402774	sigma2=0.00791164
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6838,bkg_x_model = -0.149479/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4184,bkg_x_model = -0.160596/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6562,bkg_x_model = -0.154015/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.86505,bkg_x_model = -0.181681/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.54,bkg_x_model = -0.145659/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.2017,bkg_x_model = -0.159459/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7896,bkg_x_model = -0.151585/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.5855,bkg_x_model = -0.162503/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5069,bkg_x_model = -0.143081/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.6105,bkg_x_model = -0.141918/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9162,bkg_x_model = -0.156004/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9312,bkg_x_model = -0.155926/-0.0109535), !coefficients=(nsig = 23375.1,nbkg = 5912.27)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.99873,c1 = -0.867901,mean = 1.86483,nbkg = 5912.27,nsig = 23375.1,sig1frac = 0.668814,sigma1 = 0.00402774,sigma2 = 0.00791164)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.885011	c1=-0.777139	mean=1.86483	nbkg=5911.21	nsig=23375.8	sig1frac=0.669455	sigma1=0.0040293	sigma2=0.00791854
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6823,bkg_x_model = -0.0465424/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4123,bkg_x_model = -0.056543/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6482,bkg_x_model = -0.0506234/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.8634,bkg_x_model = -0.0755096/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.543,bkg_x_model = -0.0431062/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.1943,bkg_x_model = -0.05552/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7846,bkg_x_model = -0.0484373/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.582,bkg_x_model = -0.058258/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5107,bkg_x_model = -0.0407874/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.614,bkg_x_model = -0.0397411/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9071,bkg_x_model = -0.0524125/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9221,bkg_x_model = -0.0523418/-0.0036986), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.885011,c1 = -0.777139,mean = 1.86483,nbkg = 5911.21,nsig = 23375.8,sig1frac = 0.669455,sigma1 = 0.0040293,sigma2 = 0.00791854)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.926616	c1=-0.777139	mean=1.86483	nbkg=5911.21	nsig=23375.8	sig1frac=0.669455	sigma1=0.0040293	sigma2=0.00791854
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89741), !pdfs=(sig_model = 0.00352275,bkg_x_model = -0.039649/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87898), !pdfs=(sig_model = 3.51801,bkg_x_model = -0.00263863/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88859), !pdfs=(sig_model = 0.184587,bkg_x_model = -0.021886/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89301), !pdfs=(sig_model = 0.0296794,bkg_x_model = -0.0307661/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89829), !pdfs=(sig_model = 0.00220827,bkg_x_model = -0.0414435/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88347), !pdfs=(sig_model = 1.04605,bkg_x_model = -0.0116077/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89452), !pdfs=(sig_model = 0.0147479,bkg_x_model = -0.0338229/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89279), !pdfs=(sig_model = 0.0326916,bkg_x_model = -0.0303308/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88723), !pdfs=(sig_model = 0.305003,bkg_x_model = -0.0191468/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88983), !pdfs=(sig_model = 0.11397,bkg_x_model = -0.0243781/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88659), !pdfs=(sig_model = 0.381234,bkg_x_model = -0.0178761/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88717), !pdfs=(sig_model = 0.311594,bkg_x_model = -0.0190266/0.00173295), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#     ... (remaining 5750 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.926616,c1 = -0.777139,mean = 1.86483,nbkg = 5911.21,nsig = 23375.8,sig1frac = 0.669455,sigma1 = 0.0040293,sigma2 = 0.00791854)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.99878	c1=-0.889593	mean=1.86483	nbkg=5911.21	nsig=23375.8	sig1frac=0.669455	sigma1=0.0040293	sigma2=0.00791854
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6823,bkg_x_model = -0.224593/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4123,bkg_x_model = -0.236112/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6482,bkg_x_model = -0.229294/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.8634,bkg_x_model = -0.257957/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.543,bkg_x_model = -0.220635/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.1943,bkg_x_model = -0.234934/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7846,bkg_x_model = -0.226776/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.582,bkg_x_model = -0.238087/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5107,bkg_x_model = -0.217964/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.614,bkg_x_model = -0.216759/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9071,bkg_x_model = -0.231354/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9221,bkg_x_model = -0.231273/-0.0162289), !coefficients=(nsig = 23375.8,nbkg = 5911.21)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.99878,c1 = -0.889593,mean = 1.86483,nbkg = 5911.21,nsig = 23375.8,sig1frac = 0.669455,sigma1 = 0.0040293,sigma2 = 0.00791854)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.998508	c1=-0.938658	mean=1.86483	nbkg=5912.82	nsig=23374.2	sig1frac=0.668991	sigma1=0.00402826	sigma2=0.0079122
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6839,bkg_x_model = -0.395217/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4194,bkg_x_model = -0.407646/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.655,bkg_x_model = -0.400289/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.8639,bkg_x_model = -0.431215/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.5412,bkg_x_model = -0.390946/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.2021,bkg_x_model = -0.406375/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7889,bkg_x_model = -0.397572/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.5877,bkg_x_model = -0.409778/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5082,bkg_x_model = -0.388064/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.6117,bkg_x_model = -0.386764/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9151,bkg_x_model = -0.402513/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9301,bkg_x_model = -0.402425/-0.0282121), !coefficients=(nsig = 23374.2,nbkg = 5912.82)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.998508,c1 = -0.938658,mean = 1.86483,nbkg = 5912.82,nsig = 23374.2,sig1frac = 0.668991,sigma1 = 0.00402826,sigma2 = 0.0079122)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.998701	c1=-0.835713	mean=1.86483	nbkg=5911.7	nsig=23375.3	sig1frac=0.669315	sigma1=0.00402899	sigma2=0.00791662
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.6827,bkg_x_model = -0.0379326/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 73.4145,bkg_x_model = -0.0484536/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 81.6503,bkg_x_model = -0.0422258/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.86355,bkg_x_model = -0.0684094/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 49.5425,bkg_x_model = -0.0343178/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 77.1967,bkg_x_model = -0.0473772/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.7859,bkg_x_model = -0.039926/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 65.5837,bkg_x_model = -0.0502579/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 37.5099,bkg_x_model = -0.0318786/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.6133,bkg_x_model = -0.0307779/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 82.9095,bkg_x_model = -0.0441081/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 82.9245,bkg_x_model = -0.0440336/-0.00311935), !coefficients=(nsig = 23375.3,nbkg = 5911.7)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.998701,c1 = -0.835713,mean = 1.86483,nbkg = 5911.7,nsig = 23375.3,sig1frac = 0.669315,sigma1 = 0.00402899,sigma2 = 0.00791662)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.902953	c1=-0.753099	mean=1.86491	nbkg=6170.37	nsig=23117.1	sig1frac=0.605882	sigma1=0.00388817	sigma2=0.00707178
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89913), !pdfs=(sig_model = 0.000183899,bkg_x_model = -0.0013633/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89924), !pdfs=(sig_model = 0.00017019,bkg_x_model = -0.00158461/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89925), !pdfs=(sig_model = 0.000168287,bkg_x_model = -0.00161668/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89934), !pdfs=(sig_model = 0.000159064,bkg_x_model = -0.00177718/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89913), !pdfs=(sig_model = 0.000183899,bkg_x_model = -0.0013633/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89924), !pdfs=(sig_model = 0.00017019,bkg_x_model = -0.00158461/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89925), !pdfs=(sig_model = 0.000168287,bkg_x_model = -0.00161668/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89934), !pdfs=(sig_model = 0.000159064,bkg_x_model = -0.00177718/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89913), !pdfs=(sig_model = 0.000183899,bkg_x_model = -0.0013633/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89924), !pdfs=(sig_model = 0.00017019,bkg_x_model = -0.00158461/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89925), !pdfs=(sig_model = 0.000168287,bkg_x_model = -0.00161668/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89934), !pdfs=(sig_model = 0.000159064,bkg_x_model = -0.00177718/0.0044977), !coefficients=(nsig = 23117.1,nbkg = 6170.37)
#     ... (remaining 287 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.902953,c1 = -0.753099,mean = 1.86491,nbkg = 6170.37,nsig = 23117.1,sig1frac = 0.605882,sigma1 = 0.00388817,sigma2 = 0.00707178)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.309072	c1=-0.776654	mean=1.86498	nbkg=6316.38	nsig=22971	sig1frac=0.578078	sigma1=0.00382959	sigma2=0.00672342
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.4938,bkg_x_model = -1.11728/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 76.3489,bkg_x_model = -1.13013/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 83.3064,bkg_x_model = -1.12252/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.68806,bkg_x_model = -1.15447/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 48.391,bkg_x_model = -1.11286/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 80.1259,bkg_x_model = -1.12881/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 76.4326,bkg_x_model = -1.11971/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 68.3543,bkg_x_model = -1.13233/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 36.2079,bkg_x_model = -1.10987/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 31.3453,bkg_x_model = -1.10853/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 85.2533,bkg_x_model = -1.12482/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 85.2452,bkg_x_model = -1.12473/-0.0787693), !coefficients=(nsig = 22971,nbkg = 6316.38)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.309072,c1 = -0.776654,mean = 1.86498,nbkg = 6316.38,nsig = 22971,sig1frac = 0.578078,sigma1 = 0.00382959,sigma2 = 0.00672342)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-369705 FROM MIGRAD    STATUS=FAILED        920 CALLS         921 TOTAL
#                      EDM=0.00730359    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           9.93697e-01   1.63174e-02   4.70590e-02   6.17269e-01
#    2  c1          -7.44419e-01   8.29318e-03   3.99393e-03   7.40321e+00
#    3  mean         1.86489e+00   3.76736e-05   1.79289e-03  -2.06443e+00
#    4  nbkg         6.08315e+03   1.42913e+02   3.51303e-03   2.05560e-01
#    5  nsig         2.32040e+04   1.93711e+02   5.67592e-03   4.66615e-02
#    6  sig1frac     6.13581e-01   6.11296e-02   8.77475e-03  -6.97370e-01
#    7  sigma1       3.90506e-03   1.45348e-04   1.46053e-03   1.97994e+00
#    8  sigma2       7.31457e-03   4.49739e-04   2.71082e-03   3.19916e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   2.682e-04 -8.628e-05 -1.498e-08 -3.272e-03  3.260e-03 -3.791e-06 -7.358e-09 -2.221e-08
#  -8.628e-05  6.878e-05 -2.588e-08 -9.044e-03  9.020e-03 -5.173e-06 -9.811e-09 -2.617e-08
#  -1.498e-08 -2.588e-08  1.419e-09  2.076e-04 -2.072e-04 -3.017e-08 -1.633e-10 -2.381e-10
#  -3.272e-03 -9.044e-03  2.076e-04  2.042e+04 -1.432e+04 -3.825e+00 -8.183e-03 -3.740e-02
#   3.260e-03  9.020e-03 -2.072e-04 -1.432e+04  3.753e+04  3.827e+00  8.185e-03  3.741e-02
#  -3.791e-06 -5.173e-06 -3.017e-08 -3.825e+00  3.827e+00  3.757e-03  8.490e-06  2.609e-05
#  -7.358e-09 -9.811e-09 -1.633e-10 -8.183e-03  8.185e-03  8.490e-06  2.113e-08  5.663e-08
#  -2.221e-08 -2.617e-08 -2.381e-10 -3.740e-02  3.741e-02  2.609e-05  5.663e-08  2.023e-07
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.64013   1.000 -0.635 -0.024 -0.001  0.001 -0.004 -0.003 -0.003
#         2  0.64312  -0.635  1.000 -0.083 -0.008  0.006 -0.010 -0.008 -0.007
#         3  0.14761  -0.024 -0.083  1.000  0.039 -0.028 -0.013 -0.030 -0.014
#         4  0.71848  -0.001 -0.008  0.039  1.000 -0.517 -0.437 -0.394 -0.582
#         5  0.55892   0.001  0.006 -0.028 -0.517  1.000  0.322  0.291  0.429
#         6  0.98613  -0.004 -0.010 -0.013 -0.437  0.322  1.000  0.953  0.947
#         7  0.96093  -0.003 -0.008 -0.030 -0.394  0.291  0.953  1.000  0.866
#         8  0.97176  -0.003 -0.007 -0.014 -0.582  0.429  0.947  0.866  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **   16 **SET ERR         0.5
#  **********
#  **********
#  **   17 **SET PRINT           1
#  **********
#  **********
#  **   18 **HESSE        4000
#  **********
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.818307	c1=-0.744419	mean=1.86489	nbkg=6083.15	nsig=23204	sig1frac=0.613581	sigma1=0.00390506	sigma2=0.00731457
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.4796,bkg_x_model = -0.0573004/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 74.3882,bkg_x_model = -0.0670262/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 82.2288,bkg_x_model = -0.0612693/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.98268,bkg_x_model = -0.0854702/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 48.9466,bkg_x_model = -0.0539585/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 78.198,bkg_x_model = -0.0660313/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.9435,bkg_x_model = -0.0591432/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 66.4518,bkg_x_model = -0.0686941/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 36.9072,bkg_x_model = -0.0517033/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.0622,bkg_x_model = -0.0506856/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 83.7511,bkg_x_model = -0.0630093/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 83.7578,bkg_x_model = -0.0629405/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.818307 +/- 0.0163174,c1 = -0.744419 +/- 0.00829318,mean = 1.86489 +/- 3.76736e-05,nbkg = 6083.15 +/- 142.913,nsig = 23204 +/- 193.711,sig1frac = 0.613581 +/- 0.0611296,sigma1 = 0.00390506 +/- 0.000145348,sigma2 = 0.00731457 +/- 0.000449739)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-356968) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.818307	c1=-0.744419	mean=1.86489	nbkg=6083.15	nsig=23204	sig1frac=0.613581	sigma1=0.00390506	sigma2=0.00731457
# PID4455/RooRealMPFE::nll_extended_model__5580ecf88380_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86203), !pdfs=(sig_model = 67.4796,bkg_x_model = -0.0573004/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.867), !pdfs=(sig_model = 74.3882,bkg_x_model = -0.0670262/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86406), !pdfs=(sig_model = 82.2288,bkg_x_model = -0.0612693/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87637), !pdfs=(sig_model = 6.98268,bkg_x_model = -0.0854702/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86032), !pdfs=(sig_model = 48.9466,bkg_x_model = -0.0539585/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86649), !pdfs=(sig_model = 78.198,bkg_x_model = -0.0660313/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86297), !pdfs=(sig_model = 75.9435,bkg_x_model = -0.0591432/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86785), !pdfs=(sig_model = 66.4518,bkg_x_model = -0.0686941/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85916), !pdfs=(sig_model = 36.9072,bkg_x_model = -0.0517033/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85864), !pdfs=(sig_model = 32.0622,bkg_x_model = -0.0506856/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86495), !pdfs=(sig_model = 83.7511,bkg_x_model = -0.0630093/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86491), !pdfs=(sig_model = 83.7578,bkg_x_model = -0.0629405/-0.00443923), !coefficients=(nsig = 23204,nbkg = 6083.15)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.818307 +/- 0.0163174,c1 = -0.744419 +/- 0.00829318,mean = 1.86489 +/- 3.76736e-05,nbkg = 6083.15 +/- 142.913,nsig = 23204 +/- 193.711,sig1frac = 0.613581 +/- 0.0611296,sigma1 = 0.00390506 +/- 0.000145348,sigma2 = 0.00731457 +/- 0.000449739)
#
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-369705 FROM HESSE     STATUS=OK             71 CALLS         992 TOTAL
#                      EDM=0.00727771    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  c0           9.93697e-01   4.98569e-04   5.00000e-01  -4.82473e+00
#    2  c1          -7.44419e-01   6.85324e-03   1.59757e-04  -8.39664e-01
#    3  mean         1.86489e+00   3.77162e-05   3.58578e-04   5.10551e-01
#    4  nbkg         6.08315e+03   1.47300e+02   1.40521e-04  -6.24367e-01
#    5  nsig         2.32040e+04   1.97015e+02   2.27037e-04   6.24383e-01
#    6  sig1frac     6.13581e-01   6.51319e-02   1.75495e-03   2.29163e-01
#    7  sigma1       3.90506e-03   1.53714e-04   5.84211e-05  -1.07887e+00
#    8  sigma2       7.31457e-03   4.80627e-04   1.08433e-04  -8.36440e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   2.486e-07  1.196e-06 -7.016e-10 -6.898e-04  6.898e-04  7.946e-08  1.987e-10  1.158e-09
#   1.196e-06  4.697e-05 -3.519e-08 -1.090e-02  1.090e-02 -7.682e-06 -1.469e-08 -4.085e-08
#  -7.016e-10 -3.519e-08  1.423e-09  2.253e-04 -2.253e-04 -4.112e-08 -1.903e-10 -3.220e-10
#  -6.898e-04 -1.090e-02  2.253e-04  2.170e+04 -1.561e+04 -4.624e+00 -9.935e-03 -4.346e-02
#   6.898e-04  1.090e-02 -2.253e-04 -1.561e+04  3.882e+04  4.624e+00  9.935e-03  4.346e-02
#   7.946e-08 -7.682e-06 -4.112e-08 -4.624e+00  4.624e+00  4.268e-03  9.619e-06  2.992e-05
#   1.987e-10 -1.469e-08 -1.903e-10 -9.935e-03  9.935e-03  9.619e-06  2.363e-08  6.506e-08
#   1.158e-09 -4.085e-08 -3.220e-10 -4.346e-02  4.346e-02  2.992e-05  6.506e-08  2.311e-07
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.35023   1.000  0.350 -0.037 -0.009  0.007  0.002  0.003  0.005
#         2  0.37183   0.350  1.000 -0.136 -0.011  0.008 -0.017 -0.014 -0.012
#         3  0.15491  -0.037 -0.136  1.000  0.041 -0.030 -0.017 -0.033 -0.018
#         4  0.73797  -0.009 -0.011  0.041  1.000 -0.538 -0.481 -0.439 -0.614
#         5  0.57901   0.007  0.008 -0.030 -0.538  1.000  0.359  0.328  0.459
#         6  0.98780   0.002 -0.017 -0.017 -0.481  0.359  1.000  0.958  0.953
#         7  0.96514   0.003 -0.014 -0.033 -0.439  0.328  0.958  1.000  0.880
#         8  0.97531   0.005 -0.012 -0.018 -0.614  0.459  0.953  0.880  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig1,sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (bkg_x_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
print(nsig)
print(nbkg)
# Out:
# RooRealVar::nsig = 23204 +/- 197.015  L(0 - 29287)
#
# RooRealVar::nbkg = 6083.15 +/- 147.3  L(0 - 29287)
