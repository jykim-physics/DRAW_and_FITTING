# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style") 
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
from main.draw_tools.stacking_with_error_bars import MC_stack_plot, MC_stack_plot_density

from main.data_tools.error_bars import make_data_weight
from main.data_tools.query_dataframes import cut_dfs_7types
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROOT.gROOT.LoadMacro('/home/jykim/workspace/DRAW_and_FITTING/main/Belle2Style.C')
ROOT.SetBelle2Style()
# Out:
# Applying BELLE2 style settings...

# %% [markdown]
# # Pandas

# %%
# base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_ref_sig_ext_naive_skim/'
# base_file_loc =  '/media/jykim/T7/storage/01_recon/v26_ref_sig_ext/'

# base_filter =  'D0_M>1.83 && D0_M<1.90 '
# # base_filter += '&& Dstarp_isSignal==1'
# tree = 'ref_phi'

# variables=['D0_M','Dstarp_Q','Dstarp_CMS_p','__ncandidates__','Dstarp_isSignal']
# var = 'D0_M'

base_file_loc =  '/media/jykim/T7/storage/01_recon/ref_optv1_sigext_ref_only_skim/'

base_filter =  'D0_M>1.83 && D0_M<1.90 '
base_filter += '&& Dstarp_isSignal!=1'
tree = 'ref_phi'

variables=["__experiment__", "__run__", "__event__",'D0_M','Dstarp_Q','Dstarp_CMS_p','__ncandidates__','Dstarp_isSignal','Dstarp_chiProb']
var = 'D0_M'

# %%
# ccbar_0 = base_file_loc + 'topo/resultfile/result_ref_phi/standard.root'
# ccbar_0 = base_file_loc + 'topo/generic_ccbar.root'

# ccbar_0 = base_file_loc + 'generic_ccbar.root'

# uubar_0 = base_file_loc + 'generic_uubar.root'
# ddbar_0 = base_file_loc + 'generic_ddbar.root'
# ssbar_0 = base_file_loc + 'generic_ssbar.root'
# charged_0 = base_file_loc + 'generic_charged.root'
# mixed_0 = base_file_loc + 'generic_mixed.root'
# taupair_0 = base_file_loc + 'generic_taupair.root'

ccbar_0 = base_file_loc + 'ccbar/recon_*.root'

uubar_0 = base_file_loc + 'uubar/recon_*.root'
ddbar_0 = base_file_loc + 'ddbar/recon_*.root'
ssbar_0 = base_file_loc + 'ssbar/recon_*.root'
charged_0 = base_file_loc + 'charged/recon_*.root'
mixed_0 = base_file_loc + 'mixed/recon_*.root'
taupair_0 = base_file_loc + 'taupair/recon_*.root'

# %%
base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar_0 = get_pd(file=ccbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_uubar_0 = get_pd(file=uubar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_ddbar_0 = get_pd(file=ddbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar_0 = get_pd(file=ssbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_charged_0 = get_pd(file=charged_0, tree=tree,base_filter=base_filter,variables=variables)

pd_mixed_0 = get_pd(file=mixed_0, tree=tree,base_filter=base_filter,variables=variables)

pd_taupair_0 = get_pd(file=taupair_0, tree=tree,base_filter=base_filter,variables=variables)

# %%
pd_ccbar = pd_ccbar_0.reset_index(drop=True)
pd_uubar = pd_uubar_0.reset_index(drop=True)
pd_ddbar = pd_ddbar_0.reset_index(drop=True)
pd_ssbar = pd_ssbar_0.reset_index(drop=True)
pd_charged = pd_charged_0.reset_index(drop=True)
pd_mixed = pd_mixed_0.reset_index(drop=True)
pd_taupair = pd_taupair_0.reset_index(drop=True)

# %%
pd_ccbar['rank'] = pd_ccbar.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_uubar['rank'] = pd_uubar.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_ddbar['rank'] = pd_ddbar.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_ssbar['rank'] = pd_ssbar.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_charged['rank'] = pd_charged.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_mixed['rank'] = pd_mixed.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')
pd_taupair['rank'] = pd_taupair.groupby(['__experiment__', '__run__', '__event__', ])['Dstarp_chiProb'].rank(ascending=True, method='first')

# %%
multiplicity = len(pd_ccbar[["__experiment__", "__run__", "__event__"]].drop_duplicates()) / len(pd_ccbar[["__experiment__", "__run__", "__event__"]])

numerator = len(pd_ccbar[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_uubar[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_ddbar[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_ssbar[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_charged[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_mixed[["__experiment__", "__run__", "__event__"]].drop_duplicates()) + \
            len(pd_taupair[["__experiment__", "__run__", "__event__"]].drop_duplicates())
denominator = len(pd_ccbar[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_uubar[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_ddbar[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_ssbar[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_charged[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_mixed[["__experiment__", "__run__", "__event__"]]) + \
                len(pd_taupair[["__experiment__", "__run__", "__event__"]]) 


print(numerator)
print(denominator)

multiplicity = numerator/denominator

print(multiplicity)
# Out:
# 9031
# 9048
# 0.9981211317418214

# %%
cut = 'D0_M>0.0'

pd_ccbar, pd_uubar,pd_ddbar,pd_ssbar,pd_charged, pd_mixed, pd_taupair = cut_dfs_7types(cut, pd_ccbar, pd_uubar,pd_ddbar,pd_ssbar,pd_charged, pd_mixed, pd_taupair)

# %%
labels = [   r'$\tau\bar{\tau}$', r'$B^0\bar{B}^0$', r'$B^+B^-$', r'$s\bar{s}$'  ,r'$d\bar{d}$', r'$u\bar{u}$', r'$c\bar{c}$']

# data  = [taupair_bkg[var], mixed_bkg[var], charged_bkg[var],ssbar_bkg[var], ddbar_bkg[var],uubar_bkg[var], ccbar_bkg[var]]  
var = 'D0_M'
data  = [pd_taupair[var], pd_mixed[var], pd_charged[var],pd_ssbar[var], pd_ddbar[var],pd_uubar[var], pd_ccbar[var]]  


scale = 1
xrange = (1.83,1.90)
# xrange = (1.8,1.9)

nbins = 50
xlabel = "$\mathrm{M(D^0)}$"

MC_stack_plot(data, var, scale, xrange, nbins, xlabel=xlabel, labels=labels,title="", unit="[GeV/c^2]",ncol=1)
# plt.savefig("/media/jykim/T7/saved_plots/references/ref_phi/MC15ri_optv1_ref_phi_D0M.png")
plt.savefig("/media/jykim/T7/saved_plots/references/ref_phi/MC15ri_optv1_ref_phi_D0M_isSignal_not1.png")
# Out:
# [171. 183. 152. 138. 166. 140. 154. 160. 135. 166. 161. 143. 123. 127.
#  142. 138. 126. 132. 164. 172. 244. 312. 390. 511. 557. 480. 498. 329.
#  267. 209. 172. 151. 125. 100. 111. 119. 117.  99. 113.  92. 104. 115.
#   78. 109.  90. 114. 104. 120. 110. 115.]
# fitst_bin_entries=171.0

# %%
pd_all_generic = pd.concat([pd_ccbar, pd_uubar, pd_ddbar, pd_ssbar, pd_charged, pd_mixed, pd_taupair], ignore_index=True)

pd_all_generic.describe()
# Out:
#        __experiment__   __run__     __event__           D0_M       Dstarp_Q  \
# count        174873.0  174873.0  1.748730e+05  174873.000000  174873.000000
# mean           1003.0       0.0  1.325726e+08       1.864494       0.005868
# std               0.0       0.0  7.697876e+07       0.006447       0.000231
# min            1003.0       0.0  4.500000e+02       1.830002       0.005130
# 25%            1003.0       0.0  6.585586e+07       1.861944       0.005746
# 50%            1003.0       0.0  1.322976e+08       1.864666       0.005861
# 75%            1003.0       0.0  1.993879e+08       1.867349       0.005979
# max            1003.0       0.0  3.209028e+08       1.899974       0.006730
#
#         Dstarp_CMS_p  __ncandidates__  Dstarp_isSignal  Dstarp_chiProb  \
# count  174873.000000    174873.000000    172800.000000   174873.000000
# mean        3.453439         1.003334         0.959635        0.398209
# std         0.591255         0.057940         0.196813        0.299370
# min         2.500001         1.000000         0.000000        0.001000
# 25%         2.958692         1.000000         1.000000        0.123513
# 50%         3.395586         1.000000         1.000000        0.352820
# 75%         3.900587         1.000000         1.000000        0.646232
# max         5.083045         3.000000         1.000000        0.999968
#
#                 rank
# count  174873.000000
# mean        1.001813
# std         0.042672
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000

# %%
N_isSignal_1 = len(pd_all_generic.query('Dstarp_isSignal==1'))
print(N_isSignal_1)
# Out:
# 165825

# %% [markdown]
# # Fit D0 + D0bar only in ccbar

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/ref_optv1_sigext_ref_only_skim/'

loc_ccbar = base_file_loc + 'ccbar/recon_*.root'
# loc_ccbar = base_file_loc + 'topo/resultfile/result_antiKstar/standard.root'
loc_uubar = base_file_loc + 'uubar/recon_*.root'
loc_ddbar = base_file_loc + 'ddbar/recon_*.root'
loc_ssbar = base_file_loc + 'ssbar/recon_*.root'
loc_charged = base_file_loc + 'charged/recon_*.root'
loc_mixed = base_file_loc + 'mixed/recon_*.root'
loc_taupair = base_file_loc + 'taupair/recon_*.root'

# %%
loc_ccbar_cc = base_file_loc + 'ccbar/recon_*.root/ref_phi_cc'
# loc_ccbar = base_file_loc + 'topo/resultfile/result_antiKstar/standard.root'
loc_uubar_cc  = base_file_loc + 'uubar/recon_*.root/ref_phi_cc'
loc_ddbar_cc  = base_file_loc + 'ddbar/recon_*.root/ref_phi_cc'
loc_ssbar_cc  = base_file_loc + 'ssbar/recon_*.root/ref_phi_cc'
loc_charged_cc  = base_file_loc + 'charged/recon_*.root/ref_phi_cc'
loc_mixed_cc  = base_file_loc + 'mixed/recon_*.root/ref_phi_cc'
loc_taupair_cc  = base_file_loc + 'taupair/recon_*.root/ref_phi_cc'

# %%
file_list = [loc_ccbar,loc_ccbar_cc]

mychain = ROOT.TChain("ref_phi")
# mychain = ROOT.TChain("ref_rho_cc")
 
for i in file_list:
    mychain.Add(i)

# %%
fitting_region = (1.82, 1.91)
fitting_region = (1.85, 1.88)
# 
# x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
x = ROOT.RooRealVar("D0_M", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
y = ROOT.RooRealVar("Dstarp_isSignal", "M(D^{0}) [GeV/c^{2}]", 0, 1, "")
# x.setBins(50)
# RooDataSet* data3 = new RooDataSet(“data3”,“data3”,sIeta,Import(*chain)) ;

# roodataset = ROOT.RooDataSet("roodataset","", x , ROOT.RooFit.Import(mychain), ROOT.RooFit.CutRange("D0_M>1.83 && D0_M<1.9"))
roodataset_i = ROOT.RooDataSet("roodataset_i","", ROOT.RooArgSet(x, y) , ROOT.RooFit.Import(mychain), Cut="Dstarp_isSignal==1 ")
# roodataset_i = ROOT.RooDataSet("roodataset_i","", ROOT.RooArgSet(x, y) , ROOT.RooFit.Import(mychain))



# roodataset = roodataset_i.reduce("D0_M>1.82 && D0_M<1.91 ")
roodataset = roodataset_i.reduce("D0_M>1.85 && D0_M<1.88 ")

roodataset.Print("v")
# Out:
# [#1] INFO:InputArguments -- The formula Dstarp_isSignal==1  claims to use the variables (D0_M,Dstarp_isSignal) but only (Dstarp_isSignal) seem to be in use.
#   inputs:         Dstarp_isSignal==1
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #8 because D0_M cannot accommodate the value 1.83367
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #32 because D0_M cannot accommodate the value 1.82528
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #37 because D0_M cannot accommodate the value 1.84906
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #40 because D0_M cannot accommodate the value 1.88138
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Ignored 26818 out-of-range events
# [#1] INFO:InputArguments -- The formula D0_M>1.85 && D0_M<1.88  claims to use the variables (D0_M,Dstarp_isSignal) but only (D0_M) seem to be in use.
#   inputs:         D0_M>1.85 && D0_M<1.88
# DataStore roodataset_i ()
#   Contains 317926 entries
#   Observables:
#     1)             D0_M = 1.86154  L(1.85 - 1.88)  "M(D^{0}) [GeV/c^{2}]"
#     2)  Dstarp_isSignal = 1  L(0 - 1)  "M(D^{0}) [GeV/c^{2}]"

# %%
x.setBins(70)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.85, 1.87)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.02,0.001,0.05)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.02,0.001,0.05)
sigma3 = ROOT.RooRealVar("sigma3", "width of gaussians", 0.01,0.001,0.05)
sigma4 = ROOT.RooRealVar("sigma4", "width of gaussians", 0.01,0.001,0.05)

# alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
# n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 20,0,100)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    


sig1 = ROOT.RooBreitWigner("sig1", "Signal component 1", x, mean, sigma1)

# sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
# sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean, sigma2)
sig2 = ROOT.RooBifurGauss("sig2", "Signal component 1", x, mean, sigma3,sigma4)


# sig2 = ROOT.RooBreitWigner("sig2", "Signal component 1", x, mean, sigma2)
# sig3 = ROOT.RooGaussian("sig3", "Signal component 1", x, mean, sigma3)

# RooBreitWigner (const char *name, const char *title, RooAbsReal &_x, RooAbsReal &_mean, RooAbsReal &_width)

sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
# sig2frac = ROOT.RooRealVar("sig2frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)

# sig_model1 = ROOT.RooAddPdf("sig_model1", "Signal1", [sig1, sig2], sig1frac)
# sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig3, sig_model1], sig2frac)


sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




# c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
# c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
# bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)

# bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, c0)

# tau = ROOT.RooRealVar("tau", "c1",-15, -20,0)
# bkg_x_model = ROOT.RooExponential("bkg_x_model", "Signal component 1", x, tau)



# data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

data = roodataset

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))



# nsig = ROOT.RooRealVar("nsig","# signal events",N_total*0.8,0,N_total)
# nbkg = ROOT.RooRealVar("nbkg","# bkg events",N_total*0.2,0, N_total)


# nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
# nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

# extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))

# r = extended_model.fitTo(roodataset,NumCPU=12, Range=fitting_region)

# r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

r = sig_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig_model.fitTo(data,NumCPU=12, Range=(1.85,1.88))


# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


# extended_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)

# extended_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)


# extended_model.plotOn(frame, Name="sig", Components=ROOT.RooArgSet(sig1,sig2), LineStyle=ROOT.kDashed, LineColor=ROOT.kRed)



# extended_model.plotOn(frame, Name="bkg", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+3)

# extended_model.plotOn(frame, Name="fitting")

sig_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)
sig_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+3)
# sig_model.plotOn(frame, Name="sig3", Components=sig3, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)

sig_model.plotOn(frame, Name="fitting")


# sig.paramOn(frame)
frame.GetXaxis().CenterTitle(True)

frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.65, 0.90, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "Fit", "l")
leg1.AddEntry("sig1", "Sig1", "l")
leg1.AddEntry("sig2", "Sig2", "l")
leg1.SetBorderSize(0)
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.22)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.15)
pullplot.GetYaxis().SetLabelSize(0.105)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_model_roodataset_i) constructing test statistic for sub-range named fit
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_sig_model_roodataset_i) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean         1.86000e+00  2.00000e-03    1.85000e+00  1.87000e+00
#      2 sig1frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      3 sigma1       2.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#      4 sigma3       1.00000e-02  4.50000e-03    1.00000e-03  5.00000e-02
#      5 sigma4       1.00000e-02  4.50000e-03    1.00000e-03  5.00000e-02
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        2500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-1.24438e+06 FROM MIGRAD    STATUS=INITIATE       66 CALLS          67 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         1.86000e+00   2.00000e-03   0.00000e+00  -1.69155e+05
#    2  sig1frac     5.00000e-01   1.00000e-01   0.00000e+00   5.53670e+04
#    3  sigma1       2.00000e-02   4.90000e-03   0.00000e+00   6.49485e+03
#    4  sigma3       1.00018e-03   4.50000e-03   0.00000e+00  -1.19199e+03
#    5  sigma4       6.60350e-03   4.50000e-03  -1.95885e-01   1.75167e+04
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.29612e+06 FROM MIGRAD    STATUS=CONVERGED     495 CALLS         496 TOTAL
#                      EDM=3.9469e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         1.86475e+00   1.75981e-05   6.41232e-04   3.00764e-01
#    2  sig1frac     3.22985e-01   5.87980e-03   5.77855e-03  -2.79794e-02
#    3  sigma1       7.03763e-03   1.42885e-04   2.48005e-03  -4.38873e-01
#    4  sigma3       3.64278e-03   2.32533e-05   7.05960e-04   1.47042e+00
#    5  sigma4       3.55871e-03   2.19669e-05   6.99630e-04  -9.14185e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=0.5
#   3.097e-10 -3.546e-09 -1.742e-11 -2.555e-10 -2.386e-10
#  -3.546e-09  3.457e-05 -6.230e-07 -4.213e-08  4.407e-08
#  -1.742e-11 -6.230e-07  2.042e-08  2.066e-09 -1.906e-09
#  -2.555e-10 -4.213e-08  2.066e-09  5.407e-10 -3.830e-11
#  -2.386e-10  4.407e-08 -1.906e-09 -3.830e-11  4.825e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1  0.91300   1.000 -0.034 -0.007 -0.624 -0.617
#         2  0.81148  -0.034  1.000 -0.741 -0.308  0.341
#         3  0.93457  -0.007 -0.741  1.000  0.622 -0.607
#         4  0.90407  -0.624 -0.308  0.622  1.000 -0.075
#         5  0.89724  -0.617  0.341 -0.607 -0.075  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        2500
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.29612e+06 FROM HESSE     STATUS=OK             31 CALLS         527 TOTAL
#                      EDM=3.89523e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean         1.86475e+00   1.76007e-05   2.56493e-05   4.94524e-01
#    2  sig1frac     3.22985e-01   5.70586e-03   2.31142e-04  -3.61876e-01
#    3  sigma1       7.03763e-03   1.39265e-04   9.92022e-05  -8.53470e-01
#    4  sigma3       3.64278e-03   2.31161e-05   2.82384e-05  -2.03955e+00
#    5  sigma4       3.55871e-03   2.18903e-05   2.79852e-05  -1.10969e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=0.5
#   3.098e-10 -2.382e-09 -2.675e-11 -2.547e-10 -2.396e-10
#  -2.382e-09  3.256e-05 -5.734e-07 -3.883e-08  3.879e-08
#  -2.675e-11 -5.734e-07  1.940e-08  1.996e-09 -1.822e-09
#  -2.547e-10 -3.883e-08  1.996e-09  5.344e-10 -3.321e-11
#  -2.396e-10  3.879e-08 -1.822e-09 -3.321e-11  4.792e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1  0.91303   1.000 -0.024 -0.011 -0.626 -0.622
#         2  0.79835  -0.024  1.000 -0.722 -0.294  0.311
#         3  0.93100  -0.011 -0.722  1.000  0.620 -0.598
#         4  0.90287  -0.626 -0.294  0.620  1.000 -0.066
#         5  0.89648  -0.622  0.311 -0.598 -0.066  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) only plotting range 'fit_nll_sig_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) directly selected PDF components: (sig1)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) only plotting range 'fit_nll_sig_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) directly selected PDF components: (sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) only plotting range 'fit_nll_sig_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(sig_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_sig_model_roodataset_i'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %% [markdown]
# # Fit D0 + D0 bar

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/ref_optv1_sigext_ref_only_skim/'

loc_ccbar = base_file_loc + 'ccbar/recon_*.root'
# loc_ccbar = base_file_loc + 'topo/resultfile/r = sig_model.fitTo(data,NumCPU=12, Range=fitting_region)
loc_uubar = base_file_loc + 'uubar/recon_*.root'
loc_ddbar = base_file_loc + 'ddbar/recon_*.root'
loc_ssbar = base_file_loc + 'ssbar/recon_*.root'
loc_charged = base_file_loc + 'charged/recon_*.root'
loc_mixed = base_file_loc + 'mixed/recon_*.root'
loc_taupair = base_file_loc + 'taupair/recon_*.root'

# %%
loc_ccbar_cc = base_file_loc + 'ccbar/recon_*.root/ref_phi_cc'
# loc_ccbar = base_file_loc + 'topo/resultfile/result_antiKstar/standard.root'
loc_uubar_cc  = base_file_loc + 'uubar/recon_*.root/ref_phi_cc'
loc_ddbar_cc  = base_file_loc + 'ddbar/recon_*.root/ref_phi_cc'
loc_ssbar_cc  = base_file_loc + 'ssbar/recon_*.root/ref_phi_cc'
loc_charged_cc  = base_file_loc + 'charged/recon_*.root/ref_phi_cc'
loc_mixed_cc  = base_file_loc + 'mixed/recon_*.root/ref_phi_cc'
loc_taupair_cc  = base_file_loc + 'taupair/recon_*.root/ref_phi_cc'

# %%
# file_list = [loc_ccbar,loc_uubar,loc_uubar,loc_ssbar,loc_charged,loc_mixed,loc_taupair]
file_list = [loc_ccbar,loc_uubar,loc_uubar,loc_ssbar,loc_charged,loc_mixed,loc_taupair,\
            loc_ccbar_cc,loc_uubar_cc,loc_uubar_cc,loc_ssbar_cc,loc_charged_cc,loc_mixed_cc,loc_taupair_cc]

mychain = ROOT.TChain("ref_phi")
# mychain = ROOT.TChain("ref_rho_cc")
 
for i in file_list:
    mychain.Add(i)

# %%
fitting_region = (1.83, 1.90)
# x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
x = ROOT.RooRealVar("D0_M", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
y = ROOT.RooRealVar("Dstarp_isSignal", "M(D^{0}) [GeV/c^{2}]", 0, 1, "")
# x.setBins(50)
# RooDataSet* data3 = new RooDataSet(“data3”,“data3”,sIeta,Import(*chain)) ;

# roodataset = ROOT.RooDataSet("roodataset","", x , ROOT.RooFit.Import(mychain), ROOT.RooFit.CutRange("D0_M>1.83 && D0_M<1.9"))
# roodataset_i = ROOT.RooDataSet("roodataset_i","", ROOT.RooArgSet(x, y) , ROOT.RooFit.Import(mychain), Cut="Dstarp_isSignal==1 ")
roodataset_i = ROOT.RooDataSet("roodataset_i","", ROOT.RooArgSet(x, y) , ROOT.RooFit.Import(mychain))



roodataset = roodataset_i.reduce("D0_M>1.83 && D0_M<1.90 ")
roodataset.Print("v")
# Out:
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #32 because D0_M cannot accommodate the value 1.82528
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #82 because D0_M cannot accommodate the value 1.90248
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #139 because D0_M cannot accommodate the value 1.81218
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping event #146 because D0_M cannot accommodate the value 1.80435
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(roodataset_i) Ignored 15068 out-of-range events
# [#1] INFO:InputArguments -- The formula D0_M>1.83 && D0_M<1.90  claims to use the variables (D0_M,Dstarp_isSignal) but only (D0_M) seem to be in use.
#   inputs:         D0_M>1.83 && D0_M<1.90
# DataStore roodataset_i ()
#   Contains 343432 entries
#   Observables:
#     1)             D0_M = 1.83573  L(1.83 - 1.9)  "M(D^{0}) [GeV/c^{2}]"
#     2)  Dstarp_isSignal = nan  L(0 - 1)  "M(D^{0}) [GeV/c^{2}]"

# %%
N_total = roodataset.sumEntries()
print(N_total)
# Out:
# 343432.0

# %%
x.setBins(70)

# sig1 = ROOT.RooBreitWigner("sig1", "Signal component 1", x, mean, sigma1)
mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86475,1.86475,1.86475)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 7.03763e-03,7.03763e-03,7.03763e-03)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 3.64278e-03,3.64278e-03,3.64278e-03)
sigma3 = ROOT.RooRealVar("sigma3", "width of gaussians", 3.55871e-03,3.55871e-03,3.55871e-03)


sig1 = ROOT.RooBreitWigner("sig1", "Signal component 1", x, mean,sigma1)
sig2 = ROOT.RooBifurGauss("sig2", "Signal component 1", x, mean,sigma2, sigma3)
sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 3.22985e-01,3.22985e-01,3.22985e-01)

# sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
# c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
# bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)

bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, c0)

# tau = ROOT.RooRealVar("tau", "c1",-15, -20,0)
# bkg_x_model = ROOT.RooExponential("bkg_x_model", "Signal component 1", x, tau)



# data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

data = roodataset

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))



nsig = ROOT.RooRealVar("nsig","# signal events",N_total*0.9,0,N_total)
nbkg = ROOT.RooRealVar("nbkg","# bkg events",N_total*0.1,0, N_total)


# nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
# nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))

# r = extended_model.fitTo(roodataset,NumCPU=12, Range=fitting_region)

r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


# extended_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)

# extended_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)


extended_model.plotOn(frame, Name="sig", Components=ROOT.RooArgSet(sig1,sig2), LineStyle=ROOT.kDashed, LineColor=ROOT.kRed)



extended_model.plotOn(frame, Name="bkg", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+3)

extended_model.plotOn(frame, Name="fitting")





# sig.paramOn(frame)
frame.GetXaxis().CenterTitle(True)

frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.65, 0.90, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "Fit", "l")
leg1.AddEntry("sig", "Signal", "l")
leg1.AddEntry("bkg", "Bkg", "l")
leg1.SetBorderSize(0)
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.22)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.15)
pullplot.GetYaxis().SetLabelSize(0.105)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kBlack)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kGray+1)
line2.SetLineColor(ROOT.kGray+1)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("/media/jykim/T7/saved_plots/references/ref_phi/FIT_ref_phi_MC15ri_1ab_DDbar_D0M.png")
# Out:
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_roodataset_i) constructing test statistic for sub-range named fit
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_roodataset_i) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::optimizeConstantTerms: set of constant parameters changed, rerunning const optimizer
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 c0           1.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 mean         1.86475e+00  1.86475e-01     no limits
#  **********
#  **    3 **FIX           2
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      3 nbkg         3.43432e+04  1.71716e+04    0.00000e+00  3.43432e+05
#      4 nsig         3.09089e+05  1.71716e+04    0.00000e+00  3.43432e+05
#      5 sig1frac     3.22985e-01  3.22985e-02     no limits
#  **********
#  **    4 **FIX           5
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      6 sigma1       7.03763e-03  7.03763e-04     no limits
#  **********
#  **    5 **FIX           6
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      7 sigma2       3.64278e-03  3.64278e-04     no limits
#  **********
#  **    6 **FIX           7
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      8 sigma3       3.55871e-03  3.55871e-04     no limits
#  **********
#  **    7 **FIX           8
#  **********
#  **********
#  **    8 **SET ERR         0.5
#  **********
#  **********
#  **    9 **SET PRINT           1
#  **********
#  **********
#  **   10 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   11 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.964332	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.964332,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.929259	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.929259,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.763851	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.763851,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.650079	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.650079,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.586639	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.586639,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.553458	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.553458,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.62808	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.62808,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.34253e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.530689	mean=1.86475	nbkg=34343.2	nsig=309089	sig1frac=0.322985	sigma1=0.00703763	sigma2=0.00364278	sigma3=0.00355871
# RooNLLVar::nll_extended_model_roodataset_i[ paramSet=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
# PID5897/RooRealMPFE::nll_extended_model_roodataset_i_5561500f7fb0_MPFE11[ arg=nll_extended_model_roodataset_i_GOF11 vars=(c0,mean,nbkg,nsig,sig1frac,sigma1,sigma2,sigma3) ]
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#      function value is NAN @ paramSet=(c0 = -0.530689,mean = 1.86475,nbkg = 34343.2,nsig = 309089,sig1frac = 0.322985,sigma1 = 0.00703763,sigma2 = 0.00364278,sigma3 = 0.00355871)
#     ... (remaining 26 messages suppressed)
#
#  FCN=-5.34995e+06 FROM MIGRAD    STATUS=INITIATE       32 CALLS          33 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0          -5.19373e-01   2.00000e-01  -6.46285e-01  -2.08960e+04
#    2  mean         1.86475e+00     fixed
#    3  nbkg         3.43432e+04   1.71716e+04   0.00000e+00   3.07784e+04
#    4  nsig         3.09089e+05   1.71716e+04   0.00000e+00  -3.42153e+03
#    5  sig1frac     3.22985e-01     fixed
#    6  sigma1       7.03763e-03     fixed
#    7  sigma2       3.64278e-03     fixed
#    8  sigma3       3.55871e-03     fixed
#                                ERR DEF= 0.5
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=-5.35477e+06 FROM MIGRAD    STATUS=CONVERGED     118 CALLS         119 TOTAL
#                      EDM=0.00127989    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   4.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0          -5.21721e-01   5.39848e-04   0.00000e+00  -2.44509e+01
#    2  mean         1.86475e+00     fixed
#    3  nbkg         9.82412e+03   2.03695e+02   0.00000e+00  -1.12765e+01
#    4  nsig         3.33616e+05   6.17604e+02   0.00000e+00  -1.99799e+00
#    5  sig1frac     3.22985e-01     fixed
#    6  sigma1       7.03763e-03     fixed
#    7  sigma2       3.64278e-03     fixed
#    8  sigma3       3.55871e-03     fixed
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  3    ERR DEF=0.5
#   2.914e-07  3.389e-02 -3.428e-02
#   3.389e-02  4.149e+04 -3.350e+04
#  -3.428e-02 -3.350e+04  3.814e+05
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      3      4
#         1  0.30896   1.000  0.308 -0.103
#         3  0.38810   0.308  1.000 -0.266
#         4  0.26718  -0.103 -0.266  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::optimizeConstantTerms: set of constant parameters changed, rerunning const optimizer
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **HESSE        4000
#  **********
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-5.35477e+06 FROM HESSE     STATUS=OK             22 CALLS         141 TOTAL
#                      EDM=0.00805215    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  c0          -5.21721e-01   5.37182e-04   9.79279e-04  -5.48867e-01
#    2  mean         1.86475e+00     fixed
#    3  nbkg         9.82412e+03   2.00930e+02   5.30846e-03  -1.23090e+00
#    4  nsig         3.33616e+05   6.02563e+02   1.62989e-02   1.23104e+00
#    5  sig1frac     3.22985e-01     fixed
#    6  sigma1       7.03763e-03     fixed
#    7  sigma2       3.64278e-03     fixed
#    8  sigma3       3.55871e-03     fixed
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  3    ERR DEF=0.5
#   2.886e-07  2.441e-02 -2.376e-02
#   2.441e-02  4.037e+04 -2.984e+04
#  -2.376e-02 -2.984e+04  3.631e+05
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      3      4
#         1  0.22688   1.000  0.226 -0.073
#         3  0.32290   0.226  1.000 -0.246
#         4  0.24713  -0.073 -0.246  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig1,sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (bkg_x_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_roodataset_i'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_roodataset_i'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file /media/jykim/T7/saved_plots/references/ref_phi/FIT_ref_phi_MC15ri_1ab_DDbar_D0M.png has been created

# %%
print(mean)
# Out:
# RooRealVar::mean = 1.86475 +/- 0  L(1.86475 - 1.86475)

# %%
print(nsig)
print(nbkg)
# Out:
# RooRealVar::nsig = 333616 +/- 602.563  L(0 - 343432)
#
# RooRealVar::nbkg = 9824.12 +/- 200.93  L(0 - 343432)

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.83,1.90)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.83,1.90)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["__ncandidates__"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(0,6)
    xbins = np.linspace(*xrange,7)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black',align="left")
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=5, range=(1,6))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("ncandidates")
    width = xe[1]-xe[0]
    plt.ylabel('Entries');
    plt.show()
    plt.clf()
# Out:
# __ncandidates__

# %%
# pd_ccbar = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_uubar = get_pd(file=file_uubar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ddbar = get_pd(file=file_ddbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ssbar = get_pd(file=file_ssbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_charged = get_pd(file=file_charged, tree=tree,base_filter=base_filter,variables=variables)
# pd_mixed = get_pd(file=file_mixed, tree=tree,base_filter=base_filter,variables=variables)
# pd_taupair = get_pd(file=file_taupair, tree=tree,base_filter=base_filter,variables=variables)


pd_all_generic = pd.concat([pd_ccbar_0, pd_uubar_0, pd_ddbar_0, pd_ssbar_0, pd_charged_0, pd_mixed_0, pd_taupair_0], ignore_index=True)

pd_all_generic.describe()
# Out:
#                 D0_M       Dstarp_Q   Dstarp_CMS_p  __ncandidates__  \
# count  263483.000000  263483.000000  263483.000000    263483.000000
# mean        1.864497       0.005875       3.426148         1.002471
# std         0.008345       0.000222       0.605875         0.049645
# min         1.830002       0.005330       2.450007         1.000000
# 25%         1.861490       0.005741       2.918023         1.000000
# 50%         1.864659       0.005864       3.370716         1.000000
# 75%         1.867765       0.005994       3.885420         1.000000
# max         1.899999       0.006530       5.019806         2.000000
#
#        Dstarp_isSignal
# count    260009.000000
# mean          0.946290
# std           0.225444
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %%
N_isSignal_1 = len(pd_all_generic.query('Dstarp_isSignal==1'))
print(N_isSignal_1)
# Out:
# 246044

# %%
np_data = pd_all_generic['D0_M'].to_numpy()

# %%
fitting_region = (1.83, 1.90)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(70)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.85, 1.88)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.02,0.001,0.05)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0.001,0.05)
# alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
# n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 20,0,100)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    


    
sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean, sigma2)

sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)





data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

# data = rooDataSet

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))


r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


# extended_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)

# extended_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)


extended_model.plotOn(frame, Name="sig", Components=ROOT.RooArgSet(sig1,sig2), LineStyle=ROOT.kDashed, LineColor=ROOT.kRed)



extended_model.plotOn(frame, Name="bkg", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)

extended_model.plotOn(frame, Name="fitting")





# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")

leg1 = ROOT.TLegend(0.65, 0.6, 0.9, 0.85)
# leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(0)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
# leg1.AddEntry("sig1", "sig1", "l")
# leg1.AddEntry("sig2", "sig1", "l")

leg1.AddEntry("sig", "sig", "l")
leg1.AddEntry("bkg", "bkg", "l")
leg1.SetTextSize(0.05)
leg1.SetBorderSize(0)

leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.83,1.9]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.83,1.9]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_extended_model_' created with bounds [1.83,1.9]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#0] ERROR:Integration --  RooNumIntFactory::Init : libRooFitMore cannot be loaded. GSL integrators will not beavailable !
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 c0           1.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 c1           5.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      3 mean         1.86000e+00  3.00000e-03    1.85000e+00  1.88000e+00
#      4 nbkg         5.26966e+04  2.63483e+04    0.00000e+00  2.63483e+05
#      5 nsig         2.10786e+05  2.63483e+04    0.00000e+00  2.63483e+05
#      6 sig1frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 sigma1       2.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#      8 sigma2       3.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.918864	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -2.00319/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -2.0146/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -1.99163/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -2.05133/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -2.00672/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -1.98558/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -2.04402/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -2.08194/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -2.01467/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -1.99958/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -2.08133/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -1.9965/-0.140692), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.918864,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.61721	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.956106/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.963659/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.948457/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.987968/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.958443/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.944452/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.983133/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -1.00823/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.963707/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.953721/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -1.00783/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.951681/-0.0672383), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.61721,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.94128	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -2.081/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -2.09269/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -2.06915/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -2.13034/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -2.08462/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -2.06294/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -2.12286/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -2.16173/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -2.09277/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -2.0773/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -2.1611/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -2.07414/-0.146151), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.94128,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.565798	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.77765/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.784546/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.770668/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.806738/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.779784/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.767011/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.802324/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -0.825239/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.78459/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.775473/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -0.824869/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.773611/-0.0547194), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.565798,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.54501	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.705492/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.712121/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.698778/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.733458/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.707543/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.695263/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.729214/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -0.751245/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.712163/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.703399/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -0.75089/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.701608/-0.0496573), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.54501,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.419279	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.269063/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.274084/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.263979/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.290245/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.270617/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.261317/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.28703/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -0.303719/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.274116/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.267478/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -0.303449/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.266122/-0.0190413), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.419279,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.353001	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.0390014/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.0431745/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.0347758/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.0566066/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.0402927/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.0325634/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.0539347/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -0.0678065/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.043201/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.037684/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -0.0675827/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.0365568/-0.00290217), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.353001,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.389264	c1=-0.284899	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -0.714159/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -0.719139/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -0.709113/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -0.735147/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -0.7157/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -0.70647/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -0.731965/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -0.74847/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -0.719171/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -0.712586/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -0.748204/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -0.71124/-0.0501926), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.389264,c1 = -0.284899,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.709579	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 19.6408,bkg_x_model = -1.27673/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 19.043,bkg_x_model = -1.28547/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.8157,bkg_x_model = -1.26789/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 14.9369,bkg_x_model = -1.31358/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 19.4993,bkg_x_model = -1.27944/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 19.7279,bkg_x_model = -1.26326/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 15.9403,bkg_x_model = -1.30799/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 10.4887,bkg_x_model = -1.33701/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 19.0379,bkg_x_model = -1.28552/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 19.7432,bkg_x_model = -1.27398/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 10.5755,bkg_x_model = -1.33655/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 19.7966,bkg_x_model = -1.27162/-0.0897307), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.709579,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.76877e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.332451	mean=1.86	nbkg=52696.6	nsig=210786	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 6.11086,bkg_x_model = -0.00669735/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 6.83717,bkg_x_model = -0.00440069/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 5.34448,bkg_x_model = -0.00934394/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8973), !pdfs=(sig_model = 6.01508,bkg_x_model = -0.00701429/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 6.57165,bkg_x_model = -0.00521979/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89381), !pdfs=(sig_model = 7.32099,bkg_x_model = -0.00296112/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89199), !pdfs=(sig_model = 8.07035,bkg_x_model = -0.000845726/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89159), !pdfs=(sig_model = 8.23773,bkg_x_model = -0.000389456/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8916), !pdfs=(sig_model = 8.23358,bkg_x_model = -0.000400691/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89573), !pdfs=(sig_model = 6.58057,bkg_x_model = -0.0051919/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89185), !pdfs=(sig_model = 8.12768,bkg_x_model = -0.000688844/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89789), !pdfs=(sig_model = 5.81327,bkg_x_model = -0.00769433/0.00210174), !coefficients=(nsig = 210786,nbkg = 52696.6)
#     ... (remaining 9101 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.332451,mean = 1.86,nbkg = 52696.6,nsig = 210786,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
#  FCN=-3.88852e+06 FROM MIGRAD    STATUS=INITIATE      140 CALLS         141 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           1.00000e-01   2.00000e-01   0.00000e+00  -9.07315e+03
#    2  c1          -2.84899e-01   2.00000e-01   0.00000e+00  -1.78843e+04
#    3  mean         1.86000e+00   3.00000e-03   0.00000e+00  -4.21824e+05
#    4  nbkg         5.26966e+04   2.63483e+04   0.00000e+00   4.58339e+03
#    5  nsig         2.10786e+05   2.63483e+04   0.00000e+00  -1.14678e+03
#    6  sig1frac     5.00000e-01   1.00000e-01   0.00000e+00   4.68826e+03
#    7  sigma1       4.89691e-03   4.90000e-03   0.00000e+00  -9.47313e+04
#    8  sigma2       5.62862e-03   4.90000e-03  -2.38032e+00   8.15998e+04
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73251e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.12635	c1=-0.349118	mean=1.86478	nbkg=46817.4	nsig=219498	sig1frac=0.25941	sigma1=0.00607978	sigma2=0.00374339
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 1.32572e-05,bkg_x_model = -0.0166913/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 7.06519e-05,bkg_x_model = -0.0143217/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 1.69487e-06,bkg_x_model = -0.019422/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88612), !pdfs=(sig_model = 0.0361373,bkg_x_model = -0.00365449/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8973), !pdfs=(sig_model = 1.04382e-05,bkg_x_model = -0.0170183/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 3.9368e-05,bkg_x_model = -0.0151668/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89381), !pdfs=(sig_model = 0.000191226,bkg_x_model = -0.0128365/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89199), !pdfs=(sig_model = 0.000766718,bkg_x_model = -0.010654/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89159), !pdfs=(sig_model = 0.00102249,bkg_x_model = -0.0101832/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88532), !pdfs=(sig_model = 0.0568127,bkg_x_model = -0.00270394/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8916), !pdfs=(sig_model = 0.00101532,bkg_x_model = -0.0101948/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88599), !pdfs=(sig_model = 0.0388064,bkg_x_model = -0.0035071/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#     ... (remaining 22052 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.12635,c1 = -0.349118,mean = 1.86478,nbkg = 46817.4,nsig = 219498,sig1frac = 0.25941,sigma1 = 0.00607978,sigma2 = 0.00374339)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73251e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.12635	c1=-0.349118	mean=1.86478	nbkg=46817.4	nsig=219498	sig1frac=0.25941	sigma1=0.00607978	sigma2=0.00374339
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 1.32572e-05,bkg_x_model = -0.0166913/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 7.06519e-05,bkg_x_model = -0.0143217/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 1.69487e-06,bkg_x_model = -0.019422/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88612), !pdfs=(sig_model = 0.0361373,bkg_x_model = -0.00365449/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8973), !pdfs=(sig_model = 1.04382e-05,bkg_x_model = -0.0170183/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 3.9368e-05,bkg_x_model = -0.0151668/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89381), !pdfs=(sig_model = 0.000191226,bkg_x_model = -0.0128365/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89199), !pdfs=(sig_model = 0.000766718,bkg_x_model = -0.010654/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89159), !pdfs=(sig_model = 0.00102249,bkg_x_model = -0.0101832/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88532), !pdfs=(sig_model = 0.0568127,bkg_x_model = -0.00270394/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8916), !pdfs=(sig_model = 0.00101532,bkg_x_model = -0.0101948/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88599), !pdfs=(sig_model = 0.0388064,bkg_x_model = -0.0035071/0.00148319), !coefficients=(nsig = 219498,nbkg = 46817.4)
#     ... (remaining 22052 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.12635,c1 = -0.349118,mean = 1.86478,nbkg = 46817.4,nsig = 219498,sig1frac = 0.25941,sigma1 = 0.00607978,sigma2 = 0.00374339)
#
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1068.67 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -6.7139e+00  5.6240e-02  2.5334e-01  7.3989e-01  1.0003e+00  1.1729e+00  2.7751e+00  8.7161e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 6.722602 TO DIAGONAL.
#  FCN=-3.97037e+06 FROM HESSE     STATUS=NOT POSDEF     63 CALLS         372 TOTAL
#                      EDM=1.19192e+07    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           1.26350e-01   1.52257e+00   3.33342e-02   6.53828e+02
#    2  c1          -2.71433e-01   1.30037e-04   8.17480e-02   1.36726e+03
#    3  mean         1.86478e+00   7.42342e-05   9.11971e-04   1.07105e+04
#    4  nbkg         4.68174e+04   2.47181e+02   3.69831e-03   1.04497e+04
#    5  nsig         2.19498e+05   2.25227e+02   7.06527e-03  -9.06368e+02
#    6  sig1frac     2.59410e-01   1.93431e-03   1.15256e-02  -1.26511e+03
#    7  sigma1       6.07978e-03   3.03819e-05   3.81244e-03  -2.24850e+03
#    8  sigma2       3.74339e-03   4.67704e-06   1.18431e-03  -3.22512e+04
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73251e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.788505	c1=-0.761232	mean=1.85229	nbkg=36320.7	nsig=92889.6	sig1frac=0.883464	sigma1=0.0284161	sigma2=0.00534038
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 16.78,bkg_x_model = -3.1114/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 15.0938,bkg_x_model = -3.12384/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 19.679,bkg_x_model = -3.09879/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 11.347,bkg_x_model = -3.16385/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 16.161,bkg_x_model = -3.11525/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 21.6409,bkg_x_model = -3.09219/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 12.1123,bkg_x_model = -3.15589/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 8.10689,bkg_x_model = -3.19715/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 15.0854,bkg_x_model = -3.12392/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 17.5341,bkg_x_model = -3.10747/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 8.1696,bkg_x_model = -3.19649/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 18.2881,bkg_x_model = -3.1041/-0.218303), !coefficients=(nsig = 92889.6,nbkg = 36320.7)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.788505,c1 = -0.761232,mean = 1.85229,nbkg = 36320.7,nsig = 92889.6,sig1frac = 0.883464,sigma1 = 0.0284161,sigma2 = 0.00534038)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73251e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.133646	c1=-0.529918	mean=1.85251	nbkg=1662.99	nsig=85606.8	sig1frac=0.034496	sigma1=0.048527	sigma2=0.00102177
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 0.53798,bkg_x_model = -0.59042/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 0.528423,bkg_x_model = -0.596741/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 0.545063,bkg_x_model = -0.584019/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 0.482395,bkg_x_model = -0.617086/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 0.535288,bkg_x_model = -0.592376/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 0.548272,bkg_x_model = -0.580668/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 0.493207,bkg_x_model = -0.613039/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 0.43022,bkg_x_model = -0.63405/-0.0415899), !coefficients=(nsig = 85606.8,nbkg = 1662.99)
# ...
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 0.0265349,bkg_x_model = -1.19315/-0.081001), !coefficients=(nsig = 219449,nbkg = 46893.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 87.2424,bkg_x_model = -1.15962/-0.081001), !coefficients=(nsig = 219449,nbkg = 46893.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 75.0471,bkg_x_model = -1.15208/-0.081001), !coefficients=(nsig = 219449,nbkg = 46893.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 0.0295364,bkg_x_model = -1.19285/-0.081001), !coefficients=(nsig = 219449,nbkg = 46893.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 62.227,bkg_x_model = -1.15054/-0.081001), !coefficients=(nsig = 219449,nbkg = 46893.7)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.650297,c1 = -0.271473,mean = 1.86481,nbkg = 46893.7,nsig = 219449,sig1frac = 0.258922,sigma1 = 0.00607086,sigma2 = 0.00374255)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73196e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.0411714	c1=-0.271446	mean=1.86477	nbkg=44799.6	nsig=220109	sig1frac=0.252736	sigma1=0.00620628	sigma2=0.00365803
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8631), !pdfs=(sig_model = 89.0687,bkg_x_model = -0.0189308/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86653), !pdfs=(sig_model = 88.2244,bkg_x_model = -0.0225447/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85962), !pdfs=(sig_model = 41.7177,bkg_x_model = -0.0152704/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87752), !pdfs=(sig_model = 2.15494,bkg_x_model = -0.0341718/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86416), !pdfs=(sig_model = 96.5346,bkg_x_model = -0.0200491/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85779), !pdfs=(sig_model = 21.8414,bkg_x_model = -0.0133537/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87534), !pdfs=(sig_model = 5.06195,bkg_x_model = -0.0318595/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88664), !pdfs=(sig_model = 0.0327395,bkg_x_model = -0.0438603/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86655), !pdfs=(sig_model = 88.0001,bkg_x_model = -0.0225677/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86201), !pdfs=(sig_model = 76.06,bkg_x_model = -0.0177897/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88646), !pdfs=(sig_model = 0.036281,bkg_x_model = -0.0436667/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86108), !pdfs=(sig_model = 62.6753,bkg_x_model = -0.0168133/-0.0014732), !coefficients=(nsig = 220109,nbkg = 44799.6)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.0411714,c1 = -0.271446,mean = 1.86477,nbkg = 44799.6,nsig = 220109,sig1frac = 0.252736,sigma1 = 0.00620628,sigma2 = 0.00365803)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.73196e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.0163185	c1=-0.271439	mean=1.86478	nbkg=45853.4	nsig=219789	sig1frac=0.256228	sigma1=0.00613976	sigma2=0.00370263
# PID40328/RooRealMPFE::nll_extended_model__5612c5fa86e0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 1.69443e-05,bkg_x_model = -0.00779279/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 8.74426e-05,bkg_x_model = -0.00572377/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 2.25369e-06,bkg_x_model = -0.0101768/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8973), !pdfs=(sig_model = 1.34027e-05,bkg_x_model = -0.0080783/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 4.92748e-05,bkg_x_model = -0.0064617/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89381), !pdfs=(sig_model = 0.000232187,bkg_x_model = -0.00442677/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89199), !pdfs=(sig_model = 0.000906453,bkg_x_model = -0.00252073/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89159), !pdfs=(sig_model = 0.00120218,bkg_x_model = -0.00210959/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8916), !pdfs=(sig_model = 0.00119391,bkg_x_model = -0.00211971/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89573), !pdfs=(sig_model = 5.02573e-05,bkg_x_model = -0.00643658/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89185), !pdfs=(sig_model = 0.000999326,bkg_x_model = -0.00237936/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89028), !pdfs=(sig_model = 0.00297822,bkg_x_model = -0.000746267/0.00177296), !coefficients=(nsig = 219789,nbkg = 45853.4)
#     ... (remaining 11252 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.0163185,c1 = -0.271439,mean = 1.86478,nbkg = 45853.4,nsig = 219789,sig1frac = 0.256228,sigma1 = 0.00613976,sigma2 = 0.00370263)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-3.97243e+06 FROM MIGRAD    STATUS=FAILED        897 CALLS         898 TOTAL
#                      EDM=0.00826428    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           6.51738e-02   6.83489e-03   7.24675e-03   1.51860e+01
#    2  c1          -2.71453e-01   3.36240e-03   3.69590e-03   3.01064e+01
#    3  mean         1.86472e+00   9.53309e-06   8.69434e-04  -5.68980e+00
#    4  nbkg         2.78408e+04   4.08530e+02   3.99552e-03  -1.31875e-01
#    5  nsig         2.35645e+05   6.11284e+02   8.50390e-03   9.30313e-01
#    6  sig1frac     2.44068e-01   4.33749e-03   6.00975e-03  -4.24425e-01
#    7  sigma1       9.37271e-03   1.34382e-04   4.05825e-03   2.46882e+00
#    8  sigma2       3.44578e-03   1.56241e-05   1.09128e-03   1.50188e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   4.672e-05 -1.454e-05 -2.965e-09  5.666e-02 -5.648e-02 -6.600e-07 -2.774e-08  2.097e-09
#  -1.454e-05  1.131e-05 -1.511e-09  2.776e-02 -2.767e-02 -3.352e-07 -1.392e-08  1.057e-09
#  -2.965e-09 -1.511e-09  9.088e-11  7.398e-05 -7.364e-05 -1.868e-10 -1.411e-11  1.724e-12
#   5.666e-02  2.776e-02  7.398e-05  1.669e+05 -1.384e+05 -5.472e-01 -3.926e-02  2.421e-03
#  -5.648e-02 -2.767e-02 -7.364e-05 -1.384e+05  3.737e+05  5.460e-01  3.912e-02 -2.413e-03
#  -6.600e-07 -3.352e-07 -1.868e-10 -5.472e-01  5.460e-01  1.881e-05  4.422e-07 -5.628e-08
#  -2.774e-08 -1.392e-08 -1.411e-11 -3.926e-02  3.912e-02  4.422e-07  1.806e-08 -1.463e-09
#   2.097e-09  1.057e-09  1.724e-12  2.421e-03 -2.413e-03 -5.628e-08 -1.463e-09  2.441e-10
# ERR MATRIX APPROXIMATE
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.63932   1.000 -0.633 -0.046  0.020 -0.014 -0.022 -0.030  0.020
#         2  0.63941  -0.633  1.000 -0.047  0.020 -0.013 -0.023 -0.031  0.020
#         3  0.11126  -0.046 -0.047  1.000  0.019 -0.013 -0.005 -0.011  0.012
#         4  0.81776   0.020  0.020  0.019  1.000 -0.554 -0.309 -0.715  0.379
#         5  0.57453  -0.014 -0.013 -0.013 -0.554  1.000  0.206  0.476 -0.253
#         6  0.90169  -0.022 -0.023 -0.005 -0.309  0.206  1.000  0.759 -0.830
#         7  0.91453  -0.030 -0.031 -0.011 -0.715  0.476  0.759  1.000 -0.697
#         8  0.84066   0.020  0.020  0.012  0.379 -0.253 -0.830 -0.697  1.000
#  ERR MATRIX APPROXIMATE
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        4000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-3.97243e+06 FROM HESSE     STATUS=OK             61 CALLS         959 TOTAL
#                      EDM=0.00702209    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  c0           6.51738e-02   2.82747e-02   2.89870e-04   6.52200e-02
#    2  c1          -2.71453e-01   1.38876e-02   1.47836e-04  -2.74903e-01
#    3  mean         1.86472e+00   9.53105e-06   1.73887e-04  -1.88124e-02
#    4  nbkg         2.78408e+04   4.19264e+02   1.59821e-04  -9.08644e-01
#    5  nsig         2.35645e+05   6.19327e+02   3.40156e-04   9.08677e-01
#    6  sig1frac     2.44068e-01   4.33180e-03   2.40390e-04  -2.60424e+00
#    7  sigma1       9.37271e-03   1.37418e-04   1.62330e-04  -7.18501e-01
#    8  sigma2       3.44578e-03   1.55301e-05   4.36510e-05  -2.02143e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   7.997e-04 -3.856e-04 -2.724e-09  8.646e-02 -8.645e-02 -6.914e-07 -3.357e-08  2.353e-09
#  -3.856e-04  1.929e-04 -1.324e-09  2.110e-02 -2.110e-02 -3.321e-07 -1.284e-08  9.787e-10
#  -2.724e-09 -1.324e-09  9.084e-11  7.501e-05 -7.500e-05 -1.949e-10 -1.451e-11  1.874e-12
#   8.646e-02  2.110e-02  7.501e-05  1.758e+05 -1.479e+05 -6.026e-01 -4.220e-02  2.582e-03
#  -8.645e-02 -2.110e-02 -7.500e-05 -1.479e+05  3.836e+05  6.026e-01  4.220e-02 -2.582e-03
#  -6.914e-07 -3.321e-07 -1.949e-10 -6.026e-01  6.026e-01  1.877e-05  4.531e-07 -5.572e-08
#  -3.357e-08 -1.284e-08 -1.451e-11 -4.220e-02  4.220e-02  4.531e-07  1.888e-08 -1.487e-09
#   2.353e-09  9.787e-10  1.874e-12  2.582e-03 -2.582e-03 -5.572e-08 -1.487e-09  2.412e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.98225   1.000 -0.982 -0.010  0.007 -0.005 -0.006 -0.009  0.005
#         2  0.98225  -0.982  1.000 -0.010  0.004 -0.002 -0.006 -0.007  0.005
#         3  0.10935  -0.010 -0.010  1.000  0.019 -0.013 -0.005 -0.011  0.013
#         4  0.82794   0.007  0.004  0.019  1.000 -0.570 -0.332 -0.733  0.397
#         5  0.58936  -0.005 -0.002 -0.013 -0.570  1.000  0.225  0.496 -0.268
#         6  0.90142  -0.006 -0.006 -0.005 -0.332  0.225  1.000  0.761 -0.828
#         7  0.91843  -0.009 -0.007 -0.011 -0.733  0.496  0.761  1.000 -0.697
#         8  0.83854   0.005  0.005  0.013  0.397 -0.268 -0.828 -0.697  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig1,sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (bkg_x_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# cling::DynamicLibraryManager::loadLibrary(): libgsl.so.25: cannot open shared object file: No such file or directory
# Info in <TCanvas::Print>: png file test.png has been created

# %%
print(nsig)
print(nbkg)
# Out:
# RooRealVar::nsig = 235645 +/- 619.327  L(0 - 263483)
#
# RooRealVar::nbkg = 27840.8 +/- 419.264  L(0 - 263483)

# %%
print(nsig)
print(nbkg)
# Out:
# RooRealVar::nsig = 70080.9 +/- 292.645  L(0 - 75747)
#
# RooRealVar::nbkg = 5667.61 +/- 146.239  L(0 - 75747)
