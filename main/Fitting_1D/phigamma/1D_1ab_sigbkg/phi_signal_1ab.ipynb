# %%
import ROOT
import ctypes

# %%
sig_file = ROOT.TFile.Open("/media/jykim/T7/storage/01_recon/phi/D0_massveto_v2_half_1_sig_ext_signalMC_recon_mdst_phi.root")
signal_tree = sig_file.Get("phi")


sig_1ab_file = ROOT.TFile.Open("/media/jykim/T7/storage/01_recon/massvetov2_sig_ext_1ab_sigbkg/topo/resultfile/result_phi/standard.root")
signal_1ab_tree = sig_1ab_file.Get("phi")

# %%
# D0_M_TH1F = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.67,2.06)
D0_M_TH1F = ROOT.TH1F("D0_M_TH1F","D0 mass",50,1.72,1.92)
D0_M_TH1F_2 = ROOT.TH1F("D0_M_TH1F_2","D0 mass",50,1.72,1.92)

# %%
def extract_histo(tree, histogram):
    for event in tree:
        histogram.Fill(event.D0_M)
    return histogram

# %%
def apply_cuts(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if event.D0_M > 1.78 and event.D0_M < 1.92 and event.Belle2Pi0Veto_75MeV > 0.022:

            histogram.Fill(event.D0_M)
    return histogram

# %%
def extract_signals(tree, histogram):
    for event in tree:
        # if event.D0_M > 1.67 and event.D0_M < 2.06:
        if event.nSigCascDcyBr_0==1 and event.D0_M > 1.78 and event.D0_M < 1.92 and event.Belle2Pi0Veto_75MeV > 0.022:
        # if event.nSigCascDcyBr_0==1 and event.D0_M > 1.67 and event.D0_M < 2.06 and event.Belle2Pi0Veto_75MeV > 0.02:

            histogram.Fill(event.D0_M)
    return histogram

# %%
D0_M_TH1F = apply_cuts(signal_tree, D0_M_TH1F)
c1 = ROOT.TCanvas()
D0_M_TH1F.Draw()
c1.Draw()

# %%
D0_M_TH1F_2 = extract_signals(signal_1ab_tree, D0_M_TH1F_2)
# D0_M_TH1F_2 = apply_cuts(signal_1ab_tree, D0_M_TH1F_2)

c1 = ROOT.TCanvas()
D0_M_TH1F_2.Draw()
c1.Draw()

# %%
scale_factor = D0_M_TH1F_2.GetEntries()/D0_M_TH1F.GetEntries()

# %%
scale_factor
# Out:
# 0.008684121577702087

# %%
fitting_region = (1.72, 1.92)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(50)
l = ROOT.RooArgList(x)
# signalhist = ROOT.RooDataHist("sighist", "sighist", l, D0_M_TH1F, scale_factor)
# signalhist = ROOT.RooDataHist("sighist", "sighist", l, D0_M_TH1F, 1)

signalhist = ROOT.RooDataHist("sighist", "sighist", l, D0_M_TH1F_2, 1)

# %%
mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.83, 1.89)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.03,0,0.5)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.02,0,0.5)
alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 5,0,20)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    

mu = ROOT.RooRealVar("mu", "Novo peak", 1.83,1.67,1.93)    
gamma = ROOT.RooRealVar("gamma", "Novo peak", -1,-5,0)    
para_lambda =  ROOT.RooRealVar("para_lambda", "Novo peak", 1,-5,5)    
delta = ROOT.RooRealVar("delta", "Novo peak", 1.83,0,3)

# %%
canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

    
# sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
sig1 = ROOT.RooJohnson("sig1", "Signal component 1", x,mu, para_lambda,gamma,delta)

sig2 = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)


sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)



# model = ROOT.RooCBShape("model", "Signal component 2", x, mean, sigma2, alpha, n_CB)

model = ROOT.RooAddPdf("model", "model", [sig1, sig2], sig1frac)


r = model.fitTo(signalhist,NumCPU=12,Range=fitting_region,PrintLevel=-1, Save=1)

r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

signalhist.plotOn(frame,Name = "data1", XErrorSize=0)

model.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
model.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

model.plotOn(frame, Name="fitting",)


# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("/media/jykim/T7/saved_plots/fitting/results/phigamma/phi_massveto_1ab_signal.png")

f = ROOT.TFile("phig_signalMC_fitresult.root", "RECREATE")
r.Write("phig_sig")
f.Close()
# Out:
# [#0] WARNING:InputArguments -- The parameter 'para_lambda' with range [-5, 5] of the RooJohnson 'sig1' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'delta' with range [0, 3] of the RooJohnson 'sig1' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_model_sighist) constructing test statistic for sub-range named fit
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_model_sighist) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2)
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.38835	delta=2.20674	gamma=-4.28595	mean=1.85985	mu=1.73923	n_CB=12.6621	para_lambda=-0.041017	sig1frac=7.66731e-06	sigma2=0.0160526
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.38835,delta = 2.20674,gamma = -4.28595,mean = 1.85985,mu = 1.73923,n_CB = 12.6621,para_lambda = -0.041017,sig1frac = 7.66731e-06,sigma2 = 0.0160526)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.4365	delta=2.20102	gamma=-4.27718	mean=1.85999	mu=1.73736	n_CB=12.7495	para_lambda=-0.0345725	sig1frac=2.77584e-05	sigma2=0.0160688
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.4365,delta = 2.20102,gamma = -4.27718,mean = 1.85999,mu = 1.73736,n_CB = 12.7495,para_lambda = -0.0345725,sig1frac = 2.77584e-05,sigma2 = 0.0160688)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43295	delta=2.2009	gamma=-4.27731	mean=1.86002	mu=1.73766	n_CB=12.7127	para_lambda=-0.905767	sig1frac=2.53645e-05	sigma2=0.0160264
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43295,delta = 2.2009,gamma = -4.27731,mean = 1.86002,mu = 1.73766,n_CB = 12.7127,para_lambda = -0.905767,sig1frac = 2.53645e-05,sigma2 = 0.0160264)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43696	delta=2.20211	gamma=-4.27907	mean=1.86	mu=1.73804	n_CB=12.6581	para_lambda=-1.98481	sig1frac=1.00024e-07	sigma2=0.0160222
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43696,delta = 2.20211,gamma = -4.27907,mean = 1.86,mu = 1.73804,n_CB = 12.6581,para_lambda = -1.98481,sig1frac = 1.00024e-07,sigma2 = 0.0160222)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43409	delta=2.20315	gamma=-4.28065	mean=1.86002	mu=1.73844	n_CB=12.5899	para_lambda=-1.98613	sig1frac=6.04381e-06	sigma2=0.0160255
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -1.98613,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43409	delta=2.20315	gamma=-4.28065	mean=1.86002	mu=1.73844	n_CB=12.5899	para_lambda=-0.227185	sig1frac=6.04381e-06	sigma2=0.0160255
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43409,delta = 2.20315,gamma = -4.28065,mean = 1.86002,mu = 1.73844,n_CB = 12.5899,para_lambda = -0.227185,sig1frac = 6.04381e-06,sigma2 = 0.0160255)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43423	delta=2.20313	gamma=-4.28062	mean=1.86002	mu=1.73843	n_CB=12.5932	para_lambda=-0.161774	sig1frac=5.50824e-06	sigma2=0.0160254
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43423,delta = 2.20313,gamma = -4.28062,mean = 1.86002,mu = 1.73843,n_CB = 12.5932,para_lambda = -0.161774,sig1frac = 5.50824e-06,sigma2 = 0.0160254)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43847	delta=2.20156	gamma=-4.27825	mean=1.85999	mu=1.73789	n_CB=12.5523	para_lambda=-0.161775	sig1frac=8.07598e-08	sigma2=0.0160213
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43847	delta=2.20156	gamma=-4.27825	mean=1.85999	mu=1.73789	n_CB=12.5523	para_lambda=-0.161775	sig1frac=8.07598e-08	sigma2=0.0160213
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43847,delta = 2.20156,gamma = -4.27825,mean = 1.85999,mu = 1.73789,n_CB = 12.5523,para_lambda = -0.161775,sig1frac = 8.07598e-08,sigma2 = 0.0160213)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.43863	delta=2.20151	gamma=-4.27817	mean=1.85999	mu=1.73787	n_CB=12.5507	para_lambda=-0.161774	sig1frac=4.43092e-08	sigma2=0.0160211
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.43863,delta = 2.20151,gamma = -4.27817,mean = 1.85999,mu = 1.73787,n_CB = 12.5507,para_lambda = -0.161774,sig1frac = 4.43092e-08,sigma2 = 0.0160211)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.44103	delta=2.21059	gamma=-4.2932	mean=1.86008	mu=1.7429	n_CB=11.3027	para_lambda=-0.161774	sig1frac=4.31161e-07	sigma2=0.016057
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.44103	delta=2.21059	gamma=-4.2932	mean=1.86008	mu=1.7429	n_CB=11.3027	para_lambda=-0.161774	sig1frac=4.31161e-07	sigma2=0.016057
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.44103,delta = 2.21059,gamma = -4.2932,mean = 1.86008,mu = 1.7429,n_CB = 11.3027,para_lambda = -0.161774,sig1frac = 4.31161e-07,sigma2 = 0.016057)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.47282	delta=2.22277	gamma=-4.314	mean=1.86006	mu=1.75097	n_CB=8.85675	para_lambda=-0.161772	sig1frac=2.62757e-06	sigma2=0.0160546
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.47282,delta = 2.22277,gamma = -4.314,mean = 1.86006,mu = 1.75097,n_CB = 8.85675,para_lambda = -0.161772,sig1frac = 2.62757e-06,sigma2 = 0.0160546)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.51692	delta=2.22264	gamma=-4.3146	mean=1.85994	mu=1.75224	n_CB=7.9029	para_lambda=-0.161771	sig1frac=8.55486e-08	sigma2=0.0160203
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.51692	delta=2.22264	gamma=-4.3146	mean=1.85994	mu=1.75224	n_CB=7.9029	para_lambda=-0.161771	sig1frac=8.55486e-08	sigma2=0.0160203
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
#      function value is NAN @ paramSet=(alpha = 1.51692,delta = 2.22264,gamma = -4.3146,mean = 1.85994,mu = 1.75224,n_CB = 7.9029,para_lambda = -0.161771,sig1frac = 8.55486e-08,sigma2 = 0.0160203)
# ...
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.53879,delta = 2.22402,gamma = -4.31695,mean = 1.85996,mu = 1.75337,n_CB = 7.34446,para_lambda = -0.16177,sig1frac = 2.44285e-07,sigma2 = 0.0160504)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.54032	delta=2.22316	gamma=-4.31552	mean=1.85996	mu=1.75286	n_CB=7.42796	para_lambda=-0.16177	sig1frac=1.72962e-07	sigma2=0.0160558
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.54032	delta=2.22316	gamma=-4.31552	mean=1.85996	mu=1.75286	n_CB=7.42796	para_lambda=-0.16177	sig1frac=1.72962e-07	sigma2=0.0160558
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54032,delta = 2.22316,gamma = -4.31552,mean = 1.85996,mu = 1.75286,n_CB = 7.42796,para_lambda = -0.16177,sig1frac = 1.72962e-07,sigma2 = 0.0160558)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-618.841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.54478	delta=2.22289	gamma=-4.31514	mean=1.85995	mu=1.75282	n_CB=7.34892	para_lambda=-0.16177	sig1frac=2.40318e-09	sigma2=0.0160596
# PID16246/RooRealMPFE::nll_model_sighist_561221945390_MPFE11[ arg=nll_model_sighist_GOF11 vars=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#     ... (remaining 17 messages suppressed)
# RooNLLVar::nll_model_sighist[ paramSet=(alpha,delta,gamma,mean,mu,n_CB,para_lambda,sig1frac,sigma2) ]
#      function value is NAN @ paramSet=(alpha = 1.54478,delta = 2.22289,gamma = -4.31514,mean = 1.85995,mu = 1.75282,n_CB = 7.34892,para_lambda = -0.16177,sig1frac = 2.40318e-09,sigma2 = 0.0160596)
#
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
#
#   RooFitResult: minimized FCN value: -873.234, estimated distance to minimum: 3.63221e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Floating Parameter    FinalValue +/-  Error
#   --------------------  --------------------------
#                  alpha    1.5448e+00 +/-  3.74e-01
#                  delta    2.2229e+00 +/-  1.11e+00
#                  gamma   -4.3151e+00 +/-  1.45e+00
#                   mean    1.8599e+00 +/-  1.08e-03
#                     mu    1.7528e+00 +/-  1.02e-01
#                   n_CB    7.3489e+00 +/-  6.82e+00
#            para_lambda    4.5701e-01 +/-  7.20e+00
#               sig1frac    2.4032e-09 +/-  8.63e-03
#                 sigma2    1.6060e-02 +/-  8.77e-04
#
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) only plotting range 'fit_nll_model_sighist'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_model_sighist'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (sig1)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) only plotting range 'fit_nll_model_sighist'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_model_sighist'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) directly selected PDF components: (sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) only plotting range 'fit_nll_model_sighist'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_model_sighist'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file /media/jykim/T7/saved_plots/fitting/results/phigamma/phi_massveto_1ab_signal.png has been created

# %%
model.Print("t")
# Out:
# 0x56122070e120 RooAddPdf::model = 0.0803206 [Auto,Dirty]
#   0x56121e9b9a60/V- RooJohnson::sig1 = 0.00067149 [Auto,Dirty]
#     0x56121dcdc5a0/V- RooRealVar::M(D^{0}) = 1.82
#     0x561220cc7210/V- RooRealVar::mu = 1.75282 +/- 0.101933
#     0x56121ffcc6c0/V- RooRealVar::para_lambda = 0.457013 +/- 7.19993
#     0x56122070cfd0/V- RooRealVar::gamma = -4.31514 +/- 1.44656
#     0x5612212cdab0/V- RooRealVar::delta = 2.22289 +/- 1.10596
#   0x5612212ca430/V- RooRealVar::sig1frac = 2.40318e-09 +/- 0.0086346
#   0x56121e5d9f20/V- RooCBShape::sig2 = 0.0803206 [Auto,Dirty]
#     0x56121dcdc5a0/V- RooRealVar::M(D^{0}) = 1.82
#     0x561225f2dd80/V- RooRealVar::mean = 1.85995 +/- 0.00108024
#     0x56121b596f60/V- RooRealVar::sigma2 = 0.0160596 +/- 0.000876737
#     0x56121be977a0/V- RooRealVar::alpha = 1.54478 +/- 0.374077
#     0x56121a5db880/V- RooRealVar::n_CB = 7.34892 +/- 6.82461

# %%
f = ROOT.TFile.Open("phig_signalMC_fitresult.root")
r2 = ROOT.gDirectory.Get("phig_sig")
f.Close()

# %%
r2.Print()
# Out:
#   RooFitResult: minimized FCN value: -887.083, estimated distance to minimum: 1.04054e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Floating Parameter    FinalValue +/-  Error
#   --------------------  --------------------------
#                  alpha    1.6191e+00 +/-  3.25e-01
#                   mean    1.8598e+00 +/-  9.60e-04
#                   n_CB    6.1775e+00 +/-  5.95e+00
#                 sigma2    1.6119e-02 +/-  7.52e-04

# %%
r2.correlation("alpha","n_CB")
# Out:
# -0.8203722070919535

# %%
r2.edm()
# Out:
# 1.0405431410093377e-05

# %%
r2.correlationMatrix()
# Out:
# <cppyy.gbl.TMatrixTSym<double> object at 0x55b469464fd0>
