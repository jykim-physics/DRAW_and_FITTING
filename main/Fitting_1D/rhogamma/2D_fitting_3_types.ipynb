# %% [markdown]
# ### import

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ROOT
import ctypes
import math
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
# Out:
# Welcome to JupyROOT 6.26/04

# %% [markdown]
# # 2D

# %%
#base_file_loc = '/media/jykim/T7/storage/01_recon/new_sigext_cuts_skim_1ab_inv_bkg_sig/'
# base_file_loc = '/media/jykim/T7/storage/01_recon/trainv2new_pi0veto/'
base_file_loc = '/media/jykim/T7/storage/01_recon/trainv2new_400invfb/'

base_file_loc = '/media/jykim/T7/storage/01_recon/trainv2new_sig_extract_400fb/'
base_file_loc = '/media/jykim/T7/storage/01_recon/trainv2_new_correct_data_sig_ext_sig_bkg/'
base_file_loc =  '/media/jykim/T7/storage/01_recon/train_v6_beambkg_sig_ext/'
base_file_loc =  '/media/jykim/T7/storage/01_recon/v6_pre_ext_omega_const_wide_Q/'
base_file_loc =  '/media/jykim/T7/storage/01_recon/massvetov2_sig_ext_1ab_sigbkg/'


# phigamma_ccbar = base_file_loc + 'topo/skim_1abinv_phi_D0_M/topoana.root'
phigamma_ccbar = base_file_loc + 'ccbar/recon_udst_*.root'
phigamma_uubar = base_file_loc + 'uubar/recon_udst_*.root'
phigamma_ddbar = base_file_loc + 'ddbar/recon_udst_*.root'
phigamma_ssbar = base_file_loc + 'ssbar/recon_udst_*.root'
phigamma_charged = base_file_loc + 'charged/recon_udst_*.root'
phigamma_mixed = base_file_loc + 'mixed/recon_udst_*.root'
phigamma_taupair = base_file_loc + 'taupair/recon_udst_*.root'

base_filter=' Pi0_Prob<0.85 && Pis_charge==+1 && D0_M>1.67 && D0_M<2.06 '
base_filter=' phi_rank_Dstp==1 && Dstarp_CMS_p>2.49 && Pi0_Prob<0.9  && D0_M>1.67 && D0_M<2.06 && abs(D0_cosHel_0)<=1'


base_filter='Belle2Pi0Veto_75MeV > 0.022 && D0_M>1.67 && D0_M<2.06  '

# base_filter=' Pi0_Prob<0.90 && Pis_charge==-1 && D0_M>1.72 && D0_M<2.01 '

#base_filter='Pi0_Prob<0.90  && D0_M>1.67 && D0_M<2.06 '

# base_filter='Pi0_Prob<0.95 && phi_rank_Dstp==1 && D0_M>1.67 && D0_M<2.06'

#ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_Dst_0 !=1 && iCascDcyBrP_Dst_0 !=2)'
# ccbar_filter='Pi0_Prob<0.9 && Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '


#ccbar_filter='Pi0_Prob<0.9 && D0_M>1.67 && D0_M<2.06 && (iCascDcyBrP_D0_0 !=0 ) && (phi_rank_Dstp ==1)'

variables=['D0_M','D0_cosHel_0']
# tree='antiKstar_cc'
tree='rho'

# %%
# pd_phigamma_ccbar = get_pd(file=phigamma_ccbar, tree=tree,base_filter=base_filter,variables=topo_variables)
pd_phigamma_ccbar = get_pd(file=phigamma_ccbar, tree=tree,base_filter=base_filter,variables=variables)

pd_phigamma_uubar = get_pd(file=phigamma_uubar, tree=tree,base_filter=base_filter,variables=variables)
pd_phigamma_ddbar = get_pd(file=phigamma_ddbar, tree=tree,base_filter=base_filter,variables=variables)
pd_phigamma_ssbar = get_pd(file=phigamma_ssbar, tree=tree,base_filter=base_filter,variables=variables)
pd_phigamma_charged = get_pd(file=phigamma_charged, tree=tree,base_filter=base_filter,variables=variables)
pd_phigamma_mixed = get_pd(file=phigamma_mixed, tree=tree,base_filter=base_filter,variables=variables)
pd_phigamma_taupair = get_pd(file=phigamma_taupair, tree=tree,base_filter=base_filter,variables=variables)

# %%
phigamma_generic=pd.concat([pd_phigamma_ccbar,
                           pd_phigamma_uubar,
                           pd_phigamma_ddbar,
                           pd_phigamma_ssbar,
                           pd_phigamma_charged,
                           pd_phigamma_mixed,
                           pd_phigamma_taupair],ignore_index=True)

# %%
ccbar_file = "/media/jykim/T7/storage/01_recon/massvetov2_sig_ext_1ab_sigbkg/topo/resultfile/result_rho/standard.root"
pd_only_ccbar = get_pd(file=ccbar_file, tree=tree,base_filter=base_filter,variables=variables)

D0_M_pd_data = pd_only_ccbar['D0_M']
D0_cosHel_0_pd_data = pd_only_ccbar['D0_cosHel_0']

D0_M_np_data = D0_M_pd_data.to_numpy()
D0_cosHel_0_np_data = D0_cosHel_0_pd_data.to_numpy()

# %%
# D0_M_pd_data = phigamma_generic['D0_M']
# D0_cosHel_0_pd_data = phigamma_generic['D0_cosHel_0']

# D0_M_np_data = D0_M_pd_data.to_numpy()
# D0_cosHel_0_np_data = D0_cosHel_0_pd_data.to_numpy()

# %%
# ROOT.RooClassFactory.makePdf("MyPdf_xsquared_nopara", "x", "", "x*x")
ROOT.gROOT.ProcessLineSync(".x MyPdf_xsquared_nopara.cxx+")
# Out:
# 94456269155856
# (MyPdf_xsquared_nopara) An instance of MyPdf_xsquared_nopara.

# %%
# ROOT.RooClassFactory.makePdf("MyPdf_one_minus_squared", "y", "", "1-y*y")
ROOT.gROOT.ProcessLineSync(".x MyPdf_one_minus_squared.cxx+")
# Out:
# 94456383528048
# (MyPdf_one_minus_squared) An instance of MyPdf_one_minus_squared.

# %%
file1_name="test2_x_D0.png"
file2_name="test2_y_D0.png"


####################
#D0_M
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", 1.67, 2.06, "")
# x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", 1.72, 2.01, "")

# x.setBins(50)

#### Construct signal model for x
x_sig_mean = ROOT.RooRealVar("x_sig_mean", "mean of gaussians", 1.863,1.86, 1.88)
x_sig_sigma1 = ROOT.RooRealVar("x_sig_sigma1", "width of gaussians", 0.01,0.005,0.02)
x_sig_sigma2 = ROOT.RooRealVar("x_sig_sigma2", "width of gaussians", 0.01,0.005,0.02)
x_sig_alpha = ROOT.RooRealVar("x_sig_alpha", "width of gaussians", 5,2,10)
x_sig_n_CB = ROOT.RooRealVar("x_sig_n_CB", "width of gaussians", 5,1,10)

x_sig_1 = ROOT.RooGaussian("x_sig_1", "Signal component 1", x, x_sig_mean, x_sig_sigma1)
x_sig_2 = ROOT.RooCBShape("x_sig_2", "Signal component 2", x, x_sig_mean, x_sig_sigma2, x_sig_alpha, x_sig_n_CB)

x_sigfrac = ROOT.RooRealVar("x_sigfrac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)

x_sig_model = ROOT.RooAddPdf("x_sig_model", "model", [x_sig_1, x_sig_2], x_sigfrac)

#### Construct bkg model for x
#V pi0
x_bkg1_sigma1 = ROOT.RooRealVar("x_bkg1_sigma1", "width of gaussians", 0.03,0,0.5)
x_bkg1_alpha = ROOT.RooRealVar("x_bkg1_alpha", "width of gaussians",  0.2,0.,5)
x_bkg1_n_CB = ROOT.RooRealVar("x_bkg1_n_CB", "width of gaussians", 3,0,10)
x_bkg1_mean = ROOT.RooRealVar("x_bkg1_mean", "mean of gaussians", 1.83,1.82, 1.85)

x_bkg1_model = ROOT.RooCBShape("x_bkg1_model", "Signal component 2", x, x_bkg1_mean, x_bkg1_sigma1, x_bkg1_alpha, x_bkg1_n_CB)

####BKG2
# remaining
x_bkg2_mean = ROOT.RooRealVar("x_bkg2_mean", "mean of gaussians", 1.6,1.4, 1.67)
x_bkg2_sigma1 = ROOT.RooRealVar("x_bkg2_sigma1", "width of gaussians", 0.03,0,0.5)
x_bkg2_tau = ROOT.RooRealVar("x_bkg2_tau", "tau",-2, -5,0)

x_bkg2_1 = ROOT.RooGaussian("x_bkg2_1", "Signal component 1", x, x_bkg2_mean, x_bkg2_sigma1)
x_bkg2_2 = ROOT.RooExponential("x_bkg2_2", "Signal component 1", x, x_bkg2_tau) 
x_bkg2frac = ROOT.RooRealVar("x_bkg2frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)

x_bkg2_model = ROOT.RooAddPdf("x_bkg2_model", "model", [x_bkg2_1, x_bkg2_2], x_bkg2frac)

#phipi0,Kshort K+k-
####BKG3
# x_bkg3_mean = ROOT.RooRealVar("x_bkg3_mean", "mean of gaussians", 1.65,1.58, 1.68)
# x_bkg3_sigma1 = ROOT.RooRealVar("x_bkg3_sigma1", "width of gaussians", 0.01,0,0.08)

# x_bkg3_model = ROOT.RooGaussian("x_bkg3_model", "Signal component 1", x,x_bkg3_mean, x_bkg3_sigma1)
#x_bkg3_mean = ROOT.RooRealVar("x_bkg3_mean", "mean of gaussians", 1.65,1.58, 1.7)
#x_bkg3_sigma1 = ROOT.RooRealVar("x_bkg3_sigma1", "width of gaussians", 0.01,0,0.07)


# x_bkg3_c0 = ROOT.RooRealVar("x_bkg3_c0", "c0",0.1, 0,1.)
# # c1 = ROOT.RooRealVar("c1", "c1",0.5, 0,1.)
# # c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
# x_bkg3_1 = ROOT.RooPolynomial("x_bkg3_1", "Signal component 1", x, ROOT.RooArgList(x_bkg3_c0), lowestOrder=1)
    
# x_bkg3_tau = ROOT.RooRealVar("x_bkg3_tau", "tau",-2, -20,0)
# x_bkg3_2 = ROOT.RooExponential("x_bkg3_2", "Signal component 1", x, x_bkg3_tau)    

#x_bkg3_2 = ROOT.RooGaussian("x_bkg3_2", "Signal component 1", x, x_bkg3_mean, x_bkg3_sigma1)


# x_bkg3frac1  = ROOT.RooRealVar("x_bkg3frac1", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
# x_bkg3_model = ROOT.RooAddPdf("x_bkg3_model", "Signal1", [x_bkg3_1, x_bkg3_2], x_bkg3frac1)

################
#D0_cosHel_0
yrange=(-1,1)
# yrange=(-0.8,0.8)

# yrange=(-0.,1)

y = ROOT.RooRealVar("cos#theta_{H}", "cos#theta_{H}", yrange[0], yrange[1], "")
# y.setBins(50)

y_sig_model = ROOT.MyPdf_one_minus_squared("y_sig_model", "y_sig", y)


#### Construct bkg model for y
#V pi0
y_bkg1_mean1 = ROOT.RooRealVar("y_bkg1_mean1", "mean of gaussians", -0.7,-0.8, -0.6)
y_bkg1_mean2 = ROOT.RooRealVar("y_bkg1_mean2", "mean of gaussians", 0.9,0.8, 1.2)

y_bkg1_sigma1 = ROOT.RooRealVar("y_bkg1_sigma1", "width of gaussians", 0.03,0,0.2)
y_bkg1_sigma2 = ROOT.RooRealVar("y_bkg1_sigma2", "width of gaussians", 0.1,0,0.2)


y_bkg1_Cheby_c0 = ROOT.RooRealVar("y_bkg1_Cheby_c0", "c0",0.2, -1,1)
y_bkg1_Cheby_c1 = ROOT.RooRealVar("y_bkg1_Cheby_c1", "c0",0.2, -1,1)
y_bkg1_Cheby_c2 = ROOT.RooRealVar("y_bkg1_Cheby_c2", "c0",-0.2, -1,1)


# y_bkg1_1 = ROOT.MyPdf_xsquared_nopara("sig1", "y_bkg1", y)
y_bkg1_2 = ROOT.RooGaussian("y_bkg1_2", "Signal component 1", y, y_bkg1_mean1, y_bkg1_sigma1)
y_bkg1_3 = ROOT.RooGaussian("y_bkg1_3", "Signal component 1", y, y_bkg1_mean2, y_bkg1_sigma2)
y_bkg1_4 = ROOT.RooChebychev("y_bkg1_4", "Signal component 1", y, ROOT.RooArgList(y_bkg1_Cheby_c0, y_bkg1_Cheby_c1, y_bkg1_Cheby_c2))


# y_bkg1frac_1 = ROOT.RooRealVar("y_bkg1frac_1", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
y_bkg1frac_2 = ROOT.RooRealVar("y_bkg1frac_2", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
y_bkg1frac_3 = ROOT.RooRealVar("y_bkg1frac_3", "fraction of component 1 in signal", 0.5, 0.0, 1.0)

# y_bkg1_added_1 = ROOT.RooAddPdf("y_bkg1_added_1", "model", [y_bkg1_1, y_bkg1_2], y_bkg1frac_1)
y_bkg1_added_2 = ROOT.RooAddPdf("y_bkg1_added_2", "model", [y_bkg1_3, y_bkg1_2], y_bkg1frac_2)

y_bkg1_model = ROOT.RooAddPdf("y_bkg1_model", "model", [y_bkg1_4, y_bkg1_added_2], y_bkg1frac_3)



# y_bkg1_model = ROOT.MyPdf_xsquared_nopara("y_bkg1_model", "y_bkg1", y)

#remaining
y_bkg2_mean1 = ROOT.RooRealVar("y_bkg2_mean1", "mean of gaussians", -0.7,-0.8, -0.6)
y_bkg2_sigma1 = ROOT.RooRealVar("y_bkg2_sigma1", "width of gaussians", 0.03,0,0.2)

y_bkg2_Cheby_c0 = ROOT.RooRealVar("y_bkg2_Cheby_c0", "c0",0.2, -1,1)
y_bkg2_Cheby_c1 = ROOT.RooRealVar("y_bkg2_Cheby_c1", "c0",0.2, -1,1)
y_bkg2_Cheby_c2 = ROOT.RooRealVar("y_bkg2_Cheby_c2", "c0",-0.2, -1,1)

y_bkg2_1 = ROOT.RooGaussian("y_bkg2_1", "Signal component 1", y, y_bkg2_mean1, y_bkg2_sigma1)
y_bkg2_2 = ROOT.RooChebychev("y_bkg2_2", "Signal component 1", y, ROOT.RooArgList(y_bkg2_Cheby_c0, y_bkg2_Cheby_c1, y_bkg2_Cheby_c2))


y_bkg2frac = ROOT.RooRealVar("y_bkg2frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
y_bkg2_model = ROOT.RooAddPdf("y_bkg2_model", "model", [y_bkg2_1, y_bkg2_2], y_bkg2frac)


# y_bkg2_model= ROOT.RooPolynomial("y_bkg2_model", "Signal component 1", y, ROOT.RooArgList(y_bkg2_c0, y_bkg2_c1))

####BKG3
# y_bkg3_c0 = ROOT.RooRealVar("y_bkg3_c0", "c0",0.1, 0,1.)
# y_bkg3_c1 = ROOT.RooRealVar("y_bkg3_c1", "c1",0.5, 0,1.)
# y_bkg3_c2 = ROOT.RooRealVar("y_bkg3_c2", "c2",-0.3, -1.,0.)
# y_bkg3_model = ROOT.RooChebychev("y_bkg3_model", "Signal component 1", y, ROOT.RooArgList(y_bkg3_c0, y_bkg3_c1, y_bkg3_c2))
# y_bkg3_model = ROOT.MyPdf_xsquared_nopara("y_bkg3_model", "y_bkg3", y)

#### Combine bkg models
# y_phipi0frac = ROOT.RooRealVar("y_phipi0frac", "fraction of component 1 in signal", 0.2, 0.0, 1.0)
# y_bkg_model = ROOT.RooAddPdf("y_bkg_model", "Signal", [y_bkg1_model, y_bkg2_model], y_phipi0frac)


################
bkg1_xy_model = ROOT.RooProdPdf("bkg1_xy_model","bkg1_xy_model",ROOT.RooArgSet(x_bkg1_model,y_bkg1_model))
bkg2_xy_model = ROOT.RooProdPdf("bkg2_xy_model","bkg2_xy_model",ROOT.RooArgSet(x_bkg2_model,y_bkg2_model))
# bkg3_xy_model = ROOT.RooProdPdf("bkg3_xy_model","bkg3_xy_model",ROOT.RooArgSet(x_bkg3_model,y_bkg3_model))


sig_model = ROOT.RooProdPdf("sig_model","sig_xy_model",ROOT.RooArgSet(x_sig_model, y_sig_model))


####################################
# construct signal + bkg pdf
nsig = ROOT.RooRealVar("nsig","# signal events",100,0,len(D0_M_np_data))
nbkg1 = ROOT.RooRealVar("nbkg1","# bkg events",600,0, len(D0_M_np_data))
nbkg2 = ROOT.RooRealVar("nbkg2","# bkg events",300,0, len(D0_M_np_data))
# nbkg3 = ROOT.RooRealVar("nbkg3","# bkg events",100,0, len(D0_M_np_data))

# nbkg3 = ROOT.RooRealVar("nbkg3","# bkg events",300,0., len(D0_M_np_data))


# extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg1_xy_model,bkg2_xy_model,bkg3_xy_model), ROOT.RooArgSet(nsig, nbkg1, nbkg2, nbkg3))
extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg1_xy_model,bkg2_xy_model), ROOT.RooArgSet(nsig, nbkg1, nbkg2))

#####################################
# # Associated nsig/nbkg as expected number of events with sig/bkg
# esig = ROOT.RooExtendPdf("esig", "extended signal pdf", sig_xy_model, nsig)
# ebkg = ROOT.RooExtendPdf("ebkg", "extended background pdf", bkg_xy_model, nbkg)
 
# # Sum extended components without coefs
# # -------------------------------------------------------------------------
 
# # Construct sum of two extended pdf (no coefficients required)
# extended_model = ROOT.RooAddPdf("extended_model", "bkg_sig", [ebkg, esig ])


# datax = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data['D0_M']}, [x])
# datay = ROOT.RooDataSet.from_numpy({"cos#theta_{H}": np_data['D0_cosHel_0']}, [y])

data = ROOT.RooDataSet.from_numpy({"M(D^{0})": D0_M_np_data, "cos#theta_{H}": D0_cosHel_0_np_data}, [x,y])

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

    # r = sig.fitTo(data,NumCPU=12, Range=(1.84,1.89))
# r = sig_xy_model.fitTo(data,NumCPU=12, Range=(1.70,1.98))
# r = extended_model.fitTo(data,NumCPU=12, Extended=ROOT.kTRUE)
r = extended_model.fitTo(data,NumCPU=12, Extended=ROOT.kTRUE,PrintLevel=-1, Save=1, )


    # r.Print()
canv.cd(1) 
#     frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

    # sig1.plotOn(frame, LineStyle="--", LineColor="r")
    # sig2.plotOn(frame, LineStyle="--", LineColor="r")
# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB2", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

# sig_xy_model.plotOn(frame,Components=mass_sig, ProjWData=data, Name="fitting")
extended_model.plotOn(frame, Name="fitx_sig", Components=x_sig_model, LineStyle=ROOT.kDashed, LineColor='r')
# extended_model.plotOn(frame, Name="fitx_bkg", Components=ROOT.RooArgSet(x_bkg1_model,x_bkg2_model), LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+2)
extended_model.plotOn(frame, Name="fitx_bkg1", Components=x_bkg1_model, LineStyle=ROOT.kDashed, LineColor=593)
extended_model.plotOn(frame, Name="fitx_bkg2", Components=x_bkg2_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+2)
# extended_model.plotOn(frame, Name="fitx_bkg3", Components=x_bkg3_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+10)



# extended_model.plotOn(frame, Name="fitx1", Components=x_bkg2_model, LineStyle=ROOT.kDashed, LineColor=593)

# extended_model.plotOn(frame, Name="fitx2", Components=x_sig_3, LineStyle=ROOT.kDashed, LineColor='r')
#sig_xy_model.plotOn(frame, Name="fitx3", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

extended_model.plotOn(frame,Name="fitting")
frame.Draw("PE")

    # sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
    


leg1 = ROOT.TLegend(0.65, 0.65, 0.9, 0.85)
# leg1.SetFillColor(ROOT.kWhite)
leg1.SetFillColor(0)

    # leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.AddEntry("fitx_sig", "signal", "l")
leg1.AddEntry("fitx_bkg1", "bkg1", "l")
leg1.AddEntry("fitx_bkg2", "bkg2", "l")
# leg1.AddEntry("fitx_bkg3", "bkg3", "l")

# leg1.SetTextSize(0.05)
# leg1.SetTextAlign(13)

leg1.SetBorderSize(0)
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
    # pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
    # pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(1.67)
xmax1 = ctypes.c_double(2.06)
    # xmin1 = 0.1
    # xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs(file1_name)

#######################################
canv2 = ROOT.TCanvas("Canvas", "Canvas", 700, 640)
# canv2.cd()
y_xlow = ctypes.c_double()
y_ylow = ctypes.c_double()
y_xup = ctypes.c_double()
y_yup = ctypes.c_double()

canv2.GetPad(0).GetPadPar(y_xlow, y_ylow, y_xup, y_yup)
canv2.Divide(1,2)

y_xlow = y_xlow.value
y_ylow = y_ylow.value
y_xup = y_xup.value
y_yup = y_yup.value

y_upPad = canv2.GetPad(1)
y_upPad.SetPad(y_xlow, y_ylow+0.25*(y_yup-y_ylow),y_xup,y_yup)

y_dwPad = canv2.GetPad(2)
y_dwPad.SetPad(y_xlow, y_ylow,y_xup,y_ylow+0.25*(y_yup-y_ylow))


yframe = y.frame(Title=" ")
canv2.cd(1) 
data.plotOn(yframe,Name = "data2", XErrorSize=0)

    # sig1.plotOn(frame, LineStyle="--", LineColor="r")
    # sig2.plotOn(frame, LineStyle="--", LineColor="r")
# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB2", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)

# sig_xy_model.plotOn(frame,Components=mass_sig, ProjWData=data, Name="fitting")

extended_model.plotOn(yframe, Name="fity_sig", Components=y_sig_model, LineStyle=ROOT.kDashed, LineColor='r')
extended_model.plotOn(yframe, Name="fity_bkg1", Components=ROOT.RooArgSet(y_bkg1_model), LineStyle=ROOT.kDashed, LineColor=593)
extended_model.plotOn(yframe, Name="fity_bkg2", Components=ROOT.RooArgSet(y_bkg2_model), LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+2)
# extended_model.plotOn(yframe, Name="fity_bkg3", Components=ROOT.RooArgSet(y_bkg3_model), LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+10)

# extended_model.plotOn(yframe, Name="fity_bkg", Components=ROOT.RooArgSet(y_bkg1_model,y_bkg2_model), LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen+2)
# extended_model.plotOn(yframe, Name="fity_bkg", Components=ROOT.RooArgSet(y_bkg1_model,y_bkg2_model,y_bkg3_model), LineStyle=ROOT.kDashed, LineColor=593)

#sig_xy_model.plotOn(yframe, Name="fit3", Components=sigy3, LineStyle=ROOT.kDashed, LineColor=593)



extended_model.plotOn(yframe,Name="fitting2")



yframe.Draw("PE")

    # sig.paramOn(frame)
yframe.GetXaxis().SetTitleSize(0.047)
yframe.GetXaxis().CenterTitle(True)
yframe.GetYaxis().SetTitleSize(0.04)
yframe.GetYaxis().SetTitleOffset(1.2)
    


# y_leg1 = ROOT.TLegend(0.25, 0.65, 0.5, 0.85)
y_leg1 = ROOT.TLegend(0.65, 0.65, 0.9, 0.85)


# y_leg1.SetFillColor(ROOT.kWhite)
y_leg1.SetFillColor(0)

    # leg1.SetHeader("The Legend title","C")
y_leg1.AddEntry("data2", "MC", "PE")
y_leg1.AddEntry("fitting2", "fit", "l")
y_leg1.AddEntry("fity_sig", "signal", "l")
y_leg1.AddEntry("fity_bkg1", "bkg1", "l")
y_leg1.AddEntry("fity_bkg2", "bkg2", "l")
# y_leg1.AddEntry("fity_bkg3", "bkg3", "l")

y_leg1.SetBorderSize(0)

y_leg1.Draw()

y_hpull = yframe.pullHist()
y_hpull.SetFillStyle(1001)
y_hpull.SetFillColor(1);
for i in range(0,y_hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    y_hpull.SetPointError(i,0.0,0.0,0.0,0.0)
    # pullplot = x.frame(Title(" "))
y_pullplot = y.frame()
y_pullplot.SetTitle("")
y_pullplot.addPlotable(y_hpull,"BE")
    # pullplot.addPlotable(hpull,"PE")

y_pullplot.SetYTitle("Pull")
y_pullplot.GetXaxis().SetTitleSize(0)
y_pullplot.GetYaxis().SetTitleSize(0.17)
y_pullplot.GetYaxis().CenterTitle(True)
y_pullplot.GetYaxis().SetTitleOffset(0.2)
y_pullplot.SetMinimum(-4.)
y_pullplot.SetMaximum(4.)
y_pullplot.GetXaxis().SetLabelSize(0.1)
y_pullplot.GetYaxis().SetLabelSize(0.09)
canv2.cd(2)
y_pullplot.Draw()

y_xmin1 = ctypes.c_double(-1)
y_xmax1 = ctypes.c_double(1)
y_line = ROOT.TLine(y_xmin1,0.0,y_xmax1,0.0)
y_line1 = ROOT.TLine(y_xmin1,3.0,y_xmax1,3.0)
y_line2 = ROOT.TLine(y_xmin1,-3.0,y_xmax1,-3.0)

y_line.SetLineColor(ROOT.kRed)
y_line.SetLineWidth(3)
y_line1.SetLineColor(ROOT.kRed)
y_line2.SetLineColor(ROOT.kRed)
y_line1.SetLineStyle(2)
y_line2.SetLineStyle(2)
y_line.Draw("SAME")
y_line1.Draw("SAME")
y_line2.Draw("SAME")

canv2.Update()

canv2.Draw()
canv2.SaveAs(file2_name)
# Out:
# [#0] WARNING:InputArguments -- The parameter 'x_bkg2_sigma1' with range [0, 0.5] of the RooGaussian 'x_bkg2_1' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'y_bkg1_sigma1' with range [0, 0.2] of the RooGaussian 'y_bkg1_2' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'y_bkg1_sigma2' with range [0, 0.2] of the RooGaussian 'y_bkg1_3' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'y_bkg2_sigma1' with range [0, 0.2] of the RooGaussian 'y_bkg2_1' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# [#1] INFO:Minimization --  The following expressions have been identified as constant and will be precalculated and cached: (y_sig_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (x_sig_1,x_sig_2,x_bkg1_model,y_bkg1_4,y_bkg1_3,y_bkg1_2,x_bkg2_1,x_bkg2_2,y_bkg2_1,y_bkg2_2)
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=5691.25	nbkg2=2406.11	nsig=9264.25	x_bkg1_alpha=0.057282	x_bkg1_mean=1.82293	x_bkg1_n_CB=0.0990951	x_bkg1_sigma1=0.00506842	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0672462	x_bkg2_tau=-0.480178	x_bkg2frac=0.15257	x_sig_alpha=2	x_sig_mean=1.86001	x_sig_n_CB=1	x_sig_sigma1=0.02	x_sig_sigma2=0.02	x_sigfrac=0.170404	y_bkg1_Cheby_c0=-0.943293	y_bkg1_Cheby_c1=-0.113479	y_bkg1_Cheby_c2=-0.0815142	y_bkg1_mean1=-0.8	y_bkg1_mean2=0.925229	y_bkg1_sigma1=0.0941103	y_bkg1_sigma2=0.12102	y_bkg1frac_2=0.531786	y_bkg1frac_3=0.746824	y_bkg2_Cheby_c0=-0.389515	y_bkg2_Cheby_c1=0.59895	y_bkg2_Cheby_c2=-0.0496069	y_bkg2_mean1=-0.669111	y_bkg2_sigma1=0.0605267	y_bkg2frac=0.150113
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.679442/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.32156/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0011764/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.27619/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.121335/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.36958/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0503856/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.45058/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.00937713/1,bkg1_xy_model = nan/1,bkg2_xy_model = 2.25097/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0204631/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.49468/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.307029/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.35722/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.00273352/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.49658/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.539106/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.30933/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.37485/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.22596/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.906839/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.30145/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 4.85874e-09/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.26209/1), !coefficients=(nsig = 9264.25,nbkg1 = 5691.25,nbkg2 = 2406.11)
#     ... (remaining 3522 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 5691.25,nbkg2 = 2406.11,nsig = 9264.25,x_bkg1_alpha = 0.057282,x_bkg1_mean = 1.82293,x_bkg1_n_CB = 0.0990951,x_bkg1_sigma1 = 0.00506842,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0672462,x_bkg2_tau = -0.480178,x_bkg2frac = 0.15257,x_sig_alpha = 2,x_sig_mean = 1.86001,x_sig_n_CB = 1,x_sig_sigma1 = 0.02,x_sig_sigma2 = 0.02,x_sigfrac = 0.170404,y_bkg1_Cheby_c0 = -0.943293,y_bkg1_Cheby_c1 = -0.113479,y_bkg1_Cheby_c2 = -0.0815142,y_bkg1_mean1 = -0.8,y_bkg1_mean2 = 0.925229,y_bkg1_sigma1 = 0.0941103,y_bkg1_sigma2 = 0.12102,y_bkg1frac_2 = 0.531786,y_bkg1frac_3 = 0.746824,y_bkg2_Cheby_c0 = -0.389515,y_bkg2_Cheby_c1 = 0.59895,y_bkg2_Cheby_c2 = -0.0496069,y_bkg2_mean1 = -0.669111,y_bkg2_sigma1 = 0.0605267,y_bkg2frac = 0.150113)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=5551.73	nbkg2=2440.17	nsig=7398.72	x_bkg1_alpha=3.88081	x_bkg1_mean=1.84587	x_bkg1_n_CB=0.536904	x_bkg1_sigma1=0.0430415	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0515997	x_bkg2_tau=-0.395732	x_bkg2frac=0.107007	x_sig_alpha=2.00016	x_sig_mean=1.86001	x_sig_n_CB=1.00003	x_sig_sigma1=0.02	x_sig_sigma2=0.02	x_sigfrac=0.00225374	y_bkg1_Cheby_c0=-0.998357	y_bkg1_Cheby_c1=0.980403	y_bkg1_Cheby_c2=0.158324	y_bkg1_mean1=-0.799995	y_bkg1_mean2=0.873981	y_bkg1_sigma1=0.0761713	y_bkg1_sigma2=0.150051	y_bkg1frac_2=0.477132	y_bkg1frac_3=0.896442	y_bkg2_Cheby_c0=0.000308021	y_bkg2_Cheby_c1=0.358814	y_bkg2_Cheby_c2=-0.132135	y_bkg2_mean1=-0.666677	y_bkg2_sigma1=0.0550307	y_bkg2frac=0.106339
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.50984e-08/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.728144/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.7926/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.846364/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.289688/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.07652/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.3638/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.897267/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 3.96866/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.18497/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.120042/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.75092/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.22552/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.17304/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.56133/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.77722/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.208795/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.13985/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 2.57695/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.918833/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.387315/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.910786/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.190266/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.11792/1), !coefficients=(nsig = 7398.72,nbkg1 = 5551.73,nbkg2 = 2440.17)
#     ... (remaining 10894 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 5551.73,nbkg2 = 2440.17,nsig = 7398.72,x_bkg1_alpha = 3.88081,x_bkg1_mean = 1.84587,x_bkg1_n_CB = 0.536904,x_bkg1_sigma1 = 0.0430415,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0515997,x_bkg2_tau = -0.395732,x_bkg2frac = 0.107007,x_sig_alpha = 2.00016,x_sig_mean = 1.86001,x_sig_n_CB = 1.00003,x_sig_sigma1 = 0.02,x_sig_sigma2 = 0.02,x_sigfrac = 0.00225374,y_bkg1_Cheby_c0 = -0.998357,y_bkg1_Cheby_c1 = 0.980403,y_bkg1_Cheby_c2 = 0.158324,y_bkg1_mean1 = -0.799995,y_bkg1_mean2 = 0.873981,y_bkg1_sigma1 = 0.0761713,y_bkg1_sigma2 = 0.150051,y_bkg1frac_2 = 0.477132,y_bkg1frac_3 = 0.896442,y_bkg2_Cheby_c0 = 0.000308021,y_bkg2_Cheby_c1 = 0.358814,y_bkg2_Cheby_c2 = -0.132135,y_bkg2_mean1 = -0.666677,y_bkg2_sigma1 = 0.0550307,y_bkg2frac = 0.106339)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=7642.37	nbkg2=3107.79	nsig=4012.18	x_bkg1_alpha=2.22087	x_bkg1_mean=1.85	x_bkg1_n_CB=1.41963	x_bkg1_sigma1=0.0354563	x_bkg2_mean=1.67	x_bkg2_sigma1=0.04569	x_bkg2_tau=-0.110785	x_bkg2frac=0.092506	x_sig_alpha=2.00009	x_sig_mean=1.86015	x_sig_n_CB=1.00002	x_sig_sigma1=0.0199999	x_sig_sigma2=0.02	x_sigfrac=0.0233823	y_bkg1_Cheby_c0=-0.852069	y_bkg1_Cheby_c1=0.998847	y_bkg1_Cheby_c2=-0.377249	y_bkg1_mean1=-0.799992	y_bkg1_mean2=0.885009	y_bkg1_sigma1=0.0738713	y_bkg1_sigma2=0.150406	y_bkg1frac_2=0.546173	y_bkg1frac_3=0.915822	y_bkg2_Cheby_c0=0.274054	y_bkg2_Cheby_c1=0.234191	y_bkg2_Cheby_c2=-0.263822	y_bkg2_mean1=-0.666299	y_bkg2_sigma1=0.0554413	y_bkg2frac=0.0564772
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.377696/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.821769/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 5.62239e-08/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.865244/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 5.03136/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.856785/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.120546/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.33496/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.262501/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.856345/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.124228/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.3171/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 14.1813/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.883197/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.144941/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.41318/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.17059/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.20256/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 9.48567e-07/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.780321/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.133271/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.45148/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.387273/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.940997/1), !coefficients=(nsig = 4012.18,nbkg1 = 7642.37,nbkg2 = 3107.79)
#     ... (remaining 2022 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 7642.37,nbkg2 = 3107.79,nsig = 4012.18,x_bkg1_alpha = 2.22087,x_bkg1_mean = 1.85,x_bkg1_n_CB = 1.41963,x_bkg1_sigma1 = 0.0354563,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.04569,x_bkg2_tau = -0.110785,x_bkg2frac = 0.092506,x_sig_alpha = 2.00009,x_sig_mean = 1.86015,x_sig_n_CB = 1.00002,x_sig_sigma1 = 0.0199999,x_sig_sigma2 = 0.02,x_sigfrac = 0.0233823,y_bkg1_Cheby_c0 = -0.852069,y_bkg1_Cheby_c1 = 0.998847,y_bkg1_Cheby_c2 = -0.377249,y_bkg1_mean1 = -0.799992,y_bkg1_mean2 = 0.885009,y_bkg1_sigma1 = 0.0738713,y_bkg1_sigma2 = 0.150406,y_bkg1frac_2 = 0.546173,y_bkg1frac_3 = 0.915822,y_bkg2_Cheby_c0 = 0.274054,y_bkg2_Cheby_c1 = 0.234191,y_bkg2_Cheby_c2 = -0.263822,y_bkg2_mean1 = -0.666299,y_bkg2_sigma1 = 0.0554413,y_bkg2frac = 0.0564772)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=8752.61	nbkg2=3778.93	nsig=2507.87	x_bkg1_alpha=0.153888	x_bkg1_mean=1.84749	x_bkg1_n_CB=0.119789	x_bkg1_sigma1=0.0298162	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0425279	x_bkg2_tau=-0.235207	x_bkg2frac=0.0617345	x_sig_alpha=2.00007	x_sig_mean=1.86006	x_sig_n_CB=1.00002	x_sig_sigma1=0.0199999	x_sig_sigma2=0.0199998	x_sigfrac=0.0637447	y_bkg1_Cheby_c0=-0.987038	y_bkg1_Cheby_c1=0.893491	y_bkg1_Cheby_c2=0.412059	y_bkg1_mean1=-0.799986	y_bkg1_mean2=0.871103	y_bkg1_sigma1=0.0727319	y_bkg1_sigma2=0.159015	y_bkg1frac_2=0.513521	y_bkg1frac_3=0.969241	y_bkg2_Cheby_c0=0.21945	y_bkg2_Cheby_c1=0.143979	y_bkg2_Cheby_c2=-0.114303	y_bkg2_mean1=-0.659934	y_bkg2_sigma1=0.0575097	y_bkg2frac=0.0308826
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.8382/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.17412/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.271682/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.33353/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.4037/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.22724/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 3.96784/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.46288/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0859132/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.92439/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.112623/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.93724/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.211521/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.39803/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.195851/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.36311/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 2.59696/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.25152/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.36352/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.19218/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.192231/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.41802/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0744226/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.09486/1), !coefficients=(nsig = 2507.87,nbkg1 = 8752.61,nbkg2 = 3778.93)
#     ... (remaining 13866 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 8752.61,nbkg2 = 3778.93,nsig = 2507.87,x_bkg1_alpha = 0.153888,x_bkg1_mean = 1.84749,x_bkg1_n_CB = 0.119789,x_bkg1_sigma1 = 0.0298162,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0425279,x_bkg2_tau = -0.235207,x_bkg2frac = 0.0617345,x_sig_alpha = 2.00007,x_sig_mean = 1.86006,x_sig_n_CB = 1.00002,x_sig_sigma1 = 0.0199999,x_sig_sigma2 = 0.0199998,x_sigfrac = 0.0637447,y_bkg1_Cheby_c0 = -0.987038,y_bkg1_Cheby_c1 = 0.893491,y_bkg1_Cheby_c2 = 0.412059,y_bkg1_mean1 = -0.799986,y_bkg1_mean2 = 0.871103,y_bkg1_sigma1 = 0.0727319,y_bkg1_sigma2 = 0.159015,y_bkg1frac_2 = 0.513521,y_bkg1frac_3 = 0.969241,y_bkg2_Cheby_c0 = 0.21945,y_bkg2_Cheby_c1 = 0.143979,y_bkg2_Cheby_c2 = -0.114303,y_bkg2_mean1 = -0.659934,y_bkg2_sigma1 = 0.0575097,y_bkg2frac = 0.0308826)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=3868.97	nbkg2=1626.93	nsig=6900.2	x_bkg1_alpha=0.495944	x_bkg1_mean=1.83992	x_bkg1_n_CB=0.328554	x_bkg1_sigma1=0.0153765	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0439575	x_bkg2_tau=-0.0461114	x_bkg2frac=0.230818	x_sig_alpha=2.00153	x_sig_mean=1.86054	x_sig_n_CB=1.00022	x_sig_sigma1=0.0199999	x_sig_sigma2=0.0199995	x_sigfrac=0.0667999	y_bkg1_Cheby_c0=-0.771393	y_bkg1_Cheby_c1=0.971858	y_bkg1_Cheby_c2=-0.0657601	y_bkg1_mean1=-0.799992	y_bkg1_mean2=0.895321	y_bkg1_sigma1=0.060362	y_bkg1_sigma2=0.127331	y_bkg1frac_2=0.51216	y_bkg1frac_3=0.756964	y_bkg2_Cheby_c0=0.0563518	y_bkg2_Cheby_c1=0.311472	y_bkg2_Cheby_c2=-0.155397	y_bkg2_mean1=-0.678307	y_bkg2_sigma1=0.0465969	y_bkg2frac=0.213552
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.852/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.686396/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.377/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.728098/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.193489/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.0982/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.357675/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.729381/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0804906/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.637391/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.14817/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.700367/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.16208/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.674981/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 11.9914/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.696765/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.110684/1,bkg1_xy_model = nan/1,bkg2_xy_model = 2.24694/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.115686/1,bkg1_xy_model = nan/1,bkg2_xy_model = 2.17882/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 8.19259/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.682148/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.139169/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.6776/1), !coefficients=(nsig = 6900.2,nbkg1 = 3868.97,nbkg2 = 1626.93)
#     ... (remaining 2650 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 3868.97,nbkg2 = 1626.93,nsig = 6900.2,x_bkg1_alpha = 0.495944,x_bkg1_mean = 1.83992,x_bkg1_n_CB = 0.328554,x_bkg1_sigma1 = 0.0153765,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0439575,x_bkg2_tau = -0.0461114,x_bkg2frac = 0.230818,x_sig_alpha = 2.00153,x_sig_mean = 1.86054,x_sig_n_CB = 1.00022,x_sig_sigma1 = 0.0199999,x_sig_sigma2 = 0.0199995,x_sigfrac = 0.0667999,y_bkg1_Cheby_c0 = -0.771393,y_bkg1_Cheby_c1 = 0.971858,y_bkg1_Cheby_c2 = -0.0657601,y_bkg1_mean1 = -0.799992,y_bkg1_mean2 = 0.895321,y_bkg1_sigma1 = 0.060362,y_bkg1_sigma2 = 0.127331,y_bkg1frac_2 = 0.51216,y_bkg1frac_3 = 0.756964,y_bkg2_Cheby_c0 = 0.0563518,y_bkg2_Cheby_c1 = 0.311472,y_bkg2_Cheby_c2 = -0.155397,y_bkg2_mean1 = -0.678307,y_bkg2_sigma1 = 0.0465969,y_bkg2frac = 0.213552)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=10913.6	nbkg2=5162.1	nsig=866.211	x_bkg1_alpha=0.304712	x_bkg1_mean=1.84788	x_bkg1_n_CB=0.21642	x_bkg1_sigma1=0.0194096	x_bkg2_mean=1.67	x_bkg2_sigma1=0.044733	x_bkg2_tau=-0.471416	x_bkg2frac=0.00862788	x_sig_alpha=2.00022	x_sig_mean=1.86008	x_sig_n_CB=1.00005	x_sig_sigma1=0.0199999	x_sig_sigma2=0.0199996	x_sigfrac=0.0894266	y_bkg1_Cheby_c0=-0.491659	y_bkg1_Cheby_c1=0.956294	y_bkg1_Cheby_c2=-0.736154	y_bkg1_mean1=-0.799976	y_bkg1_mean2=0.824856	y_bkg1_sigma1=0.0743653	y_bkg1_sigma2=0.182423	y_bkg1frac_2=0.571469	y_bkg1frac_3=0.992174	y_bkg2_Cheby_c0=0.412764	y_bkg2_Cheby_c1=0.232113	y_bkg2_Cheby_c2=-0.247445	y_bkg2_mean1=-0.660687	y_bkg2_sigma1=0.0578457	y_bkg2frac=0.00530599
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.351832/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.613119/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.301635/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.616015/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 2.41356/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.625433/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.93606/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.701722/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.403278/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.650554/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.352963/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.931457/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.12583/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.672584/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 4.01232/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.598345/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 5.51619e-08/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.951885/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.188916/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.696495/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.113748/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.701923/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.00970528/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.594265/1), !coefficients=(nsig = 866.211,nbkg1 = 10913.6,nbkg2 = 5162.1)
#     ... (remaining 8946 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 10913.6,nbkg2 = 5162.1,nsig = 866.211,x_bkg1_alpha = 0.304712,x_bkg1_mean = 1.84788,x_bkg1_n_CB = 0.21642,x_bkg1_sigma1 = 0.0194096,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.044733,x_bkg2_tau = -0.471416,x_bkg2frac = 0.00862788,x_sig_alpha = 2.00022,x_sig_mean = 1.86008,x_sig_n_CB = 1.00005,x_sig_sigma1 = 0.0199999,x_sig_sigma2 = 0.0199996,x_sigfrac = 0.0894266,y_bkg1_Cheby_c0 = -0.491659,y_bkg1_Cheby_c1 = 0.956294,y_bkg1_Cheby_c2 = -0.736154,y_bkg1_mean1 = -0.799976,y_bkg1_mean2 = 0.824856,y_bkg1_sigma1 = 0.0743653,y_bkg1_sigma2 = 0.182423,y_bkg1frac_2 = 0.571469,y_bkg1frac_3 = 0.992174,y_bkg2_Cheby_c0 = 0.412764,y_bkg2_Cheby_c1 = 0.232113,y_bkg2_Cheby_c2 = -0.247445,y_bkg2_mean1 = -0.660687,y_bkg2_sigma1 = 0.0578457,y_bkg2frac = 0.00530599)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=10716.1	nbkg2=4870.81	nsig=725.695	x_bkg1_alpha=0.777796	x_bkg1_mean=1.84666	x_bkg1_n_CB=0.255854	x_bkg1_sigma1=0.0141644	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0418229	x_bkg2_tau=-0.157249	x_bkg2frac=0.012126	x_sig_alpha=2.00063	x_sig_mean=1.86002	x_sig_n_CB=1.00012	x_sig_sigma1=0.0199999	x_sig_sigma2=0.0199999	x_sigfrac=0.118561	y_bkg1_Cheby_c0=-0.705505	y_bkg1_Cheby_c1=0.998791	y_bkg1_Cheby_c2=0.567657	y_bkg1_mean1=-0.799971	y_bkg1_mean2=0.827926	y_bkg1_sigma1=0.0710166	y_bkg1_sigma2=0.178134	y_bkg1frac_2=0.588654	y_bkg1frac_3=0.972185	y_bkg2_Cheby_c0=0.0980974	y_bkg2_Cheby_c1=0.171175	y_bkg2_Cheby_c2=0.0704009	y_bkg2_mean1=-0.66602	y_bkg2_sigma1=0.0534269	y_bkg2frac=0.0340284
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.52474e-08/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.04935/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.8773/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.06559/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.255666/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.10153/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.4448/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.07165/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 3.98971/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.21023/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.105914/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.22673/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.198988/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.11435/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.56332/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.08064/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.184228/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.10946/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 2.59547/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.0729/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.342518/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.08121/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.191747/1,bkg1_xy_model = nan/1,bkg2_xy_model = 1.17459/1), !coefficients=(nsig = 725.695,nbkg1 = 10716.1,nbkg2 = 4870.81)
#     ... (remaining 13586 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 10716.1,nbkg2 = 4870.81,nsig = 725.695,x_bkg1_alpha = 0.777796,x_bkg1_mean = 1.84666,x_bkg1_n_CB = 0.255854,x_bkg1_sigma1 = 0.0141644,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0418229,x_bkg2_tau = -0.157249,x_bkg2frac = 0.012126,x_sig_alpha = 2.00063,x_sig_mean = 1.86002,x_sig_n_CB = 1.00012,x_sig_sigma1 = 0.0199999,x_sig_sigma2 = 0.0199999,x_sigfrac = 0.118561,y_bkg1_Cheby_c0 = -0.705505,y_bkg1_Cheby_c1 = 0.998791,y_bkg1_Cheby_c2 = 0.567657,y_bkg1_mean1 = -0.799971,y_bkg1_mean2 = 0.827926,y_bkg1_sigma1 = 0.0710166,y_bkg1_sigma2 = 0.178134,y_bkg1frac_2 = 0.588654,y_bkg1frac_3 = 0.972185,y_bkg2_Cheby_c0 = 0.0980974,y_bkg2_Cheby_c1 = 0.171175,y_bkg2_Cheby_c2 = 0.0704009,y_bkg2_mean1 = -0.66602,y_bkg2_sigma1 = 0.0534269,y_bkg2frac = 0.0340284)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127620) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	nbkg1=12061.5	nbkg2=5734.51	nsig=277.5	x_bkg1_alpha=1.53222	x_bkg1_mean=1.83465	x_bkg1_n_CB=0.0203969	x_bkg1_sigma1=0.0259349	x_bkg2_mean=1.67	x_bkg2_sigma1=0.0384878	x_bkg2_tau=-0.153465	x_bkg2frac=0.000398524	x_sig_alpha=2.00054	x_sig_mean=1.86009	x_sig_n_CB=1.00011	x_sig_sigma1=0.0199998	x_sig_sigma2=0.0199998	x_sigfrac=0.151965	y_bkg1_Cheby_c0=-0.58444	y_bkg1_Cheby_c1=0.999615	y_bkg1_Cheby_c2=-0.0430307	y_bkg1_mean1=-0.799961	y_bkg1_mean2=0.80979	y_bkg1_sigma1=0.0731439	y_bkg1_sigma2=0.18768	y_bkg1frac_2=0.594679	y_bkg1frac_3=0.988687	y_bkg2_Cheby_c0=0.0127822	y_bkg2_Cheby_c1=0.377001	y_bkg2_Cheby_c2=-0.0286783	y_bkg2_mean1=-0.665069	y_bkg2_sigma1=0.0537359	y_bkg2frac=0.0323511
# PID40592/RooRealMPFE::nll_extended_model__55e85ac67170_MPFE11[ arg=nll_extended_model__GOF11 vars=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.5638e-08/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.874273/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 13.9032/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.938413/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.55457/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.893158/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.177128/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.966944/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.329317/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.936645/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0751964/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.895543/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.0582738/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.88081/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.17391/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.950222/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.107212/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.913457/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 1.18792/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.929888/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 11.8994/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.946175/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(sig_model = 0.10571/1,bkg1_xy_model = nan/1,bkg2_xy_model = 0.99745/1), !coefficients=(nsig = 277.5,nbkg1 = 12061.5,nbkg2 = 5734.51)
#     ... (remaining 3274 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(nbkg1,nbkg2,nsig,x_bkg1_alpha,x_bkg1_mean,x_bkg1_n_CB,x_bkg1_sigma1,x_bkg2_mean,x_bkg2_sigma1,x_bkg2_tau,x_bkg2frac,x_sig_alpha,x_sig_mean,x_sig_n_CB,x_sig_sigma1,x_sig_sigma2,x_sigfrac,y_bkg1_Cheby_c0,y_bkg1_Cheby_c1,y_bkg1_Cheby_c2,y_bkg1_mean1,y_bkg1_mean2,y_bkg1_sigma1,y_bkg1_sigma2,y_bkg1frac_2,y_bkg1frac_3,y_bkg2_Cheby_c0,y_bkg2_Cheby_c1,y_bkg2_Cheby_c2,y_bkg2_mean1,y_bkg2_sigma1,y_bkg2frac) ]
#      function value is NAN @ paramSet=(nbkg1 = 12061.5,nbkg2 = 5734.51,nsig = 277.5,x_bkg1_alpha = 1.53222,x_bkg1_mean = 1.83465,x_bkg1_n_CB = 0.0203969,x_bkg1_sigma1 = 0.0259349,x_bkg2_mean = 1.67,x_bkg2_sigma1 = 0.0384878,x_bkg2_tau = -0.153465,x_bkg2frac = 0.000398524,x_sig_alpha = 2.00054,x_sig_mean = 1.86009,x_sig_n_CB = 1.00011,x_sig_sigma1 = 0.0199998,x_sig_sigma2 = 0.0199998,x_sigfrac = 0.151965,y_bkg1_Cheby_c0 = -0.58444,y_bkg1_Cheby_c1 = 0.999615,y_bkg1_Cheby_c2 = -0.0430307,y_bkg1_mean1 = -0.799961,y_bkg1_mean2 = 0.80979,y_bkg1_sigma1 = 0.0731439,y_bkg1_sigma2 = 0.18768,y_bkg1frac_2 = 0.594679,y_bkg1frac_3 = 0.988687,y_bkg2_Cheby_c0 = 0.0127822,y_bkg2_Cheby_c1 = 0.377001,y_bkg2_Cheby_c2 = -0.0286783,y_bkg2_mean1 = -0.665069,y_bkg2_sigma1 = 0.0537359,y_bkg2frac = 0.0323511)
#
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (x_sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (x_sig_1,x_sig_2,sig_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on M(D^{0}) integrates over variables (cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (x_bkg1_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (bkg1_xy_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on M(D^{0}) integrates over variables (cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (x_bkg2_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (x_bkg2_1,x_bkg2_2,bkg2_xy_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on M(D^{0}) integrates over variables (cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on M(D^{0}) integrates over variables (cos#theta_{H})
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (y_sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on cos#theta_{H} integrates over variables (M(D^{0}))
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (y_bkg1_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (y_bkg1_4,y_bkg1_added_2,y_bkg1_3,y_bkg1_2,bkg1_xy_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on cos#theta_{H} integrates over variables (M(D^{0}))
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (y_bkg2_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (y_bkg2_1,y_bkg2_2,bkg2_xy_model)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on cos#theta_{H} integrates over variables (M(D^{0}))
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# [#1] INFO:Plotting -- RooAbsReal::plotOn(extended_model) plot on cos#theta_{H} integrates over variables (M(D^{0}))
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(y_sig_model_Int[cos#theta_{H}]) using numeric integrator RooIntegrator1D to calculate Int(cos#theta_{H})
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test2_x_D0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test2_y_D0.png has been created

# %%
from IPython.display import Image
Image("test2_x_D0.png")

# %%
Image("test2_y_D0.png")

# %%
extended_model.Print("t")
# Out:
# 0x55e858c0d060 RooAddPdf::extended_model = 0.107549 [Auto,Dirty]
#   0x55e85a104af0/V- RooProdPdf::sig_model = 0.979186 [Auto,Dirty]
#   RooProdPdf begin partial integral cache
#   [0]0x55e85ae531f0 RooAddPdf::x_sig_model = 0.979186 [Auto,Dirty]
#   [0]  0x55e85aef7c70/V- RooGaussian::x_sig_1 = 0.995411 [Auto,Dirty]
#   [0]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [0]    0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#   [0]    0x55e85abca7f0/V- RooRealVar::x_sig_sigma1 = 0.02 +/- 0.00329276
#   [0]  0x55e85872d070/V- RooRealVar::x_sigfrac = 0.538877 +/- 0.244876
#   [0]  0x55e85ae6c940/V- RooCBShape::x_sig_2 = 0.960224 [Auto,Dirty]
#   [0]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [0]    0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#   [0]    0x55e8587419c0/V- RooRealVar::x_sig_sigma2 = 0.00673276 +/- 0.00214226
#   [0]    0x55e85872bf50/V- RooRealVar::x_sig_alpha = 3.32125 +/- 6.11866
#   [0]    0x55e850c81b80/V- RooRealVar::x_sig_n_CB = 1.02986 +/- 4.91694
#   [0]0x55e85ad1a590 MyPdf_one_minus_squared::y_sig_model = 1 [Auto,Dirty]
#   [0]  0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]0x55e85ae531f0 RooAddPdf::x_sig_model = 0.979186 [Auto,Dirty]
#   [1]  0x55e85aef7c70/V- RooGaussian::x_sig_1 = 0.995411 [Auto,Dirty]
#   [1]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [1]    0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#   [1]    0x55e85abca7f0/V- RooRealVar::x_sig_sigma1 = 0.02 +/- 0.00329276
#   [1]  0x55e85872d070/V- RooRealVar::x_sigfrac = 0.538877 +/- 0.244876
#   [1]  0x55e85ae6c940/V- RooCBShape::x_sig_2 = 0.960224 [Auto,Dirty]
#   [1]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [1]    0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#   [1]    0x55e8587419c0/V- RooRealVar::x_sig_sigma2 = 0.00673276 +/- 0.00214226
#   [1]    0x55e85872bf50/V- RooRealVar::x_sig_alpha = 3.32125 +/- 6.11866
#   [1]    0x55e850c81b80/V- RooRealVar::x_sig_n_CB = 1.02986 +/- 4.91694
#   [1]0x55e85ad1a590 MyPdf_one_minus_squared::y_sig_model = 1 [Auto,Dirty]
#   [1]  0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   RooProdPdf end partial integral cache
#     0x55e85ae531f0/V- RooAddPdf::x_sig_model = 0.979186 [Auto,Dirty]
#       0x55e85aef7c70/V- RooGaussian::x_sig_1 = 0.995411 [Auto,Dirty]
#         0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#         0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#         0x55e85abca7f0/V- RooRealVar::x_sig_sigma1 = 0.02 +/- 0.00329276
#       0x55e85872d070/V- RooRealVar::x_sigfrac = 0.538877 +/- 0.244876
#       0x55e85ae6c940/V- RooCBShape::x_sig_2 = 0.960224 [Auto,Dirty]
#         0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#         0x55e85ad82d30/V- RooRealVar::x_sig_mean = 1.86308 +/- 0.00221242
#         0x55e8587419c0/V- RooRealVar::x_sig_sigma2 = 0.00673276 +/- 0.00214226
#         0x55e85872bf50/V- RooRealVar::x_sig_alpha = 3.32125 +/- 6.11866
#         0x55e850c81b80/V- RooRealVar::x_sig_n_CB = 1.02986 +/- 4.91694
#     0x55e85ad1a590/V- MyPdf_one_minus_squared::y_sig_model = 1 [Auto,Dirty]
#       0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   0x55e858b96cb0/V- RooRealVar::nsig = 276.739 +/- 64.8121
#   0x55e85a105150/V- RooProdPdf::bkg1_xy_model = 0.0368873 [Auto,Dirty]
#   RooProdPdf begin partial integral cache
#   [0]0x55e85ae83f20 RooCBShape::x_bkg1_model = 0.416023 [Auto,Dirty]
#   [0]  0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [0]  0x55e84fd57950/V- RooRealVar::x_bkg1_mean = 1.84052 +/- 0.000758002
#   [0]  0x55e858eedc10/V- RooRealVar::x_bkg1_sigma1 = 0.0184818 +/- 0.000632904
#   [0]  0x55e858ee4030/V- RooRealVar::x_bkg1_alpha = 0.892447 +/- 0.0891714
#   [0]  0x55e859cb04c0/V- RooRealVar::x_bkg1_n_CB = 0.435123 +/- 0.0788839
#   [0]0x55e84fd58020 RooAddPdf::y_bkg1_model = 0.0886665 [Auto,Dirty]
#   [0]  0x55e858b328b0/V- RooChebychev::y_bkg1_4 = 0.122876 [Auto,Dirty]
#   [0]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [0]    0x55e858b1b770/V- RooRealVar::y_bkg1_Cheby_c0 = -1 +/- 0.0467134
#   [0]    0x55e858bc60d0/V- RooRealVar::y_bkg1_Cheby_c1 = 0.877124 +/- 0.0182618
#   [0]    0x55e859d6be50/V- RooRealVar::y_bkg1_Cheby_c2 = -0.24572 +/- 0.0187577
#   [0]  0x55e858b2ae60/V- RooRealVar::y_bkg1frac_3 = 0.721587 +/- 0.0134191
#   [0]  0x55e85acebf70/V- RooAddPdf::y_bkg1_added_2 = 3.62436e-06 [Auto,Dirty]
#   [0]    0x55e85888d700/V- RooGaussian::y_bkg1_3 = 5.72094e-06 [Auto,Dirty]
#   [0]      0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [0]      0x55e859f03610/V- RooRealVar::y_bkg1_mean2 = 0.871037 +/- 0.015597
#   [0]      0x55e858bafbd0/V- RooRealVar::y_bkg1_sigma2 = 0.177273 +/- 0.0111096
#   [0]    0x55e858b9da10/V- RooRealVar::y_bkg1frac_2 = 0.633525 +/- 0.0225704
#   [0]    0x55e85945d480/V- RooGaussian::y_bkg1_2 = 1.59251e-20 [Auto,Dirty]
#   [0]      0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [0]      0x55e858ac9450/V- RooRealVar::y_bkg1_mean1 = -0.675535 +/- 0.0065403
#   [0]      0x55e858b600e0/V- RooRealVar::y_bkg1_sigma1 = 0.0707482 +/- 0.00563806
#   [1]0x55e85ae83f20 RooCBShape::x_bkg1_model = 0.416023 [Auto,Dirty]
#   [1]  0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [1]  0x55e84fd57950/V- RooRealVar::x_bkg1_mean = 1.84052 +/- 0.000758002
#   [1]  0x55e858eedc10/V- RooRealVar::x_bkg1_sigma1 = 0.0184818 +/- 0.000632904
#   [1]  0x55e858ee4030/V- RooRealVar::x_bkg1_alpha = 0.892447 +/- 0.0891714
#   [1]  0x55e859cb04c0/V- RooRealVar::x_bkg1_n_CB = 0.435123 +/- 0.0788839
#   [1]0x55e84fd58020 RooAddPdf::y_bkg1_model = 0.0886665 [Auto,Dirty]
#   [1]  0x55e858b328b0/V- RooChebychev::y_bkg1_4 = 0.122876 [Auto,Dirty]
#   [1]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]    0x55e858b1b770/V- RooRealVar::y_bkg1_Cheby_c0 = -1 +/- 0.0467134
#   [1]    0x55e858bc60d0/V- RooRealVar::y_bkg1_Cheby_c1 = 0.877124 +/- 0.0182618
#   [1]    0x55e859d6be50/V- RooRealVar::y_bkg1_Cheby_c2 = -0.24572 +/- 0.0187577
#   [1]  0x55e858b2ae60/V- RooRealVar::y_bkg1frac_3 = 0.721587 +/- 0.0134191
#   [1]  0x55e85acebf70/V- RooAddPdf::y_bkg1_added_2 = 3.62436e-06 [Auto,Dirty]
#   [1]    0x55e85888d700/V- RooGaussian::y_bkg1_3 = 5.72094e-06 [Auto,Dirty]
#   [1]      0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]      0x55e859f03610/V- RooRealVar::y_bkg1_mean2 = 0.871037 +/- 0.015597
#   [1]      0x55e858bafbd0/V- RooRealVar::y_bkg1_sigma2 = 0.177273 +/- 0.0111096
#   [1]    0x55e858b9da10/V- RooRealVar::y_bkg1frac_2 = 0.633525 +/- 0.0225704
#   [1]    0x55e85945d480/V- RooGaussian::y_bkg1_2 = 1.59251e-20 [Auto,Dirty]
#   [1]      0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]      0x55e858ac9450/V- RooRealVar::y_bkg1_mean1 = -0.675535 +/- 0.0065403
#   [1]      0x55e858b600e0/V- RooRealVar::y_bkg1_sigma1 = 0.0707482 +/- 0.00563806
#   RooProdPdf end partial integral cache
#     0x55e85ae83f20/V- RooCBShape::x_bkg1_model = 0.416023 [Auto,Dirty]
#       0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#       0x55e84fd57950/V- RooRealVar::x_bkg1_mean = 1.84052 +/- 0.000758002
#       0x55e858eedc10/V- RooRealVar::x_bkg1_sigma1 = 0.0184818 +/- 0.000632904
#       0x55e858ee4030/V- RooRealVar::x_bkg1_alpha = 0.892447 +/- 0.0891714
#       0x55e859cb04c0/V- RooRealVar::x_bkg1_n_CB = 0.435123 +/- 0.0788839
#     0x55e84fd58020/V- RooAddPdf::y_bkg1_model = 0.0886665 [Auto,Dirty]
#       0x55e858b328b0/V- RooChebychev::y_bkg1_4 = 0.122876 [Auto,Dirty]
#         0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#         0x55e858b1b770/V- RooRealVar::y_bkg1_Cheby_c0 = -1 +/- 0.0467134
#         0x55e858bc60d0/V- RooRealVar::y_bkg1_Cheby_c1 = 0.877124 +/- 0.0182618
#         0x55e859d6be50/V- RooRealVar::y_bkg1_Cheby_c2 = -0.24572 +/- 0.0187577
#       0x55e858b2ae60/V- RooRealVar::y_bkg1frac_3 = 0.721587 +/- 0.0134191
#       0x55e85acebf70/V- RooAddPdf::y_bkg1_added_2 = 3.62436e-06 [Auto,Dirty]
#         0x55e85888d700/V- RooGaussian::y_bkg1_3 = 5.72094e-06 [Auto,Dirty]
#           0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#           0x55e859f03610/V- RooRealVar::y_bkg1_mean2 = 0.871037 +/- 0.015597
#           0x55e858bafbd0/V- RooRealVar::y_bkg1_sigma2 = 0.177273 +/- 0.0111096
#         0x55e858b9da10/V- RooRealVar::y_bkg1frac_2 = 0.633525 +/- 0.0225704
#         0x55e85945d480/V- RooGaussian::y_bkg1_2 = 1.59251e-20 [Auto,Dirty]
#           0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#           0x55e858ac9450/V- RooRealVar::y_bkg1_mean1 = -0.675535 +/- 0.0065403
#           0x55e858b600e0/V- RooRealVar::y_bkg1_sigma1 = 0.0707482 +/- 0.00563806
#   0x55e858cc65c0/V- RooRealVar::nbkg1 = 10979.1 +/- 260.093
#   0x55e85ae838c0/V- RooProdPdf::bkg2_xy_model = 0.183732 [Auto,Dirty]
#   RooProdPdf begin partial integral cache
#   [0]0x55e85ad60d50 RooAddPdf::x_bkg2_model = 0.271809 [Auto,Dirty]
#   [0]  0x55e85ae5cc00/V- RooGaussian::x_bkg2_1 = 9.31407e-07 [Auto,Dirty]
#   [0]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [0]    0x55e858aa69e0/V- RooRealVar::x_bkg2_mean = 1.67 +/- 0.0142314
#   [0]    0x55e858b29cb0/V- RooRealVar::x_bkg2_sigma1 = 0.0370017 +/- 0.00777769
#   [0]  0x55e858b3d040/V- RooRealVar::x_bkg2frac = 0.0468679 +/- 0.0204464
#   [0]  0x55e858b9eb90/V- RooExponential::x_bkg2_2 = 0.285174 [Auto,Dirty]
#   [0]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [0]    0x55e858b76460/V- RooRealVar::x_bkg2_tau = -0.672737 +/- 0.342182
#   [0]0x55e858bb0d50 RooAddPdf::y_bkg2_model = 0.675959 [Auto,Dirty]
#   [0]  0x55e85ad8bea0/V- RooGaussian::y_bkg2_1 = 1.28347e-14 [Auto,Dirty]
#   [0]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [0]    0x55e858bc4f90/V- RooRealVar::y_bkg2_mean1 = -0.669164 +/- 0.020634
#   [0]    0x55e858bf2560/V- RooRealVar::y_bkg2_sigma1 = 0.083663 +/- 0.0155727
#   [0]  0x55e858ba1760/V- RooRealVar::y_bkg2frac = 0.0478828 +/- 0.0125617
#   [0]  0x55e858baa940/V- RooChebychev::y_bkg2_2 = 0.709954 [Auto,Dirty]
#   [0]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [0]    0x55e859f20820/V- RooRealVar::y_bkg2_Cheby_c0 = -0.0570641 +/- 0.0464102
#   [0]    0x55e858bfbae0/V- RooRealVar::y_bkg2_Cheby_c1 = 0.290046 +/- 0.0288644
#   [0]    0x55e858be1ea0/V- RooRealVar::y_bkg2_Cheby_c2 = -0.0783098 +/- 0.0289649
#   [1]0x55e85ad60d50 RooAddPdf::x_bkg2_model = 0.271809 [Auto,Dirty]
#   [1]  0x55e85ae5cc00/V- RooGaussian::x_bkg2_1 = 9.31407e-07 [Auto,Dirty]
#   [1]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [1]    0x55e858aa69e0/V- RooRealVar::x_bkg2_mean = 1.67 +/- 0.0142314
#   [1]    0x55e858b29cb0/V- RooRealVar::x_bkg2_sigma1 = 0.0370017 +/- 0.00777769
#   [1]  0x55e858b3d040/V- RooRealVar::x_bkg2frac = 0.0468679 +/- 0.0204464
#   [1]  0x55e858b9eb90/V- RooExponential::x_bkg2_2 = 0.285174 [Auto,Dirty]
#   [1]    0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#   [1]    0x55e858b76460/V- RooRealVar::x_bkg2_tau = -0.672737 +/- 0.342182
#   [1]0x55e858bb0d50 RooAddPdf::y_bkg2_model = 0.675959 [Auto,Dirty]
#   [1]  0x55e85ad8bea0/V- RooGaussian::y_bkg2_1 = 1.28347e-14 [Auto,Dirty]
#   [1]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]    0x55e858bc4f90/V- RooRealVar::y_bkg2_mean1 = -0.669164 +/- 0.020634
#   [1]    0x55e858bf2560/V- RooRealVar::y_bkg2_sigma1 = 0.083663 +/- 0.0155727
#   [1]  0x55e858ba1760/V- RooRealVar::y_bkg2frac = 0.0478828 +/- 0.0125617
#   [1]  0x55e858baa940/V- RooChebychev::y_bkg2_2 = 0.709954 [Auto,Dirty]
#   [1]    0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#   [1]    0x55e859f20820/V- RooRealVar::y_bkg2_Cheby_c0 = -0.0570641 +/- 0.0464102
#   [1]    0x55e858bfbae0/V- RooRealVar::y_bkg2_Cheby_c1 = 0.290046 +/- 0.0288644
#   [1]    0x55e858be1ea0/V- RooRealVar::y_bkg2_Cheby_c2 = -0.0783098 +/- 0.0289649
#   RooProdPdf end partial integral cache
#     0x55e85ad60d50/V- RooAddPdf::x_bkg2_model = 0.271809 [Auto,Dirty]
#       0x55e85ae5cc00/V- RooGaussian::x_bkg2_1 = 9.31407e-07 [Auto,Dirty]
#         0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#         0x55e858aa69e0/V- RooRealVar::x_bkg2_mean = 1.67 +/- 0.0142314
#         0x55e858b29cb0/V- RooRealVar::x_bkg2_sigma1 = 0.0370017 +/- 0.00777769
#       0x55e858b3d040/V- RooRealVar::x_bkg2frac = 0.0468679 +/- 0.0204464
#       0x55e858b9eb90/V- RooExponential::x_bkg2_2 = 0.285174 [Auto,Dirty]
#         0x55e85ac2a190/V- RooRealVar::M(D^{0}) = 1.865
#         0x55e858b76460/V- RooRealVar::x_bkg2_tau = -0.672737 +/- 0.342182
#     0x55e858bb0d50/V- RooAddPdf::y_bkg2_model = 0.675959 [Auto,Dirty]
#       0x55e85ad8bea0/V- RooGaussian::y_bkg2_1 = 1.28347e-14 [Auto,Dirty]
#         0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#         0x55e858bc4f90/V- RooRealVar::y_bkg2_mean1 = -0.669164 +/- 0.020634
#         0x55e858bf2560/V- RooRealVar::y_bkg2_sigma1 = 0.083663 +/- 0.0155727
#       0x55e858ba1760/V- RooRealVar::y_bkg2frac = 0.0478828 +/- 0.0125617
#       0x55e858baa940/V- RooChebychev::y_bkg2_2 = 0.709954 [Auto,Dirty]
#         0x55e85abd8e90/V- RooRealVar::cos#theta_{H} = 0
#         0x55e859f20820/V- RooRealVar::y_bkg2_Cheby_c0 = -0.0570641 +/- 0.0464102
#         0x55e858bfbae0/V- RooRealVar::y_bkg2_Cheby_c1 = 0.290046 +/- 0.0288644
#         0x55e858be1ea0/V- RooRealVar::y_bkg2_Cheby_c2 = -0.0783098 +/- 0.0289649
#   0x55e858bec0d0/V- RooRealVar::nbkg2 = 7017.13 +/- 237.484

# %%
print(nsig)
print(nbkg1)
print(nbkg2)
# print(nbkg3)
# Out:
# RooRealVar::nsig = 276.739 +/- 64.8121  L(0 - 18273)
#
# RooRealVar::nbkg1 = 10979.1 +/- 260.093  L(0 - 18273)
#
# RooRealVar::nbkg2 = 7017.13 +/- 237.484  L(0 - 18273)

# %%
print(nsig)
print(nbkg1)
print(nbkg2)
# print(nbkg3)
# Out:
# RooRealVar::nsig = 361.844 +/- 73.2325  L(0 - 18273)
#
# RooRealVar::nbkg1 = 10892.4 +/- 253.9  L(0 - 18273)
#
# RooRealVar::nbkg2 = 7018.92 +/- 226.953  L(0 - 18273)

# %%
print(nsig)
print(nbkg1)
print(nbkg2)
# print(nbkg3)
# Out:
# RooRealVar::nsig = 361.844 +/- 73.2325  L(0 - 18273)
#
# RooRealVar::nbkg1 = 10892.4 +/- 253.9  L(0 - 18273)
#
# RooRealVar::nbkg2 = 7018.92 +/- 226.953  L(0 - 18273)

# %%
print(nsig)
print(nbkg1)
print(nbkg2)
# print(nbkg3)
# Out:
# RooRealVar::nsig = 361.844 +/- 73.2325  L(0 - 18273)
#
# RooRealVar::nbkg1 = 10892.4 +/- 253.9  L(0 - 18273)
#
# RooRealVar::nbkg2 = 7018.92 +/- 226.953  L(0 - 18273)
