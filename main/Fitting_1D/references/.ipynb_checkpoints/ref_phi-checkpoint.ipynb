# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style") 
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_file_loc =  '/media/jykim/T7/storage/01_recon/v16_ref_sig_ext_naive_skim/'

base_filter =  'D0_M>1.83 && D0_M<1.90 '
# base_filter += '&& Dstarp_isSignal==1'
tree = 'ref_phi'

variables=['D0_M','Dstarp_Q','Dstarp_CMS_p','__ncandidates__']
var = 'D0_M'

# %%
ccbar_0 = base_file_loc + 'topo/resultfile/result_ref_phi/standard.root'

uubar_0 = base_file_loc + 'generic_uubar.root'
ddbar_0 = base_file_loc + 'generic_ddbar.root'
ssbar_0 = base_file_loc + 'generic_ssbar.root'
charged_0 = base_file_loc + 'generic_charged.root'
mixed_0 = base_file_loc + 'generic_mixed.root'
taupair_0 = base_file_loc + 'generic_taupair.root'

# %%
base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar_0 = get_pd(file=ccbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_uubar_0 = get_pd(file=uubar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_ddbar_0 = get_pd(file=ddbar_0, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar_0 = get_pd(file=ssbar_0, tree=tree,base_filter=base_filter,variables=variables)

pd_charged_0 = get_pd(file=charged_0, tree=tree,base_filter=base_filter,variables=variables)

pd_mixed_0 = get_pd(file=mixed_0, tree=tree,base_filter=base_filter,variables=variables)

pd_taupair_0 = get_pd(file=taupair_0, tree=tree,base_filter=base_filter,variables=variables)

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["D0_M"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(1.83,1.90)
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=(1.67,2.06))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()
# Out:
# D0_M

# %%
labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']


colors=b2helix(7)

data_list=dict()
signal_variables = ["__ncandidates__"]

for var in signal_variables:
#     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    print(var)
    mixed_bkg = {var : pd_mixed_0[var] }
    charged_bkg = {var : pd_charged_0[var] }
    ccbar_bkg = {var : pd_ccbar_0[var] }
    uubar_bkg = {var : pd_uubar_0[var] }
    ddbar_bkg = {var : pd_ddbar_0[var] }
    ssbar_bkg = {var : pd_ssbar_0[var] }
    taupair_bkg = {var : pd_taupair_0[var] }
    
    
    
    #print(mixed_bkg)
#     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

#     for labeling in labels:
    xrange=(0,6)
    xbins = np.linspace(*xrange,7)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black',align="left")
    
#     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')
    
    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend(prop={'size':13})
    
#     DRAW(pd_Dtokshortpi0, cut)
    
    watermark(t="",logo="MC15ri")
    ax=plt.gca()
#     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=5, range=(1,6))

    ax.set_xlim(*xrange)
#     ax.set_ylim(0,6000)

    plt.xlabel("ncandidates")
    width = xe[1]-xe[0]
    plt.ylabel('Entries');
    plt.show()
    plt.clf()
# Out:
# __ncandidates__

# %%
# pd_ccbar = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_uubar = get_pd(file=file_uubar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ddbar = get_pd(file=file_ddbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ssbar = get_pd(file=file_ssbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_charged = get_pd(file=file_charged, tree=tree,base_filter=base_filter,variables=variables)
# pd_mixed = get_pd(file=file_mixed, tree=tree,base_filter=base_filter,variables=variables)
# pd_taupair = get_pd(file=file_taupair, tree=tree,base_filter=base_filter,variables=variables)


pd_all_generic = pd.concat([pd_ccbar_0, pd_uubar_0, pd_ddbar_0, pd_ssbar_0, pd_charged_0, pd_mixed_0, pd_taupair_0], ignore_index=True)

pd_all_generic.describe()
# Out:
#                D0_M      Dstarp_Q  Dstarp_CMS_p  __ncandidates__
# count  75747.000000  75747.000000  75747.000000     75747.000000
# mean       1.864491      0.005870      3.419538         1.004198
# std        0.007011      0.000270      0.603456         0.065267
# min        1.830002      0.004931      2.450026         1.000000
# 25%        1.861857      0.005741      2.917283         1.000000
# 50%        1.864666      0.005862      3.359193         1.000000
# 75%        1.867416      0.005986      3.871929         1.000000
# max        1.899945      0.006930      5.083045         3.000000

# %%
np_data = pd_all_generic['D0_M'].to_numpy()

# %%
fitting_region = (1.83, 1.90)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(70)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.85, 1.88)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.02,0.001,0.05)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.03,0.001,0.05)
# alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
# n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 20,0,100)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    


    
sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean, sigma2)

sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)





data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

# data = rooDataSet

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))


r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


# extended_model.plotOn(frame, Name="sig1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=ROOT.kBlue)

# extended_model.plotOn(frame, Name="sig2", Components=sig2, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)


extended_model.plotOn(frame, Name="sig", Components=ROOT.RooArgSet(sig1,sig2), LineStyle=ROOT.kDashed, LineColor=ROOT.kRed)



extended_model.plotOn(frame, Name="bkg", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=ROOT.kGreen)

extended_model.plotOn(frame, Name="fitting")





# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")

leg1 = ROOT.TLegend(0.65, 0.6, 0.9, 0.85)
# leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(0)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
# leg1.AddEntry("sig1", "sig1", "l")
# leg1.AddEntry("sig2", "sig1", "l")

leg1.AddEntry("sig", "sig", "l")
leg1.AddEntry("bkg", "bkg", "l")
leg1.SetTextSize(0.05)
leg1.SetBorderSize(0)

leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.83,1.9]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.83,1.9]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_extended_model_' created with bounds [1.83,1.9]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **  280 **SET PRINT           1
#  **********
#  **********
#  **  281 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 c0           1.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 c1           5.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      3 mean         1.86000e+00  3.00000e-03    1.85000e+00  1.88000e+00
#      4 nbkg         1.51494e+04  7.57470e+03    0.00000e+00  7.57470e+04
#      5 nsig         6.05976e+04  7.57470e+03    0.00000e+00  7.57470e+04
#      6 sig1frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 sigma1       2.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#      8 sigma2       3.00000e-02  4.90000e-03    1.00000e-03  5.00000e-02
#  **********
#  **  282 **SET ERR         0.5
#  **********
#  **********
#  **  283 **SET PRINT           1
#  **********
#  **********
#  **  284 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **  285 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.925013	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -2.04702/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -2.03503/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -2.01717/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -2.02814/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -2.02132/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -2.00254/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -2.03912/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -2.03185/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -2.03909/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -2.03722/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -2.02985/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -2.03892/-0.14219), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.925013,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.99881	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -2.30502/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -2.29205/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -2.27272/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -2.28459/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -2.27721/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -2.25689/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -2.29648/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -2.28861/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -2.29644/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -2.29442/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -2.28644/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -2.29626/-0.16016), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.99881,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.620727	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.983185/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.975259/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.963448/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.970701/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.966191/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.953772/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.977965/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.973153/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.977941/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.976703/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.971832/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.97783/-0.0680948), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.620727,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.607273	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.936145/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.928399/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.916855/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.923945/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.919537/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.907399/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.931043/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.92634/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.93102/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.92981/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.92505/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.930912/-0.0648185), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.607273,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.433221	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.32763/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.322206/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.314124/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.319088/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.316002/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.307504/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.324058/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.320765/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.324042/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.323195/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.319861/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.323966/-0.0224361), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.433221,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.338933	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 6.11086,bkg_x_model = -0.0300251/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 6.83718,bkg_x_model = -0.0276798/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87909), !pdfs=(sig_model = 14.1876,bkg_x_model = -0.00885264/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 5.34462,bkg_x_model = -0.0327272/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87222), !pdfs=(sig_model = 17.2468,bkg_x_model = -0.000811533/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87205), !pdfs=(sig_model = 17.315,bkg_x_model = -0.000605045/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8716), !pdfs=(sig_model = 17.4824,bkg_x_model = -8.98191e-05/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87283), !pdfs=(sig_model = 17.0077,bkg_x_model = -0.00151933/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87254), !pdfs=(sig_model = 17.1236,bkg_x_model = -0.001179/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87283), !pdfs=(sig_model = 17.0073,bkg_x_model = -0.0015205/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87751), !pdfs=(sig_model = 14.9427,bkg_x_model = -0.00700366/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.87214), !pdfs=(sig_model = 17.2802,bkg_x_model = -0.000710687/0.000523287), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 16763 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.338933,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.389264	c1=-0.290398	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.743127/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.737861/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.730009/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.734832/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.731833/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.723571/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.739659/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.736461/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.739643/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.738821/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.735584/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.73957/-0.0515316), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.389264,c1 = -0.290398,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.1	c1=-0.576616	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.828964/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.821626/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.810693/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.817407/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.813232/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.801736/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.824131/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.819677/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.824109/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.822963/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.818454/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.824007/-0.0573535), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.1,c1 = -0.576616,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.00493913	c1=-0.290398	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8698), !pdfs=(sig_model = 18.1175,bkg_x_model = -0.0245144/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86623), !pdfs=(sig_model = 19.1102,bkg_x_model = -0.0206216/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.8609), !pdfs=(sig_model = 19.8035,bkg_x_model = -0.01482/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86417), !pdfs=(sig_model = 19.497,bkg_x_model = -0.0183831/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86214), !pdfs=(sig_model = 19.7336,bkg_x_model = -0.0161678/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.85651), !pdfs=(sig_model = 19.5935,bkg_x_model = -0.0100667/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86745), !pdfs=(sig_model = 18.8146,bkg_x_model = -0.0219505/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86528), !pdfs=(sig_model = 19.3068,bkg_x_model = -0.0195872/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86744), !pdfs=(sig_model = 18.8173,bkg_x_model = -0.021939/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86688), !pdfs=(sig_model = 18.9583,bkg_x_model = -0.021331/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86469), !pdfs=(sig_model = 19.4145,bkg_x_model = -0.0189385/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.86739), !pdfs=(sig_model = 18.8303,bkg_x_model = -0.0218846/-0.00135797), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 73718 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.00493913,c1 = -0.290398,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.0175852	c1=-0.290398	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 6.11086,bkg_x_model = -0.0117034/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 6.83718,bkg_x_model = -0.00955919/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 5.34462,bkg_x_model = -0.0141736/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 6.57165,bkg_x_model = -0.0103239/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89635), !pdfs=(sig_model = 6.35618,bkg_x_model = -0.0109602/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89768), !pdfs=(sig_model = 5.88487,bkg_x_model = -0.0124071/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88882), !pdfs=(sig_model = 9.4664,bkg_x_model = -0.00282023/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88967), !pdfs=(sig_model = 9.08175,bkg_x_model = -0.00373489/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88826), !pdfs=(sig_model = 9.72225,bkg_x_model = -0.00222137/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89397), !pdfs=(sig_model = 7.25893,bkg_x_model = -0.00838424/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89604), !pdfs=(sig_model = 6.46595,bkg_x_model = -0.0106342/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88914), !pdfs=(sig_model = 9.31789,bkg_x_model = -0.00317122/0.00158258), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 2813 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.0175852,c1 = -0.290398,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-990644) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.0320537	c1=-0.297789	mean=1.86	nbkg=15149.4	nsig=60597.6	sig1frac=0.5	sigma1=0.02	sigma2=0.03
# PID4441/RooRealMPFE::nll_extended_model__55c4e3a7d6b0_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89703), !pdfs=(sig_model = 6.11086,bkg_x_model = -0.0108536/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89505), !pdfs=(sig_model = 6.83718,bkg_x_model = -0.0086826/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89931), !pdfs=(sig_model = 5.34462,bkg_x_model = -0.0133548/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89576), !pdfs=(sig_model = 6.57165,bkg_x_model = -0.0094569/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89635), !pdfs=(sig_model = 6.35618,bkg_x_model = -0.0101012/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89768), !pdfs=(sig_model = 5.88487,bkg_x_model = -0.0115661/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88882), !pdfs=(sig_model = 9.4664,bkg_x_model = -0.00185952/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88967), !pdfs=(sig_model = 9.08175,bkg_x_model = -0.00278557/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88826), !pdfs=(sig_model = 9.72225,bkg_x_model = -0.0012532/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89397), !pdfs=(sig_model = 7.25893,bkg_x_model = -0.00749296/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.89604), !pdfs=(sig_model = 6.46595,bkg_x_model = -0.00977109/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(M(D^{0}) = 1.88914), !pdfs=(sig_model = 9.31789,bkg_x_model = -0.00221488/0.00167176), !coefficients=(nsig = 60597.6,nbkg = 15149.4)
#     ... (remaining 2615 messages suppressed)
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.0320537,c1 = -0.297789,mean = 1.86,nbkg = 15149.4,nsig = 60597.6,sig1frac = 0.5,sigma1 = 0.02,sigma2 = 0.03)
#
#  FCN=-1.03239e+06 FROM MIGRAD    STATUS=INITIATE      192 CALLS         193 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0