# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import ROOT
import ctypes
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style") 
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
# Out:
# Welcome to JupyROOT 6.26/04

# %%
base_filter = ' Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && Pi0_Prob<0.8'
base_filter = ' Pis_charge==1 && D0_M>1.67 && D0_M<2.06 '
base_filter = ' Pis_charge==1 && D0_M>1.82 && D0_M<1.90 && Dstarp_CMS_p>2.4'

tree = 'ref_phi'

variables=['D0_M','Dstarp_Q','Dstarp_CMS_p']
var = 'D0_M'

base_file_loc =  '/media/jykim/T7/storage/01_recon/trainv2new_ref_study/'

# %%
pd_isSignal_True = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter + ' && Dstarp_isSignal==1',variables=variables)
len(pd_isSignal_True)
# Out:
# 101357

# %%
pd_isSignal_False = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter + ' && Dstarp_isSignal!=1',variables=variables)
len(pd_isSignal_False)
# Out:
# 7445

# %%
file_ccbar = []
file_uubar = []
file_ddbar = []
file_ssbar = []
file_charged = []
file_mixed = []
file_taupair = []

for i in range(0,1158):
    file_loc = base_file_loc + 'ccbar/recon_output_' + str(i).zfill(5) + '.root'
    file_ccbar.append(file_loc)
    
for i in range(0,1277):
    file_loc = base_file_loc + 'uubar/recon_output_' + str(i).zfill(5) + '.root'
    file_uubar.append(file_loc)
    
for i in range(0,321):
    file_loc = base_file_loc + 'ddbar/recon_output_' + str(i).zfill(5) + '.root'
    file_ddbar.append(file_loc)
for i in range(0,306):
    file_loc = base_file_loc + 'ssbar/recon_output_' + str(i).zfill(5) + '.root'
    file_ssbar.append(file_loc)
for i in range(0,602):
    file_loc = base_file_loc + 'charged/recon_output_' + str(i).zfill(5) + '.root'
    file_charged.append(file_loc)
for i in range(0,562):
    file_loc = base_file_loc + 'mixed/recon_output_' + str(i).zfill(5) + '.root'
    file_mixed.append(file_loc)
for i in range(0,410):
    file_loc = base_file_loc + 'taupair/recon_output_' + str(i).zfill(5) + '.root'
    file_taupair.append(file_loc)
    

base_filter = base_filter
varaiables = variables
tree=tree

pd_ccbar = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter,variables=variables)
pd_uubar = get_pd(file=file_uubar, tree=tree,base_filter=base_filter,variables=variables)
pd_ddbar = get_pd(file=file_ddbar, tree=tree,base_filter=base_filter,variables=variables)
pd_ssbar = get_pd(file=file_ssbar, tree=tree,base_filter=base_filter,variables=variables)
pd_charged = get_pd(file=file_charged, tree=tree,base_filter=base_filter,variables=variables)
pd_mixed = get_pd(file=file_mixed, tree=tree,base_filter=base_filter,variables=variables)
pd_taupair = get_pd(file=file_taupair, tree=tree,base_filter=base_filter,variables=variables)

# %%
def Draw(var, xrange:tuple):
    global pd_ccbar
    global pd_uubar
    global pd_ddbar
    global pd_ssbar
    global pd_charged
    global pd_mixed
    global pd_taupair
    var = var
    labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    colors=b2helix(7)


    var = var
    data_list=dict()
    #     labels = ['mixed', 'charged', 'uubar', 'ddbar', 'ssbar', 'taupair','ccbar']
    mixed_bkg = {var : pd_mixed[var] }
    charged_bkg = {var : pd_charged[var] }
    ccbar_bkg = {var : pd_ccbar[var] }
    uubar_bkg = {var : pd_uubar[var] }
    ddbar_bkg = {var : pd_ddbar[var] }
    ssbar_bkg = {var : pd_ssbar[var] }
    taupair_bkg = {var : pd_taupair[var] }

    #print(mixed_bkg)
    #     data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  
    data_list[var]  = [mixed_bkg[var], charged_bkg[var], uubar_bkg[var], ddbar_bkg[var], ssbar_bkg[var], taupair_bkg[var], ccbar_bkg[var]]  

    #     for labeling in labels:
    xrange=xrange
    xbins = np.linspace(*xrange,51)
    plt.hist(data_list[var], bins=xbins, histtype='stepfilled', stacked=True,label=labels,color=colors,edgecolor='black')

    #     plt.hist(pd_phigamma_ccbar_signal[var],bins=xbins,histtype='step',color='r',label='signal')

    ax = plt.gca()

    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width , box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))   
    plt.legend()

    #     DRAW(pd_Dtokshortpi0, cut)

    watermark(t="",logo="MC15ri")
    ax=plt.gca()
    #     ax.set_title(r'$D^0 \to K^0_S \pi^0$ sample' )

    n, xe = np.histogram(ccbar_bkg[var], bins=50, range=xrange)

    ax.set_xlim(*xrange)
    #     ax.set_ylim(0,6000)

    plt.xlabel("$\mathrm{M(D^0)} \; [\mathrm{GeV/c^2}]$")
    width = xe[1]-xe[0]
    plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');
    plt.show()
    plt.clf()

# %%
Draw('D0_M',(1.82,1.90))

# %%
# pd_ccbar = get_pd(file=file_ccbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_uubar = get_pd(file=file_uubar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ddbar = get_pd(file=file_ddbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_ssbar = get_pd(file=file_ssbar, tree=tree,base_filter=base_filter,variables=variables)
# pd_charged = get_pd(file=file_charged, tree=tree,base_filter=base_filter,variables=variables)
# pd_mixed = get_pd(file=file_mixed, tree=tree,base_filter=base_filter,variables=variables)
# pd_taupair = get_pd(file=file_taupair, tree=tree,base_filter=base_filter,variables=variables)


pd_all_generic = pd.concat([pd_ccbar, pd_uubar, pd_ddbar, pd_ssbar, pd_charged, pd_mixed, pd_taupair], ignore_index=True)

# %%
np_data = pd_all_generic['D0_M'].to_numpy()

# %%
fitting_region = (1.82, 1.90)
x = ROOT.RooRealVar("M(D^{0})", "M(D^{0}) [GeV/c^{2}]", fitting_region[0], fitting_region[1], "")
# x.setBins(100)


# rooDataSet = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x))), ("D0_M")
# )
# rooDataSet2 = ROOT_df_start.Book(
#     ROOT.std.move(ROOT.RooDataSetHelper("dataset", "Title of dataset", ROOT.RooArgSet(x, y))), ("D0_M", "Dstarp_Q")
# )


mean = ROOT.RooRealVar("mean", "mean of gaussians", 1.86,1.85, 1.88)
sigma1 = ROOT.RooRealVar("sigma1", "width of gaussians", 0.02,0,0.1)
sigma2 = ROOT.RooRealVar("sigma2", "width of gaussians", 0.05,0,0.1)
# alpha = ROOT.RooRealVar("alpha", "width of gaussians", 0.5,0,20)
# n_CB = ROOT.RooRealVar("n_CB", "width of gaussians", 20,0,100)
 
# Novo_peak = ROOT.RooRealVar("Novo_peak", "Novo peak", 1.83,1.67,1.93)    
# Novo_width = ROOT.RooRealVar("Novo_widh", "Novo peak", 0.05,0,0.5)    
# Novo_tail = ROOT.RooRealVar("Novo_tail", "Novo peak", 0.5,0,10)    


    
sig1 = ROOT.RooGaussian("sig1", "Signal component 1", x, mean, sigma1)
sig2 = ROOT.RooGaussian("sig2", "Signal component 1", x, mean, sigma2)

sig1frac = ROOT.RooRealVar("sig1frac", "fraction of component 1 in signal", 0.5, 0.0, 1.0)
sig_model = ROOT.RooAddPdf("sig_model", "Signal1", [sig1, sig2], sig1frac)




c0 = ROOT.RooRealVar("c0", "c0",0.1, -1,1)
c1 = ROOT.RooRealVar("c1", "c1",0.5, -1,1)
#c2 = ROOT.RooRealVar("c2", "c2",-0.3, -1.,0.)
bkg_x_model = ROOT.RooPolynomial("bkg_x_model", "Signal component 1", x, ROOT.RooArgList(c0,c1))
#sig = ROOT.RooCBShape("sig2", "Signal component 2", x, mean, sigma2, alpha, n_CB)
# sig3 = ROOT.RooNovosibirsk("sig3", "Signal component 3", x, mean, Novo_width, Novo_tail)





data = ROOT.RooDataSet.from_numpy({"M(D^{0})": np_data}, [x])

# data = rooDataSet

canv = ROOT.TCanvas("Canvas", "Canvas", 700, 640)

xlow = ctypes.c_double()
ylow = ctypes.c_double()
xup = ctypes.c_double()
yup = ctypes.c_double()

canv.GetPad(0).GetPadPar(xlow, ylow, xup, yup)
canv.Divide(1,2)

xlow = xlow.value
ylow = ylow.value
xup = xup.value
yup = yup.value

upPad = canv.GetPad(1)
upPad.SetPad(xlow, ylow+0.25*(yup-ylow),xup,yup)

dwPad = canv.GetPad(2)
dwPad.SetPad(xlow, ylow,xup,ylow+0.25*(yup-ylow))

nsig = ROOT.RooRealVar("nsig","# signal events",len(np_data)*0.8,0,len(np_data))
nbkg = ROOT.RooRealVar("nbkg","# bkg events",len(np_data)*0.2,0, len(np_data))

extended_model = ROOT.RooAddPdf("extended_model", "x_model", ROOT.RooArgSet(sig_model,bkg_x_model), ROOT.RooArgSet(nsig, nbkg))


r = extended_model.fitTo(data,NumCPU=12, Range=fitting_region)
# r = sig.fitTo(data,NumCPU=12, Range=fitting_region)

# r.Print()
canv.cd(1) 
# frame = x.frame(Title="D^{0} #rightarrow #bar{K}^{*0} #pi^{0}")
frame = x.frame(Title=" ")

data.plotOn(frame,Name = "data1", XErrorSize=0)

# sig.plotOn(frame, Name="gauss1", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="CB1", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)
# sig.plotOn(frame, Name="Novo", Components=sig3, LineStyle=ROOT.kDashed, LineColor=593)


extended_model.plotOn(frame, Name="Novo", Components=sig_model, LineStyle=ROOT.kDashed, LineColor=593)
extended_model.plotOn(frame, Name="Novo", Components=sig1, LineStyle=ROOT.kDashed, LineColor=593)

extended_model.plotOn(frame, Name="Novo", Components=sig2, LineStyle=ROOT.kDashed, LineColor=593)

extended_model.plotOn(frame, Name="Novo", Components=bkg_x_model, LineStyle=ROOT.kDashed, LineColor=593)

extended_model.plotOn(frame, Name="fitting",)





# sig.paramOn(frame)
frame.GetXaxis().SetTitleSize(0.047)
frame.GetXaxis().CenterTitle(True)
frame.GetYaxis().SetTitleSize(0.04)
frame.GetYaxis().SetTitleOffset(1.2)
frame.Draw("PE")


leg1 = ROOT.TLegend(0.75, 0.75, 0.9, 0.9)
leg1.SetFillColor(ROOT.kWhite)
# leg1.SetHeader("The Legend title","C")
leg1.AddEntry("data1", "MC", "PE")
leg1.AddEntry("fitting", "fit", "l")
leg1.Draw()

hpull = frame.pullHist()
hpull.SetFillStyle(1001)
hpull.SetFillColor(1);
for i in range(0,hpull.GetN()):#(int i=0;i<hpull.GetN();++i): 
    hpull.SetPointError(i,0.0,0.0,0.0,0.0)
# pullplot = x.frame(Title(" "))
pullplot = x.frame()
pullplot.SetTitle("")
pullplot.addPlotable(hpull,"BE")
# pullplot.addPlotable(hpull,"PE")

pullplot.SetYTitle("Pull")
pullplot.GetXaxis().SetTitleSize(0)
pullplot.GetYaxis().SetTitleSize(0.17)
pullplot.GetYaxis().CenterTitle(True)
pullplot.GetYaxis().SetTitleOffset(0.2)
pullplot.SetMinimum(-4.)
pullplot.SetMaximum(4.)
pullplot.GetXaxis().SetLabelSize(0.1)
pullplot.GetYaxis().SetLabelSize(0.09)
canv.cd(2)
pullplot.Draw()

xmin1 = ctypes.c_double(fitting_region[0])
xmax1 = ctypes.c_double(fitting_region[1])
# xmin1 = 0.1
# xmax1 = 0.18
line = ROOT.TLine(xmin1,0.0,xmax1,0.0)
line1 = ROOT.TLine(xmin1,3.0,xmax1,3.0)
line2 = ROOT.TLine(xmin1,-3.0,xmax1,-3.0)

line.SetLineColor(ROOT.kRed)
line.SetLineWidth(3)
line1.SetLineColor(ROOT.kRed)
line2.SetLineColor(ROOT.kRed)
line1.SetLineStyle(2)
line2.SetLineStyle(2)
line.Draw("SAME")
line1.Draw("SAME")
line2.Draw("SAME")

canv.Update()

canv.Draw()
canv.SaveAs("test.png")
# Out:
# [#0] WARNING:InputArguments -- The parameter 'sigma1' with range [0, 0.1] of the RooGaussian 'sig1' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'sigma2' with range [0, 0.1] of the RooGaussian 'sig2' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit' created with bounds [1.82,1.9]
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) constructing test statistic for sub-range named fit
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'NormalizationRangeForfit' created with bounds [1.82,1.9]
# [#1] INFO:Eval -- RooRealVar::setRange(M(D^{0})) new range named 'fit_nll_extended_model_' created with bounds [1.82,1.9]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_extended_model_) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Eval -- RooAbsTestStatistic::initMPMode: started 12 remote server process.
#  **********
#  **   37 **SET PRINT           1
#  **********
#  **********
#  **   38 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 c0           1.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      2 c1           5.00000e-01  2.00000e-01   -1.00000e+00  1.00000e+00
#      3 mean         1.86000e+00  3.00000e-03    1.85000e+00  1.88000e+00
#      4 nbkg         2.19802e+04  1.09901e+04    0.00000e+00  1.09901e+05
#      5 nsig         8.79208e+04  1.09901e+04    0.00000e+00  1.09901e+05
#      6 sig1frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 sigma1       2.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#      8 sigma2       5.00000e-02  1.00000e-02    0.00000e+00  1.00000e-01
#  **********
#  **   39 **SET ERR         0.5
#  **********
#  **********
#  **   40 **SET PRINT           1
#  **********
#  **********
#  **   41 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   42 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig1,sig2,bkg_x_model)
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-1.51867e+06 FROM MIGRAD    STATUS=INITIATE      117 CALLS         118 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0          -9.99807e-01   2.00000e-01   0.00000e+00   8.63097e-01
#    2  c1           5.00000e-01   2.00000e-01   0.00000e+00  -1.78309e+01
#    3  mean         1.86000e+00   3.00000e-03   0.00000e+00  -8.43752e+04
#    4  nbkg         2.19802e+04   1.09901e+04   0.00000e+00   1.22510e+04
#    5  nsig         8.79208e+04   1.09901e+04   0.00000e+00  -3.06311e+03
#    6  sig1frac     5.00000e-01   1.00000e-01   0.00000e+00  -6.57899e+03
#    7  sigma1       6.48976e-03   1.00000e-02   0.00000e+00   3.15650e+04
#    8  sigma2       1.10422e-02   1.00000e-02  -8.93319e-01   4.05536e+04
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999981	c1=0.100294	mean=1.86468	nbkg=17557.7	nsig=92880.7	sig1frac=0.777024	sigma1=0.00476479	sigma2=0.00226585
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999981,c1 = 0.100294,mean = 1.86468,nbkg = 17557.7,nsig = 92880.7,sig1frac = 0.777024,sigma1 = 0.00476479,sigma2 = 0.00226585)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999981,c1 = 0.100294)
#      p.d.f normalization integral is zero or negative: -0.041035 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999981,c1 = 0.100294)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999981	c1=0.100299	mean=1.86468	nbkg=17557.6	nsig=92880.5	sig1frac=0.777009	sigma1=0.00476477	sigma2=0.00226592
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999981,c1 = 0.100299,mean = 1.86468,nbkg = 17557.6,nsig = 92880.5,sig1frac = 0.777009,sigma1 = 0.00476477,sigma2 = 0.00226592)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999981,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999981,c1 = 0.100299)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999978	c1=0.100299	mean=1.8648	nbkg=17880.3	nsig=92539.5	sig1frac=0.752607	sigma1=0.00492828	sigma2=0.00223225
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999978,c1 = 0.100299,mean = 1.8648,nbkg = 17880.3,nsig = 92539.5,sig1frac = 0.752607,sigma1 = 0.00492828,sigma2 = 0.00223225)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999978,c1 = 0.100299)
#      p.d.f normalization integral is zero or negative: -0.041033 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999978,c1 = 0.100299)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999978	c1=0.170074	mean=1.8648	nbkg=17880.3	nsig=92539.5	sig1frac=0.752607	sigma1=0.00492828	sigma2=0.00223225
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999978,c1 = 0.170074,mean = 1.8648,nbkg = 17880.3,nsig = 92539.5,sig1frac = 0.752607,sigma1 = 0.00492828,sigma2 = 0.00223225)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999978,c1 = 0.170074)
#      p.d.f normalization integral is zero or negative: -0.021718 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999978,c1 = 0.170074)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999944	c1=0.225377	mean=1.86474	nbkg=17485.1	nsig=91186.8	sig1frac=0.493236	sigma1=0.00566387	sigma2=0.00300581
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999944,c1 = 0.225377,mean = 1.86474,nbkg = 17485.1,nsig = 91186.8,sig1frac = 0.493236,sigma1 = 0.00566387,sigma2 = 0.00300581)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999944,c1 = 0.225377)
#      p.d.f normalization integral is zero or negative: -0.006405 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999944,c1 = 0.225377)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.999913	c1=0.225386	mean=1.8647	nbkg=16885.5	nsig=91551.8	sig1frac=0.399598	sigma1=0.00606352	sigma2=0.00305917
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.999913,c1 = 0.225386,mean = 1.8647,nbkg = 16885.5,nsig = 91551.8,sig1frac = 0.399598,sigma1 = 0.00606352,sigma2 = 0.00305917)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.863, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.999913,c1 = 0.225386)
#      p.d.f normalization integral is zero or negative: -0.006398 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.999913,c1 = 0.225386)
#     ... (remaining 73718 messages suppressed)
#
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 11.5446 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.55379e+06 FROM HESSE     STATUS=OK             73 CALLS         658 TOTAL
#                      EDM=16.5026    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           9.99999e-01   4.00179e-02   5.00000e-01  -1.12702e-03
#    2  c1           5.65095e-01   1.48159e+00   2.65027e-01   5.68967e+00
#    3  mean         1.86471e+00   1.47758e-05   8.47146e-04   3.71718e-01
#    4  nbkg         1.27835e+04   2.26830e+02   3.70566e-03  -8.15612e-01
#    5  nsig         9.71189e+04   3.67989e+02   7.84525e-03   6.23145e-01
#    6  sig1frac     2.49464e-01   6.26188e-03   5.73266e-03   2.11333e-01
#    7  sigma1       9.52578e-03   1.83958e-04   2.48153e-03   9.38351e-01
#    8  sigma2       3.42455e-03   2.28030e-05   6.24528e-04   3.35024e+00
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.99813	c1=-0.847344	mean=1.86471	nbkg=12721.5	nsig=97180	sig1frac=0.249178	sigma1=0.00955985	sigma2=0.00342636
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.99813,c1 = -0.847344,mean = 1.86471,nbkg = 12721.5,nsig = 97180,sig1frac = 0.249178,sigma1 = 0.00955985,sigma2 = 0.00342636)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.863, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.99813,c1 = -0.847344)
#      p.d.f normalization integral is zero or negative: -0.006032 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.99813,c1 = -0.847344)
#     ... (remaining 73718 messages suppressed)
#
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.14352 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -7.7548e-01  1.5457e-02  3.4127e-02  7.2715e-02  2.0775e-01  9.9997e-01  1.3359e+00  6.1096e+00
#  MINUIT WARNING IN MIGRAD
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.781585 TO DIAGONAL.
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.0234 added to diagonal of error matrix
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999793	c1=-0.851694	mean=1.86039	nbkg=48302	nsig=109659	sig1frac=0.743021	sigma1=0.099872	sigma2=0.0658376
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999793,c1 = -0.851694,mean = 1.86039,nbkg = 48302,nsig = 109659,sig1frac = 0.743021,sigma1 = 0.099872,sigma2 = 0.0658376)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999793,c1 = -0.851694)
#      p.d.f normalization integral is zero or negative: -0.006989 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999793,c1 = -0.851694)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.987637	c1=-0.999775	mean=1.87758	nbkg=4153.57	nsig=17794.6	sig1frac=0.38819	sigma1=0.00411451	sigma2=0.0878823
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.987637,c1 = -0.999775,mean = 1.87758,nbkg = 4153.57,nsig = 17794.6,sig1frac = 0.38819,sigma1 = 0.00411451,sigma2 = 0.0878823)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.863, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.987637,c1 = -0.999775)
#      p.d.f normalization integral is zero or negative: -0.049788 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.987637,c1 = -0.999775)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.40118e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999915	c1=-0.994113	mean=1.86268	nbkg=7731.67	nsig=19411.6	sig1frac=0.614545	sigma1=0.0144076	sigma2=0.058431
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999915,c1 = -0.994113,mean = 1.86268,nbkg = 7731.67,nsig = 19411.6,sig1frac = 0.614545,sigma1 = 0.0144076,sigma2 = 0.058431)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999915,c1 = -0.994113)
#      p.d.f normalization integral is zero or negative: -0.046394 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999915,c1 = -0.994113)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.963463	c1=-0.993396	mean=1.86863	nbkg=5523.9	nsig=38206	sig1frac=0.875057	sigma1=0.013512	sigma2=0.019319
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.963463,c1 = -0.993396,mean = 1.86863,nbkg = 5523.9,nsig = 38206,sig1frac = 0.875057,sigma1 = 0.013512,sigma2 = 0.019319)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.863, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.963463,c1 = -0.993396)
#      p.d.f normalization integral is zero or negative: -0.051619 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.963463,c1 = -0.993396)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999988	c1=-0.901269	mean=1.86386	nbkg=106100	nsig=25194.5	sig1frac=0.00043679	sigma1=0.0986645	sigma2=0.00841579
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999988,c1 = -0.901269,mean = 1.86386,nbkg = 106100,nsig = 25194.5,sig1frac = 0.00043679,sigma1 = 0.0986645,sigma2 = 0.00841579)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999988,c1 = -0.901269)
#      p.d.f normalization integral is zero or negative: -0.020683 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999988,c1 = -0.901269)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.970165	c1=-0.991869	mean=1.86435	nbkg=11263.1	nsig=101344	sig1frac=0.158178	sigma1=0.0451632	sigma2=0.00906001
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.970165,c1 = -0.991869,mean = 1.86435,nbkg = 11263.1,nsig = 101344,sig1frac = 0.158178,sigma1 = 0.0451632,sigma2 = 0.00906001)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.863, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.970165,c1 = -0.991869)
#      p.d.f normalization integral is zero or negative: -0.050199 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.970165,c1 = -0.991869)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999993	c1=-0.897568	mean=1.86469	nbkg=11791.8	nsig=97829.3	sig1frac=0.231612	sigma1=0.00997745	sigma2=0.00353062
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999993,c1 = -0.897568,mean = 1.86469,nbkg = 11791.8,nsig = 97829.3,sig1frac = 0.231612,sigma1 = 0.00997745,sigma2 = 0.00353062)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999993,c1 = -0.897568)
#      p.d.f normalization integral is zero or negative: -0.019657 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999993,c1 = -0.897568)
#     ... (remaining 73718 messages suppressed)
#
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.01157 added to diagonal of error matrix
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999992	c1=-0.952564	mean=1.87962	nbkg=109410	nsig=104615	sig1frac=0.645476	sigma1=0.00693792	sigma2=0.0891106
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999992,c1 = -0.952564,mean = 1.87962,nbkg = 109410,nsig = 104615,sig1frac = 0.645476,sigma1 = 0.00693792,sigma2 = 0.0891106)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999992,c1 = -0.952564)
#      p.d.f normalization integral is zero or negative: -0.034881 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999992,c1 = -0.952564)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.999919	c1=-0.965893	mean=1.87505	nbkg=4619.7	nsig=107861	sig1frac=0.576358	sigma1=0.0995486	sigma2=0.0836028
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.999919,c1 = -0.965893,mean = 1.87505,nbkg = 4619.7,nsig = 107861,sig1frac = 0.576358,sigma1 = 0.0995486,sigma2 = 0.0836028)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.863, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999919,c1 = -0.965893)
#      p.d.f normalization integral is zero or negative: -0.038582 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999919,c1 = -0.965893)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.972359	c1=-0.859353	mean=1.87895	nbkg=3771.59	nsig=107716	sig1frac=0.918187	sigma1=0.074196	sigma2=0.0243554
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.972359,c1 = -0.859353,mean = 1.87895,nbkg = 3771.59,nsig = 107716,sig1frac = 0.918187,sigma1 = 0.074196,sigma2 = 0.0243554)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.863, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.972359,c1 = -0.859353)
#      p.d.f normalization integral is zero or negative: -0.013191 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.972359,c1 = -0.859353)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.693458	c1=-0.888783	mean=1.86589	nbkg=64596.6	nsig=72953.4	sig1frac=0.0935567	sigma1=0.0330341	sigma2=5.8844e-05
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.693458,c1 = -0.888783,mean = 1.86589,nbkg = 64596.6,nsig = 72953.4,sig1frac = 0.0935567,sigma1 = 0.0330341,sigma2 = 5.8844e-05)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.863, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.693458,c1 = -0.888783)
#      p.d.f normalization integral is zero or negative: -0.062838 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.693458,c1 = -0.888783)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# ...
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.999964,c1 = -0.942884)
#      p.d.f normalization integral is zero or negative: -0.032206 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.999964,c1 = -0.942884)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=0.703746	c1=-0.791443	mean=1.86526	nbkg=27601.1	nsig=60105.6	sig1frac=0.570932	sigma1=0.00667402	sigma2=0.0201051
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = 0.703746,c1 = -0.791443,mean = 1.86526,nbkg = 27601.1,nsig = 60105.6,sig1frac = 0.570932,sigma1 = 0.00667402,sigma2 = 0.0201051)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86514, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86539, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86797, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86214, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.863, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86236, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.86182, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.8668, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.87004, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.8803, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.89603, coefList=(c0 = 0.703746,c1 = -0.791443)
#      p.d.f normalization integral is zero or negative: -0.034363 @ x=M(D^{0})=1.87296, coefList=(c0 = 0.703746,c1 = -0.791443)
#     ... (remaining 73718 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.21888e+06) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	c0=-0.664172	c1=-0.731618	mean=1.86472	nbkg=11936.1	nsig=97968.8	sig1frac=0.239118	sigma1=0.0101592	sigma2=0.00347192
# RooNLLVar::nll_extended_model_[ paramSet=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      function value is NAN @ paramSet=(c0 = -0.664172,c1 = -0.731618,mean = 1.86472,nbkg = 11936.1,nsig = 97968.8,sig1frac = 0.239118,sigma1 = 0.0101592,sigma2 = 0.00347192)
# PID1523991/RooRealMPFE::nll_extended_model__563a300fcb30_MPFE11[ arg=nll_extended_model__GOF11 vars=(c0,c1,mean,nbkg,nsig,sig1frac,sigma1,sigma2) ]
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86514, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86539, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86797, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86214, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.863, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86236, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.86182, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.8668, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.87004, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.8803, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.89603, coefList=(c0 = -0.664172,c1 = -0.731618)
#      p.d.f normalization integral is zero or negative: -0.221348 @ x=M(D^{0})=1.87296, coefList=(c0 = -0.664172,c1 = -0.731618)
#     ... (remaining 73718 messages suppressed)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.55384e+06 FROM MIGRAD    STATUS=CONVERGED    1396 CALLS        1397 TOTAL
#                      EDM=0.000983697    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  c0           9.99968e-01   1.41296e+00   4.95471e-02   4.51380e-03
#    2  c1          -7.07624e-01   1.38792e-02   1.24552e-02   8.73500e-01
#    3  mean         1.86472e+00   1.48241e-05   8.47341e-04  -7.86853e+00
#    4  nbkg         1.20478e+04   2.47877e+02   3.73869e-03  -6.22745e-01
#    5  nsig         9.78554e+04   3.83304e+02   8.07447e-03   8.49935e-01
#    6  sig1frac     2.44010e-01   5.74664e-03   5.53303e-03  -1.98998e+00
#    7  sigma1       1.00145e-02   2.05798e-04   2.58046e-03  -3.03046e+00
#    8  sigma2       3.45239e-03   2.24374e-05   6.18051e-04   3.95003e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   1.236e-04  9.308e-05  4.392e-09 -3.355e-01  3.342e-01 -3.005e-06  2.524e-07  1.449e-08
#   9.308e-05  1.927e-04 -1.016e-08  7.126e-01 -7.096e-01  5.985e-06 -5.229e-07 -2.970e-08
#   4.392e-09 -1.016e-08  2.198e-10 -4.562e-05  4.540e-05  2.129e-10  3.132e-11 -2.132e-12
#  -3.355e-01  7.126e-01 -4.562e-05  6.144e+04 -4.919e+04  4.000e-01 -3.572e-02 -2.028e-03
#   3.342e-01 -7.096e-01  4.540e-05 -4.919e+04  1.469e+05 -3.993e-01  3.561e-02  2.022e-03
#  -3.005e-06  5.985e-06  2.129e-10  4.000e-01 -3.993e-01  3.303e-05 -8.637e-07 -1.028e-07
#   2.524e-07 -5.229e-07  3.132e-11 -3.572e-02  3.561e-02 -8.637e-07  4.235e-08  3.098e-09
#   1.449e-08 -2.970e-08 -2.132e-12 -2.028e-03  2.022e-03 -1.028e-07  3.098e-09  5.034e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.66221   1.000  0.603  0.027 -0.122  0.078 -0.047  0.110  0.058
#         2  0.67607   0.603  1.000 -0.049  0.207 -0.133  0.075 -0.183 -0.095
#         3  0.09035   0.027 -0.049  1.000 -0.012  0.008  0.002  0.010 -0.006
#         4  0.79877  -0.122  0.207 -0.012  1.000 -0.518  0.281 -0.700 -0.365
#         5  0.54231   0.078 -0.133  0.008 -0.518  1.000 -0.181  0.451  0.235
#         6  0.87704  -0.047  0.075  0.002  0.281 -0.181  1.000 -0.730 -0.797
#         7  0.89933   0.110 -0.183  0.010 -0.700  0.451 -0.730  1.000  0.671
#         8  0.81158   0.058 -0.095 -0.006 -0.365  0.235 -0.797  0.671  1.000
#  **********
#  **   43 **SET ERR         0.5
#  **********
#  **********
#  **   44 **SET PRINT           1
#  **********
#  **********
#  **   45 **HESSE        4000
#  **********
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -3.1638e+00  9.0008e-02  3.3804e-01  9.9476e-01  1.0937e+00  1.2310e+00  2.2283e+00  5.1881e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 3.169033 TO DIAGONAL.
#  FCN=-1.55384e+06 FROM HESSE     STATUS=NOT POSDEF     67 CALLS        1464 TOTAL
#                      EDM=0.0161204    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  c0           9.99968e-01   6.97286e-02   5.00000e-01   1.56279e+00
#    2  c1          -7.07624e-01   1.00766e-01   4.98207e-04  -7.86130e-01
#    3  mean         1.86472e+00   7.23439e-06   1.69468e-04  -1.84348e-02
#    4  nbkg         1.20478e+04   7.45155e+01   1.49548e-04  -8.95868e-01
#    5  nsig         9.78554e+04   1.58255e+02   3.22979e-04   8.95933e-01
#    6  sig1frac     2.44010e-01   1.38561e-03   1.10661e-03  -5.37489e-01
#    7  sigma1       1.00145e-02   4.62305e-05   1.03218e-04  -9.26813e-01
#    8  sigma2       3.45239e-03   6.49155e-06   2.47220e-05  -1.19701e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   9.052e-06  3.038e-04 -5.256e-10 -1.375e-02  9.364e-03  7.656e-08  3.043e-08 -8.034e-11
#   3.038e-04  1.022e-02 -1.843e-08 -4.464e-01  3.039e-01  2.465e-06  1.014e-06 -2.812e-09
#  -5.256e-10 -1.843e-08  5.234e-11  1.708e-06 -1.163e-06 -7.024e-12 -1.562e-12 -1.557e-13
#  -1.375e-02 -4.464e-01  1.708e-06  5.553e+03 -7.610e+02 -7.720e-03 -5.441e-04 -8.806e-06
#   9.364e-03  3.039e-01 -1.163e-06 -7.610e+02  2.504e+04  5.256e-03  3.705e-04  5.994e-06
#   7.656e-08  2.465e-06 -7.024e-12 -7.720e-03  5.256e-03  1.920e-06 -8.048e-09 -1.298e-09
#   3.043e-08  1.014e-06 -1.562e-12 -5.441e-04  3.705e-04 -8.048e-09  2.137e-09  9.567e-12
#  -8.034e-11 -2.812e-09 -1.557e-13 -8.806e-06  5.994e-06 -1.298e-09  9.567e-12  4.214e-11
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.99876   1.000  0.999 -0.024 -0.061  0.020  0.018  0.219 -0.004
#         2  0.99875   0.999  1.000 -0.025 -0.059  0.019  0.018  0.217 -0.004
#         3  0.03271  -0.024 -0.025  1.000  0.003 -0.001 -0.001 -0.005 -0.003
#         4  0.19810  -0.061 -0.059  0.003  1.000 -0.065 -0.075 -0.158 -0.018
#         5  0.08151   0.020  0.019 -0.001 -0.065  1.000  0.024  0.051  0.006
#         6  0.21848   0.018  0.018 -0.001 -0.075  0.024  1.000 -0.126 -0.144
#         7  0.30181   0.219  0.217 -0.005 -0.158  0.051 -0.126  1.000  0.032
#         8  0.14783  -0.004 -0.004 -0.003 -0.018  0.006 -0.144  0.032  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig1,sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig1)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (sig2)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: (sig_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) directly selected PDF components: (bkg_x_model)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) only plotting range 'fit_nll_extended_model_'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(extended_model) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_extended_model_'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
# Info in <TCanvas::Print>: png file test.png has been created

# %%
print(nsig)
print(nbkg)
# Out:
# RooRealVar::nsig = 97855.4 +/- 158.255  L(0 - 109901)
#
# RooRealVar::nbkg = 12047.8 +/- 74.5155  L(0 - 109901)
