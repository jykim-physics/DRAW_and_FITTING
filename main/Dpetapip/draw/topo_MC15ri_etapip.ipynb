# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
try:
#     plt.style.use('belle2')
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

# %%
from main.data_tools.extract_ntuples import get_pd, get_np
# Out:
# Welcome to JupyROOT 6.26/04

# %% [markdown]
# # D+ -> eta pi+, pipipi

# %%
file_name = '/media/jykim/T7_2/storage/Ntuples_ghi_2/MC15ri_generic/MC15ri_etaetapip_tight_v0_looseeta_240317_treefit_BCS/topo/resultfile/result_etapip_pipipi/*.root'
# file_name = '/home/jykim/ntuple_10e5.root'

base_filter = 'Dp_M'

tree = 'etapip_pipipi'
variables = ["__experiment__", "__run__", "__event__",\
             'Dp_M','Dp_chiProb','Dp_isSignal','Dp_CMS_p','Dp_cosAngleBetweenMomentumAndVertexVector','Dp_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'Dp_acos_cosAngleBetweenMomentumAndVertexVector','Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'etapip_Eta_M','etapip_Eta_isSignal','etapip_Eta_p',\
             'etapip_pi0_gamma1_p','etapip_pi0_gamma2_p','etapip_pi0_gamma1_clusterNHits','etapip_pi0_gamma2_clusterNHits',\
             'etapip_pi0_gamma1_clusterReg', 'etapip_pi0_gamma2_clusterReg',\
             'eta_Pi0_M',"eta_Pi0_daughterAngle_0_1","eta_Pi0_daughterDiffOfPhi_0_1","eta_Pi0_Easym",\
             'eta_Pip_pionID','eta_Pim_pionID',\
             'eta_Pip_pionIDNN','eta_Pim_pionIDNN','eta_Pip_mcPDG','eta_Pim_mcPDG',\
             'Pip_pionID','Pip_pionIDNN','Pip_mcPDG','Pip_dr','Pip_dz','Pip_p','Pip_pt','etapip_pipipi_rank',\
             'iProdBrP_Dsp_0','iProdBrP_Dp_0','iCascDcyBrP_Dp_0','iCascDcyBrCcP_Dp_0','iCascDcyBrP_Dsp_0','iCascDcyBrCcP_Dsp_0']

# %%
pd_df_v0 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=variables)

# %%
# cut = "etapip_pipipi_rank==1 & Dp_chiProb>0.01"
cut = "etapip_pipipi_rank==1"

# cut = "Dp_M>0"

pd_df_test=pd_df_v0.query(cut)

# pd_df_test=pd_df_test.query("etapip_pipipi_rank==1")

pd_df_test
# Out:
#         __experiment__  __run__  __event__      Dp_M  Dp_chiProb  Dp_isSignal  \
# 0                 1003        0   39598589  1.837997    0.003408          0.0
# 1                 1003        0   39600298  1.852987    0.477515          1.0
# 2                 1003        0   18741049  1.770360    0.290075          0.0
# 3                 1003        0   18741812  1.602618    0.259288          NaN
# 4                 1003        0   18742802  1.621657    0.050076          0.0
# ...                ...      ...        ...       ...         ...          ...
# 838361            1003        0  180378896  1.778199    0.017038          0.0
# 838362            1003        0  180379450  1.652180    0.218831          0.0
# 838364            1003        0  180382265  1.911063    0.623305          0.0
# 838365            1003        0  172496768  1.967671    0.093692          NaN
# 838366            1003        0  172496877  1.962337    0.140522          0.0
#
#         Dp_CMS_p  Dp_cosAngleBetweenMomentumAndVertexVector  \
# 0       2.509299                                   0.823164
# 1       2.543879                                  -0.535389
# 2       3.353344                                   0.544381
# 3       2.581486                                   0.900376
# 4       2.671850                                   0.872910
# ...          ...                                        ...
# 838361  2.832714                                   0.662185
# 838362  3.309314                                   0.702709
# 838364  2.757964                                   0.882023
# 838365  3.009005                                  -0.764888
# 838366  3.121098                                   0.729601
#
#         Dp_cosAngleBetweenMomentumAndVertexVectorInXYPlane  \
# 0                                                0.997302
# 1                                                0.999998
# 2                                                0.999997
# 3                                                0.998968
# 4                                                0.999979
# ...                                                   ...
# 838361                                           0.997741
# 838362                                           0.999988
# 838364                                           1.000000
# 838365                                           0.995091
# 838366                                           0.998926
#
#         Dp_acos_cosAngleBetweenMomentumAndVertexVector  ...    Pip_dz  \
# 0                                             0.603836  ...  0.001629
# 1                                             2.135764  ... -0.015674
# 2                                             0.995145  ...  0.027466
# 3                                             0.450162  ...  0.039848
# 4                                             0.509660  ...  0.059454
# ...                                                ...  ...       ...
# 838361                                        0.847065  ...  0.044480
# 838362                                        0.791598  ...  0.024873
# 838364                                        0.490657  ... -0.008290
# 838365                                        2.441664  ...  0.057847
# 838366                                        0.753058  ...  0.002673
#
#            Pip_p    Pip_pt  etapip_pipipi_rank  iProdBrP_Dsp_0  iProdBrP_Dp_0  \
# 0       0.363431  0.227763                 1.0               0             -1
# 1       0.492355  0.433097                 1.0              -1              0
# 2       2.219934  2.219777                 1.0              -1             -1
# 3       0.141868  0.104995                 1.0              -1             -1
# 4       1.178877  0.726635                 1.0               2             -1
# ...          ...       ...                 ...             ...            ...
# 838361  1.262723  1.155686                 1.0              -1              0
# 838362  1.378329  1.292737                 1.0              -1             -1
# 838364  0.812297  0.787357                 1.0              -1              0
# 838365  0.809655  0.663124                 1.0              -1              0
# 838366  1.319355  1.126436                 1.0               0             -1
#
#         iCascDcyBrP_Dp_0  iCascDcyBrCcP_Dp_0  iCascDcyBrP_Dsp_0  \
# 0                     -1                  -1                  0
# 1                      0                   1                 -1
# 2                     -1                   2                 -1
# 3                     -1                  -1                 -1
# 4                     -1                  -1                  2
# ...                  ...                 ...                ...
# 838361                11                   8                 -1
# 838362                -1                  -1                 -1
# 838364                 7                  -1                 -1
# 838365                16                  -1                 -1
# 838366                -1                 112                  5
#
#         iCascDcyBrCcP_Dsp_0
# 0                        -1
# 1                        -1
# 2                        -1
# 3                         1
# 4                        -1
# ...                     ...
# 838361                   -1
# 838362                    2
# 838364                   -1
# 838365                   -1
# 838366                   -1
#
# [690630 rows x 44 columns]

# %%
fig = plt.figure()
ax = fig.subplots()
xrange = (1.6,2.1,51)

xm = np.linspace(*xrange)

df = pd_df_test
# df2 = pd_df_test2

N_df = len(df)
# N_df2 = len(df2)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$ event(' + str(N_df) +')');
# plt.hist(df2["D0_M"],bins=xm,histtype='step',label=r'$D^0 \to K^- \pi^+ \gamma_F$ MC matched(' + str(N_df2) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.tight_layout()
# file1_name="/media/jykim/T7/saved_plots/DRAW/antiKstargamma/MC15ri_D0_M_FSR.png"
# plt.savefig(file1_name)
print(len(df))
# Out:
# 690630

# %%
figure_size_inches = (8, 5.5)  # Width, Height
fig = plt.figure(figsize=figure_size_inches)
ax = fig.subplots()
xrange = (1.6,2.1,51)

xm = np.linspace(*xrange)

# cut1 = "(iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3) & (iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5)"
# cut2 = "(iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) & (iCascDcyBrP_Dp_0!=0 & iCascDcccvyBrCcP_Dp_0!=0) "
# cut3 = "(iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0)"
# cut4 = "( (iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) |  (iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) ) & (iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0)"

cut1 = "(iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3) & (iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5)"

cut2 = "(iCascDcyBrP_Dp_0==0 & iCascDcyBrCcP_Dp_0!=0) & (iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0==3) & (iCascDcyBrP_Dsp_0!=5)"
cut3 = "(iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0==3 & iCascDcyBrCcP_Dsp_0!=3) & (iCascDcyBrCcP_Dsp_0!=5)"
cut4 = "(iCascDcyBrP_Dp_0==0 & iCascDcyBrCcP_Dp_0!=0) & (iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0==5) & (iCascDcyBrP_Dsp_0!=3)"
cut5 = "(iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0==5 & iCascDcyBrCcP_Dsp_0!=5) & (iCascDcyBrCcP_Dsp_0!=3)"

cut6 = "(iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0) & (iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5)"
cut7 = "(iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0) & (iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3)"



remained_cut = "iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0 & \
                iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3 & \
                iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5"
df = pd_df_test.query(cut1)
df2 = pd_df_test.query(cut2)
df3 = pd_df_test.query(cut3)
df4 = pd_df_test.query(cut4)
df5 = pd_df_test.query(cut5)
df6 = pd_df_test.query(cut6)
df7 = pd_df_test.query(cut7)

df_rest = pd_df_test.query(remained_cut)


# df2 = pd_df_test.query("iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0")

# df2 = pd_df_test2

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df4 = len(df4)
N_df5 = len(df5)
N_df6 = len(df6)
N_df7 = len(df7)

N_df_rest = len(df_rest)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$(' + str(N_df) +')');
plt.hist(df2["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \eta \pi^+$(' + str(N_df2) +')');
plt.hist(df3["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df3) +')');
plt.hist(df4["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df4) +')');
plt.hist(df5["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df5) +')');
plt.hist(df6["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df6) +')');
plt.hist(df7["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df7) +')');

plt.hist(df_rest["Dp_M"],bins=xm,histtype='step',label=r'Remained(' + str(N_df_rest) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.legend(loc="upper left",fontsize=12)

plt.tight_layout()

# file1_name="/media/jykim/T7/saved_plots/DRAW/etapip/MC15ri_generic/pipipi/topo/MC15ri_etaetapip_3pi_tight_v0_looseeta_240317_treefit_BCS_Dp_M.png"
# plt.savefig(file1_name)
print(N_df+N_df2+N_df3+N_df4+N_df5+N_df6+N_df7+N_df_rest)
# print(N_df+N_df2+N_df3+N_df_rest)
# Out:
# 690892

# %%
figure_size_inches = (8, 5.5)  # Width, Height
fig = plt.figure(figsize=figure_size_inches)
ax = fig.subplots()
xrange = (1.6,2.1,51)

xm = np.linspace(*xrange)

cut1 = "(iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3) & (iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5)"
cut2 = "(iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) & (iCascDcyBrP_Dp_0!=0 & iCascDcccvyBrCcP_Dp_0!=0) "
cut3 = "(iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0)"
cut4 = "( (iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) |  (iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) ) & (iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0)"

remained_cut = "iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0 & \
                iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3 & \
                iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5"
df = pd_df_test.query(cut1)
df2 = pd_df_test.query(cut2)
df3 = pd_df_test.query(cut3)
df4 = pd_df_test.query(cut4)
df_rest = pd_df_test.query(remained_cut)


# df2 = pd_df_test.query("iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0")

# df2 = pd_df_test2

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df4 = len(df4)

N_df_rest = len(df_rest)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$(' + str(N_df) +')');
plt.hist(df2["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \eta \pi^+$(' + str(N_df2) +')');
plt.hist(df3["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df3) +')');
plt.hist(df4["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df4) +')');

plt.hist(df_rest["Dp_M"],bins=xm,histtype='step',label=r'Remained(' + str(N_df_rest) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.legend(loc="upper left")

plt.tight_layout()

# file1_name="/media/jykim/T7/saved_plots/DRAW/etapip/MC15ri_generic/pipipi/topo/MC15ri_etaetapip_3pi_tight_v0_looseeta_240317_treefit_BCS_Dp_M.png"
# plt.savefig(file1_name)
print(N_df+N_df2+N_df3+N_df4+N_df_rest)
# print(N_df+N_df2+N_df3+N_df_rest)
# Out:
# 690892

# %%
figure_size_inches = (8, 5.5)  # Width, Height
fig = plt.figure(figsize=figure_size_inches)
ax = fig.subplots()
xrange = (1.75, 1.95, 51)

xm = np.linspace(*xrange)

cut1 = "(iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0) & (iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3) & (iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5)"
cut2 = "(iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0) "
cut3 = "(iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0)"

remained_cut = "iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0 & \
                iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3 & \
                iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5"
df = pd_df_test.query(cut1)
df2 = pd_df_test.query(cut2)
df3 = pd_df_test.query(cut3)
df_rest = pd_df_test.query(remained_cut)

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df_rest = len(df_rest)

# Plot the stacked histograms
plt.hist([df_rest["Dp_M"], df2["Dp_M"], df3["Dp_M"], df["Dp_M"]], bins=xm, histtype='step', label=['Remained', r'$D^+_s \to \eta \pi^+$', r'$D^+_s \to \rho^+ \eta$', r'$D^+ \to \eta \pi^+$'], stacked=True)

plt.legend(loc="upper right", fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar')

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0], xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1] - xe[0]
plt.ylabel('Entries' + ' /' + '$(' + ' ' + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$')

plt.xlim(xrange[0], xrange[1])
plt.legend(loc="upper left")

plt.tight_layout()
plt.ylim(0,12000)

# file1_name = "/media/jykim/T7/saved_plots/DRAW/etapip/MC15ri_generic/pipipi/topo/MC15ri_etaetapip_3pi_tight_v0_looseeta_240317_treefit_BCS_Dp_M_stacked.png"
# plt.savefig(file1_name)
print(N_df + N_df2 + N_df3 + N_df_rest)
# Out:
# 690755

# %%
fig = plt.figure()
ax = fig.subplots()
xrange = (0,1,101)

xm = np.linspace(*xrange)

cut1 = "iCascDcyBrP_Dp_0==0 | iCascDcyBrCcP_Dp_0==0"
cut2 = "(iCascDcyBrP_Dsp_0==3 | iCascDcyBrCcP_Dsp_0==3) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0) "
cut3 = "(iCascDcyBrP_Dsp_0==5 | iCascDcyBrCcP_Dsp_0==5) & (iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0)"

remained_cut = "iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0 & \
                iCascDcyBrP_Dsp_0!=3 & iCascDcyBrCcP_Dsp_0!=3 & \
                iCascDcyBrP_Dsp_0!=5 & iCascDcyBrCcP_Dsp_0!=5"
df = pd_df_test.query(cut1)
df2 = pd_df_test.query(cut2)
df3 = pd_df_test.query(cut3)
df_rest = pd_df_test.query(remained_cut)


# df2 = pd_df_test.query("iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0")

# df2 = pd_df_test2

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df_rest = len(df_rest)

value = "Dp_chiProb"
plt.hist(df[value],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$(' + str(N_df) +')' );
plt.hist(df2[value],bins=xm,histtype='step',label=r'$D^+_s \to \eta \pi^+$(' + str(N_df2) +')' );
plt.hist(df3[value],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df3) +')');
plt.hist(df_rest[value],bins=xm,histtype='step',label=r'Remained(' + str(N_df_rest) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.legend(loc="upper left")

plt.tight_layout()
plt.yscale('log')
# file1_name="/media/jykim/T7/saved_plots/DRAW/antiKstargamma/MC15ri_D0_M_FSR.png"
# plt.savefig(file1_name)
print(N_df+N_df2+N_df3+N_df_rest)
# Out:
# 690892

# %% [markdown]
# # D+ -> eta pi+,gg

# %%
file_name = '/media/jykim/T7_2/storage/Ntuples_ghi_2/MC15ri_generic/MC15ri_etaetapip_tight_v0_looseeta_240317_treefit_BCS/topo/resultfile/result_etapip_gg/*.root'
# file_name = '/home/jykim/ntuple_10e5.root'

base_filter = 'Dp_M'

tree = 'etapip_gg'
variables = ["__experiment__", "__run__", "__event__",\
             'Dp_M','Dp_chiProb','Dp_isSignal','Dp_CMS_p','Dp_cosAngleBetweenMomentumAndVertexVector','Dp_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'Dp_acos_cosAngleBetweenMomentumAndVertexVector','Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'etapip_Eta_M','etapip_Eta_isSignal','etapip_Eta_daughterDiffOfPhi_0_1','etapip_Eta_daughterAngle_0_1','etapip_Eta_Easym','etapip_Eta_p',\
             'etapip_gamma1_p','etapip_gamma2_p','etapip_gamma1_clusterNHits','etapip_gamma2_clusterNHits',\
             'etapip_gamma1_clusterReg', 'etapip_gamma2_clusterReg',\
             'Pip_pionID','Pip_pionIDNN','Pip_mcPDG','Pip_dr','Pip_dr','Pip_p',\
             'ROE_Mgg','dM_pi0','ROE_Mgg_50MeV','dM_pi0_50MeV','ROE_Mgg_75MeV','dM_pi0_75MeV','ROE_Mgg_mask','dM_pi0_mask',\
             'ROE_Mgg_2','dM_pi0_2','ROE_Mgg_50MeV_2','dM_pi0_50MeV_2','ROE_Mgg_75MeV_2','dM_pi0_75MeV_2','ROE_Mgg_mask_2','dM_pi0_mask_2',\
             'veto_isSignal','veto_isSignal_50MeV','veto_isSignal_75MeV','veto_isSignal_mask','etapip_gg_rank',\
             'iCascDcyBrP_Dp_0', 'iCascDcyBrCcP_Dp_0','iCascDcyBrP_Dsp_0','iCascDcyBrCcP_Dsp_0']

# %%
pd_df_v0_gg = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=variables)

# %%
# cut = "etapip_pipipi_rank==1 & Dp_chiProb>0.01"
cut = "etapip_gg_rank==1"

# cut = "Dp_M>0"

pd_df_test_gg=pd_df_v0_gg.query(cut)

# pd_df_test=pd_df_test.query("etapip_pipipi_rank==1")

pd_df_test_gg
# Out:
#          __experiment__  __run__  __event__      Dp_M  Dp_chiProb  \
# 0                  1003        0   39597017  1.969848    0.239098
# 1                  1003        0   39599680  1.684093    0.184726
# 2                  1003        0   39599990  1.909355    0.303265
# 3                  1003        0   39601555  2.062016    0.695542
# 4                  1003        0   39602706  1.714970    0.483659
# ...                 ...      ...        ...       ...         ...
# 1450120            1003        0  172496012  1.661741    0.548390
# 1450121            1003        0  172496506  1.704536    0.574830
# 1450122            1003        0  172496677  1.753857    0.249541
# 1450123            1003        0  172498884  1.680029    0.999152
# 1450124            1003        0  172499955  1.851581    0.793856
#
#          Dp_isSignal  Dp_CMS_p  Dp_cosAngleBetweenMomentumAndVertexVector  \
# 0                0.0  3.740139                                   0.880462
# 1                0.0  2.936318                                   0.566250
# 2                0.0  3.021850                                  -0.410985
# 3                0.0  2.648754                                   0.324492
# 4                0.0  2.739957                                   0.920596
# ...              ...       ...                                        ...
# 1450120          0.0  2.936278                                  -0.551033
# 1450121          NaN  2.529701                                   0.532036
# 1450122          0.0  3.521456                                   0.983537
# 1450123          NaN  2.538596                                   0.999951
# 1450124          0.0  2.544488                                   0.724177
#
#          Dp_cosAngleBetweenMomentumAndVertexVectorInXYPlane  \
# 0                                                 0.999998
# 1                                                 0.999586
# 2                                                 0.997751
# 3                                                 0.999702
# 4                                                 0.999882
# ...                                                    ...
# 1450120                                           0.999999
# 1450121                                           0.999953
# 1450122                                           0.999275
# 1450123                                           1.000000
# 1450124                                           0.998381
#
#          Dp_acos_cosAngleBetweenMomentumAndVertexVector  ...  dM_pi0_mask_2  \
# 0                                              0.493960  ...       0.255087
# 1                                              0.968847  ...       0.111773
# 2                                              1.994331  ...       0.340246
# 3                                              1.240322  ...       0.011482
# 4                                              0.401193  ...       1.942482
# ...                                                 ...  ...            ...
# 1450120                                        2.154398  ...       0.023113
# 1450121                                        1.009793  ...       0.330484
# 1450122                                        0.181707  ...       0.019068
# 1450123                                        0.009942  ...       0.011551
# 1450124                                        0.760956  ...       0.227754
#
#          veto_isSignal  veto_isSignal_50MeV  veto_isSignal_75MeV  \
# 0                  0.0                  0.0                  0.0
# 1                  NaN                  NaN                  0.0
# 2                  0.0                  0.0                  0.0
# 3                  0.0                  0.0                  0.0
# 4                  1.0                  NaN                  NaN
# ...                ...                  ...                  ...
# 1450120            0.0                  1.0                  1.0
# 1450121            NaN                  NaN                  NaN
# 1450122            0.0                  0.0                  0.0
# 1450123            NaN                  NaN                  NaN
# 1450124            0.0                  NaN                  0.0
#
#          veto_isSignal_mask  etapip_gg_rank  iCascDcyBrP_Dp_0  \
# 0                       0.0             1.0                 0
# 1                       NaN             1.0                -1
# 2                       0.0             1.0                -1
# 3                       0.0             1.0                 1
# 4                       NaN             1.0                -1
# ...                     ...             ...               ...
# 1450120                 1.0             1.0                -1
# 1450121                 NaN             1.0                -1
# 1450122                 0.0             1.0                -1
# 1450123                 NaN             1.0                -1
# 1450124                 0.0             1.0                77
#
#          iCascDcyBrCcP_Dp_0  iCascDcyBrP_Dsp_0  iCascDcyBrCcP_Dsp_0
# 0                        -1                 -1                    0
# 1                        -1                  1                    2
# 2                        -1                 -1                   -1
# 3                        -1                 -1                   -1
# 4                        -1                 -1                   -1
# ...                     ...                ...                  ...
# 1450120                  -1                 -1                   -1
# 1450121                  -1                 -1                   -1
# 1450122                  29                  1                   -1
# 1450123                  -1                 -1                   -1
# 1450124                  28                 -1                   -1
#
# [1339517 rows x 53 columns]

# %%
fig = plt.figure()
ax = fig.subplots()
xrange = (1.6,2.1,51)

xm = np.linspace(*xrange)

df = pd_df_test_gg
# df2 = pd_df_test2

N_df = len(df)
# N_df2 = len(df2)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$ event(' + str(N_df) +')');
# plt.hist(df2["D0_M"],bins=xm,histtype='step',label=r'$D^0 \to K^- \pi^+ \gamma_F$ MC matched(' + str(N_df2) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.tight_layout()
# file1_name="/media/jykim/T7/saved_plots/DRAW/antiKstargamma/MC15ri_D0_M_FSR.png"
# plt.savefig(file1_name)
print(len(df))
# Out:
# 1339517

# %%
figure_size_inches = (8, 5.5)  # Width, Height
fig = plt.figure(figsize=figure_size_inches)
ax = fig.subplots()
xrange = (1.6,2.1,51)

xm = np.linspace(*xrange)

cut1 = "(iCascDcyBrP_Dp_0==3 | iCascDcyBrCcP_Dp_0==3) & (iCascDcyBrP_Dsp_0!=0 & iCascDcyBrCcP_Dsp_0!=0) & (iCascDcyBrP_Dsp_0!=1 & iCascDcyBrCcP_Dsp_0!=1)"
cut2 = "(iCascDcyBrP_Dsp_0==0 | iCascDcyBrCcP_Dsp_0==0) & (iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3) "
cut3 = "(iCascDcyBrP_Dsp_0==1 | iCascDcyBrCcP_Dsp_0==1) & (iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3)"

remained_cut = "iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3 & \
                iCascDcyBrP_Dsp_0!=0 & iCascDcyBrCcP_Dsp_0!=0 & \
                iCascDcyBrP_Dsp_0!=1 & iCascDcyBrCcP_Dsp_0!=1"
df = pd_df_test_gg.query(cut1)
df2 = pd_df_test_gg.query(cut2)
df3 = pd_df_test_gg.query(cut3)
df_rest = pd_df_test_gg.query(remained_cut)


# df2 = pd_df_test.query("iCascDcyBrP_Dp_0!=0 & iCascDcyBrCcP_Dp_0!=0")

# df2 = pd_df_test2

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df_rest = len(df_rest)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$(' + str(N_df) +')');
plt.hist(df2["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \eta \pi^+$(' + str(N_df2) +')');
plt.hist(df3["Dp_M"],bins=xm,histtype='step',label=r'$D^+_s \to \rho^+ \eta$(' + str(N_df3) +')');
plt.hist(df_rest["Dp_M"],bins=xm,histtype='step',label=r'Remained(' + str(N_df_rest) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.legend(loc="upper left")

plt.tight_layout()

file1_name="/media/jykim/T7/saved_plots/DRAW/etapip/MC15ri_generic/gg/topo/MC15ri_etaetapip_gg_tight_v0_looseeta_240317_treefit_BCS_Dp_M.png"
plt.savefig(file1_name)
print(N_df+N_df2+N_df3+N_df_rest)
# Out:
# 1340141

# %%
figure_size_inches = (8, 5.5)  # Width, Height
fig = plt.figure(figsize=figure_size_inches)
ax = fig.subplots()
xrange = (1.6, 2.1, 51)

xm = np.linspace(*xrange)

cut1 = "(iCascDcyBrP_Dp_0==3 | iCascDcyBrCcP_Dp_0==3) & (iCascDcyBrP_Dsp_0!=0 & iCascDcyBrCcP_Dsp_0!=0) & (iCascDcyBrP_Dsp_0!=1 & iCascDcyBrCcP_Dsp_0!=1)"
cut2 = "(iCascDcyBrP_Dsp_0==0 | iCascDcyBrCcP_Dsp_0==0) & (iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3) "
cut3 = "(iCascDcyBrP_Dsp_0==1 | iCascDcyBrCcP_Dsp_0==1) & (iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3)"

remained_cut = "iCascDcyBrP_Dp_0!=3 & iCascDcyBrCcP_Dp_0!=3 & \
                iCascDcyBrP_Dsp_0!=0 & iCascDcyBrCcP_Dsp_0!=0 & \
                iCascDcyBrP_Dsp_0!=1 & iCascDcyBrCcP_Dsp_0!=1"
df = pd_df_test_gg.query(cut1)
df2 = pd_df_test_gg.query(cut2)
df3 = pd_df_test_gg.query(cut3)
df_rest = pd_df_test_gg.query(remained_cut)

N_df = len(df)
N_df2 = len(df2)
N_df3 = len(df3)
N_df_rest = len(df_rest)

# Plot the stacked histograms
plt.hist([df_rest["Dp_M"], df2["Dp_M"], df3["Dp_M"], df["Dp_M"]], bins=xm, histtype='step', label=['Remained', r'$D^+_s \to \eta \pi^+$', r'$D^+_s \to \rho^+ \eta$', r'$D^+ \to \eta \pi^+$'], stacked=True)

plt.legend(loc="upper right", fontsize=12.5)
ax.set_title(r'MC15ri 1/ab ccbar')

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0], xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1] - xe[0]
plt.ylabel('Entries' + ' /' + '$(' + ' ' + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$')

plt.xlim(xrange[0], xrange[1])
plt.legend(loc="upper left")

plt.tight_layout()
plt.ylim(0,65000)

file1_name = "/media/jykim/T7/saved_plots/DRAW/etapip/MC15ri_generic/gg/topo/MC15ri_etaetapip_gg_tight_v0_looseeta_240317_treefit_BCS_Dp_M_stacked.png"
plt.savefig(file1_name)
print(N_df + N_df2 + N_df3 + N_df_rest)
# Out:
# 1340141

# %% [markdown]
# # D+ -> eta pi+, gg

# %%
file_name = '/share/storage/jykim/storage_b2/storage/reduced_ntuples/MC15ri/etapip_eteeta/MC15ri_etaetapip_tight_v3_241014/topo/resultfile/result_etapip_gg/etapip_gg/*.root'
base_filter = 'Dp_M'
tree = 'etapip_gg'
variables = ['dM_pi0_mask','dM_pi0_mask_2','iCascDcyBrP_Dp_0','iCascDcyBrCcP_Dp_0','iCascDcyBrP_Dsp_0','iCascDcyBrCcP_Dsp_0','Dp_M','Pip_charge','Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane']

# %%
pd_df_v0 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=variables)

# %%
cut = "Dp_M>0"

pd_df_test=pd_df_v0.query(cut)

# pd_df_test=pd_df_test.query("etapip_pipipi_rank==1")

pd_df_test
# Out:
#          dM_pi0_mask  dM_pi0_mask_2  iCascDcyBrP_Dp_0  iCascDcyBrCcP_Dp_0  \
# 0           0.011676       0.254296                 0                  -1
# 1           0.024938       0.114100                -1                  -1
# 2           0.190660       0.341785                -1                  -1
# 3           0.146499       0.058316                -1                   1
# 4           6.438153       1.964803                -1                  -1
# ...              ...            ...               ...                 ...
# 1262699     0.086674       0.468101                -1                  -1
# 1262700     0.054112       0.330603                -1                  -1
# 1262701     0.014997       0.019859                -1                  31
# 1262702     0.014724       0.015226                -1                  16
# 1262703     0.145709       0.229670                88                  38
#
#          iCascDcyBrP_Dsp_0  iCascDcyBrCcP_Dsp_0      Dp_M  Pip_charge  \
# 0                       -1                    0  1.964095        -1.0
# 1                        1                    2  1.700870         1.0
# 2                       -1                   -1  1.917501        -1.0
# 3                       -1                   -1  2.037930         1.0
# 4                       -1                   -1  1.723858        -1.0
# ...                    ...                  ...       ...         ...
# 1262699                 -1                    0  1.962555        -1.0
# 1262700                 -1                   -1  1.705513         1.0
# 1262701                  1                   -1  1.760718         1.0
# 1262702                125                   -1  1.602293         1.0
# 1262703                 -1                   -1  1.881549        -1.0
#
#          Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane
# 0                                                 0.001895
# 1                                                 0.028728
# 2                                                 0.067286
# 3                                                 0.070214
# 4                                                 0.015355
# ...                                                    ...
# 1262699                                           0.000861
# 1262700                                           0.009702
# 1262701                                           0.038157
# 1262702                                           0.006353
# 1262703                                           0.057250
#
# [1262704 rows x 9 columns]

# %%
pd_ccbar_others = pd_df_test.query('Pip_charge==1')
pd_ccbar_others['iCascDcyBrP_Dp_0'].value_counts().nlargest(20)
# Out:
# -1     519310
#  5      50401
#  16      5265
#  8       5168
#  20      5109
#  37      2837
#  4       2673
#  36      2124
#  39      1460
#  10      1457
#  12      1204
#  29      1142
#  17      1105
#  18       976
#  13       938
#  21       917
#  38       882
#  0        863
#  45       730
#  56       705
# Name: iCascDcyBrP_Dp_0, dtype: int64

# %%
nan_columns = pd_df_test.isnull().any()
print(nan_columns)
# Out:
# dM_pi0_mask                                                False
# dM_pi0_mask_2                                              False
# iCascDcyBrP_Dp_0                                           False
# iCascDcyBrCcP_Dp_0                                         False
# iCascDcyBrP_Dsp_0                                          False
# iCascDcyBrCcP_Dsp_0                                        False
# Dp_M                                                       False
# Pip_charge                                                 False
# Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane    False
# dtype: bool

# %%
# Assuming you have defined pd_ccbar_others DataFrame and other required variables


bkg_listing = pd_df_test['iCascDcyBrP_Dp_0'].value_counts()

plotted_indices = set()  # To store indices that have been plotted

N_total = 0
for i in range(3):  # Loop from 0 to 5
    decay_chain = bkg_listing.index[i]
    df = pd_ccbar_others[(pd_ccbar_others['iCascDcyBrP_Dp_0'] == decay_chain)]
    
    N_total += len(df)
    plt.hist(df.dM_pi0_mask, bins=np.linspace(0,5, 51), histtype='step', label=decay_chain)
    
    
    
    plotted_indices.add(decay_chain)

remaining_candidates = [decay_chain for decay_chain in bkg_listing.index if decay_chain not in plotted_indices]

if remaining_candidates:
    remaining_df = pd_ccbar_others[pd_ccbar_others['iCascDcyBrP_Dp_0'].isin(remaining_candidates)]
    
    N_total += len(remaining_df)
    plt.hist(remaining_df.dM_pi0_mask, bins=np.linspace(0,5, 51), histtype='step', label='Remaining candidates')

plt.xlim(0,5)
# plt.tight_layout()
plt.legend(loc='best')
plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
plt.tight_layout()

# plt.savefig("/media/jykim/T7/saved_plots/DRAW/CALIB/MC15ri/MC15ri_kshortg_1ab_onlyD0_topo_excpet_pi0eta.png")
plt.yscale('log')
plt.show()


print(N_total)
# Out:
# 625235

# %% [markdown]
# # D+ -> eta pi+, pipipi

# %%
# file_name = '/media/jykim/T7_2/storage/Ntuples_ghi_2/MC15ri_generic/MC15ri_etaetapip_tight_v0_looseeta_240317_treefit_BCS/topo/resultfile/result_etapip_pipipi/*.root'
# file_name = '/home/jykim/ntuple_10e5.root'
file_name = '/share/storage/jykim/storage_b2/storage/reduced_ntuples/MC15ri/etapip_eteeta/MC15ri_etaetapip_tight_v3_241014/topo/resultfile/result_etapip_pipipi/etapip_pipipi/*.root'

base_filter = 'Dp_M'

tree = 'etapip_pipipi'
variables = ["__experiment__", "__run__", "__event__",\
             'Dp_M','Dp_chiProb','Dp_isSignal','Dp_CMS_p','Dp_cosAngleBetweenMomentumAndVertexVector','Dp_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'Dp_acos_cosAngleBetweenMomentumAndVertexVector','Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane',\
             'etapip_Eta_M','etapip_Eta_isSignal','etapip_Eta_p',\
             'etapip_pi0_gamma1_p','etapip_pi0_gamma2_p','etapip_pi0_gamma1_clusterNHits','etapip_pi0_gamma2_clusterNHits',\
             'etapip_pi0_gamma1_clusterReg', 'etapip_pi0_gamma2_clusterReg',\
             'eta_Pi0_M',"eta_Pi0_daughterAngle_0_1","eta_Pi0_daughterDiffOfPhi_0_1","eta_Pi0_Easym",\
             'eta_Pip_pionID','eta_Pim_pionID',\
             'eta_Pip_pionIDNN','eta_Pim_pionIDNN','eta_Pip_mcPDG','eta_Pim_mcPDG',\
             'Pip_pionID','Pip_pionIDNN','Pip_mcPDG','Pip_dr','Pip_dz','Pip_p','Pip_pt','etapip_pipipi_rank',\
             'iProdBrP_Dsp_0','iProdBrP_Dp_0','iCascDcyBrP_Dp_0','iCascDcyBrCcP_Dp_0','iCascDcyBrP_Dsp_0','iCascDcyBrCcP_Dsp_0']
variables = ['iCascDcyBrP_Dp_0','iCascDcyBrCcP_Dp_0','iCascDcyBrP_Dsp_0','iCascDcyBrCcP_Dsp_0','Dp_M','Pip_charge','Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane']

# %%
pd_df_v0 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=variables)
# Out:
# ---------------------------------------------------------------------------
# runtime_error                             Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 pd_df_v0 = get_pd(file=file_name, tree=tree,base_filter=base_filter,variables=variables)
#
# File ~/workspace/DRAW_and_FITTING/main/data_tools/extract_ntuples.py:12, in get_pd(file, tree, base_filter, variables)
#       9 base_filter  = base_filter
#      11 ROOT_df_start = ROOT.RDataFrame(tree, f)
# ---> 12 col_dict  = ROOT_df_start.AsNumpy(variables)
#      14 if base_filter !=None:
#      15     ROOT_df_filtered  = ROOT_df_start.Filter(base_filter)
#
# File ~/anaconda3/envs/draw/lib/python3.10/site-packages/ROOT/_pythonization/_rdataframe.py:79, in RDataFrameAsNumpy(df, columns, exclude, lazy)
#      77 result_ptrs = {}
#      78 for column in columns:
# ---> 79     column_type = df.GetColumnType(column)
#      80     result_ptrs[column] = df.Take[column_type](column)
#      82 result = AsNumpyResult(result_ptrs, columns)
#
# runtime_error: string ROOT::RDF::RInterface<ROOT::Detail::RDF::RLoopManager,void>::GetColumnType(basic_string_view<char,char_traits<char> > column) =>
#     runtime_error: Column "dM_pi0_mask" is not in a dataset and is not a custom column been defined.

# %%
# cut = "etapip_pipipi_rank==1 & Dp_chiProb>0.01"
cut = "etapip_pipipi_rank==1"

cut = "Dp_M>0"

pd_df_test=pd_df_v0.query(cut)

# pd_df_test=pd_df_test.query("etapip_pipipi_rank==1")

pd_df_test
# Out:
#         iCascDcyBrP_Dp_0  iCascDcyBrCcP_Dp_0  iCascDcyBrP_Dsp_0  \
# 0                      0                   1                 -1
# 1                     -1                  -1                 -1
# 2                     -1                  -1                 -1
# 3                     -1                  -1                 -1
# 4                     -1                  -1                 -1
# ...                  ...                 ...                ...
# 496982                -1                  -1                 -1
# 496983                 5                  -1                 -1
# 496984                12                  -1                 -1
# 496985                -1                  65                  4
# 496986                -1                  -1                 -1
#
#         iCascDcyBrCcP_Dsp_0      Dp_M  Pip_charge  \
# 0                        -1  1.870283         1.0
# 1                         0  1.603145         1.0
# 2                        -1  1.721134         1.0
# 3                         1  1.644120        -1.0
# 4                        -1  1.759243         1.0
# ...                     ...       ...         ...
# 496982                    6  1.629409        -1.0
# 496983                   -1  1.906003         1.0
# 496984                   -1  1.979412        -1.0
# 496985                   -1  1.973463         1.0
# 496986                   -1  1.787513        -1.0
#
#         Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane
# 0                                                0.001414
# 1                                                0.041214
# 2                                                0.053868
# 3                                                0.069508
# 4                                                0.018736
# ...                                                   ...
# 496982                                           0.006279
# 496983                                           0.000948
# 496984                                           0.097852
# 496985                                           0.043768
# 496986                                           0.094373
#
# [496987 rows x 7 columns]

# %%
fig = plt.figure()
ax = fig.subplots()
xrange = (1.7,2.05,51)

xm = np.linspace(*xrange)

df = pd_df_test
# df2 = pd_df_test2

N_df = len(df)
# N_df2 = len(df2)

plt.hist(df["Dp_M"],bins=xm,histtype='step',label=r'$D^+ \to \eta \pi^+$ event(' + str(N_df) +')');
# plt.hist(df2["D0_M"],bins=xm,histtype='step',label=r'$D^0 \to K^- \pi^+ \gamma_F$ MC matched(' + str(N_df2) +')');

plt.legend(loc="upper right",fontsize=12.5)
ax.set_title(r'MC15ri 1/ab' )

n, xe = np.histogram(df["Dp_M"], bins=50, range=(xrange[0],xrange[1]))

plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
width = xe[1]-xe[0]
plt.ylabel('Entries'+' /' + '$(' + ' '  + "{0:.3f}".format(width).rstrip('0').rstrip('.') + '\mathrm{GeV/c^2})$');

plt.xlim(xrange[0],xrange[1])
plt.tight_layout()
# file1_name="/media/jykim/T7/saved_plots/DRAW/antiKstargamma/MC15ri_D0_M_FSR.png"
# plt.savefig(file1_name)
print(len(df))
# Out:
# 496987

# %%
pd_ccbar_others = pd_df_test.query('Pip_charge==1')
pd_ccbar_others['iCascDcyBrP_Dp_0'].value_counts().nlargest(20)
# Out:
# -1     208299
#  0      19279
#  6       4740
#  5       1702
#  17       759
#  18       639
#  10       575
#  4        568
#  64       362
#  20       349
#  7        340
#  30       328
#  57       316
#  25       316
#  23       283
#  9        267
#  8        215
#  1        212
#  38       203
#  24       201
# Name: iCascDcyBrP_Dp_0, dtype: int64

# %%
# Assuming you have defined pd_ccbar_others DataFrame and other required variables


bkg_listing = pd_df_test['iCascDcyBrP_Dp_0'].value_counts()

plotted_indices = set()  # To store indices that have been plotted

N_total = 0
for i in range(3):  # Loop from 0 to 5
    decay_chain = bkg_listing.index[i]
    df = pd_ccbar_others[(pd_ccbar_others['iCascDcyBrP_Dp_0'] == decay_chain)]
    
    N_total += len(df)
    plt.hist(df.Dp_M, bins=np.linspace(1.7, 2.05, 51), histtype='step', label=decay_chain)
    
    
    
    plotted_indices.add(decay_chain)

remaining_candidates = [decay_chain for decay_chain in bkg_listing.index if decay_chain not in plotted_indices]

if remaining_candidates:
    remaining_df = pd_ccbar_others[pd_ccbar_others['iCascDcyBrP_Dp_0'].isin(remaining_candidates)]
    
    N_total += len(remaining_df)
    plt.hist(remaining_df.Dp_M, bins=np.linspace(1.7, 2.05, 51), histtype='step', label='Remaining candidates')

plt.xlim(1.7, 2.05)
# plt.tight_layout()
plt.legend(loc='best')
plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
plt.tight_layout()

# plt.savefig("/media/jykim/T7/saved_plots/DRAW/CALIB/MC15ri/MC15ri_kshortg_1ab_onlyD0_topo_excpet_pi0eta.png")
plt.yscale('log')
plt.show()


print(N_total)
# Out:
# 248079

# %%
# Assuming you have defined pd_ccbar_others DataFrame and other required variables


bkg_listing = pd_df_test['iCascDcyBrP_Dp_0'].value_counts()

plotted_indices = set()  # To store indices that have been plotted

N_total = 0
for i in range(5):  # Loop from 0 to 5
    decay_chain = bkg_listing.index[i]
    df = pd_ccbar_others[(pd_ccbar_others['iCascDcyBrP_Dp_0'] == decay_chain)]
    
    N_total += len(df)
    plt.hist(df.Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane, bins=np.linspace(0,0.1, 51), histtype='step', label=decay_chain)
    
    
    
    plotted_indices.add(decay_chain)

remaining_candidates = [decay_chain for decay_chain in bkg_listing.index if decay_chain not in plotted_indices]

if remaining_candidates:
    remaining_df = pd_ccbar_others[pd_ccbar_others['iCascDcyBrP_Dp_0'].isin(remaining_candidates)]
    
    N_total += len(remaining_df)
    plt.hist(remaining_df.Dp_acos_cosAngleBetweenMomentumAndVertexVectorInXYPlane, bins=np.linspace(0,0.1, 51), histtype='step', label='Remaining candidates')

plt.xlim(0,0.1)
# plt.tight_layout()
plt.legend(loc='best')
plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
plt.tight_layout()

# plt.savefig("/media/jykim/T7/saved_plots/DRAW/CALIB/MC15ri/MC15ri_kshortg_1ab_onlyD0_topo_excpet_pi0eta.png")
plt.yscale('log')
plt.show()


print(N_total)
# Out:
# 248079

# %%
pd_ccbar_others = pd_df_test.query('Pip_charge==1')
pd_ccbar_others['iCascDcyBrP_Dsp_0'].value_counts().nlargest(20)
# Out:
# -1     112020
#  2      67030
#  4      45049
#  6       3299
#  15      2634
#  10      1686
#  12      1236
#  34      1037
#  17       999
#  14       963
#  0        930
#  33       917
#  8        652
#  53       647
#  25       637
#  7        354
#  31       331
#  3        308
#  75       297
#  1        269
# Name: iCascDcyBrP_Dsp_0, dtype: int64

# %%
# Assuming you have defined pd_ccbar_others DataFrame and other required variables


bkg_listing = pd_df_test['iCascDcyBrP_Dsp_0'].value_counts()

plotted_indices = set()  # To store indices that have been plotted

N_total = 0
for i in range(3):  # Loop from 0 to 5
    decay_chain = bkg_listing.index[i]
    df = pd_ccbar_others[(pd_ccbar_others['iCascDcyBrP_Dsp_0'] == decay_chain)]
    
    N_total += len(df)
    plt.hist(df.Dp_M, bins=np.linspace(1.7, 2.05, 51), histtype='step', label=decay_chain)
    
    
    
    plotted_indices.add(decay_chain)

remaining_candidates = [decay_chain for decay_chain in bkg_listing.index if decay_chain not in plotted_indices]

if remaining_candidates:
    remaining_df = pd_ccbar_others[pd_ccbar_others['iCascDcyBrP_Dsp_0'].isin(remaining_candidates)]
    
    N_total += len(remaining_df)
    plt.hist(remaining_df.Dp_M, bins=np.linspace(1.7, 2.05, 51), histtype='step', label='Remaining candidates')

plt.xlim(1.7, 2.05)
# plt.tight_layout()
plt.legend(loc='best')
plt.xlabel("$\mathrm{M(D^+)} \; [\mathrm{GeV/c^2}]$")
plt.tight_layout()

# plt.savefig("/media/jykim/T7/saved_plots/DRAW/CALIB/MC15ri/MC15ri_kshortg_1ab_onlyD0_topo_excpet_pi0eta.png")

plt.yscale('log')
plt.show()


print(N_total)
# Out:
# 248079
