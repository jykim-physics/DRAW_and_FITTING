# %% [markdown]
# # D+ -> eta pi+

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.75), marker='')
q2in= diagram.vertex(xy=(.15,.25), marker='')
v1 = diagram.vertex(xy=(.5,.75))
vmerge = diagram.vertex(xy=(.6,.5))
q1pout = diagram.vertex(xy=(.80,.75), marker='')
q2pout = diagram.vertex(xy=(.80,.25), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.35), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(q1_2out, vmerge, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(vmerge, q2_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.6, r"$W^+$", fontsize=40)

diagram.text(.12, 0.75, "c", fontsize=40)
diagram.text(.12, 0.25, r"$\mathrm{\bar{d}}$",fontsize=40)

diagram.text(0.85, 0.35, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.85, 0.25, r"$\mathrm{\bar{d}}$", fontsize=40)

diagram.text(0.85, 0.75, r"$\mathrm{d,s}$", fontsize=40)
diagram.text(0.85, 0.65, r"$\mathrm{\bar{d}}\mathrm{,\bar{s}}$",fontsize=40)

diagram.text(0.05, 0.5, r"$D^+$", fontsize=45)
diagram.text(0.94, 0.3, r"$\pi^+$" , fontsize=45)
diagram.text(0.93, 0.7, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()

diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_diagram_color_suppressed_SCS.png')

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.40), marker='')
q2in= diagram.vertex(xy=(.15,.30), marker='')
v1 = diagram.vertex(xy=(.5,.40))
vmerge = diagram.vertex(xy=(.55,.6))
q1pout = diagram.vertex(xy=(.80,.40), marker='')
q2pout = diagram.vertex(xy=(.80,.3), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.55), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(vmerge, q1_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(q2_2out, vmerge,  color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.5, r"$W^+$", fontsize=40)

diagram.text(.12, 0.4, "c", fontsize=40)
diagram.text(.12, 0.3, r"$\mathrm{\bar{d}}$",fontsize=40)

diagram.text(0.83, 0.4, r"$\mathrm{d}$", fontsize=40)
diagram.text(0.83, 0.3, r"$\mathrm{\bar{d}}$", fontsize=40)

diagram.text(0.83, 0.65, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.83, 0.55, r"$\mathrm{\bar{d}}$",fontsize=40)

diagram.text(0.05, 0.35, r"$D^+$", fontsize=45)
diagram.text(0.90, 0.6, r"$\pi^+$", fontsize=45)
diagram.text(0.90, 0.35, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()

diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_diagram_color_favored.png')

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

diagram = Diagram(ax)

# -----------------------------------
# shift to move the diagram to center
# -----------------------------------
dx = 0.025
dy = 0.0

# --------------------------------------------------
# Vertices
# --------------------------------------------------
# Incoming quarks
c_in    = diagram.vertex(xy=(0.15 + dx, 0.75 + dy), marker='')
qbar_in = diagram.vertex(xy=(0.15 + dx, 0.25 + dy), marker='')

# W-annihilation vertex and W-decay vertex
v1 = diagram.vertex(xy=(0.38 + dx, 0.50 + dy), marker='')
v2 = diagram.vertex(xy=(0.58 + dx, 0.50 + dy), marker='')

# Outgoing quarks from W+
u_out    = diagram.vertex(xy=(0.80 + dx, 0.75 + dy), marker='')
qbar_out = diagram.vertex(xy=(0.80 + dx, 0.25 + dy), marker='')

# Popped u ubar pair
vpair    = diagram.vertex(xy=(0.70 + dx, 0.50 + dy), marker='')
ubar_out = diagram.vertex(xy=(0.80 + dx, 0.5 + 0.1 * 10/11 + dy), marker='')
u2_out   = diagram.vertex(xy=(0.80 + dx, 0.5 - 0.1 * 10/11 + dy), marker='')

lw = 5
qcolor = 'black'
wcolor = 'black'

# --------------------------------------------------
# Lines
# --------------------------------------------------
diagram.line(
    c_in, v1,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    v1, qbar_in,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    v1, v2,
    style='wiggly',
    color=wcolor, lw=lw
)

diagram.line(
    v2, u_out,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    qbar_out, v2,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    ubar_out, vpair,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    vpair, u2_out,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

# --------------------------------------------------
# Text labels
# --------------------------------------------------
diagram.text(0.49 + dx, 0.58 + dy, r"$W^+$", fontsize=40)

# Left side quark labels
diagram.text(0.12 + dx, 0.75 + dy, r"$c$", fontsize=40)
diagram.text(0.10 + dx, 0.25 + dy, r"$\bar{d}$", fontsize=40)

# Right side quark labels
diagram.text(0.83 + dx, 0.75 + dy, r"$u$", fontsize=40)
diagram.text(0.83 + dx, 0.5 + 0.1 * 10/11 + dy, r"$\bar{u}$", fontsize=40)
diagram.text(0.83 + dx, 0.5 - 0.1 * 10/11 + dy, r"$u$", fontsize=40)
diagram.text(0.83 + dx, 0.25 + dy, r"$\bar{d}$", fontsize=40)

# Hadron labels
diagram.text(0.05 + dx, 0.50 + dy, r"$D^+$", fontsize=45)
diagram.text(0.89 + dx, (0.75 + 0.5 + 0.1 * 10/11)/2 + dy, r"$\eta$", fontsize=45)
diagram.text(0.90 + dx, (0.25 + 0.5 - 0.1 * 10/11)/2 + dy, r"$\pi^+$", fontsize=45)

diagram.plot()
diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_Wannihilation.png')
plt.show()

# %% [markdown]
# # D+ -> eta K+

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.40), marker='')
q2in= diagram.vertex(xy=(.15,.30), marker='')
v1 = diagram.vertex(xy=(.5,.40))
vmerge = diagram.vertex(xy=(.55,.6))
q1pout = diagram.vertex(xy=(.80,.40), marker='')
q2pout = diagram.vertex(xy=(.80,.3), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.55), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(vmerge, q1_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(q2_2out, vmerge,  color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.5, r"$W^+$", fontsize=40)

diagram.text(.12, 0.4, "c", fontsize=40)
diagram.text(.12, 0.3, r"$\mathrm{\bar{d}}$",fontsize=40)

diagram.text(0.83, 0.4, r"$\mathrm{d}$", fontsize=40)
diagram.text(0.83, 0.3, r"$\mathrm{\bar{d}}$", fontsize=40)

diagram.text(0.83, 0.65, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.83, 0.55, r"$\mathrm{\bar{s}}$",fontsize=40)

diagram.text(0.05, 0.35, r"$D^+$", fontsize=45)
diagram.text(0.90, 0.6, r"$K^+$", fontsize=45)
diagram.text(0.90, 0.35, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()

diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/DptoetaK_diagram_color_favored_DCS.png')

# %% [markdown]
# # Ds+ -> eta K+

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.75), marker='')
q2in= diagram.vertex(xy=(.15,.25), marker='')
v1 = diagram.vertex(xy=(.5,.75))
vmerge = diagram.vertex(xy=(.6,.5))
q1pout = diagram.vertex(xy=(.80,.75), marker='')
q2pout = diagram.vertex(xy=(.80,.25), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.35), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(q1_2out, vmerge, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(vmerge, q2_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.6, r"$W^+$", fontsize=40)

diagram.text(.12, 0.75, "c", fontsize=40)
diagram.text(.12, 0.25, r"$\mathrm{\bar{s}}$",fontsize=40)

diagram.text(0.85, 0.35, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.85, 0.25, r"$\mathrm{\bar{s}}$", fontsize=40)

diagram.text(0.85, 0.75, r"$\mathrm{d,s}$", fontsize=40)
diagram.text(0.85, 0.65, r"$\mathrm{\bar{d}}\mathrm{,\bar{s}}$",fontsize=40)

diagram.text(0.05, 0.5, r"$D^+_s$", fontsize=45)
diagram.text(0.94, 0.3, r"$K^+$" , fontsize=45)
diagram.text(0.93, 0.7, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()

diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/DspetaKp/DsptoetaK_diagram_color_suppressed_SCS.png')

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.40), marker='')
q2in= diagram.vertex(xy=(.15,.30), marker='')
v1 = diagram.vertex(xy=(.5,.40))
vmerge = diagram.vertex(xy=(.55,.6))
q1pout = diagram.vertex(xy=(.80,.40), marker='')
q2pout = diagram.vertex(xy=(.80,.3), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.55), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(vmerge, q1_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(q2_2out, vmerge,  color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.5, r"$W^+$", fontsize=40)

diagram.text(.12, 0.4, "c", fontsize=40)
diagram.text(.12, 0.3, r"$\mathrm{\bar{s}}$",fontsize=40)

diagram.text(0.83, 0.4, r"$\mathrm{s}$", fontsize=40)
diagram.text(0.83, 0.3, r"$\mathrm{\bar{s}}$", fontsize=40)

diagram.text(0.83, 0.65, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.83, 0.55, r"$\mathrm{\bar{s}}$",fontsize=40)

diagram.text(0.05, 0.35, r"$D^+_s$", fontsize=45)
diagram.text(0.90, 0.6, r"$K^+$", fontsize=45)
diagram.text(0.90, 0.35, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()
diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/DspetaKp/DsptoetaK_diagram_color_favored_SCS.png')

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

diagram = Diagram(ax)

# -----------------------------------
# shift to move the diagram to center
# -----------------------------------
dx = 0.025
dy = 0.0

# --------------------------------------------------
# Vertices
# --------------------------------------------------
# Incoming quarks
c_in    = diagram.vertex(xy=(0.15 + dx, 0.75 + dy), marker='')
qbar_in = diagram.vertex(xy=(0.15 + dx, 0.25 + dy), marker='')

# W-annihilation vertex and W-decay vertex
v1 = diagram.vertex(xy=(0.38 + dx, 0.50 + dy), marker='')
v2 = diagram.vertex(xy=(0.58 + dx, 0.50 + dy), marker='')

# Outgoing quarks from W+
u_out    = diagram.vertex(xy=(0.80 + dx, 0.75 + dy), marker='')
qbar_out = diagram.vertex(xy=(0.80 + dx, 0.25 + dy), marker='')

# Popped u ubar pair
vpair    = diagram.vertex(xy=(0.70 + dx, 0.50 + dy), marker='')
ubar_out = diagram.vertex(xy=(0.80 + dx, 0.5 + 0.1 * 10/11 + dy), marker='')
u2_out   = diagram.vertex(xy=(0.80 + dx, 0.5 - 0.1 * 10/11 + dy), marker='')

lw = 5
qcolor = 'black'
wcolor = 'black'

# --------------------------------------------------
# Lines
# --------------------------------------------------
diagram.line(
    c_in, v1,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    v1, qbar_in,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    v1, v2,
    style='wiggly',
    color=wcolor, lw=lw
)

diagram.line(
    v2, u_out,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    qbar_out, v2,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    ubar_out, vpair,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

diagram.line(
    vpair, u2_out,
    color=qcolor, lw=lw,
    arrow_param=dict(color=qcolor, length=0.08, width=0.02)
)

# --------------------------------------------------
# Text labels
# --------------------------------------------------
diagram.text(0.49 + dx, 0.58 + dy, r"$W^+$", fontsize=40)

# Left side quark labels
diagram.text(0.12 + dx, 0.75 + dy, r"$c$", fontsize=40)
diagram.text(0.10 + dx, 0.25 + dy, r"$\bar{s}$", fontsize=40)

# Right side quark labels
diagram.text(0.83 + dx, 0.75 + dy, r"$u$", fontsize=40)
diagram.text(0.83 + dx, 0.5 + 0.1 * 10/11 + dy, r"$\bar{u}$", fontsize=40)
diagram.text(0.83 + dx, 0.5 - 0.1 * 10/11 + dy, r"$u$", fontsize=40)
diagram.text(0.83 + dx, 0.25 + dy, r"$\bar{s}$", fontsize=40)

# Hadron labels
diagram.text(0.05 + dx, 0.50 + dy, r"$D^+_s$", fontsize=45)
diagram.text(0.89 + dx, (0.75 + 0.5 + 0.1 * 10/11)/2 + dy, r"$\eta$", fontsize=45)
diagram.text(0.90 + dx, (0.25 + 0.5 - 0.1 * 10/11)/2 + dy, r"$K^+$", fontsize=45)

diagram.plot()
diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/DspetaKp/DsptoetaK_diagram_Wannihilation.png')
plt.show()

# %% [markdown]
# # Ds+ -> eta pi+

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.40), marker='')
q2in= diagram.vertex(xy=(.15,.30), marker='')
v1 = diagram.vertex(xy=(.5,.40))
vmerge = diagram.vertex(xy=(.55,.6))
q1pout = diagram.vertex(xy=(.80,.40), marker='')
q2pout = diagram.vertex(xy=(.80,.3), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.55), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(vmerge, q1_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(q2_2out, vmerge,  color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.5, r"$W^+$", fontsize=40)

diagram.text(.12, 0.4, "c", fontsize=40)
diagram.text(.12, 0.3, r"$\mathrm{\bar{s}}$",fontsize=40)

diagram.text(0.83, 0.4, r"$\mathrm{s}$", fontsize=40)
diagram.text(0.83, 0.3, r"$\mathrm{\bar{s}}$", fontsize=40)

diagram.text(0.83, 0.65, r"$\mathrm{u}$", fontsize=40)
diagram.text(0.83, 0.55, r"$\mathrm{\bar{d}}$",fontsize=40)

diagram.text(0.05, 0.35, r"$D^+_s$", fontsize=45)
diagram.text(0.90, 0.6, r"$\pi^+$", fontsize=45)
diagram.text(0.90, 0.35, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()
# matplotlib.pyplot.tight_layout()
diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/DspetaPip/DsptoetaPi_diagram_color_favored.png')

# %% [markdown]
# # D(s)+ -> eta pi+

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

fig = matplotlib.pyplot.figure(figsize=(10.,10.))
ax = fig.add_axes([0,0,1,1], frameon=False)

diagram = Diagram(ax)
# diagram.text(.5,0.9,"Color suppressed", fontsize=40)
q1in = diagram.vertex(xy=(.15,.75), marker='')
q2in= diagram.vertex(xy=(.15,.25), marker='')
v1 = diagram.vertex(xy=(.5,.75))
vmerge = diagram.vertex(xy=(.6,.5))
q1pout = diagram.vertex(xy=(.80,.75), marker='')
q2pout = diagram.vertex(xy=(.80,.25), marker='')
q1_2out = diagram.vertex(xy=(.80,.65), marker='')
q2_2out = diagram.vertex(xy=(.80,.35), marker='')

lw = 5
# Quarks
q1 = diagram.line(q1in, v1, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2 = diagram.line(q2pout,q2in, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q1p = diagram.line(v1, q1pout, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

# Bosons
w1 = diagram.line(v1, vmerge, style='wiggly', color='black', lw=lw)

# Leptons
q1_2 = diagram.line(q1_2out, vmerge, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))
q2_2 = diagram.line(vmerge, q2_2out, color='black', lw=lw, arrow_param=dict(color='black', length=0.08, width=0.02))

diagram.text(0.45, 0.6, r"$W^+$", fontsize=40)

diagram.text(.12, 0.75, "$c$", fontsize=40)
diagram.text(.08, 0.25, r"$\bar{d}\;(\bar{s})$",fontsize=40)

diagram.text(0.85, 0.35, r"$u$", fontsize=40)
diagram.text(0.85, 0.25, r"$\bar{d}\;(\bar{s})$", fontsize=40)

diagram.text(0.85, 0.75, r"$d,s$", fontsize=40)
diagram.text(0.85, 0.65, r"$\bar{d},\bar{s}$",fontsize=40)

diagram.text(0.05, 0.5, r"$D^+_{(s)}$", fontsize=45)
diagram.text(0.98, 0.3, r"$\pi^+\,(K^+)$" , fontsize=45)
diagram.text(0.93, 0.7, r"$\eta$" , fontsize=45)


diagram.plot()
# matplotlib.pyplot.show()

diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_Dsptoetapi_diagram_color_suppressed_SCS.png')

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

from feynman import Diagram

# Wider aspect ratio for a decay diagram
fig = plt.figure(figsize=(12, 7))
ax = fig.add_axes([0, 0, 1, 1], frameon=False)

diagram = Diagram(ax)

# --------------------------------------------------
# Vertices
# --------------------------------------------------
q1in  = diagram.vertex(xy=(0.12, 0.72), marker='')
q2in  = diagram.vertex(xy=(0.12, 0.28), marker='')

v1     = diagram.vertex(xy=(0.45, 0.72))
vmerge = diagram.vertex(xy=(0.56, 0.50))

# eta
q1pout  = diagram.vertex(xy=(0.82, 0.72), marker='')
q1_2out = diagram.vertex(xy=(0.82, 0.62), marker='')

# pi+ (K+)
q2_2out = diagram.vertex(xy=(0.82, 0.38), marker='')
q2pout  = diagram.vertex(xy=(0.82, 0.28), marker='')

lw = 4

arrow = dict(color='black', length=0.07, width=0.018)

# --------------------------------------------------
# Quark lines
# --------------------------------------------------
# Initial c
diagram.line(
    q1in, v1,
    color='black', lw=lw,
    arrow_param=arrow
)

# Spectator anti-d (anti-s)
diagram.line(
    q2pout, q2in,
    color='black', lw=lw,
    arrow_param=arrow
)

# c -> d,s
diagram.line(
    v1, q1pout,
    color='black', lw=lw,
    arrow_param=arrow
)

# --------------------------------------------------
# W boson
# --------------------------------------------------
diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

# W+ -> u + anti-d / anti-s
diagram.line(
    q1_2out, vmerge,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    vmerge, q2_2out,
    color='black', lw=lw,
    arrow_param=arrow
)

# --------------------------------------------------
# Labels
# --------------------------------------------------
fs_quark = 32
fs_particle = 36

# W
diagram.text(
    0.45, 0.55,
    r"$W^+$",
    fontsize=fs_quark
)

# Initial state
diagram.text(
    0.085, 0.72,
    r"$c$",
    fontsize=fs_quark
)

diagram.text(
    0.075, 0.28,
    r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark
)

# Final-state quarks
diagram.text(
    0.86, 0.72,
    r"$d,s$",
    fontsize=fs_quark
)

diagram.text(
    0.86, 0.62,
    r"$\bar{d},\bar{s}$",
    fontsize=fs_quark
)

diagram.text(
    0.86, 0.38,
    r"$u$",
    fontsize=fs_quark
)

diagram.text(
    0.86, 0.28,
    r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark
)

# Hadron labels
diagram.text(
    0.025, 0.50,
    r"$D^+_{(s)}$",
    fontsize=fs_particle
)

diagram.text(
    0.96, 0.67,
    r"$\eta$",
    fontsize=fs_particle
)

diagram.text(
    0.99, 0.33,
    r"$\pi^+\,(K^+)$",
    fontsize=fs_particle
)

diagram.plot()
plt.savefig(
    '/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_DsptoetaK_diagram_color_suppressed_SCS.png',
    bbox_inches='tight',
    pad_inches=0.08,
    dpi=300
)
# diagram.savefig('/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_Dsptoetapi_diagram_color_suppressed_SCS.png')

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# --------------------------------------------------
# Figure / axes : same convention as your final version
# --------------------------------------------------
fig = plt.figure(figsize=(12, 7))
ax = fig.add_axes([0, 0, 1, 1], frameon=False)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

diagram = Diagram(ax)

# -----------------------------------
# shift to move the diagram to center
# -----------------------------------
dx = 0.025
dy = 0.0

# --------------------------------------------------
# Vertices
# --------------------------------------------------
# Incoming quarks
c_in    = diagram.vertex(xy=(0.15 + dx, 0.75 + dy), marker='')
qbar_in = diagram.vertex(xy=(0.15 + dx, 0.25 + dy), marker='')

# W-annihilation vertex and W-decay vertex
v1 = diagram.vertex(xy=(0.38 + dx, 0.50 + dy), marker='')
v2 = diagram.vertex(xy=(0.58 + dx, 0.50 + dy), marker='')

# Outgoing quarks from W+
u_out    = diagram.vertex(xy=(0.80 + dx, 0.75 + dy), marker='')
qbar_out = diagram.vertex(xy=(0.80 + dx, 0.25 + dy), marker='')

# Popped u ubar pair
vpair    = diagram.vertex(xy=(0.70 + dx, 0.50 + dy), marker='')
ubar_out = diagram.vertex(xy=(0.80 + dx, 0.5 + 0.1 * 10/11 + dy), marker='')
u2_out   = diagram.vertex(xy=(0.80 + dx, 0.5 - 0.1 * 10/11 + dy), marker='')

# --------------------------------------------------
# Style : same convention as your final version
# --------------------------------------------------
lw = 4
qcolor = 'black'
wcolor = 'black'
arrow = dict(color='black', length=0.07, width=0.018)

fs_quark = 32
fs_particle = 36

# --------------------------------------------------
# Lines
# --------------------------------------------------
diagram.line(
    c_in, v1,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, qbar_in,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, v2,
    style='wiggly',
    color=wcolor, lw=lw
)

diagram.line(
    v2, u_out,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

diagram.line(
    qbar_out, v2,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

diagram.line(
    ubar_out, vpair,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

diagram.line(
    vpair, u2_out,
    color=qcolor, lw=lw,
    arrow_param=arrow
)

# --------------------------------------------------
# Text labels
# --------------------------------------------------
diagram.text(0.49 + dx, 0.56 + dy, r"$W^+$", fontsize=fs_quark)

# Left side quark labels
diagram.text(0.11 + dx, 0.75 + dy, r"$c$", fontsize=fs_quark)
diagram.text(0.10 + dx, 0.25 + dy, r"$\bar{d}\;(\bar{s})$", fontsize=fs_quark)

# Right side quark labels
diagram.text(0.84 + dx, 0.75 + dy, r"$u$", fontsize=fs_quark)
diagram.text(0.84 + dx, 0.5 + 0.1 * 10/11 + dy, r"$\bar{u}$", fontsize=fs_quark)
diagram.text(0.84 + dx, 0.5 - 0.1 * 10/11 + dy, r"$u$", fontsize=fs_quark)
diagram.text(0.84 + dx, 0.25 + dy, r"$d\;(\bar{s})$", fontsize=fs_quark)

# Hadron labels
diagram.text(0.04 + dx, 0.50 + dy, r"$D^+_{(s)}$", fontsize=fs_particle)
diagram.text(0.93 + dx, (0.75 + 0.5 + 0.1 * 10/11)/2 + dy, r"$\eta$", fontsize=fs_particle)
diagram.text(0.93 + dx, (0.25 + 0.5 - 0.1 * 10/11)/2 + dy, r"$\pi^+\,(K^+)$", fontsize=fs_particle)

diagram.plot()

plt.savefig(
    '/media/jykim/T7/saved_plots/feynman_diagram/DspetaKp/Dptoetapi_DsptoetaK_diagram_Wannihilation.png',
    bbox_inches='tight',
    pad_inches=0.08,
    dpi=300
)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# --------------------------------------------------
# Figure / axes
# --------------------------------------------------
fig = plt.figure(figsize=(12, 7))
ax = fig.add_axes([0, 0, 1, 1], frameon=False)

diagram = Diagram(ax)

# --------------------------------------------------
# Vertices
# --------------------------------------------------
q1in = diagram.vertex(xy=(0.12, 0.40), marker='')
q2in = diagram.vertex(xy=(0.12, 0.28), marker='')

v1     = diagram.vertex(xy=(0.45, 0.40))
vmerge = diagram.vertex(xy=(0.56, 0.60))

# eta
q1pout = diagram.vertex(xy=(0.82, 0.40), marker='')
q2pout = diagram.vertex(xy=(0.82, 0.28), marker='')

# pi+ (K+)
q1_2out = diagram.vertex(xy=(0.82, 0.66), marker='')
q2_2out = diagram.vertex(xy=(0.82, 0.54), marker='')

# --------------------------------------------------
# Style
# --------------------------------------------------
lw = 4
arrow = dict(color='black', length=0.07, width=0.018)

fs_quark = 32
fs_particle = 36

# --------------------------------------------------
# Quark lines
# --------------------------------------------------
diagram.line(
    q1in, v1,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2pout, q2in,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, q1pout,
    color='black', lw=lw,
    arrow_param=arrow
)

# --------------------------------------------------
# W boson
# --------------------------------------------------
diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

# --------------------------------------------------
# W+ decay products
# --------------------------------------------------
diagram.line(
    vmerge, q1_2out,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2_2out, vmerge,
    color='black', lw=lw,
    arrow_param=arrow
)

# --------------------------------------------------
# Labels
# --------------------------------------------------
diagram.text(
    0.45, 0.52,
    r"$W^+$",
    fontsize=fs_quark
)

# Initial state
diagram.text(
    0.085, 0.40,
    r"$c$",
    fontsize=fs_quark
)

diagram.text(
    0.075, 0.28,
    r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark
)

# Final-state quarks: eta
diagram.text(
    0.86, 0.40,
    r"$d\;(s)$",
    fontsize=fs_quark
)

diagram.text(
    0.86, 0.28,
    r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark
)

# Final-state quarks: pi+ (K+)
diagram.text(
    0.86, 0.66,
    r"$u$",
    fontsize=fs_quark
)

diagram.text(
    0.86, 0.54,
    r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark
)

# Hadron labels
diagram.text(
    0.005, 0.34,
    r"$D^+_{(s)}$",
    fontsize=fs_particle
)

diagram.text(
    0.97, 0.60,
    r"$\pi^+\,(K^+)$",
    fontsize=fs_particle
)

diagram.text(
    0.96, 0.34,
    r"$\eta$",
    fontsize=fs_particle
)

diagram.plot()


plt.savefig(
    '/media/jykim/T7/saved_plots/feynman_diagram/Dpetapip/Dptoetapi_DspetaK_diagram_color_favored.png',
    bbox_inches='tight',
    pad_inches=0.08,
    dpi=300
)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# ============================================================
# PRD single-column size
# ============================================================
PRD_COLUMN_WIDTH = 3.375   # inch = 8.57 cm
FIG_HEIGHT = 1.55          # inch

fig, axes = plt.subplots(
    1, 3,
    figsize=(PRD_COLUMN_WIDTH, FIG_HEIGHT)
)

fig.subplots_adjust(
    left=0.005,
    right=0.995,
    bottom=0.02,
    top=0.98,
    wspace=0.015
)

# ============================================================
# Common style
# ============================================================
lw = 0.9

arrow = dict(
    color='black',
    length=0.060,
    width=0.015
)

fs_quark = 6.5
fs_particle = 7.3
fs_W = 6.5

for ax in axes:
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.axis("off")


# ============================================================
# (a) Color-suppressed
# ============================================================
ax = axes[0]
diagram = Diagram(ax)

q1in = diagram.vertex(xy=(0.13, 0.72), marker='')
q2in = diagram.vertex(xy=(0.13, 0.28), marker='')

v1 = diagram.vertex(xy=(0.42, 0.72))
vmerge = diagram.vertex(xy=(0.53, 0.50))

q1pout = diagram.vertex(xy=(0.76, 0.72), marker='')
q1_2out = diagram.vertex(xy=(0.76, 0.62), marker='')

q2_2out = diagram.vertex(xy=(0.76, 0.38), marker='')
q2pout = diagram.vertex(xy=(0.76, 0.28), marker='')

# quarks
diagram.line(
    q1in, v1,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2pout, q2in,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, q1pout,
    color='black', lw=lw,
    arrow_param=arrow
)

# W
diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

diagram.line(
    q1_2out, vmerge,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    vmerge, q2_2out,
    color='black', lw=lw,
    arrow_param=arrow
)

# labels
ax.text(
    0.41, 0.54, r"$W^+$",
    fontsize=fs_W,
    ha='center', va='center'
)

# initial quarks
ax.text(
    0.13, 0.79, r"$c$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.13, 0.21, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# final quarks
ax.text(
    0.70, 0.78, r"$d,s$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.57, r"$\bar{d},\bar{s}$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.43, r"$u$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.22, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# hadron labels
ax.text(
    0.02, 0.50, r"$D^+_{(s)}$",
    fontsize=fs_particle,
    ha='left', va='center'
)

ax.text(
    0.98, 0.67, r"$\eta$",
    fontsize=fs_particle,
    ha='right', va='center'
)

ax.text(
    0.98, 0.33, r"$\pi^+\,(K^+)$",
    fontsize=fs_particle,
    ha='right', va='center'
)

diagram.plot()


# ============================================================
# (b) W-annihilation
# ============================================================
ax = axes[1]
diagram = Diagram(ax)

c_in = diagram.vertex(xy=(0.13, 0.75), marker='')
qbar_in = diagram.vertex(xy=(0.13, 0.25), marker='')

v1 = diagram.vertex(xy=(0.34, 0.50), marker='')
v2 = diagram.vertex(xy=(0.53, 0.50), marker='')

u_out = diagram.vertex(xy=(0.76, 0.75), marker='')
qbar_out = diagram.vertex(xy=(0.76, 0.25), marker='')

vpair = diagram.vertex(xy=(0.64, 0.50), marker='')

ubar_out = diagram.vertex(xy=(0.76, 0.59), marker='')
u2_out = diagram.vertex(xy=(0.76, 0.41), marker='')

# incoming
diagram.line(
    c_in, v1,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, qbar_in,
    color='black', lw=lw,
    arrow_param=arrow
)

# W
diagram.line(
    v1, v2,
    style='wiggly',
    color='black',
    lw=lw
)

# W decay
diagram.line(
    v2, u_out,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    qbar_out, v2,
    color='black', lw=lw,
    arrow_param=arrow
)

# popped pair
diagram.line(
    ubar_out, vpair,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    vpair, u2_out,
    color='black', lw=lw,
    arrow_param=arrow
)

# labels
ax.text(
    0.44, 0.56, r"$W^+$",
    fontsize=fs_W,
    ha='center', va='center'
)

# initial
ax.text(
    0.13, 0.82, r"$c$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.13, 0.18, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# final quarks
ax.text(
    0.70, 0.81, r"$u$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.55, r"$\bar{u}$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.45, r"$u$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.19, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# hadrons
ax.text(
    0.02, 0.50, r"$D^+_{(s)}$",
    fontsize=fs_particle,
    ha='left', va='center'
)

ax.text(
    0.98, 0.67, r"$\eta$",
    fontsize=fs_particle,
    ha='right', va='center'
)

ax.text(
    0.98, 0.33, r"$\pi^+\,(K^+)$",
    fontsize=fs_particle,
    ha='right', va='center'
)

diagram.plot()


# ============================================================
# (c) Color-favored
# ============================================================
ax = axes[2]
diagram = Diagram(ax)

q1in = diagram.vertex(xy=(0.13, 0.40), marker='')
q2in = diagram.vertex(xy=(0.13, 0.28), marker='')

v1 = diagram.vertex(xy=(0.42, 0.40))
vmerge = diagram.vertex(xy=(0.53, 0.60))

# eta
q1pout = diagram.vertex(xy=(0.76, 0.40), marker='')
q2pout = diagram.vertex(xy=(0.76, 0.28), marker='')

# pi+ (K+)
q1_2out = diagram.vertex(xy=(0.76, 0.66), marker='')
q2_2out = diagram.vertex(xy=(0.76, 0.54), marker='')

# quark lines
diagram.line(
    q1in, v1,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2pout, q2in,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, q1pout,
    color='black', lw=lw,
    arrow_param=arrow
)

# W
diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

diagram.line(
    vmerge, q1_2out,
    color='black', lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2_2out, vmerge,
    color='black', lw=lw,
    arrow_param=arrow
)

# labels
ax.text(
    0.41, 0.52, r"$W^+$",
    fontsize=fs_W,
    ha='center', va='center'
)

# initial
ax.text(
    0.13, 0.47, r"$c$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.13, 0.21, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# final eta quarks
ax.text(
    0.70, 0.46, r"$d\;(s)$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.22, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# final pi/K quarks
ax.text(
    0.70, 0.72, r"$u$",
    fontsize=fs_quark,
    ha='center', va='center'
)

ax.text(
    0.70, 0.50, r"$\bar{d}\;(\bar{s})$",
    fontsize=fs_quark,
    ha='center', va='center'
)

# hadron labels
ax.text(
    0.02, 0.34, r"$D^+_{(s)}$",
    fontsize=fs_particle,
    ha='left', va='center'
)

ax.text(
    0.98, 0.60, r"$\pi^+\,(K^+)$",
    fontsize=fs_particle,
    ha='right', va='center'
)

ax.text(
    0.98, 0.34, r"$\eta$",
    fontsize=fs_particle,
    ha='right', va='center'
)

diagram.plot()


# ============================================================
# Optional panel labels
# ============================================================
axes[0].text(
    0.02, 0.96, "(a)",
    fontsize=6.5,
    ha='left', va='top'
)

axes[1].text(
    0.02, 0.96, "(b)",
    fontsize=6.5,
    ha='left', va='top'
)

axes[2].text(
    0.02, 0.96, "(c)",
    fontsize=6.5,
    ha='left', va='top'
)


# ============================================================
# Save as vector PDF
# ============================================================
output = (
    '/media/jykim/T7/saved_plots/feynman_diagram/'
    'D_to_eta_h_feynman_diagrams.pdf'
)

fig.savefig(
    output,
    format='pdf',
    # IMPORTANT:
    # do not use bbox_inches='tight' if you want the PDF page
    # itself to remain exactly 3.375 inch wide.
    bbox_inches=None,
    pad_inches=0
)
print(output)
plt.show()
# Out:
# /media/jykim/T7/saved_plots/feynman_diagram/D_to_eta_h_feynman_diagrams.pdf

# %%
import matplotlib
import matplotlib.pyplot as plt
from feynman import Diagram

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# ============================================================
# PRD two-column figure
# ============================================================
FIG_WIDTH = 7.0      # inch
FIG_HEIGHT = 2.55    # inch

fig, axes = plt.subplots(
    1, 3,
    figsize=(FIG_WIDTH, FIG_HEIGHT)
)

fig.subplots_adjust(
    left=0.015,
    right=0.985,
    bottom=0.04,
    top=0.96,
    wspace=0.10
)

# ============================================================
# Common style
# ============================================================
lw = 1.35

arrow = dict(
    color='black',
    length=0.060,
    width=0.015
)

fs_quark = 9.5
fs_particle = 11.0
fs_W = 9.5
fs_panel = 9.5

vertex_ms = 4.0


def setup_ax(ax):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.axis("off")


def dot(ax, x, y):
    ax.plot(
        x, y,
        marker='o',
        markersize=vertex_ms,
        color='black',
        markeredgewidth=0,
        clip_on=False
    )


def txt(ax, x, y, text, fs,
        ha='center', va='center'):

    ax.text(
        x, y,
        text,
        fontsize=fs,
        ha=ha,
        va=va
    )


for ax in axes:
    setup_ax(ax)


# ============================================================
# (a) Color-suppressed
# ============================================================
ax = axes[0]
diagram = Diagram(ax)

# vertices
q1in = diagram.vertex(xy=(0.13, 0.72), marker='')
q2in = diagram.vertex(xy=(0.13, 0.28), marker='')

v1 = diagram.vertex(xy=(0.42, 0.72), marker='')
vmerge = diagram.vertex(xy=(0.52, 0.50), marker='')

q1pout = diagram.vertex(xy=(0.76, 0.72), marker='')
q1_2out = diagram.vertex(xy=(0.76, 0.62), marker='')

q2_2out = diagram.vertex(xy=(0.76, 0.38), marker='')
q2pout = diagram.vertex(xy=(0.76, 0.28), marker='')

# lines
diagram.line(
    q1in, v1,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2pout, q2in,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, q1pout,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

diagram.line(
    q1_2out, vmerge,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    vmerge, q2_2out,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.plot()

# small vertices
dot(ax, 0.42, 0.72)
dot(ax, 0.52, 0.50)

# panel
txt(
    ax, 0.02, 0.96,
    "(a)",
    fs_panel,
    ha='left',
    va='top'
)

# W
txt(
    ax, 0.42, 0.55,
    r"$W^+$",
    fs_W
)

# incoming
txt(
    ax, 0.09, 0.79,
    r"$c$",
    fs_quark
)

txt(
    ax, 0.09, 0.21,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark
)

# outgoing eta quarks
txt(
    ax, 0.79, 0.77,
    r"$d,s$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.79, 0.60,
    r"$\bar{d},\bar{s}$",
    fs_quark,
    ha='left'
)

# outgoing pi/K quarks
txt(
    ax, 0.79, 0.40,
    r"$u$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.79, 0.23,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark,
    ha='left'
)

# hadrons
txt(
    ax, 0.00, 0.50,
    r"$D^+_{(s)}$",
    fs_particle,
    ha='left'
)

txt(
    ax, 0.99, 0.68,
    r"$\eta$",
    fs_particle,
    ha='right'
)

txt(
    ax, 0.99, 0.32,
    r"$\pi^+\,(K^+)$",
    fs_particle,
    ha='right'
)


# ============================================================
# (b) W-annihilation
# ============================================================
ax = axes[1]
diagram = Diagram(ax)

c_in = diagram.vertex(
    xy=(0.13, 0.76),
    marker=''
)

qbar_in = diagram.vertex(
    xy=(0.13, 0.24),
    marker=''
)

v1 = diagram.vertex(
    xy=(0.35, 0.50),
    marker=''
)

v2 = diagram.vertex(
    xy=(0.55, 0.50),
    marker=''
)

u_out = diagram.vertex(
    xy=(0.77, 0.76),
    marker=''
)

qbar_out = diagram.vertex(
    xy=(0.77, 0.24),
    marker=''
)

vpair = diagram.vertex(
    xy=(0.66, 0.50),
    marker=''
)

ubar_out = diagram.vertex(
    xy=(0.77, 0.61),
    marker=''
)

u2_out = diagram.vertex(
    xy=(0.77, 0.39),
    marker=''
)

# lines
diagram.line(
    c_in, v1,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, qbar_in,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, v2,
    style='wiggly',
    color='black',
    lw=lw
)

diagram.line(
    v2, u_out,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    qbar_out, v2,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    ubar_out, vpair,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    vpair, u2_out,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.plot()

# vertices
dot(ax, 0.35, 0.50)
dot(ax, 0.55, 0.50)
dot(ax, 0.66, 0.50)

# panel
txt(
    ax, 0.02, 0.96,
    "(b)",
    fs_panel,
    ha='left',
    va='top'
)

# W
txt(
    ax, 0.45, 0.57,
    r"$W^+$",
    fs_W
)

# incoming
txt(
    ax, 0.09, 0.82,
    r"$c$",
    fs_quark
)

txt(
    ax, 0.09, 0.18,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark
)

# outgoing
txt(
    ax, 0.79, 0.82,
    r"$u$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.72, 0.62,
    r"$\bar{u}$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.72, 0.38,
    r"$u$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.79, 0.18,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark,
    ha='left'
)

# hadrons
txt(
    ax, 0.00, 0.50,
    r"$D^+_{(s)}$",
    fs_particle,
    ha='left'
)

txt(
    ax, 0.99, 0.69,
    r"$\eta$",
    fs_particle,
    ha='right'
)

txt(
    ax, 0.99, 0.31,
    r"$\pi^+\,(K^+)$",
    fs_particle,
    ha='right'
)


# ============================================================
# (c) Color-favored
# ============================================================
ax = axes[2]
diagram = Diagram(ax)

q1in = diagram.vertex(
    xy=(0.13, 0.40),
    marker=''
)

q2in = diagram.vertex(
    xy=(0.13, 0.28),
    marker=''
)

v1 = diagram.vertex(
    xy=(0.42, 0.40),
    marker=''
)

vmerge = diagram.vertex(
    xy=(0.52, 0.60),
    marker=''
)

q1pout = diagram.vertex(
    xy=(0.76, 0.40),
    marker=''
)

q2pout = diagram.vertex(
    xy=(0.76, 0.28),
    marker=''
)

q1_2out = diagram.vertex(
    xy=(0.76, 0.66),
    marker=''
)

q2_2out = diagram.vertex(
    xy=(0.76, 0.54),
    marker=''
)

# lines
diagram.line(
    q1in, v1,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2pout, q2in,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, q1pout,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    v1, vmerge,
    style='wiggly',
    color='black',
    lw=lw
)

diagram.line(
    vmerge, q1_2out,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.line(
    q2_2out, vmerge,
    color='black',
    lw=lw,
    arrow_param=arrow
)

diagram.plot()

# vertices
dot(ax, 0.42, 0.40)
dot(ax, 0.52, 0.60)

# panel
txt(
    ax, 0.02, 0.96,
    "(c)",
    fs_panel,
    ha='left',
    va='top'
)

# W
txt(
    ax, 0.42, 0.50,
    r"$W^+$",
    fs_W
)

# incoming
txt(
    ax, 0.09, 0.46,
    r"$c$",
    fs_quark
)

txt(
    ax, 0.09, 0.21,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark
)

# eta quarks
txt(
    ax, 0.79, 0.45,
    r"$d\;(s)$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.79, 0.23,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark,
    ha='left'
)

# pi/K quarks
txt(
    ax, 0.79, 0.72,
    r"$u$",
    fs_quark,
    ha='left'
)

txt(
    ax, 0.79, 0.55,
    r"$\bar{d}\;(\bar{s})$",
    fs_quark,
    ha='left'
)

# hadrons
txt(
    ax, 0.00, 0.34,
    r"$D^+_{(s)}$",
    fs_particle,
    ha='left'
)

txt(
    ax, 0.99, 0.61,
    r"$\pi^+\,(K^+)$",
    fs_particle,
    ha='right'
)

txt(
    ax, 0.99, 0.34,
    r"$\eta$",
    fs_particle,
    ha='right'
)


# ============================================================
# Save vector PDF
# ============================================================
output = (
    '/media/jykim/T7/saved_plots/feynman_diagram/'
    'D_to_eta_h_feynman_diagrams_twocolumn.pdf'
)

fig.savefig(
    output,
    format='pdf',
    bbox_inches=None,
    pad_inches=0
)
print(output)
plt.show()
# Out:
# /media/jykim/T7/saved_plots/feynman_diagram/D_to_eta_h_feynman_diagrams_twocolumn.pdf
