# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
try:
#     plt.style.use('belle2')
\
    plt.style.use('belle2_serif')
#     plt.style.use('belle2_modern')
except OSError:
    print("Please install belle2 matplotlib style")   
px = 1/plt.rcParams['figure.dpi']

from main.data_tools.extract_ntuples import get_pd, get_np
from main.draw_tools.decorations import b2helix, watermark
from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.cm as cm
import matplotlib.ticker as ticker
# Out:
# Welcome to JupyROOT 6.26/04

# %% [markdown]
# # signal decays

# %%
file = '/media/jykim/T7/storage/01_recon/phi/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_phi.root'
tree = 'phi'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/phi/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_phi.root'
tree = 'phi'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \phi \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \phi \gamma$(veto)",density=True)

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = '/media/jykim/T7/storage/01_recon/rho/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_rho.root'
tree = 'rho'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.75 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/rho/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_rho.root'
tree = 'rho'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.75 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)`

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \rho^0 \gamma$(veto)",density=True)

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = '/media/jykim/T7/storage/01_recon/antiKstar/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_antiKstar.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/antiKstar/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_antiKstar.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$(veto)",density=True)

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = '/media/jykim/T7/storage/01_recon/omega/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_omega.root'
tree = 'omega'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.8 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/omega/D0_v16_half1M_1_pre_sigMC_signalMC_recon_mdst_omega.root'
tree = 'omega'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.8 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \omega \gamma$(veto)",density=True)

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)
ax = plt.gca()
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %% [markdown]
# # calibration decays

# %%
file = '/media/jykim/T7/storage/01_recon/D2antiKstarpi0/v16_signal_extraction_signalMC_recon_mdst.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/D2antiKstarpi0/v16_signal_extraction_signalMC_recon_mdst.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$")
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$(veto)")

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))

plt.xlim(xrange)
ax = plt.gca()
ax.set_title(r'Sample:$D^0 \to\bar{K}^{*0} \pi^0$ signalMC' )
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()

# %%
file = '/media/jykim/T7/storage/01_recon/D2antiKstarpi0/v16_signal_extraction_signalMC_recon_mdst.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)

file = '/media/jykim/T7/storage/01_recon/D2antiKstarpi0/v16_signal_extraction_signalMC_recon_mdst.root'
tree = 'antiKstar'
base_filter = 'Pis_charge==1 && D0_M>1.67 && D0_M<2.06 && abs(Dstarp_Q-0.00593)<0.0006 && Dstarp_CMS_p>2.45 && Pi0_Prob<0.9 '
variables = ['gamma_p','gamma_cosTheta','gamma_genMotherPDG','D0_M','Pi0_Prob']
pd_phig_veto_sigMC = get_pd(file=file, tree=tree,base_filter=base_filter,variables=variables)


h1=pd_phig_sigMC['D0_M']
h2=pd_phig_veto_sigMC['D0_M']

xrange=(1.67,2.06)
xbins = np.linspace(*xrange,51)

plt.hist(h1, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$",density=True)
plt.hist(h2, bins=xbins, histtype='step',label=r"$D^0 \rightarrow \bar{K}^{*0} \gamma$(veto)",density=True)

px = 1/plt.rcParams['figure.dpi']
# plt.figure(figsize=(576*px, 396*px))
# watermark(t="",logo="Normalized")
plt.xlim(xrange)
ax = plt.gca()
ax.set_title(r'Sample:$D^0 \to\bar{K}^{*0} \pi^0$ signalMC' )
xlabel = r"$M(D^0) \; [\mathrm{GeV/c^2}]$"
ax.set_xlabel(xlabel)
plt.legend()

plt.show()
